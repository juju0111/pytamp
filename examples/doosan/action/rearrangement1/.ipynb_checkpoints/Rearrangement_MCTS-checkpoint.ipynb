# %%
import numpy as np
import argparse
import os, time


from pykin.utils import plot_utils as p_utils


from pytamp.benchmark import Rearrange1
from pytamp.benchmark.rearrange1 import make_scene
from pytamp.search.mcts_for_rearragement import MCTS_rearrangement

def get_parser():
    parser = argparse.ArgumentParser(description="Test Rearragement 1.")
    parser.add_argument("--budgets", metavar="T", type=int, default=100, help="Horizon")
    parser.add_argument("--max_depth", metavar="H", type=int, default=10, help="Max depth")
#     parser.add_argument("--seed", metavar="i", type=int, default=7, help="A random seed")
    parser.add_argument("--seed", metavar="i", type=int, default=144, help="A random seed")
    parser.add_argument(
        "--algo",
        metavar="alg",
        type=str,
        default="bai_perturb",
        choices=["bai_perturb", "bai_ucb", "uct", "random", "greedy"],
        help="Choose one (bai_perturb, bai_ucb, uct)",
    )
    parser.add_argument(
        "--debug_mode", default=False, type=lambda x: (str(x).lower() == "true"), help="Debug mode"
    )
#     parser.add_argument("--box_number", metavar="N", type=int, default=6, help="Box Number(6 or less)")
    try:
        args = parser.parse_args() #call from command line
    except:
        args = parser.parse_args(args=[]) #call from notebook
    return args 

args = get_parser() 

debug_mode = args.debug_mode
budgets = args.budgets
max_depth = args.max_depth
algo = args.algo
seed = args.seed
np.random.seed(seed)

object_names, init_scene, goal_scene = make_scene()
rearrangement1 = Rearrange1('doosan', object_names, init_scene, goal_scene, is_pyplot=False)

final_level_1_values = []
final_level_2_values = []
final_optimal_nodes = []
final_pnp_all_joint_paths = []
final_pick_all_objects = []
final_place_all_object_poses = []

# final_optimal_trees = []
c_list = 10 ** np.linspace(-2, 2.0, 10)
# Out:
# usage: ipykernel_launcher.py [-h] [--budgets T] [--max_depth H] [--seed i]
#                              [--algo alg] [--debug_mode DEBUG_MODE]
# ipykernel_launcher.py: error: unrecognized arguments: -f /home/juju/.local/share/jupyter/runtime/kernel-5428bd61-8f24-40f8-9628-4a168e05e430.json
# *********************** Logical States ***********************
# OrderedDict([('ben_cube0',
#               {'on': Object(name=table, pos=[ 0.9   -0.6    0.043])}),
#              ('can0',
#               {'on': Object(name=table, pos=[ 0.9   -0.6    0.043])}),
#              ('can1',
#               {'on': Object(name=table, pos=[ 0.9   -0.6    0.043])}),
#              ('milk0',
#               {'on': Object(name=table, pos=[ 0.9   -0.6    0.043])}),
#              ('cereal0',
#               {'on': Object(name=table, pos=[ 0.9   -0.6    0.043])}),
#              ('table',
#               {'static': True,
#                'support': [Object(name=ben_cube0, pos=[0.30355822 0.00852862 0.84779998]),
#                            Object(name=can0, pos=[0.39698326 0.00357495 0.83501831]),
#                            Object(name=can1, pos=[0.76977701 0.03858527 0.83512874]),
#                            Object(name=milk0, pos=[ 0.48530145 -0.34550815  0.83236691]),
#                            Object(name=cereal0, pos=[0.43695543 0.12948806 0.88526188])]}),
#              ('robotiq140_gripper', {'holding': None})])
# ***************************************************************
#
# *********************** Logical States ***********************
# OrderedDict([('ben_cube0',
#               {'on': Object(name=table, pos=[ 0.9   -0.6    0.043])}),
#              ('can0',
#               {'on': Object(name=table, pos=[ 0.9   -0.6    0.043])}),
#              ('can1',
#               {'on': Object(name=table, pos=[ 0.9   -0.6    0.043])}),
#              ('milk0',
#               {'on': Object(name=table, pos=[ 0.9   -0.6    0.043])}),
#              ('cereal0',
#               {'on': Object(name=table, pos=[ 0.9   -0.6    0.043])}),
#              ('table',
#               {'static': True,
#                'support': [Object(name=ben_cube0, pos=[0.5356105  0.17191691 0.84779998]),
#                            Object(name=can0, pos=[0.29896213 0.01771398 0.85059666]),
#                            Object(name=can1, pos=[ 0.4043516  -0.157966    0.85059666]),
#                            Object(name=milk0, pos=[ 0.44086927 -0.03354331  0.87809554]),
#                            Object(name=cereal0, pos=[ 0.42959145 -0.33381047  0.88526188])]}),
#              ('robotiq140_gripper', {'holding': None})])
# ***************************************************************

# %% [markdown]
# # Start Scene
#
# ![image-2.png](attachment:image-2.png)

# %%
#######################
fig, ax = p_utils.init_3d_figure(name="Rearrangement 1")
# init_scene
rearrangement1.scene_mngr.render_scene(ax)
rearrangement1.render_axis(rearrangement1.scene_mngr)
# rearrangement1.render_axis_2(rearrangement1.scene_mngr)
rearrangement1.scene_mngr.show()
# Out:
# {'table': Object(name=table, pos=[ 0.9   -0.6    0.043]), 'ben_cube0': Object(name=ben_cube0, pos=[0.30355822 0.00852862 0.84779998]), 'can0': Object(name=can0, pos=[0.39698326 0.00357495 0.83501831]), 'can1': Object(name=can1, pos=[0.76977701 0.03858527 0.83512874]), 'milk0': Object(name=milk0, pos=[ 0.48530145 -0.34550815  0.83236691]), 'cereal0': Object(name=cereal0, pos=[0.43695543 0.12948806 0.88526188])}

# %% [markdown]
# # Goal Scene
#
# ![image-2.png](attachment:image-2.png)

# %%
# goal_scene
rearrangement1.goal_scene_mngr.render_scene(ax)
rearrangement1.render_axis(rearrangement1.goal_scene_mngr)
rearrangement1.goal_scene_mngr.show()
# Out:
# {'table': Object(name=table, pos=[ 0.9   -0.6    0.043]), 'ben_cube0': Object(name=ben_cube0, pos=[0.5356105  0.17191691 0.84779998]), 'can0': Object(name=can0, pos=[0.29896213 0.01771398 0.85059666]), 'can1': Object(name=can1, pos=[ 0.4043516  -0.157966    0.85059666]), 'milk0': Object(name=milk0, pos=[ 0.44086927 -0.03354331  0.87809554]), 'cereal0': Object(name=cereal0, pos=[ 0.42959145 -0.33381047  0.88526188])}

# %%
c = 2.5
idx = 0
mcts = MCTS_rearrangement(
        scene_mngr=rearrangement1.scene_mngr,
        init_scene=rearrangement1.init_scene,
        sampling_method=args.algo,
        budgets=args.budgets,
        max_depth=args.max_depth,
        c=c,
        debug_mode=args.debug_mode,
    )
mcts.only_optimize_1 = False

# %%
start_time = time.time()
for i in range(budgets):
    print(
        f"\n[{idx+1}/{len(c_list)}] Benchmark: {rearrangement1.scene_mngr.scene.bench_num}, Algo: {algo}, C: {c}, Seed: {seed}"
    )
    mcts.do_planning_rearrange(i)

    print("########### Running time : ", time.time()- start_time, "##############")
    final_level_1_values.append(mcts.values_for_level_1)
# Out:
# [1/10] Benchmark: 0, Algo: bai_perturb, C: 2.5, Seed: 144
# =========== Search iteration : 1 ===========
# [Action] Rearr ben_cube0
# Good Action
# [Reward] S(0) -> A(2) -> S'(9) Reward : 10.0
# [Action] Rearr can0
# placed another place not goal
# [Reward] S(9) -> A(10) -> S'(17) Reward : -1
# [Action] Rearr ben_cube0
# Bad Action
# [Reward] S(17) -> A(18) -> S'(24) Reward : -6.667
# [Action] Rearr can1
# Good Action
# [Reward] S(24) -> A(28) -> S'(32) Reward : 4.0
# [Action] Rearr ben_cube0
# placed another place not goal
# [Reward] S(32) -> A(33) -> S'(40) Reward : -1
# [Action] Rearr milk0
# placed another place not goal
# [Reward] S(40) -> A(44) -> S'(47) Reward : -1
# [Action] Rearr ben_cube0
# placed another place not goal
# [Reward] S(47) -> A(48) -> S'(55) Reward : -1
# [Action] Rearr milk0
# placed another place not goal
# [Reward] S(55) -> A(59) -> S'(63) Reward : -1
# [Action] Rearr can0
# placed another place not goal
# [Reward] S(63) -> A(66) -> S'(70) Reward : -1
# [Action] Rearr can1
# Bad Action
# [Reward] S(70) -> A(73) -> S'(78) Reward : -2.0
# Exceeded the maximum depth!!
# ########### Running time :  2.0451438426971436 ##############
#
# [1/10] Benchmark: 0, Algo: bai_perturb, C: 2.5, Seed: 144
# =========== Search iteration : 2 ===========
# [Action] Rearr ben_cube0
# placed another place not goal
# [Reward] S(0) -> A(1) -> S'(79) Reward : -1
# [Action] Rearr milk0
# placed another place not goal
# [Reward] S(79) -> A(84) -> S'(87) Reward : -1
# [Action] Rearr can0
# Good Action
# [Reward] S(87) -> A(91) -> S'(95) Reward : 5.0
# [Action] Rearr milk0
# Good Action
# [Reward] S(95) -> A(101) -> S'(103) Reward : 4.0
# [Action] Rearr can1
# placed another place not goal
# [Reward] S(103) -> A(107) -> S'(111) Reward : -1
# [Action] Rearr cereal0
# placed another place not goal
# [Reward] S(111) -> A(116) -> S'(118) Reward : -1
# [Action] Rearr ben_cube0
# Good Action
# [Reward] S(118) -> A(120) -> S'(125) Reward : 2.5
# [Action] Rearr can1
# placed another place not goal
# [Reward] S(125) -> A(126) -> S'(131) Reward : -1
# [Action] Rearr cereal0
# placed another place not goal
# [Reward] S(131) -> A(135) -> S'(137) Reward : -1
# [Action] Rearr ben_cube0
# Bad Action
# [Reward] S(137) -> A(138) -> S'(142) Reward : -2.0
# Exceeded the maximum depth!!
# ########### Running time :  3.9143664836883545 ##############
#
# [1/10] Benchmark: 0, Algo: bai_perturb, C: 2.5, Seed: 144
# =========== Search iteration : 3 ===========
# [Action] Rearr can0
# placed another place not goal
# [Reward] S(0) -> A(3) -> S'(143) Reward : -1
# [Action] Rearr milk0
# placed another place not goal
# [Reward] S(143) -> A(148) -> S'(151) Reward : -1
# [Action] Rearr can0
# placed another place not goal
# [Reward] S(151) -> A(154) -> S'(159) Reward : -1
# [Action] Rearr can1
# placed another place not goal
# [Reward] S(159) -> A(162) -> S'(167) Reward : -1
# [Action] Rearr cereal0
# placed another place not goal
# [Reward] S(167) -> A(173) -> S'(175) Reward : -1
# [Action] Rearr milk0
# Good Action
# [Reward] S(175) -> A(181) -> S'(182) Reward : 2.857
# [Action] Rearr can1
# placed another place not goal
# [Reward] S(182) -> A(185) -> S'(189) Reward : -1
# [Action] Rearr milk0
# Bad Action
# [Reward] S(189) -> A(192) -> S'(195) Reward : -2.5
# [Action] Rearr cereal0
# Good Action
# [Reward] S(195) -> A(201) -> S'(202) Reward : 2.0
# [Action] Rearr milk0
# placed another place not goal
# [Reward] S(202) -> A(208) -> S'(210) Reward : -1
# Exceeded the maximum depth!!
# ########### Running time :  5.6949708461761475 ##############
#
# [1/10] Benchmark: 0, Algo: bai_perturb, C: 2.5, Seed: 144
# =========== Search iteration : 4 ===========
# [Action] Rearr can1
# placed another place not goal
# [Reward] S(0) -> A(4) -> S'(211) Reward : -1
# [Action] Rearr cereal0
# placed another place not goal
# [Reward] S(211) -> A(217) -> S'(218) Reward : -1
# [Action] Rearr ben_cube0
# placed another place not goal
# [Reward] S(218) -> A(219) -> S'(226) Reward : -1
# [Action] Rearr milk0
# placed another place not goal
# [Reward] S(226) -> A(231) -> S'(234) Reward : -1
# [Action] Rearr ben_cube0
# placed another place not goal
# [Reward] S(234) -> A(235) -> S'(243) Reward : -1
# [Action] Rearr can1
# placed another place not goal
# [Reward] S(243) -> A(246) -> S'(252) Reward : -1
# [Action] Rearr ben_cube0
# placed another place not goal
# [Reward] S(252) -> A(253) -> S'(261) Reward : -1
# [Action] Rearr can0
# Good Action
# [Reward] S(261) -> A(263) -> S'(270) Reward : 2.222
# [Action] Rearr cereal0
# Good Action
# [Reward] S(270) -> A(278) -> S'(279) Reward : 2.0
# [Action] Rearr ben_cube0
# Good Action
# [Reward] S(279) -> A(281) -> S'(287) Reward : 1.818
# Exceeded the maximum depth!!
# ########### Running time :  7.541599273681641 ##############
#
# [1/10] Benchmark: 0, Algo: bai_perturb, C: 2.5, Seed: 144
# =========== Search iteration : 5 ===========
# [Action] Rearr can1
# Good Action
# [Reward] S(0) -> A(5) -> S'(288) Reward : 10.0
# [Action] Rearr milk0
# placed another place not goal
# [Reward] S(288) -> A(292) -> S'(295) Reward : -1
# [Action] Rearr can0
# placed another place not goal
# [Reward] S(295) -> A(298) -> S'(302) Reward : -1
# [Action] Rearr milk0
# placed another place not goal
# [Reward] S(302) -> A(306) -> S'(310) Reward : -1
# [Action] Rearr ben_cube0
# placed another place not goal
# [Reward] S(310) -> A(311) -> S'(317) Reward : -1
# [Action] Rearr milk0
# Good Action
# [Reward] S(317) -> A(321) -> S'(324) Reward : 2.857
# [Action] Rearr ben_cube0
# placed another place not goal
# [Reward] S(324) -> A(325) -> S'(332) Reward : -1
# [Action] Rearr can1
# Bad Action
# [Reward] S(332) -> A(335) -> S'(339) Reward : -2.5
# [Action] Rearr can0
# Good Action
# [Reward] S(339) -> A(343) -> S'(347) Reward : 2.0
# [Action] Rearr can1
# Good Action
# [Reward] S(347) -> A(351) -> S'(355) Reward : 1.818
# Exceeded the maximum depth!!
# ########### Running time :  9.359267950057983 ##############
#
# [1/10] Benchmark: 0, Algo: bai_perturb, C: 2.5, Seed: 144
# =========== Search iteration : 6 ===========
# [Action] Rearr milk0
# placed another place not goal
# [Reward] S(0) -> A(6) -> S'(356) Reward : -1
# [Action] Rearr cereal0
# placed another place not goal
# [Reward] S(356) -> A(362) -> S'(364) Reward : -1
# [Action] Rearr ben_cube0
# Good Action
# [Reward] S(364) -> A(366) -> S'(372) Reward : 5.0
# [Action] Rearr can1
# placed another place not goal
# [Reward] S(372) -> A(375) -> S'(381) Reward : -1
# [Action] Rearr cereal0
# Good Action
# [Reward] S(381) -> A(388) -> S'(389) Reward : 3.333
# [Action] Rearr milk0
# Good Action
# [Reward] S(389) -> A(396) -> S'(397) Reward : 2.857
# [Action] Rearr ben_cube0
# Bad Action
# [Reward] S(397) -> A(398) -> S'(404) Reward : -2.857
# [Action] Rearr milk0
# Bad Action
# [Reward] S(404) -> A(409) -> S'(411) Reward : -2.5
# [Action] Rearr ben_cube0
# placed another place not goal
# [Reward] S(411) -> A(412) -> S'(418) Reward : -1
# [Action] Rearr can0
# Good Action
# [Reward] S(418) -> A(420) -> S'(426) Reward : 1.818
# Exceeded the maximum depth!!
# ########### Running time :  11.178245782852173 ##############
#
# [1/10] Benchmark: 0, Algo: bai_perturb, C: 2.5, Seed: 144
# =========== Search iteration :
Reward : -1
# [Action] Rearr ben_cube0
# Good Action
# [Reward] S(2363) -> A(2364) -> S'(2368) Reward : 2.0
# [Action] Rearr can0
# Bad Action
# [Reward] S(2368) -> A(2369) -> S'(2375) Reward : -2.0
# Exceeded the maximum depth!!
# ########### Running time :  64.64924669265747 ##############
#
# [1/10] Benchmark: 0, Algo: bai_perturb, C: 2.5, Seed: 144
# =========== Search iteration : 40 ===========
# [Action] Rearr can1
# placed another place not goal
# [Reward] S(0) -> A(4) -> S'(211) Reward : -1
# [Action] Rearr ben_cube0
# Good Action
# [Reward] S(211) -> A(213) -> S'(979) Reward : 6.667
# [Action] Rearr can0
# placed another place not goal
# [Reward] S(979) -> A(980) -> S'(2376) Reward : -1
# [Action] Rearr milk0
# Good Action
# [Reward] S(2376) -> A(2381) -> S'(2383) Reward : 4.0
# [Action] Rearr cereal0
# Good Action
# [Reward] S(2383) -> A(2390) -> S'(2391) Reward : 3.333
# [Action] Rearr ben_cube0
# Bad Action
# [Reward] S(2391) -> A(2392) -> S'(2398) Reward : -3.333
# [Action] Rearr can0
# placed another place not goal
# [Reward] S(2398) -> A(2399) -> S'(2405) Reward : -1
# [Action] Rearr can1
# Good Action
# [Reward] S(2405) -> A(2409) -> S'(2412) Reward : 2.222
# [Action] Rearr ben_cube0
# Good Action
# [Reward] S(2412) -> A(2414) -> S'(2419) Reward : 2.0
# [Action] Rearr can0
# Good Action
# [Reward] S(2419) -> A(2421) -> S'(2425) Reward : 1.818
# ##########['milk0', 'cereal0', 'can1', 'ben_cube0', 'can0']#############
# Success!!!!!
# Terminal State! Reward is 5
# ########### Running time :  65.98812961578369 ##############
#
# [1/10] Benchmark: 0, Algo: bai_perturb, C: 2.5, Seed: 144
# =========== Search iteration : 41 ===========
# [Action] Rearr can1
# placed another place not goal
# [Reward] S(0) -> A(4) -> S'(211) Reward : -1
# [Action] Rearr ben_cube0
# Good Action
# [Reward] S(211) -> A(213) -> S'(979) Reward : 6.667
# [Action] Rearr can0
# Good Action
# [Reward] S(979) -> A(981) -> S'(2426) Reward : 5.0
# [Action] Rearr can1
# placed another place not goal
# [Reward] S(2426) -> A(2428) -> S'(2433) Reward : -1
# [Action] Rearr milk0
# placed another place not goal
# [Reward] S(2433) -> A(2436) -> S'(2439) Reward : -1
# [Action] Rearr ben_cube0
# Bad Action
# [Reward] S(2439) -> A(2440) -> S'(2446) Reward : -3.333
# [Action] Rearr milk0
# Good Action
# [Reward] S(2446) -> A(2451) -> S'(2454) Reward : 2.5
# [Action] Rearr ben_cube0
# placed another place not goal
# [Reward] S(2454) -> A(2455) -> S'(2461) Reward : -1
# [Action] Rearr can1
# Good Action
# [Reward] S(2461) -> A(2464) -> S'(2468) Reward : 2.0
# [Action] Rearr ben_cube0
# Good Action
# [Reward] S(2468) -> A(2470) -> S'(2474) Reward : 1.818
# Exceeded the maximum depth!!
# ########### Running time :  67.306471824646 ##############
#
# [1/10] Benchmark: 0, Algo: bai_perturb, C: 2.5, Seed: 144
# =========== Search iteration : 42 ===========
# [Action] Rearr ben_cube0
# placed another place not goal
# [Reward] S(0) -> A(1) -> S'(79) Reward : -1
# [Action] Rearr cereal0
# placed another place not goal
# [Reward] S(79) -> A(86) -> S'(2315) Reward : -1
# [Action] Rearr ben_cube0
# placed another place not goal
# [Reward] S(2315) -> A(2316) -> S'(2475) Reward : -1
# [Action] Rearr can1
# placed another place not goal
# [Reward] S(2475) -> A(2478) -> S'(2483) Reward : -1
# [Action] Rearr cereal0
# placed another place not goal
# [Reward] S(2483) -> A(2490) -> S'(2491) Reward : -1
# [Action] Rearr can1
# placed another place not goal
# [Reward] S(2491) -> A(2496) -> S'(2500) Reward : -1
# [Action] Rearr can0
# Good Action
# [Reward] S(2500) -> A(2504) -> S'(2508) Reward : 2.5
# [Action] Rearr ben_cube0
# Good Action
# [Reward] S(2508) -> A(2510) -> S'(2516) Reward : 2.222
# [Action] Rearr can0
# Bad Action
# [Reward] S(2516) -> A(2517) -> S'(2522) Reward : -2.222
# [Action] Rearr milk0
# Good Action
# [Reward] S(2522) -> A(2527) -> S'(2529) Reward : 1.818
# Exceeded the maximum depth!!
# ########### Running time :  68.6032030582428 ##############
#
# [1/10] Benchmark: 0, Algo: bai_perturb, C: 2.5, Seed: 144
# =========== Search iteration : 43 ===========
# [Action] Rearr can1
# placed another place not goal
# [Reward] S(0) -> A(4) -> S'(211) Reward : -1
# [Action] Rearr ben_cube0
# ...
# ########### Running time :  129.44469928741455 ##############
#
# [1/10] Benchmark: 0, Algo: bai_perturb, C: 2.5, Seed: 144
# =========== Search iteration : 86 ===========
# [Action] Rearr can1
# Good Action
# [Reward] S(0) -> A(5) -> S'(288) Reward : 10.0
# [Action] Rearr milk0
# Good Action
# [Reward] S(288) -> A(293) -> S'(2642) Reward : 6.667
# [Action] Rearr cereal0
# Good Action
# [Reward] S(2642) -> A(2648) -> S'(4761) Reward : 5.0
# [Action] Rearr ben_cube0
# Good Action
# [Reward] S(4761) -> A(4763) -> S'(4767) Reward : 4.0
# [Action] Rearr can0
# placed another place not goal
# [Reward] S(4767) -> A(4768) -> S'(4773) Reward : -1
# [Action] Rearr ben_cube0
# Bad Action
# [Reward] S(4773) -> A(4774) -> S'(4778) Reward : -3.333
# [Action] Rearr cereal0
# Bad Action
# [Reward] S(4778) -> A(4783) -> S'(4784) Reward : -2.857
# [Action] Rearr ben_cube0
# Good Action
# [Reward] S(4784) -> A(4786) -> S'(4791) Reward : 2.222
# [Action] Rearr can0
# placed another place not goal
# [Reward] S(4791) -> A(4792) -> S'(4798) Reward : -1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 6
#       2 for i in range(budgets):
#       3     print(
#       4         f"\n[{idx+1}/{len(c_list)}] Benchmark: {rearrangement1.scene_mngr.scene.bench_num}, Algo: {algo}, C: {c}, Seed: {seed}"
#       5     )
# ----> 6     mcts.do_planning_rearrange(i)
#       8     print("########### Running time : ", time.time()- start_time, "##############")
#       9     final_level_1_values.append(mcts.values_for_level_1)
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/pytamp/search/mcts_for_rearragement.py:191, in MCTS_rearrangement.do_planning_rearrange(self, iter)
#     188     self.visualize_tree("Next Logical Node", self.tree)
#     189 self.success_level_1_leaf_node = None
# --> 191 self._level_wise_1_optimize_rearr(state_node=0, depth=0)
#     192 max_level_1_value = self.get_max_value_level_1()
#     193 self.values_for_level_1.append(max_level_1_value)
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/pytamp/search/mcts_for_rearragement.py:342, in MCTS_rearrangement._level_wise_1_optimize_rearr(self, state_node, depth)
#     337     if self.scene_mngr.scene.bench_num >= 3:
#     338         discount_value = -0.5
#     339     value = (
#     340         reward
#     341         + discount_value
# --> 342         + self.gamma * self._level_wise_1_optimize_rearr(next_state_node, depth + 1)
#     343     )
#     345 self._update_value(cur_state_node, value)
#     346 # print(f"{sc.MAGENTA}[Backpropagation]{sc.ENDC} Cur state Node : {cur_state_node}, Value : {np.round(value,3)}")
#     347 # if self.debug_mode:
#     348 #     self.visualize_tree("Backpropagation", self.tree)
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/pytamp/search/mcts_for_rearragement.py:342, in MCTS_rearrangement._level_wise_1_optimize_rearr(self, state_node, depth)
#     337     if self.scene_mngr.scene.bench_num >= 3:
#     338         discount_value = -0.5
#     339     value = (
#     340         reward
#     341         + discount_value
# --> 342         + self.gamma * self._level_wise_1_optimize_rearr(next_state_node, depth + 1)
#     343     )
#     345 self._update_value(cur_state_node, value)
#     346 # print(f"{sc.MAGENTA}[Backpropagation]{sc.ENDC} Cur state Node : {cur_state_node}, Value : {np.round(value,3)}")
#     347 # if self.debug_mode:
#     348 #     self.visualize_tree("Backpropagation", self.tree)
#
#     [... skipping similar frames: MCTS_rearrangement._level_wise_1_optimize_rearr at line 342 (6 times)]
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/pytamp/search/mcts_for_rearragement.py:342, in MCTS_rearrangement._level_wise_1_optimize_rearr(self, state_node, depth)
#     337     if self.scene_mngr.scene.bench_num >= 3:
#     338         discount_value = -0.5
#     339     value = (
#     340         reward
#     341         + discount_value
# --> 342         + self.gamma * self._level_wise_1_optimize_rearr(next_state_node, depth + 1)
#     343     )
#     345 self._update_value(cur_state_node, value)
#     346 # print(f"{sc.MAGENTA}[Backpropagation]{sc.ENDC} Cur state Node : {cur_state_node}, Value : {np.round(value,3)}")
#     347 # if self.debug_mode:
#     348 #     self.visualize_tree("Backpropagation", self.tree)
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/pytamp/search/mcts_for_rearragement.py:274, in MCTS_rearrangement._level_wise_1_optimize_rearr(self, state_node, depth)
#     270     return 0
#     272 # ? Select Logical Action
#     273 # *======================================================================================================================== #
# --> 274 cur_logical_action_node = self._select_logical_action_node_rearr(
#     275     cur_state_node, cur_state, depth, self._sampling_method
#     276 )
#     277 cur_logical_action = None
#     279 # #! [DEBUG]
#     280 # if self.debug_mode:
#     281 #     self.visualize_tree("Next Logical Node", self.tree)
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/pytamp/search/mcts_for_rearragement.py:380, in MCTS_rearrangement._select_logical_action_node_rearr(self, cur_state_node, cur_state, depth, exploration_method)
#     377 visit = self.tree.nodes[cur_state_node][NodeData.VISIT]
#     378 if visit == 0:
#     379     # print(f"Current state node {cur_state_node} is a leaf node, So expand")
# --> 380     self._expand_action_node_rearr(cur_state_node, cur_state, depth)
#     381 expanded_children = [child for child in self.tree.neighbors(cur_state_node)]
#     382 if not expanded_children:
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/pytamp/search/mcts_for_rearragement.py:426, in MCTS_rearrangement._expand_action_node_rearr(self, cur_state_node, cur_state, depth)
#     415         possible_actions = list(
#     416             self.rearr_action.get_possible_actions_level_1(
#     417                 scene=cur_state,
#    (...)
#     420             )
#     421         )
#     422         # possible_actions = list(self.place_action.get_possible_actions_level_1(cur_state))
#     423         # self.render_action("Place Action", cur_state, possible_actions, is_holding)
#     424 else:
#     425     ## consider only rearr in level_1
# --> 426     possible_actions = list(
#     427         self.rearr_action.get_possible_actions_level_1(
#     428             scene=cur_state,
#     429             scene_for_sample=self.init_scene,
#     430             use_pick_action=self.use_pick_action,
#     431         )
#     432     )
#     434 for possible_action in possible_actions:
#     435     # print("possible actions :" ,possible_action)
#     436     if possible_action[self.rearr_action.info.TYPE] == "pick":
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/pytamp/action/rearrangement.py:52, in RearrangementAction.get_possible_actions_level_1(self, scene, scene_for_sample, use_pick_action)
#      32 def get_possible_actions_level_1(
#      33     self,
#      34     scene: Scene = None,
#      35     scene_for_sample: Make_Scene = None,
#      36     use_pick_action=False,
#      37 ) -> dict:
#      38     """
#      39     Args :
#      40         scene :
#    (...)
#      50
#      51     """
# ---> 52     self.deepcopy_scene(scene)
#      54     self.use_pick_action = use_pick_action
#      55     # change collision_mngr obj_poses
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/pytamp/action/activity.py:112, in ActivityBase.deepcopy_scene(self, scene)
#     110 if scene is None:
#     111     scene = self.scene_mngr.scene
# --> 112 self.scene_mngr.scene = deepcopy(scene)
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/copy.py:270, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268 if state is not None:
#     269     if deep:
# --> 270         state = deepcopy(state, memo)
#     271     if hasattr(y, '__setstate__'):
#     272         y.__setstate__(state)
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/copy.py:230, in _deepcopy_dict(x, memo, deepcopy)
#     228 memo[id(x)] = y
#     229 for key, value in x.items():
# --> 230     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231 return y
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/copy.py:270, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268 if state is not None:
#     269     if deep:
# --> 270         state = deepcopy(state, memo)
#     271     if hasattr(y, '__setstate__'):
#     272         y.__setstate__(state)
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/copy.py:230, in _deepcopy_dict(x, memo, deepcopy)
#     228 memo[id(x)] = y
#     229 for key, value in x.items():
# --> 230     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231 return y
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/copy.py:230, in _deepcopy_dict(x, memo, deepcopy)
#     228 memo[id(x)] = y
#     229 for key, value in x.items():
# --> 230     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231 return y
#
#     [... skipping similar frames: deepcopy at line 146 (1 times)]
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/copy.py:230, in _deepcopy_dict(x, memo, deepcopy)
#     228 memo[id(x)] = y
#     229 for key, value in x.items():
# --> 230     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231 return y
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/copy.py:205, in _deepcopy_list(x, memo, deepcopy)
#     203 append = y.append
#     204 for a in x:
# --> 205     append(deepcopy(a, memo))
#     206 return y
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/copy.py:205, in _deepcopy_list(x, memo, deepcopy)
#     203 append = y.append
#     204 for a in x:
# --> 205     append(deepcopy(a, memo))
#     206 return y
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/copy.py:153, in deepcopy(x, memo, _nil)
#     151 copier = getattr(x, "__deepcopy__", None)
#     152 if copier is not None:
# --> 153     y = copier(memo)
#     154 else:
#     155     reductor = dispatch_table.get(cls)
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/trimesh/base.py:3070, in Trimesh.__deepcopy__(self, *args)
#    3068 def __deepcopy__(self, *args):
#    3069     # interpret deep copy as "get rid of cached data"
# -> 3070     return self.copy(include_cache=False)
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/trimesh/base.py:3047, in Trimesh.copy(self, include_cache)
#    3045 copied._data.data = copy.deepcopy(self._data.data)
#    3046 # copy visual information
# -> 3047 copied.visual = self.visual.copy()
#    3048 # get metadata
#    3049 copied.metadata = copy.deepcopy(self.metadata)
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/trimesh/visual/color.py:154, in ColorVisuals.copy(self)
#     152 # call the literally insane generators
#     153 self.face_colors
# --> 154 self.vertex_colors
#     155 # copy anything that's actually data
#     156 copied._data.data = copy.deepcopy(self._data.data)
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/trimesh/visual/color.py:215, in ColorVisuals.vertex_colors(self)
#     206 @property
#     207 def vertex_colors(self):
#     208     """
#     209     Return the colors for each vertex of a mesh
#     210
#    (...)
#     213     colors: (len(mesh.vertices), 4) uint8, color for each vertex
#     214     """
# --> 215     return self._get_colors(name='vertex')
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/trimesh/visual/color.py:334, in ColorVisuals._get_colors(self, name)
#     329     colors = vertex_to_face_color(
#     330         vertex_colors=self.vertex_colors,
#     331         faces=self.mesh.faces)
#     332 elif (self.kind == 'face' and
#     333       name == 'vertex'):
# --> 334     colors = face_to_vertex_color(
#     335         mesh=self.mesh,
#     336         face_colors=self.face_colors)
#     337 else:
#     338     raise ValueError('self.kind not accepted values!!')
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/trimesh/visual/color.py:729, in face_to_vertex_color(mesh, face_colors, dtype)
#     715 """
#     716 Convert face colors into vertex colors.
#     717
#    (...)
#     726 vertex_colors: (m,4) dtype, colors for each vertex
#     727 """
#     728 rgba = to_rgba(face_colors)
# --> 729 vertex = mesh.faces_sparse.dot(rgba.astype(np.float64))
#     730 degree = mesh.vertex_degree
#     732 # normalize color by the number of faces including
#     733 # the vertex (i.e. the vertex degree)
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/trimesh/caching.py:139, in cache_decorator.<locals>.get_cached(*args, **kwargs)
#     137     return self._cache.cache[name]
#     138 # value not in cache so execute the function
# --> 139 value = function(*args, **kwargs)
#     140 # store the value
#     141 if self._cache.force_immutable and hasattr(
#     142         value, 'flags') and len(value.shape) > 0:
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/trimesh/base.py:300, in Trimesh.faces_sparse(self)
#     288 @caching.cache_decorator
#     289 def faces_sparse(self):
#     290     """
#     291     A sparse matrix representation of the faces.
#     292
#    (...)
#     298       shape : (len(self.vertices), len(self.faces))
#     299     """
# --> 300     sparse = geometry.index_sparse(
#     301         columns=len(self.vertices),
#     302         indices=self.faces)
#     303     return sparse
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/trimesh/geometry.py:473, in index_sparse(columns, indices, data)
#     470     data = np.ones(len(col), dtype=bool)
#     472 # assemble into sparse matrix
# --> 473 matrix = scipy.sparse.coo_matrix((data, (row, col)),
#     474                                  shape=shape,
#     475                                  dtype=data.dtype)
#     477 return matrix
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/scipy/sparse/_coo.py:160, in coo_matrix.__init__(self, arg1, shape, dtype, copy)
#     158 idx_dtype = get_index_dtype(maxval=max(self.shape))
#     159 self.row = np.array(row, copy=copy, dtype=idx_dtype)
# --> 160 self.col = np.array(col, copy=copy, dtype=idx_dtype)
#     161 self.data = getdata(obj, copy=copy, dtype=dtype)
#     162 self.has_canonical_format = False
#
# KeyboardInterrupt:

# %%
max_level_1_value = mcts.get_max_value_level_1()
max_level_1_value
# Out:
# 30.257142857142853

# %%
mcts.history_level_1_dict
# Out:
# {0: {'nodes': [0,
#    6,
#    356,
#    360,
#    1578,
#    1585,
#    1586,
#    1593,
#    1594,
#    1599,
#    1601,
#    1604,
#    1607,
#    1610,
#    1613,
#    1614,
#    1618,
#    1622,
#    1624,
#    1627,
#    1630],
#   'value': 16.516594516594516},
#  1: {'nodes': [0,
#    4,
#    211,
#    212,
#    922,
#    923,
#    1763,
#    1768,
#    1771,
#    1777,
#    1779,
#    1785,
#    1787,
#    1794,
#    1795,
#    1796,
#    1802,
#    1804,
#    1808,
#    1810,
#    1814],
#   'value': 11.50865800865801},
#  2: {'nodes': [0,
#    4,
#    211,
#    213,
#    979,
#    980,
#    2376,
#    2381,
#    2383,
#    2390,
#    2391,
#    2392,
#    2398,
#    2399,
#    2405,
#    2409,
#    2412,
#    2414,
#    2419,
#    2421,
#    2425],
#   'value': 17.707070707070706},
#  3: {'nodes': [0,
#    6,
#    356,
#    362,
#    364,
#    365,
#    3277,
#    3284,
#    3285,
#    3292,
#    3293,
#    3294,
#    3300,
#    3306,
#    3308,
#    3312,
#    3315,
#    3317,
#    3320,
#    3323,
#    3326],
#   'value': 12.175324675324678},
#  4: {'nodes': [0,
#    5,
#    288,
#    293,
#    2642,
#    2646,
#    4551,
#    4556,
#    4558,
#    4559,
#    4564,
#    4565,
#    4571,
#    4577,
#    4578,
#    4582,
#    4584],
#   'value': 24.112698412698414},
#  5: {'nodes': [0,
#    5,
#    288,
#    293,
#    2642,
#    2647,
#    4585,
#    4587,
#    4591,
#    4597,
#    4598,
#    4601,
#    4604],
#   'value': 30.257142857142853}}

# %%
########## level 1 ##########
if mcts.history_level_1_dict:
    j, max_value_nodes = mcts.get_max_value_nodes_level_1()
    print(f"Result {j} : ", max_value_nodes)
    print("state num :", len(max_value_nodes))
    mcts.render_rearr("_", max_value_nodes)
# Out:
# Result 5 :  [0, 5, 288, 293, 2642, 2647, 4585, 4587, 4591, 4597, 4598, 4601, 4604]
# state num : 13

# %%
state_list = [i for _, i in enumerate(max_value_nodes) if not _ % 2]
action_list = [i for _, i in enumerate(max_value_nodes) if _ % 2]

# %%
state_list, action_list
# Out:
# ([0, 288, 2642, 4585, 4591, 4598, 4604], [5, 293, 2647, 4587, 4597, 4601])

# %%
for i in range(len(max_value_nodes)//2):
    print("current state : ", max_value_nodes[2*i])
    print("action : ", max_value_nodes[2*i + 1])
    print("next state : ", max_value_nodes[2*(i+1)])
    
    print("manipulate object", mcts.tree.nodes[max_value_nodes[2*i + 1]]['action']['rearr_obj_name'])
    current_state_pc, current_count = rearrangement1.get_obj_point_clouds(mcts.tree.nodes[max_value_nodes[2*i]]['state'], mcts.tree.nodes[max_value_nodes[2*i + 1]]['action']['rearr_obj_name'])
    next_state_pc, next_count = rearrangement1.get_obj_point_clouds(mcts.tree.nodes[max_value_nodes[2*(i+1)]]['state'], mcts.tree.nodes[max_value_nodes[2*i + 1]]['action']['rearr_obj_name'])
    
    print()
    
    if i>2:
        break
# Out:
# current state :  0
# action :  5
# next state :  288
# manipulate object can1
#
# current state :  288
# action :  293
# next state :  2642
# manipulate object milk0
#
# current state :  2642
# action :  2647
# next state :  4585
# manipulate object cereal0
#
# current state :  4585
# action :  4587
# next state :  4591
# manipulate object ben_cube0

# %%
print(mcts.tree.nodes[max_value_nodes[2*i]]['state'].objs[mcts.tree.nodes[max_value_nodes[2*i + 1]]['action']['rearr_obj_name']].h_mat)
print(mcts.tree.nodes[max_value_nodes[2*(i+1)]]['state'].objs[mcts.tree.nodes[max_value_nodes[2*i + 1]]['action']['rearr_obj_name']].h_mat)
# Out:
# [[ 0.         -0.90181322 -0.43212604  0.30355822]
#  [ 0.          0.43212604 -0.90181322  0.00852862]
#  [ 1.          0.          0.          0.84779998]
#  [ 0.          0.          0.          1.        ]]
# [[-0.133875    0.99099823  0.          0.5356105 ]
#  [-0.99099823 -0.133875    0.          0.17191691]
#  [ 0.          0.          1.          0.84779998]
#  [ 0.          0.          0.          1.        ]]

# %%
combined_pc = rearrangement1.get_combined_point_cloud(mcts.tree.nodes[max_value_nodes[2*i]]['state'],
                                        mcts.tree.nodes[max_value_nodes[2*(i+1)]]['state'],
                                        mcts.tree.nodes[max_value_nodes[2*i + 1]]['action']['rearr_obj_name'],
                                        current_state_pc,
                                        next_state_pc,
                                        next_count
                                       )

# %%
##### %matplotlib inline
import trimesh
from trimesh.util import concatenate

# table_point_cloud =  rearrangement1.get_support_space_point_cloud()

# # obj_point_clouds = rearrangement1.get_obj_point_clouds(mcts.tree.nodes[1936]['state'])
# point_clouds = rearrangement1.get_obj_point_clouds(mcts.tree.nodes[311]['state'])

# point_clouds = np.vstack((point_clouds, table_point_cloud))
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
print(len(next_state_pc))

# matplotlib으로 point cloud 시각화하기
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(combined_pc[:, 0], combined_pc[:, 1], combined_pc[:, 2], c='b', marker='.')
ax.set_xlim(.2,0.8)
ax.set_ylim(-.6,0.6)
ax.set_zlim(0.5,1.3)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

ax.view_init(elev=90, azim=0)

plt.show()
# Out:
# 5000

# %%
from pykin.utils import mesh_utils as m_utils

# current obj -> next_scene obj 
cTn = m_utils.get_relative_transform(mcts.tree.nodes[max_value_nodes[2*i]]['state'].objs[mcts.tree.nodes[max_value_nodes[2*i + 1]]['action']['rearr_obj_name']].h_mat,
       mcts.tree.nodes[max_value_nodes[2*(i+1)]]['state'].objs[mcts.tree.nodes[max_value_nodes[2*i + 1]]['action']['rearr_obj_name']].h_mat)
cTn
# Out:
# array([[ 0.        ,  0.        ,  1.        ,  0.        ],
#        [-0.30750589, -0.95154618,  0.        , -0.13866348],
#        [ 0.95154618, -0.30750589,  0.        , -0.24762155],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])

# %%
mcts.tree.nodes[max_value_nodes[2*(i)]]['state'].objs, mcts.tree.nodes[max_value_nodes[2*i + 1]]['action']['rearr_obj_name']
# Out:
# ({'table': Object(name=table, pos=[ 0.9   -0.6    0.043]),
#   'ben_cube0': Object(name=ben_cube0, pos=[0.30355822 0.00852862 0.84779998]),
#   'can0': Object(name=can0, pos=[0.39698326 0.00357495 0.83501831]),
#   'can1': Object(name=can1, pos=[ 0.4043516  -0.157966    0.85059666]),
#   'milk0': Object(name=milk0, pos=[ 0.44086927 -0.03354331  0.87809554]),
#   'cereal0': Object(name=cereal0, pos=[ 0.87301896 -0.09254935  0.88526188])},
#  'ben_cube0')

# %%
current_state_pc

o_arr = np.full((len(current_state_pc), 1), 1)
current_state_pc_h = np.hstack((current_state_pc, o_arr))

transformed_current_pc =  np.dot(current_state_pc_h, cTn[:3].T)
transformed_current_pc
# Out:
# array([[ 0.88529998, -0.2275991 ,  0.04721988],
#        [ 0.86912021, -0.22019725, -0.00192715],
#        [ 0.85703812, -0.21809468, -0.00221119],
#        ...,
#        [ 0.96010673, -0.28007764,  0.60388239],
#        [ 0.95214137, -0.30203801,  0.61862221],
#        [ 0.930368  , -0.30535379,  0.58533033]])

# %%
milk_current_mean = np.array([np.mean(transformed_current_pc[1000*(current_count):1000*(current_count+1)][:,0]), np.mean(transformed_current_pc[1000*(current_count):1000*(current_count+1)][:,1]), np.mean(transformed_current_pc[1000*(current_count):1000*(current_count+1)][:,2])])
transformed_current_pc, milk_current_mean
# Out:
# (array([[ 0.88529998, -0.2275991 ,  0.04721988],
#         [ 0.86912021, -0.22019725, -0.00192715],
#         [ 0.85703812, -0.21809468, -0.00221119],
#         ...,
#         [ 0.96010673, -0.28007764,  0.60388239],
#         [ 0.95214137, -0.30203801,  0.61862221],
#         [ 0.930368  , -0.30535379,  0.58533033]]),
#  array([ 0.84701031, -0.23864406,  0.03845587]))

# %%
milk_next_mean = np.array([np.mean(next_state_pc[1000*(current_count):1000*(current_count+1)][:,0]), np.mean(next_state_pc[1000*(current_count):1000*(current_count+1)][:,1]),  np.mean(next_state_pc[1000*(current_count):1000*(current_count+1)][:,2])])
next_state_pc, milk_next_mean
# Out:
# (array([[ 0.51928653,  0.17399936,  0.88529998],
#         [ 0.5012266 ,  0.13872123,  0.82928108],
#         [ 0.52571938,  0.16947586,  0.88529998],
#         ...,
#         [ 0.85194895, -0.12993387,  0.92494681],
#         [ 0.89452958, -0.05480465,  0.82599171],
#         [ 0.85037821, -0.12939211,  0.81029998]]),
#  array([0.53475389, 0.17350673, 0.84820679]))

# %%
transition_xy = milk_next_mean - milk_current_mean
transition_xy
# Out:
# array([-0.31225642,  0.41215078,  0.80975091])

# %%
##### %matplotlib inline
import trimesh
from trimesh.util import concatenate

# table_point_cloud =  rearrangement1.get_support_space_point_cloud()

# # obj_point_clouds = rearrangement1.get_obj_point_clouds(mcts.tree.nodes[1936]['state'])
# point_clouds = rearrangement1.get_obj_point_clouds(mcts.tree.nodes[311]['state'])

# point_clouds = np.vstack((point_clouds, table_point_cloud))
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
print(len(transformed_current_pc))

transformed_current_pc_2 = transformed_current_pc + transition_xy

# matplotlib으로 point cloud 시각화하기
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(transformed_current_pc_2[:, 0], transformed_current_pc_2[:, 1], transformed_current_pc_2[:, 2], c='b', marker='.')
ax.scatter(transformed_current_pc_2[1000*current_count:1000*(current_count+1), 0], transformed_current_pc_2[1000*current_count:1000*(current_count+1), 1], transformed_current_pc_2[1000*current_count:1000*(current_count+1), 2], c='r', marker='.')
ax.set_xlim(-0.,0.8)
ax.set_ylim(-.6,0.6)
ax.set_zlim(0.3,1.3)


ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

ax.view_init(elev=0, azim=0)

plt.show()
# Out:
# 5000

# %%
##### %matplotlib inline
import trimesh
from trimesh.util import concatenate

# table_point_cloud =  rearrangement1.get_support_space_point_cloud()

# # obj_point_clouds = rearrangement1.get_obj_point_clouds(mcts.tree.nodes[1936]['state'])
# point_clouds = rearrangement1.get_obj_point_clouds(mcts.tree.nodes[311]['state'])

# point_clouds = np.vstack((point_clouds, table_point_cloud))
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
print(len(current_state_pc))

# matplotlib으로 point cloud 시각화하기
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(current_state_pc[:, 0], current_state_pc[:, 1], current_state_pc[:, 2], c='b', marker='.')
ax.set_xlim(.2,0.8)
ax.set_ylim(-.6,0.6)
ax.set_zlim(0.5,1.3)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

ax.view_init(elev=90, azim=0)

plt.show()
# Out:
# 5000

# %%
##### %matplotlib inline
import trimesh
from trimesh.util import concatenate

# table_point_cloud =  rearrangement1.get_support_space_point_cloud()

# # obj_point_clouds = rearrangement1.get_obj_point_clouds(mcts.tree.nodes[1936]['state'])
# point_clouds = rearrangement1.get_obj_point_clouds(mcts.tree.nodes[311]['state'])

# point_clouds = np.vstack((point_clouds, table_point_cloud))
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
print(len(next_state_pc))

# matplotlib으로 point cloud 시각화하기
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(next_state_pc[1000*current_count:1000*(current_count+1), 0], next_state_pc[1000*current_count:1000*(current_count+1), 1], next_state_pc[1000*current_count:1000*(current_count+1), 2], c='g', marker='.')
ax.scatter(next_state_pc[:, 0], next_state_pc[:, 1], next_state_pc[:, 2], c='b', marker='.')
ax.set_xlim(.2,0.8)
ax.set_ylim(-.6,0.6)
ax.set_zlim(0.5,1.3)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

ax.view_init(elev=90, azim=0)

plt.show()
# Out:
# 5000

# %% [markdown]
# ## Combined PC

# %%
##### %matplotlib inline
import trimesh
from trimesh.util import concatenate

# table_point_cloud =  rearrangement1.get_support_space_point_cloud()

# # obj_point_clouds = rearrangement1.get_obj_point_clouds(mcts.tree.nodes[1936]['state'])
# point_clouds = rearrangement1.get_obj_point_clouds(mcts.tree.nodes[311]['state'])

# point_clouds = np.vstack((point_clouds, table_point_cloud))
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
print(len(next_state_pc))

combined_pc = np.vstack([next_state_pc, transformed_current_pc_2])

# matplotlib으로 point cloud 시각화하기
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(combined_pc[:, 0], combined_pc[:, 1], combined_pc[:, 2], c='b', marker='.')
ax.set_xlim(-0.,0.8)
ax.set_ylim(-.6,0.6)
ax.set_zlim(0.3,1.3)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

ax.view_init(elev=90, azim=0)

plt.show()
# Out:
# 5000

# %%
len(combined_pc)
# Out:
# 10000

# %%
idx = 0
val_ = -np.inf
for k,v in mcts.history_level_1_dict.items():
    if val_ < v['value']:
        idx = k
        val_ = v['value']
        
max_value_nodes = mcts.history_level_1_dict[2]['nodes']
mcts.render_rearr("_", max_value_nodes)
# idx, max_value_nodes

# %%
mcts.do_planning_rearrange(0)

mcts.visualize_tree("Siccess nodes", mcts.tree)
# Out:
# =========== Search iteration : 1 ===========
# Possible action :  [{'table': array([[-0.65439006, -0.75615716,  0.        ,  0.81258534],
#        [ 0.75615716, -0.65439006,  0.        ,  0.59000015],
#        [ 0.        ,  0.        ,  1.        ,  0.84779998],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}, {'table': array([[-0.85692728, -0.51543732,  0.        ,  0.60659851],
#        [ 0.51543732, -0.85692728,  0.        ,  0.38424777],
#        [ 0.        ,  0.        ,  1.        ,  0.84779998],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]
# Possible action :  [{'table': array([[ 0.49456394, -0.86914125,  0.        ,  0.69975171],
#        [ 0.86914125,  0.49456394,  0.        ,  0.56444204],
#        [ 0.        ,  0.        ,  1.        ,  0.85059666],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]
# Possible action :  [{'table': array([[ 0.91856648, -0.39526653,  0.        ,  0.32757333],
#        [ 0.39526653,  0.91856648,  0.        ,  0.33862818],
#        [ 0.        ,  0.        ,  1.        ,  0.85059666],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}, {'table': array([[-0.73037522, -0.68304614,  0.        ,  0.44169133],
#        [ 0.68304614, -0.73037522,  0.        , -0.42009045],
#        [ 0.        ,  0.        ,  1.        ,  0.85059666],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]
# Possible action :  [{'table': array([[-0.90963078,  0.41541767,  0.        ,  0.47810825],
#        [-0.41541767, -0.90963078,  0.        , -0.06287902],
#        [ 0.        ,  0.        ,  1.        ,  0.87809554],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}, {'table': array([[ 0.10791734, -0.99415987,  0.        ,  0.81318761],
#        [ 0.99415987,  0.10791734,  0.        , -0.4551765 ],
#        [ 0.        ,  0.        ,  1.        ,  0.87809554],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]
# Possible action :  [{'table': array([[ 0.76411862,  0.64507576,  0.        ,  0.40761815],
#        [-0.64507576,  0.76411862,  0.        ,  0.37854922],
#        [ 0.        ,  0.        ,  1.        ,  0.88526188],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}, {'table': array([[ 0.74260901,  0.66972521,  0.        ,  0.70680931],
#        [-0.66972521,  0.74260901,  0.        ,  0.29006184],
#        [ 0.        ,  0.        ,  1.        ,  0.88526188],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]
# [Action] Rearr milk0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 mcts.do_planning_rearrange(0)
#       3 mcts.visualize_tree("Siccess nodes", mcts.tree)
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/pytamp/search/mcts_for_rearragement.py:189, in MCTS_rearrangement.do_planning_rearrange(self, iter)
#     186     self.visualize_tree("Next Logical Node", self.tree)
#     187 self.success_level_1_leaf_node = None
# --> 189 self._level_wise_1_optimize_rearr(state_node=0, depth=0)
#     190 max_level_1_value = self.get_max_value_level_1()
#     191 self.values_for_level_1.append(max_level_1_value)
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/pytamp/search/mcts_for_rearragement.py:304, in MCTS_rearrangement._level_wise_1_optimize_rearr(self, state_node, depth)
#     298     print(
#     299         f"{sc.COLOR_BROWN}[Action]{sc.ENDC} {sc.OKGREEN}Rearr {cur_logical_action[self.rearr_action.info.REARR_OBJ_NAME]}{sc.ENDC}"
#     300     )
#     302 # ? Select Next State
#     303 # *======================================================================================================================== #
# --> 304 next_state_node = self._select_next_state_node(
#     305     cur_logical_action_node,
#     306     cur_state,
#     307     cur_logical_action,
#     308     depth,
#     309     self._sampling_method,
#     310 )
#     311 # assert next_state_node is not None, f"Next state node is None... Why??"
#     312 if next_state_node is not None:
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/pytamp/search/mcts_for_rearragement.py:528, in MCTS_rearrangement._select_next_state_node(self, cur_logical_action_node, cur_state, cur_logical_action, depth, exploration_method)
#     525 visit = self.tree.nodes[cur_logical_action_node][NodeData.VISIT]
#     526 if visit == 0:
#     527     # print(f"Logical action node {cur_logical_action_node} is a leaf node, So expand")
# --> 528     self._expand_next_state_node_arr(
#     529         cur_logical_action_node, cur_state, cur_logical_action, depth
#     530     )
#     531 expanded_children = [
#     532     child for child in self.tree.neighbors(cur_logical_action_node)
#     533 ]
#     534 if not expanded_children:
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/pytamp/search/mcts_for_rearragement.py:580, in MCTS_rearrangement._expand_next_state_node_arr(self, cur_logical_action_node, cur_state, cur_logical_action, depth)
#     573     next_states = list(
#     574         self.place_action.get_possible_transitions(
#     575             cur_state, cur_logical_action
#     576         )
#     577     )
#     579 if logical_action_type == "rearr":
# --> 580     next_states = list(
#     581         self.rearr_action.get_possible_transitions(
#     582             cur_state, cur_logical_action
#     583         )
#     584     )
#     586 for next_state in next_states:
#     587     next_node = self.tree.number_of_nodes()
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/pytamp/action/rearrangement.py:291, in RearrangementAction.get_possible_transitions(self, scene, action)
#     288 c_T_w = t_utils.get_inverse_homogeneous(scene.objs[name].h_mat)
#     290 held_obj_name = action[self.info.REARR_OBJ_NAME]
# --> 291 place_obj_name = action[self.info.PLACE_OBJ_NAME]
#     293 # print(action)
#     295 for rearr_pose, obj_pose_transformed in action[self.info.REARR_POSES]:
#
# KeyError: 'place_obj_name'

# %%
mcts.rearr_action.scene_mngr.init_scene.objs
# Out:
# {'table': Object(name=table, pos=[ 0.9   -0.6    0.043]),
#  'ben_cube0': Object(name=ben_cube0, pos=[ 0.51224777 -0.30205152  0.84779998]),
#  'can0': Object(name=can0, pos=[0.52298875 0.45872414 0.85059666]),
#  'can1': Object(name=can1, pos=[0.57888044 0.07873193 0.83516771]),
#  'milk0': Object(name=milk0, pos=[ 0.82293572 -0.52496244  0.83236691]),
#  'cereal0': Object(name=cereal0, pos=[ 0.4360076  -0.25732616  0.86029978])}

# %% [markdown]
# # Scene collision info

# %%
col_info = {}

def get_h_mat(position=np.zeros(3), orientation=np.array([1.0, 0.0, 0.0, 0.0])):
    """
    Returns homogeneous matrix from position and orientation
    """
    position = np.asarray(position)
    orientation = np.asarray(orientation)
    if orientation.shape == (3,):  # RPY Euler angles
        R = get_matrix_from_rpy(orientation)
    elif orientation.shape == (4,):  # quaternion in the form [x,y,z,w]
        R = get_matrix_from_quaternion(orientation)
    elif orientation.shape == (3, 3):  # Rotation matrix
        R = orientation

    H = np.vstack((np.hstack((R, position.reshape(-1, 1))), np.array([[0, 0, 0, 1]])))
    return H

for name, info in mcts.init_scene.collision_manager._objs.items():
    T = get_h_mat(
        position=info["obj"].getTranslation(),
        orientation=info["obj"].getRotation(),
    )
    col_info[name] = T

# %% [markdown]
# # Collision check

# %%
idx = 4148
try:
    print(mcts.tree.nodes[idx]['state'].objs), print(mcts.tree.nodes[idx]['action']['rearr_poses'])
except:
    print(mcts.tree.nodes[idx]['state'].objs), print(mcts.tree.nodes[idx]['action'])
# Out:
# {'table': Object(name=table, pos=[ 1.    -0.6    0.043]), 'ben_cube0': Object(name=ben_cube0, pos=[0.70176068 0.39897795 0.84779998]), 'bottle0': Object(name=bottle0, pos=[0.9662838  0.26164643 0.83593754]), 'can0': Object(name=can0, pos=[ 0.69793541 -0.27222775  0.85059666]), 'milk0': Object(name=milk0, pos=[0.81366052 0.0371563  0.87809554]), 'cereal0': Object(name=cereal0, pos=[ 0.40749753 -0.09764542  0.88526188])}
# [{'milk0': array([[ 0.96655143, -0.25647288,  0.        ,  0.88596138],
#        [ 0.25647288,  0.96655143,  0.        , -0.40701088],
#        [ 0.        ,  0.        ,  1.        ,  0.87809554],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}, {'milk0': array([[ 0.49220865,  0.87047725,  0.        ,  0.81366052],
#        [-0.87047725,  0.49220865,  0.        ,  0.0371563 ],
#        [ 0.        ,  0.        ,  1.        ,  0.87809554],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]

# %%
idx = 4153
try:
    print(mcts.tree.nodes[idx]['state'].objs), print(mcts.tree.nodes[idx]['action']['rearr_poses'])
except:
    print(mcts.tree.nodes[idx]['state'].objs), print(mcts.tree.nodes[idx]['action'])
# Out:
# {'table': Object(name=table, pos=[ 1.    -0.6    0.043]), 'ben_cube0': Object(name=ben_cube0, pos=[0.70176068 0.39897795 0.84779998]), 'bottle0': Object(name=bottle0, pos=[0.9662838  0.26164643 0.83593754]), 'can0': Object(name=can0, pos=[ 0.69793541 -0.27222775  0.85059666]), 'milk0': Object(name=milk0, pos=[0.81366052 0.0371563  0.87809554]), 'cereal0': Object(name=cereal0, pos=[ 0.40749753 -0.09764542  0.88526188])}
# [{'bottle0': array([[-0.14103772,  0.99000422,  0.        ,  0.82751786],
#        [-0.99000422, -0.14103772,  0.        , -0.4207895 ],
#        [ 0.        ,  0.        ,  1.        ,  0.87515735],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}, {'bottle0': array([[-0.05088925, -0.9987043 ,  0.        ,  0.62542366],
#        [ 0.9987043 , -0.05088925,  0.        , -0.24336767],
#        [ 0.        ,  0.        ,  1.        ,  0.87515735],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}]

# %%
mcts.render_rearr_state( None,title =  '_', state = mcts.tree.nodes[idx]['state'])

# %%
mcts.scene_mngr.scene.objs
# Out:
# {'table': Object(name=table, pos=[ 1.    -0.6    0.043]),
#  'ben_cube0': Object(name=ben_cube0, pos=[0.7449755  0.50675499 0.84779998]),
#  'bottle0': Object(name=bottle0, pos=[ 0.74971138 -0.29269512  0.83593753]),
#  'can0': Object(name=can0, pos=[0.58752796 0.31872161 0.83500836]),
#  'milk0': Object(name=milk0, pos=[ 0.47826872 -0.11880885  0.83236691])}

# %%
idx, list(mcts.rearr_action.get_goal_location_not_collision(mcts.tree.nodes[idx]['state'],mcts.tree.nodes[idx]['action']['rearr_poses']))
# Out:
# (862,
#  [{'can0': array([[ 0.71035039, -0.70384822,  0.        ,  0.7415683 ],
#           [ 0.70384822,  0.71035039,  0.        , -0.55474858],
#           [ 0.        ,  0.        ,  1.        ,  0.85059666],
#           [ 0.        ,  0.        ,  0.        ,  1.        ]])},
#   {'can0': array([[-0.17171101,  0.98514736,  0.        ,  0.83996994],
#           [-0.98514736, -0.17171101,  0.        , -0.27054348],
#           [ 0.        ,  0.        ,  1.        ,  0.85059666],
#           [ 0.        ,  0.        ,  0.        ,  1.        ]])}])

# %%
mcts.scene_mngr.obj_collision_mngr.get_collision_info()
# Out:
# {'table': array([[ 1.   ,  0.   ,  0.   ,  1.   ],
#         [ 0.   ,  1.   ,  0.   , -0.6  ],
#         [ 0.   ,  0.   ,  1.   ,  0.043],
#         [ 0.   ,  0.   ,  0.   ,  1.   ]]),
#  'ben_cube0': array([[ 0.        ,  0.78165694, -0.62370861,  0.84763533],
#         [ 0.        ,  0.62370861,  0.78165694,  0.36753831],
#         [ 1.        ,  0.        ,  0.        ,  0.84779998],
#         [ 0.        ,  0.        ,  0.        ,  1.        ]]),
#  'bottle0': array([[-0.65291822,  0.75742841,  0.        ,  0.83010826],
#         [-0.75742841, -0.65291822,  0.        , -0.20864996],
#         [ 0.        ,  0.        ,  1.        ,  0.87515735],
#         [ 0.        ,  0.        ,  0.        ,  1.        ]]),
#  'ben_cube1': array([[-0.17287648,  0.98494351,  0.        ,  0.49591774],
#         [ 0.98494351,  0.17287648,  0.        ,  0.45601634],
#         [ 0.        ,  0.        , -1.        ,  0.84779998],
#         [ 0.        ,  0.        ,  0.        ,  1.        ]]),
#  'bottle1': array([[-0.81254636,  0.58289657,  0.        ,  0.38289801],
#         [-0.58289657, -0.81254636,  0.        ,  0.37264649],
#         [ 0.        ,  0.        ,  1.        ,  0.87515735],
#         [ 0.        ,  0.        ,  0.        ,  1.        ]])}

# %%
for name, obj in mcts.rearr_action.scene_mngr.scene.objs.items():
    print(name, obj.h_mat)
# Out:
# table [[ 1.     0.     0.     1.   ]
#  [ 0.     1.     0.    -0.6  ]
#  [ 0.     0.     1.     0.043]
#  [ 0.     0.     0.     1.   ]]
# ben_cube0 [[-0.34614189 -0.93818217  0.          0.46298891]
#  [ 0.93818217 -0.34614189  0.          0.02937996]
#  [ 0.          0.          1.          0.84779998]
#  [ 0.          0.          0.          1.        ]]
# bottle0 [[-0.65291822  0.75742841  0.          0.83010826]
#  [-0.75742841 -0.65291822  0.         -0.20864996]
#  [ 0.          0.          1.          0.87515735]
#  [ 0.          0.          0.          1.        ]]
# ben_cube1 [[-0.19514173  0.98077505  0.          0.96563102]
#  [-0.98077505 -0.19514173  0.          0.29412445]
#  [ 0.          0.          1.          0.84779998]
#  [ 0.          0.          0.          1.        ]]
# bottle1 [[-0.81254636  0.58289657  0.          0.38289801]
#  [-0.58289657 -0.81254636  0.          0.37264649]
#  [ 0.          0.          1.          0.87515735]
#  [ 0.          0.          0.          1.        ]]
