# %%
from pykin.utils import plot_utils as p_utils
from pytamp.action.pick import PickAction
from pytamp.benchmark import Benchmark2

benchmark2 = Benchmark2(
    robot_name="doosan", geom="visual", is_pyplot=True, bottle_num=1
)
pick = PickAction(
    benchmark2.scene_mngr, n_contacts=10, n_directions=3, retreat_distance=0.1
)
# Out:
# *********************** Logical States ***********************
# OrderedDict([('shelf_0', {'static': True}),
#              ('bin_0', {'static': True}),
#              ('shelf_1', {'static': True}),
#              ('bin_1', {'static': True}),
#              ('shelf_2', {'static': True}),
#              ('bin_2', {'static': True}),
#              ('shelf_3', {'static': True}),
#              ('bin_3', {'static': True}),
#              ('shelf_4', {'static': True}),
#              ('bin_4', {'static': True}),
#              ('shelf_5', {'static': True}),
#              ('bin_5', {'static': True}),
#              ('shelf_6', {'static': True}),
#              ('bin_6', {'static': True}),
#              ('shelf_7', {'static': True}),
#              ('bin_7', {'static': True}),
#              ('shelf_8', {'static': True}),
#              ('bin_8', {'static': True}),
#              ('shelf_9',
#               {'static': True,
#                'support': [Object(name=goal_bottle, pos=[1.04 0.   1.29])]}),
#              ('bin_9', {'static': True}),
#              ('shelf_10', {'static': True}),
#              ('bin_10', {'static': True}),
#              ('shelf_11', {'static': True}),
#              ('bin_11', {'static': True}),
#              ('shelf_12', {'static': True}),
#              ('bin_12', {'static': True}),
#              ('shelf_13', {'static': True}),
#              ('bin_13', {'static': True}),
#              ('shelf_14', {'static': True}),
#              ('bin_14', {'static': True}),
#              ('shelf_15', {'static': True}),
#              ('bin_15', {'static': True}),
#              ('shelf_16', {'static': True}),
#              ('bin_16', {'static': True}),
#              ('shelf_17', {'static': True}),
#              ('bin_17', {'static': True}),
#              ('shelf_18', {'static': True}),
#              ('bin_18', {'static': True}),
#              ('shelf_19', {'static': True}),
#              ('bin_19', {'static': True}),
#              ('goal_bottle',
#               {'on': Object(name=shelf_9, pos=[0.9        0.         1.41725156])}),
#              ('robotiq140_gripper', {'holding': None})])
# ***************************************************************

# %%
################# Action Test ##################
actions = list(pick.get_possible_actions_level_1())

pick_all_joint_path = []
pick_all_objects = []
pick_all_object_poses = []

pick_path = []
pick_objects = []
pick_object_poses = []

# %%
success_joint_path = False
for pick_action in actions:
    for idx, pick_scene in enumerate(
        pick.get_possible_transitions(pick.scene_mngr.scene, action=pick_action)
    ):
        pick_joint_path = pick.get_possible_joint_path_level_2(
            scene=pick_scene, grasp_poses=pick_scene.grasp_poses
        )
        if pick_joint_path:
            success_joint_path = True
            pick_path += pick_joint_path
            pick_objects.append(pick.scene_mngr.attached_obj_name)
            pick_object_poses.append(pick.scene_mngr.scene.robot.gripper.pick_obj_pose)
        if success_joint_path:
            break
    if success_joint_path:
        break
# Out:
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# [INFO] [RRT Star Planner]: The joint limit has been successfully checked. Pose error is 0.000000
# solve the problem using LM2!!
# Iterators : 7
# WorkingTime[inverse_kinematics]: 0.0058 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 4 --> 30
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000001
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000001
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# Cost is 2.303
# WorkingTime[run]: 3.4546 sec
#
# WorkingTime[run]: 0.0897 sec
#
# WorkingTime[run]: 0.0860 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 3 --> 20
# Cost is 2.353
# WorkingTime[run]: 3.4063 sec

# %%
pick_path
# Out:
# [OrderedDict([('pre_grasp',
#                [array([ 0.01250357, -1.0033403 ,  2.09039216, -0.06146633,  1.05506363,
#                        -0.0180082 ]),
#                 array([ 0.02500714, -0.95948305,  2.08638921, -0.12293266,  1.06292971,
#                        -0.03601639]),
#                 array([ 0.0375107 , -0.9156258 ,  2.08238626, -0.184399  ,  1.0707958 ,
#                        -0.05402459]),
#                 array([ 0.05001427, -0.87176855,  2.07838332, -0.24586533,  1.07866188,
#                        -0.07203278]),
#                 array([ 0.06251784, -0.82791129,  2.07438037, -0.30733166,  1.08652796,
#                        -0.09004098]),
#                 array([ 0.07502141, -0.78405404,  2.07037743, -0.36879799,  1.09439404,
#                        -0.10804917]),
#                 array([ 0.08752498, -0.74019679,  2.06637448, -0.43026432,  1.10226012,
#                        -0.12605737]),
#                 array([ 0.10002854, -0.69633954,  2.06237153, -0.49173065,  1.11012621,
#                        -0.14406556]),
#                 array([ 0.11253211, -0.65248229,  2.05836859, -0.55319699,  1.11799229,
#                        -0.16207376]),
#                 array([ 0.12503568, -0.60862504,  2.05436564, -0.61466332,  1.12585837,
#                        -0.18008195]),
#                 array([ 0.14796132, -0.54967945,  2.05676428, -0.70506255,  1.1281676 ,
#                        -0.21748782]),
#                 array([ 0.17088696, -0.49073387,  2.05916293, -0.79546177,  1.13047683,
#                        -0.2548937 ]),
#                 array([ 0.1938126 , -0.43178829,  2.06156157, -0.885861  ,  1.13278605,
#                        -0.29229957]),
#                 array([ 0.21673824, -0.37284271,  2.06396022, -0.97626023,  1.13509528,
#                        -0.32970545]),
#                 array([ 0.23966389, -0.31389713,  2.06635886, -1.06665945,  1.13740451,
#                        -0.36711132]),
#                 array([ 0.26258953, -0.25495155,  2.0687575 , -1.15705868,  1.13971374,
#                        -0.40451719]),
#                 array([ 0.28551517, -0.19600597,  2.07115615, -1.24745791,  1.14202297,
#                        -0.44192307]),
#                 array([ 0.30844081, -0.13706039,  2.07355479, -1.33785713,  1.1443322 ,
#                        -0.47932894]),
#                 array([ 0.33136645, -0.07811481,  2.07595343, -1.42825636,  1.14664143,
#                        -0.51673481]),
#                 array([ 0.35429209, -0.01916923,  2.07835208, -1.51865559,  1.14895065,
#                        -0.55414069]),
#                 array([ 0.36668897, -0.00389166,  2.08495324, -1.5441625 ,  1.14691176,
#                        -0.56483715]),
#                 array([ 0.37908584,  0.01138592,  2.09155439, -1.56966942,  1.14487286,
#                        -0.57553362]),
#                 array([ 0.39148271,  0.02666349,  2.09815555, -1.59517634,  1.14283397,
#                        -0.58623008]),
#                 array([ 0.40387959,  0.04194106,  2.10475671, -1.62068326,  1.14079507,
#                        -0.59692654]),
#                 array([ 0.41627646,  0.05721863,  2.11135787, -1.64619017,  1.13875618,
#                        -0.60762301]),
#                 array([ 0.42867334,  0.0724962 ,  2.11795903, -1.67169709,  1.13671729,
#                        -0.61831947]),
#                 array([ 0.44107021,  0.08777377,  2.12456019, -1.69720401,  1.13467839,
#                        -0.62901594]),
#                 array([ 0.45346709,  0.10305134,  2.13116135, -1.72271092,  1.1326395 ,
#                        -0.6397124 ]),
#                 array([ 0.46586396,  0.11832891,  2.1377625 , -1.74821784,  1.1306006 ,
#                        -0.65040886]),
#                 array([ 0.47826084,  0.13360648,  2.14436366, -1.77372476,  1.12856171,
#                        -0.66110533])]),
#               ('grasp',
#                [array([ 0.47826084,  0.13360648,  2.14436366, -1.77372476,  1.12856171,
#                        -0.66110533]),
#                 array([ 0.47636608,  0.13439555,  2.1437789 , -1.77518854,  1.12719262,
#                        -0.66056223]),
#                 array([ 0.45759931,  0.14244352,  2.13769883, -1.78978434,  1.11367666,
#                        -0.65509283]),
#                 array([ 0.43916853,  0.15073569,  2.13123353, -1.80426774,  1.10047287,
#                        -0.64959169]),
#                 array([ 0.42107772,  0.15926099,  2.12438742, -1.81862387,  1.08757656,
#                        -0.64407644]),
#                 array([ 0.40332982,  0.16800853,  2.11716504, -1.83283808,  1.07498184,
#                        -0.63856448]),
#                 array([ 0.38592674,  0.1769677 ,  2.10957097, -1.84689602,  1.0626817 ,
#                        -0.63307292]),
#                 array([ 0.36886948,  0.18612814,  2.10160985, -1.86078371,  1.05066814,
#                        -0.62761847]),
#                 array([ 0.35215814,  0.19547986,  2.09328634, -1.87448761,  1.03893228,
#                        -0.62221738]),
#                 array([ 0.33579202,  0.20501319,  2.08460508, -1.88799469,  1.02746448,
#                        -0.61688537]),
#                 array([ 0.31976966,  0.21471886,  2.0755707 , -1.90129242,  1.01625444,
#                        -0.61163756]),
#                 array([ 0.30564172,  0.22359401,  2.06714163, -1.91307152,  1.00637685,
#                        -0.60699854])]),
#               ('post_grasp',
#                [array([ 0.30564172,  0.22359401,  2.06714163, -1.91307152,  1.00637685,
#                        -0.60699854]),
#                 array([ 0.30564075,  0.22225564,  2.06633303, -1.91179294,  1.00565548,
#                        -0.60939144]),
#                 array([ 0.30563621,  0.20909318,  2.05802072, -1.89883826,  0.99859907,
#                        -0.63346324]),
#                 array([ 0.30563166,  0.19632169,  2.04935493, -1.88564932,  0.9918202 ,
#                        -0.65770796]),
#                 array([ 0.30562709,  0.18394422,  2.04033979, -1.87223747,  0.98532594,
#                        -0.68211284]),
#                 array([ 0.30562252,  0.17196321,  2.0309794 , -1.85861458,  0.97912262,
#                        -0.70666499]),
#                 array([ 0.30561793,  0.16038054,  2.02127777, -1.84479295,  0.97321589,
#                        -0.73135138]),
#                 array([ 0.30561333,  0.14919752,  2.01123883, -1.83078523,  0.96761069,
#                        -0.75615892]),
#                 array([ 0.30560873,  0.13841498,  2.00086639, -1.81660445,  0.96231124,
#                        -0.7810745 ]),
#                 array([ 0.30560411,  0.12803324,  1.99016413, -1.80226388,  0.95732116,
#                        -0.80608499]),
#                 array([ 0.30559949,  0.11805217,  1.97913559, -1.78777702,  0.95264337,
#                        -0.83117733]),
#                 array([ 0.30559533,  0.10941135,  1.96893373, -1.77462504,  0.94870231,
#                        -0.8538197 ])]),
#               ('default_grasp',
#                [array([ 0.28256254,  0.06069462,  1.95909825, -1.67665483,  0.95508163,
#                        -0.81511601]),
#                 array([ 0.25952974,  0.01197789,  1.94926276, -1.57868462,  0.96146094,
#                        -0.77641232]),
#                 array([ 0.23649695, -0.03673884,  1.93942728, -1.48071441,  0.96784026,
#                        -0.73770863]),
#                 array([ 0.21346416, -0.08545557,  1.92959179, -1.3827442 ,  0.97421958,
#                        -0.69900494]),
#                 array([ 0.19043137, -0.1341723 ,  1.9197563 , -1.28477399,  0.9805989 ,
#                        -0.66030125]),
#                 array([ 0.16739858, -0.18288903,  1.90992082, -1.18680378,  0.98697821,
#                        -0.62159756]),
#                 array([ 0.14436579, -0.23160576,  1.90008533, -1.08883357,  0.99335753,
#                        -0.58289387]),
#                 array([ 0.121333  , -0.28032248,  1.89024985, -0.99086336,  0.99973685,
#                        -0.54419018]),
#                 array([ 0.09830021, -0.32903921,  1.88041436, -0.89289315,  1.00611617,
#                        -0.50548649]),
#                 array([ 0.07526741, -0.37775594,  1.87057888, -0.79492294,  1.01249549,
#                        -0.4667828 ]),
#                 array([ 0.06774067, -0.4447001 ,  1.8929605 , -0.71543065,  1.01596569,
#                        -0.42010452]),
#                 array([ 0.06021393, -0.51164426,  1.91534212, -0.63593835,  1.0194359 ,
#                        -0.37342624]),
#                 array([ 0.05268719, -0.57858842,  1.93772375, -0.55644606,  1.02290611,
#                        -0.32674796]),
#                 array([ 0.04516045, -0.64553259,  1.96010537, -0.47695377,  1.02637631,
#                        -0.28006968]),
#                 array([ 0.03763371, -0.71247675,  1.98248699, -0.39746147,  1.02984652,
#                        -0.2333914 ]),
#                 array([ 0.03010697, -0.77942091,  2.00486861, -0.31796918,  1.03331673,
#                        -0.18671312]),
#                 array([ 0.02258022, -0.84636507,  2.02725024, -0.23847688,  1.03678693,
#                        -0.14003484]),
#                 array([ 0.01505348, -0.91330923,  2.04963186, -0.15898459,  1.04025714,
#                        -0.09335656]),
#                 array([ 0.00752674, -0.98025339,  2.07201348, -0.07949229,  1.04372734,
#                        -0.04667828]),
#                 array([ 0.        , -1.04719755,  2.0943951 ,  0.        ,  1.04719755,
#                         0.        ])])])]

# %%
pick_all_joint_path.append(pick_path)
pick_all_objects.append(pick_objects)
pick_all_object_poses.append(pick_object_poses)
fig, ax = p_utils.init_3d_figure(name="Level wise 2")

# %%
pick.simulate_path(
    pick_all_joint_path,
    pick_all_objects,
    pick_all_object_poses,
    is_save=True,
    video_name="benchmark2_pick_test"
    )
# Out:
# PWD :  /home/juju/pytamp/examples/doosan/action/rearrangement1
# Animation Finished..
# Save finished..

# %%
from pytamp.action.pick import PickAction
from pytamp.action.place import PlaceAction
from pytamp.benchmark import Benchmark2

benchmark2 = Benchmark2(
    robot_name="doosan", geom="visual", is_pyplot=True, bottle_num=1
)
pick = PickAction(
    benchmark2.scene_mngr, n_contacts=1, n_directions=10, retreat_distance=0.1
)
place = PlaceAction(
    benchmark2.scene_mngr, n_samples_held_obj=1, n_samples_support_obj=0
)
pick_actions = list(pick.get_possible_actions_level_1())

pnp_all_joint_path = []
pick_all_objects = []
place_all_object_poses = []

pnp_path = []
pick_objects = []
place_object_poses = []

success_joint_path = False
cnt = 0
for pick_action in pick_actions:
    for pick_scene in pick.get_possible_transitions(
        pick.scene_mngr.init_scene, action=pick_action
    ):
        pick_joint_path = pick.get_possible_joint_path_level_2(
            scene=pick_scene, grasp_poses=pick_scene.grasp_poses
        )
        if pick_joint_path:
            place_actions = list(place.get_possible_actions_level_1(pick_scene))
            for place_action in place_actions:
                for place_scene in place.get_possible_transitions(
                    scene=pick_scene, action=place_action
                ):
                    place_joint_path = place.get_possible_joint_path_level_2(
                        scene=place_scene,
                        release_poses=place_scene.release_poses,
                        init_thetas=pick_joint_path[-1][
                            place.move_data.MOVE_default_grasp
                        ][-1],
                    )
                    if place_joint_path:
                        success_joint_path = True
                        pnp_path += pick_joint_path + place_joint_path
                        pick_objects.append(pick_scene.robot.gripper.attached_obj_name)
                        place_object_poses.append(
                            place_scene.objs[place_scene.pick_obj_name].h_mat
                        )
                        break
                if success_joint_path:
                    break
        if success_joint_path:
            break
    if success_joint_path:
        break
pnp_all_joint_path.append(pnp_path)
pick_all_objects.append(pick_objects)
place_all_object_poses.append(place_object_poses)

place.simulate_path(pnp_all_joint_path, pick_all_objects, place_all_object_poses)
# Out:
# *********************** Logical States ***********************
# OrderedDict([('shelf_0', {'static': True}),
#              ('bin_0', {'static': True}),
#              ('shelf_1', {'static': True}),
#              ('bin_1', {'static': True}),
#              ('shelf_2', {'static': True}),
#              ('bin_2', {'static': True}),
#              ('shelf_3', {'static': True}),
#              ('bin_3', {'static': True}),
#              ('shelf_4', {'static': True}),
#              ('bin_4', {'static': True}),
#              ('shelf_5', {'static': True}),
#              ('bin_5', {'static': True}),
#              ('shelf_6', {'static': True}),
#              ('bin_6', {'static': True}),
#              ('shelf_7', {'static': True}),
#              ('bin_7', {'static': True}),
#              ('shelf_8', {'static': True}),
#              ('bin_8', {'static': True}),
#              ('shelf_9',
#               {'static': True,
#                'support': [Object(name=goal_bottle, pos=[1.04 0.   1.29])]}),
#              ('bin_9', {'static': True}),
#              ('shelf_10', {'static': True}),
#              ('bin_10', {'static': True}),
#              ('shelf_11', {'static': True}),
#              ('bin_11', {'static': True}),
#              ('shelf_12', {'static': True}),
#              ('bin_12', {'static': True}),
#              ('shelf_13', {'static': True}),
#              ('bin_13', {'static': True}),
#              ('shelf_14', {'static': True}),
#              ('bin_14', {'static': True}),
#              ('shelf_15', {'static': True}),
#              ('bin_15', {'static': True}),
#              ('shelf_16', {'static': True}),
#              ('bin_16', {'static': True}),
#              ('shelf_17', {'static': True}),
#              ('bin_17', {'static': True}),
#              ('shelf_18', {'static': True}),
#              ('bin_18', {'static': True}),
#              ('shelf_19', {'static': True}),
#              ('bin_19', {'static': True}),
#              ('goal_bottle',
#               {'on': Object(name=shelf_9, pos=[0.9        0.         1.41725156])}),
#              ('robotiq140_gripper', {'holding': None})])
# ***************************************************************
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# [INFO] [RRT Star Planner]: The joint limit has been successfully checked. Pose error is 0.000002
# [WARNING] [RRT Star Planner]: Occur Collision for goal joints
# solve the problem using LM2!!
# Iterators : 10
# WorkingTime[inverse_kinematics]: 0.0142 sec
#
# {('link4', 'shelf_12'), ('link5', 'shelf_7'), ('link5', 'shelf_12'), ('link4', 'shelf_7')}
# *********************** Scene ***********************
# {'bin_0': Object(name=bin_0, pos=[0.        1.        0.3864222]),
#  'bin_1': Object(name=bin_1, pos=[0.        1.        0.3864222]),
#  'bin_10': Object(name=bin_10, pos=[0.        1.        0.3864222]),
#  'bin_11': Object(name=bin_11, pos=[0.        1.        0.3864222]),
#  'bin_12': Object(name=bin_12, pos=[0.        1.        0.3864222]),
#  'bin_13': Object(name=bin_13, pos=[0.        1.        0.3864222]),
#  'bin_14': Object(name=bin_14, pos=[0.        1.        0.3864222]),
#  'bin_15': Object(name=bin_15, pos=[0.        1.        0.3864222]),
#  'bin_16': Object(name=bin_16, pos=[0.        1.        0.3864222]),
#  'bin_17': Object(name=bin_17, pos=[0.        1.        0.3864222]),
#  'bin_18': Object(name=bin_18, pos=[0.        1.        0.3864222]),
#  'bin_19': Object(name=bin_19, pos=[0.        1.        0.3864222]),
#  'bin_2': Object(name=bin_2, pos=[0.        1.        0.3864222]),
#  'bin_3': Object(name=bin_3, pos=[0.        1.        0.3864222]),
#  'bin_4': Object(name=bin_4, pos=[0.        1.        0.3864222]),
#  'bin_5': Object(name=bin_5, pos=[0.        1.        0.3864222]),
#  'bin_6': Object(name=bin_6, pos=[0.        1.        0.3864222]),
#  'bin_7': Object(name=bin_7, pos=[0.        1.        0.3864222]),
#  'bin_8': Object(name=bin_8, pos=[0.        1.        0.3864222]),
#  'bin_9': Object(name=bin_9, pos=[0.        1.        0.3864222]),
#  'goal_bottle': Object(name=goal_bottle, pos=[1.04 0.   1.29]),
#  'shelf_0': Object(name=shelf_0, pos=[0.9        0.         1.41725156]),
#  'shelf_1': Object(name=shelf_1, pos=[0.9        0.         1.41725156]),
#  'shelf_10': Object(name=shelf_10, pos=[0.9        0.         1.41725156]),
#  'shelf_11': Object(name=shelf_11, pos=[0.9        0.         1.41725156]),
#  'shelf_12': Object(name=shelf_12, pos=[0.9        0.         1.41725156]),
#  'shelf_13': Object(name=shelf_13, pos=[0.9        0.         1.41725156]),
#  'shelf_14': Object(name=shelf_14, pos=[0.9        0.         1.41725156]),
#  'shelf_15': Object(name=shelf_15, pos=[0.9        0.         1.41725156]),
#  'shelf_16': Object(name=shelf_16, pos=[0.9        0.         1.41725156]),
#  'shelf_17': Object(name=shelf_17, pos=[0.9        0.         1.41725156]),
#  'shelf_18': Object(name=shelf_18, pos=[0.9        0.         1.41725156]),
#  'shelf_19': Object(name=shelf_19, pos=[0.9        0.         1.41725156]),
#  'shelf_2': Object(name=shelf_2, pos=[0.9        0.         1.41725156]),
#  'shelf_3': Object(name=shelf_3, pos=[0.9        0.         1.41725156]),
#  'shelf_4': Object(name=shelf_4, pos=[0.9        0.         1.41725156]),
#  'shelf_5': Object(name=shelf_5, pos=[0.9        0.         1.41725156]),
#  'shelf_6': Object(name=shelf_6, pos=[0.9        0.         1.41725156]),
#  'shelf_7': Object(name=shelf_7, pos=[0.9        0.         1.41725156]),
#  'shelf_8': Object(name=shelf_8, pos=[0.9        0.         1.41725156]),
#  'shelf_9': Object(name=shelf_9, pos=[0.9        0.         1.41725156])}
# doosan Transform(pos=[0.3   0.    0.913], rot=[1. 0. 0. 0.])
# robotiq140_gripper [[ 9.05206831e-08 -9.54287018e-01  2.98891765e-01  9.61459827e-01]
#  [-3.35768892e-01  2.81539395e-01  8.98885321e-01 -2.41946361e-01]
#  [-9.41944399e-01 -1.00358638e-01 -3.20419870e-01  1.39096943e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# ***************************************************************
#
# ******************** Robot Collision Info ********************
# base_0 [0.3   0.    0.913]
# doosan_pedestal [ 0.56     0.345   -0.00188]
# link1 [0.3   0.    1.108]
# link2 [0.32102362 0.03284825 1.108     ]
# link3 [ 0.51895247 -0.09376457  1.61632407]
# link4 [ 0.92438495 -0.3534118   1.43067974]
# link5 [ 0.92438495 -0.3534118   1.43067974]
# link6 [ 0.96145983 -0.24194636  1.39096943]
# right_gripper [ 0.96116841 -0.24282277  1.39128184]
# left_outer_knuckle [ 1.0067812  -0.20207665  1.37678331]
# left_outer_finger [ 1.03580634 -0.21418976  1.38112799]
# left_inner_finger [ 1.12029444 -0.16378266  1.36321463]
# left_inner_finger_pad [ 1.1079943  -0.11499754  1.34580141]
# right_outer_knuckle [ 0.94837692 -0.18486231  1.37059506]
# right_outer_finger [ 0.91719675 -0.17923024  1.36856061]
# right_inner_finger [ 0.8783212  -0.09246244  1.33757606]
# right_inner_finger_pad [ 0.91797314 -0.0589899   1.32566744]
# right_inner_knuckle [ 0.96740689 -0.1840411   1.37031753]
# left_inner_knuckle [ 0.99164578 -0.19118538  1.37288577]
# ***************************************************************
#
# ******************** Object Collision Info ********************
# shelf_0 [0.9        0.         1.41725156]
# shelf_1 [0.9        0.         1.41725156]
# shelf_2 [0.9        0.         1.41725156]
# shelf_3 [0.9        0.         1.41725156]
# shelf_4 [0.9        0.         1.41725156]
# shelf_5 [0.9        0.         1.41725156]
# shelf_6 [0.9        0.         1.41725156]
# shelf_7 [0.9        0.         1.41725156]
# shelf_8 [0.9        0.         1.41725156]
# shelf_9 [0.9        0.         1.41725156]
# shelf_10 [0.9        0.         1.41725156]
# shelf_11 [0.9        0.         1.41725156]
# shelf_12 [0.9        0.         1.41725156]
# shelf_13 [0.9        0.         1.41725156]
# shelf_14 [0.9        0.         1.41725156]
# shelf_15 [0.9        0.         1.41725156]
# shelf_16 [0.9        0.         1.41725156]
# shelf_17 [0.9        0.         1.41725156]
# shelf_18 [0.9        0.         1.41725156]
# shelf_19 [0.9        0.         1.41725156]
# bin_0 [0.        1.        0.3864222]
# bin_1 [0.        1.        0.3864222]
# bin_2 [0.        1.        0.3864222]
# bin_3 [0.        1.        0.3864222]
# bin_4 [0.        1.        0.3864222]
# bin_5 [0.        1.        0.3864222]
# bin_6 [0.        1.        0.3864222]
# bin_7 [0.        1.        0.3864222]
# bin_8 [0.        1.        0.3864222]
# bin_9 [0.        1.        0.3864222]
# bin_10 [0.        1.        0.3864222]
# bin_11 [0.        1.        0.3864222]
# bin_12 [0.        1.        0.3864222]
# bin_13 [0.        1.        0.3864222]
# bin_14 [0.        1.        0.3864222]
# bin_15 [0.        1.        0.3864222]
# bin_16 [0.        1.        0.3864222]
# bin_17 [0.        1.        0.3864222]
# bin_18 [0.        1.        0.3864222]
# bin_19 [0.        1.        0.3864222]
# goal_bottle [1.04 0.   1.29]
# ***************************************************************
# [INFO] [RRT Star Planner]: The joint limit has been successfully checked. Pose error is 0.000000
# [WARNING] [RRT Star Planner]: Occur Collision for goal joints
# solve the problem using LM2!!
# Iterators : 10
# WorkingTime[inverse_kinematics]: 0.0417 sec
#
# {('link4', 'shelf_12'), ('link5', 'shelf_12')}
# *********************** Scene ***********************
# {'bin_0': Object(name=bin_0, pos=[0.        1.        0.3864222]),
#  'bin_1': Object(name=bin_1, pos=[0.        1.        0.3864222]),
#  'bin_10': Object(name=bin_10, pos=[0.        1.        0.3864222]),
#  'bin_11': Object(name=bin_11, pos=[0.        1.        0.3864222]),
#  'bin_12': Object(name=bin_12, pos=[0.        1.        0.3864222]),
#  'bin_13': Object(name=bin_13, pos=[0.        1.        0.3864222]),
#  'bin_14': Object(name=bin_14, pos=[0.        1.        0.3864222]),
#  'bin_15': Object(name=bin_15, pos=[0.        1.        0.3864222]),
#  'bin_16': Object(name=bin_16, pos=[0.        1.        0.3864222]),
#  'bin_17': Object(name=bin_17, pos=[0.        1.        0.3864222]),
#  'bin_18': Object(name=bin_18, pos=[0.        1.        0.3864222]),
#  'bin_19': Object(name=bin_19, pos=[0.        1.        0.3864222]),
#  'bin_2': Object(name=bin_2, pos=[0.        1.        0.3864222]),
#  'bin_3': Object(name=bin_3, pos=[0.        1.        0.3864222]),
#  'bin_4': Object(name=bin_4, pos=[0.        1.        0.3864222]),
#  'bin_5': Object(name=bin_5, pos=[0.        1.        0.3864222]),
#  'bin_6': Object(name=bin_6, pos=[0.        1.        0.3864222]),
#  'bin_7': Object(name=bin_7, pos=[0.        1.        0.3864222]),
#  'bin_8': Object(name=bin_8, pos=[0.        1.        0.3864222]),
#  'bin_9': Object(name=bin_9, pos=[0.        1.        0.3864222]),
#  'goal_bottle': Object(name=goal_bottle, pos=[1.04 0.   1.29]),
#  'shelf_0': Object(name=shelf_0, pos=[0.9        0.         1.41725156]),
#  'shelf_1': Object(name=shelf_1, pos=[0.9        0.         1.41725156]),
#  'shelf_10': Object(name=shelf_10, pos=[0.9        0.         1.41725156]),
#  'shelf_11': Object(name=shelf_11, pos=[0.9        0.         1.41725156]),
#  'shelf_12': Object(name=shelf_12, pos=[0.9        0.         1.41725156]),
#  'shelf_13': Object(name=shelf_13, pos=[0.9        0.         1.41725156]),
#  'shelf_14': Object(name=shelf_14, pos=[0.9        0.         1.41725156]),
#  'shelf_15': Object(name=shelf_15, pos=[0.9        0.         1.41725156]),
#  'shelf_16': Object(name=shelf_16, pos=[0.9        0.         1.41725156]),
#  'shelf_17': Object(name=shelf_17, pos=[0.9        0.         1.41725156]),
#  'shelf_18': Object(name=shelf_18, pos=[0.9        0.         1.41725156]),
#  'shelf_19': Object(name=shelf_19, pos=[0.9        0.         1.41725156]),
#  'shelf_2': Object(name=shelf_2, pos=[0.9        0.         1.41725156]),
#  'shelf_3': Object(name=shelf_3, pos=[0.9        0.         1.41725156]),
#  'shelf_4': Object(name=shelf_4, pos=[0.9        0.         1.41725156]),
#  'shelf_5': Object(name=shelf_5, pos=[0.9        0.         1.41725156]),
#  'shelf_6': Object(name=shelf_6, pos=[0.9        0.         1.41725156]),
#  'shelf_7': Object(name=shelf_7, pos=[0.9        0.         1.41725156]),
#  'shelf_8': Object(name=shelf_8, pos=[0.9        0.         1.41725156]),
#  'shelf_9': Object(name=shelf_9, pos=[0.9        0.         1.41725156])}
# doosan Transform(pos=[0.3   0.    0.913], rot=[1. 0. 0. 0.])
# robotiq140_gripper [[-5.27654875e-09 -9.54287373e-01  2.98890631e-01  9.61460167e-01]
#  [-3.35768680e-01  2.81538380e-01  8.98885718e-01 -2.41946546e-01]
#  [-9.41944475e-01 -1.00358108e-01 -3.20419813e-01  1.39096948e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# ***************************************************************
#
# ******************** Robot Collision Info ********************
# base_0 [0.3   0.    0.913]
# doosan_pedestal [ 0.56     0.345   -0.00188]
# link1 [0.3   0.    1.108]
# link2 [0.32102273 0.03284882 1.108     ]
# link3 [ 0.51895615 -0.09375934  1.61632345]
# link4 [ 0.92441004 -0.35340471  1.43072329]
# link5 [ 0.92441004 -0.35340471  1.43072329]
# link6 [ 0.96146017 -0.24194655  1.39096948]
# right_gripper [ 0.96116875 -0.24282296  1.39128189]
# left_outer_knuckle [ 1.00678149 -0.20207678  1.37678335]
# left_outer_finger [ 1.03580664 -0.21418986  1.38112801]
# left_inner_finger [ 1.12029468 -0.16378266  1.36321462]
# left_inner_finger_pad [ 1.10799448 -0.11499755  1.34580142]
# right_outer_knuckle [ 0.94837719 -0.1848625   1.37059513]
# right_outer_finger [ 0.91719701 -0.17923047  1.3685607 ]
# right_inner_finger [ 0.87832136 -0.0924627   1.33757618]
# right_inner_finger_pad [ 0.91797325 -0.05899012  1.32566756]
# right_inner_knuckle [ 0.96740716 -0.18404127  1.37031759]
# left_inner_knuckle [ 0.99164606 -0.19118553  1.37288582]
# ***************************************************************
#
# ******************** Object Collision Info ********************
# shelf_0 [0.9        0.         1.41725156]
# shelf_1 [0.9        0.         1.41725156]
# shelf_2 [0.9        0.         1.41725156]
# shelf_3 [0.9        0.         1.41725156]
# shelf_4 [0.9        0.         1.41725156]
# shelf_5 [0.9        0.         1.41725156]
# shelf_6 [0.9        0.         1.41725156]
# shelf_7 [0.9        0.         1.41725156]
# shelf_8 [0.9        0.         1.41725156]
# shelf_9 [0.9        0.         1.41725156]
# shelf_10 [0.9        0.         1.41725156]
# shelf_11 [0.9        0.         1.41725156]
# shelf_12 [0.9        0.         1.41725156]
# shelf_13 [0.9        0.         1.41725156]
# shelf_14 [0.9        0.         1.41725156]
# shelf_15 [0.9        0.         1.41725156]
# shelf_16 [0.9        0.         1.41725156]
# shelf_17 [0.9        0.         1.41725156]
# shelf_18 [0.9        0.         1.41725156]
# shelf_19 [0.9        0.         1.41725156]
# bin_0 [0.        1.        0.3864222]
# bin_1 [0.        1.        0.3864222]
# bin_2 [0.        1.        0.3864222]
# bin_3 [0.        1.        0.3864222]
# bin_4 [0.        1.        0.3864222]
# bin_5 [0.        1.        0.3864222]
# bin_6 [0.        1.        0.3864222]
# bin_7 [0.        1.        0.3864222]
# bin_8 [0.        1.        0.3864222]
# bin_9 [0.        1.        0.3864222]
# bin_10 [0.        1.        0.3864222]
# bin_11 [0.        1.        0.3864222]
# bin_12 [0.        1.        0.3864222]
# bin_13 [0.        1.        0.3864222]
# bin_14 [0.        1.        0.3864222]
# bin_15 [0.        1.        0.3864222]
# bin_16 [0.        1.        0.3864222]
# bin_17 [0.        1.        0.3864222]
# bin_18 [0.        1.        0.3864222]
# bin_19 [0.        1.        0.3864222]
# goal_bottle [1.04 0.   1.29]
# ***************************************************************
# [INFO] [RRT Star Planner]: The joint limit has been successfully checked. Pose error is 0.000000
# [WARNING] [RRT Star Planner]: Occur Collision for goal joints
# solve the problem using LM2!!
# Iterators : 9
# WorkingTime[inverse_kinematics]: 0.0100 sec
#
# {('link4', 'shelf_12'), ('link5', 'shelf_12')}
# *********************** Scene ***********************
# {'bin_0': Object(name=bin_0, pos=[0.        1.        0.3864222]),
#  'bin_1': Object(name=bin_1, pos=[0.        1.        0.3864222]),
#  'bin_10': Object(name=bin_10, pos=[0.        1.        0.3864222]),
#  'bin_11': Object(name=bin_11, pos=[0.        1.        0.3864222]),
#  'bin_12': Object(name=bin_12, pos=[0.        1.        0.3864222]),
#  'bin_13': Object(name=bin_13, pos=[0.        1.        0.3864222]),
#  'bin_14': Object(name=bin_14, pos=[0.        1.        0.3864222]),
#  'bin_15': Object(name=bin_15, pos=[0.        1.        0.3864222]),
#  'bin_16': Object(name=bin_16, pos=[0.        1.        0.3864222]),
#  'bin_17': Object(name=bin_17, pos=[0.        1.        0.3864222]),
#  'bin_18': Object(name=bin_18, pos=[0.        1.        0.3864222]),
#  'bin_19': Object(name=bin_19, pos=[0.        1.        0.3864222]),
#  'bin_2': Object(name=bin_2, pos=[0.        1.        0.3864222]),
#  'bin_3': Object(name=bin_3, pos=[0.        1.        0.3864222]),
#  'bin_4': Object(name=bin_4, pos=[0.        1.        0.3864222]),
#  'bin_5': Object(name=bin_5, pos=[0.        1.        0.3864222]),
#  'bin_6': Object(name=bin_6, pos=[0.        1.        0.3864222]),
#  'bin_7': Object(name=bin_7, pos=[0.        1.        0.3864222]),
#  'bin_8': Object(name=bin_8, pos=[0.        1.        0.3864222]),
#  'bin_9': Object(name=bin_9, pos=[0.        1.        0.3864222]),
#  'goal_bottle': Object(name=goal_bottle, pos=[1.04 0.   1.29]),
#  'shelf_0': Object(name=shelf_0, pos=[0.9        0.         1.41725156]),
#  'shelf_1': Object(name=shelf_1, pos=[0.9        0.         1.41725156]),
#  'shelf_10': Object(name=shelf_10, pos=[0.9        0.         1.41725156]),
#  'shelf_11': Object(name=shelf_11, pos=[0.9        0.         1.41725156]),
#  'shelf_12': Object(name=shelf_12, pos=[0.9        0.         1.41725156]),
#  'shelf_13': Object(name=shelf_13, pos=[0.9        0.         1.41725156]),
#  'shelf_14': Object(name=shelf_14, pos=[0.9        0.         1.41725156]),
#  'shelf_15': Object(name=shelf_15, pos=[0.9        0.         1.41725156]),
#  'shelf_16': Object(name=shelf_16, pos=[0.9        0.         1.41725156]),
#  'shelf_17': Object(name=shelf_17, pos=[0.9        0.         1.41725156]),
#  'shelf_18': Object(name=shelf_18, pos=[0.9        0.         1.41725156]),
#  'shelf_19': Object(name=shelf_19, pos=[0.9        0.         1.41725156]),
#  'shelf_2': Object(name=shelf_2, pos=[0.9        0.         1.41725156]),
#  'shelf_3': Object(name=shelf_3, pos=[0.9        0.         1.41725156]),
#  'shelf_4': Object(name=shelf_4, pos=[0.9        0.         1.41725156]),
#  'shelf_5': Object(name=shelf_5, pos=[0.9        0.         1.41725156]),
#  'shelf_6': Object(name=shelf_6, pos=[0.9        0.         1.41725156]),
#  'shelf_7': Object(name=shelf_7, pos=[0.9        0.         1.41725156]),
#  'shelf_8': Object(name=shelf_8, pos=[0.9        0.         1.41725156]),
#  'shelf_9': Object(name=shelf_9, pos=[0.9        0.         1.41725156])}
# doosan Transform(pos=[0.3   0.    0.913], rot=[1. 0. 0. 0.])
# robotiq140_gripper [[ 2.19219126e-09 -9.54287364e-01  2.98890661e-01  9.61460158e-01]
#  [-3.35768681e-01  2.81538406e-01  8.98885710e-01 -2.41946541e-01]
#  [-9.41944475e-01 -1.00358125e-01 -3.20419809e-01  1.39096948e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# ***************************************************************
#
# ******************** Robot Collision Info ********************
# base_0 [0.3   0.    0.913]
# doosan_pedestal [ 0.56     0.345   -0.00188]
# link1 [0.3   0.    1.108]
# link2 [0.32102273 0.03284882 1.108     ]
# link3 [ 0.51895614 -0.09375933  1.61632346]
# link4 [ 0.92441003 -0.35340471  1.43072328]
# link5 [ 0.92441003 -0.35340471  1.43072328]
# link6 [ 0.96146016 -0.24194654  1.39096948]
# right_gripper [ 0.96116874 -0.24282295  1.39128189]
# left_outer_knuckle [ 1.00678148 -0.20207677  1.37678335]
# left_outer_finger [ 1.03580664 -0.21418985  1.38112801]
# left_inner_finger [ 1.12029467 -0.16378266  1.36321462]
# left_inner_finger_pad [ 1.10799448 -0.11499755  1.34580142]
# right_outer_knuckle [ 0.94837718 -0.1848625   1.37059513]
# right_outer_finger [ 0.917197   -0.17923046  1.3685607 ]
# right_inner_finger [ 0.87832135 -0.09246269  1.33757618]
# right_inner_finger_pad [ 0.91797324 -0.05899011  1.32566756]
# right_inner_knuckle [ 0.96740715 -0.18404127  1.37031759]
# left_inner_knuckle [ 0.99164605 -0.19118552  1.37288582]
# ***************************************************************
#
# ******************** Object Collision Info ********************
# shelf_0 [0.9        0.         1.41725156]
# shelf_1 [0.9        0.         1.41725156]
# shelf_2 [0.9        0.         1.41725156]
# shelf_3 [0.9        0.         1.41725156]
# shelf_4 [0.9        0.         1.41725156]
# shelf_5 [0.9        0.         1.41725156]
# shelf_6 [0.9        0.         1.41725156]
# shelf_7 [0.9        0.         1.41725156]
# shelf_8 [0.9        0.         1.41725156]
# shelf_9 [0.9        0.         1.41725156]
# shelf_10 [0.9        0.         1.41725156]
# shelf_11 [0.9        0.         1.41725156]
# shelf_12 [0.9        0.         1.41725156]
# shelf_13 [0.9        0.         1.41725156]
# shelf_14 [0.9        0.         1.41725156]
# shelf_15 [0.9        0.         1.41725156]
# shelf_16 [0.9        0.         1.41725156]
# shelf_17 [0.9        0.         1.41725156]
# shelf_18 [0.9        0.         1.41725156]
# shelf_19 [0.9        0.         1.41725156]
# bin_0 [0.        1.        0.3864222]
# bin_1 [0.        1.        0.3864222]
# bin_2 [0.        1.        0.3864222]
# bin_3 [0.        1.        0.3864222]
# bin_4 [0.        1.        0.3864222]
# bin_5 [0.        1.        0.3864222]
# bin_6 [0.        1.        0.3864222]
# bin_7 [0.        1.        0.3864222]
# bin_8 [0.        1.        0.3864222]
# bin_9 [0.        1.        0.3864222]
# bin_10 [0.        1.        0.3864222]
# bin_11 [0.        1.        0.3864222]
# bin_12 [0.        1.        0.3864222]
# bin_13 [0.        1.        0.3864222]
# bin_14 [0.        1.        0.3864222]
# bin_15 [0.        1.        0.3864222]
# bin_16 [0.        1.        0.3864222]
# bin_17 [0.        1.        0.3864222]
# bin_18 [0.        1.        0.3864222]
# bin_19 [0.        1.        0.3864222]
# goal_bottle [1.04 0.   1.29]
# ***************************************************************
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/IPython/core/formatters.py:338, in BaseFormatter.__call__(self, obj)
#     336     pass
#     337 else:
# --> 338     return printer(obj)
#     339 # Finally look for special method names
#     340 method = get_real_method(obj, self.print_method)
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/matplotlib/backend_bases.py:2295, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2289     renderer = _get_renderer(
#    2290         self.figure,
#    2291         functools.partial(
#    2292             print_method, orientation=orientation)
#    2293     )
#    2294     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2295         self.figure.draw(renderer)
#    2297 if bbox_inches:
#    2298     if bbox_inches == "tight":
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/matplotlib/artist.py:73, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      71 @wraps(draw)
#      72 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73     result = draw(artist, renderer, *args, **kwargs)
#      74     if renderer._rasterizing:
#      75         renderer.stop_rasterizing()
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/matplotlib/figure.py:2837, in Figure.draw(self, renderer)
#    2834         # ValueError can occur when resizing a window.
#    2836 self.patch.draw(renderer)
# -> 2837 mimage._draw_list_compositing_images(
#    2838     renderer, self, artists, self.suppressComposite)
#    2840 for sfig in self.subfigs:
#    2841     sfig.draw(renderer)
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/mpl_toolkits/mplot3d/axes3d.py:451, in Axes3D.draw(self, renderer)
#     448 zorder_offset = max(axis.get_zorder()
#     449                     for axis in self._get_axis_list()) + 1
#     450 collection_zorder = patch_zorder = zorder_offset
# --> 451 for artist in sorted(collections_and_patches,
#     452                      key=do_3d_projection,
#     453                      reverse=True):
#     454     if isinstance(artist, mcoll.Collection):
#     455         artist.zorder = collection_zorder
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/mpl_toolkits/mplot3d/axes3d.py:440, in Axes3D.draw.<locals>.do_3d_projection(artist)
#     437     return artist.do_3d_projection(renderer)
#     438 else:
#     439     # Call this directly once the deprecation period expires.
# --> 440     return artist.do_3d_projection()
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/matplotlib/_api/deprecation.py:389, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     384 @functools.wraps(func)
#     385 def wrapper(*inner_args, **inner_kwargs):
#     386     if len(inner_args) <= name_idx and name not in inner_kwargs:
#     387         # Early return in the simple, non-deprecated case (much faster than
#     388         # calling bind()).
# --> 389         return func(*inner_args, **inner_kwargs)
#     390     arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     391     if is_varargs and arguments.get(name):
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/mpl_toolkits/mplot3d/art3d.py:841, in Poly3DCollection.do_3d_projection(self, renderer)
#     839     PolyCollection.set_verts_and_codes(self, segments_2d, codes)
#     840 else:
# --> 841     PolyCollection.set_verts(self, segments_2d, self._closed)
#     843 if len(self._edgecolor3d) != len(cface):
#     844     self._edgecolors2d = self._edgecolor3d
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/matplotlib/collections.py:1232, in PolyCollection.set_verts(self, verts, closed)
#    1230         xy = np.ma.concatenate([xy, xy[:1]])
#    1231     else:
# -> 1232         xy = np.concatenate([xy, xy[:1]])
#    1233     self._paths.append(mpath.Path(xy, closed=True))
#    1234 else:
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/pykin/robots/robot.py:8, in handler(signum, frame)
#       7 def handler(signum, frame):
# ----> 8     exit()
#
# NameError: name 'exit' is not defined
# [INFO] [RRT Star Planner]: The joint limit has been successfully checked. Pose error is 0.000000
# [WARNING] [RRT Star Planner]: Occur Collision for goal joints
# solve the problem using LM2!!
# Iterators : 13
# WorkingTime[inverse_kinematics]: 0.0165 sec
#
# {('link4', 'shelf_12'), ('link5', 'shelf_7'), ('link5', 'shelf_12'), ('link4', 'shelf_7')}
# *********************** Scene ***********************
# {'bin_0': Object(name=bin_0, pos=[0.        1.        0.3864222]),
#  'bin_1': Object(name=bin_1, pos=[0.        1.        0.3864222]),
#  'bin_10': Object(name=bin_10, pos=[0.        1.        0.3864222]),
#  'bin_11': Object(name=bin_11, pos=[0.        1.        0.3864222]),
#  'bin_12': Object(name=bin_12, pos=[0.        1.        0.3864222]),
#  'bin_13': Object(name=bin_13, pos=[0.        1.        0.3864222]),
#  'bin_14': Object(name=bin_14, pos=[0.        1.        0.3864222]),
#  'bin_15': Object(name=bin_15, pos=[0.        1.        0.3864222]),
#  'bin_16': Object(name=bin_16, pos=[0.        1.        0.3864222]),
#  'bin_17': Object(name=bin_17, pos=[0.        1.        0.3864222]),
#  'bin_18': Object(name=bin_18, pos=[0.        1.        0.3864222]),
#  'bin_19': Object(name=bin_19, pos=[0.        1.        0.3864222]),
#  'bin_2': Object(name=bin_2, pos=[0.        1.        0.3864222]),
#  'bin_3': Object(name=bin_3, pos=[0.        1.        0.3864222]),
#  'bin_4': Object(name=bin_4, pos=[0.        1.        0.3864222]),
#  'bin_5': Object(name=bin_5, pos=[0.        1.        0.3864222]),
#  'bin_6': Object(name=bin_6, pos=[0.        1.        0.3864222]),
#  'bin_7': Object(name=bin_7, pos=[0.        1.        0.3864222]),
#  'bin_8': Object(name=bin_8, pos=[0.        1.        0.3864222]),
#  'bin_9': Object(name=bin_9, pos=[0.        1.        0.3864222]),
#  'goal_bottle': Object(name=goal_bottle, pos=[1.04 0.   1.29]),
#  'shelf_0': Object(name=shelf_0, pos=[0.9        0.         1.41725156]),
#  'shelf_1': Object(name=shelf_1, pos=[0.9        0.         1.41725156]),
#  'shelf_10': Object(name=shelf_10, pos=[0.9        0.         1.41725156]),
#  'shelf_11': Object(name=shelf_11, pos=[0.9        0.         1.41725156]),
#  'shelf_12': Object(name=shelf_12, pos=[0.9        0.         1.41725156]),
#  'shelf_13': Object(name=shelf_13, pos=[0.9        0.         1.41725156]),
#  'shelf_14': Object(name=shelf_14, pos=[0.9        0.         1.41725156]),
#  'shelf_15': Object(name=shelf_15, pos=[0.9        0.         1.41725156]),
#  'shelf_16': Object(name=shelf_16, pos=[0.9        0.         1.41725156]),
#  'shelf_17': Object(name=shelf_17, pos=[0.9        0.         1.41725156]),
#  'shelf_18': Object(name=shelf_18, pos=[0.9        0.         1.41725156]),
#  'shelf_19': Object(name=shelf_19, pos=[0.9        0.         1.41725156]),
#  'shelf_2': Object(name=shelf_2, pos=[0.9        0.         1.41725156]),
#  'shelf_3': Object(name=shelf_3, pos=[0.9        0.         1.41725156]),
#  'shelf_4': Object(name=shelf_4, pos=[0.9        0.         1.41725156]),
#  'shelf_5': Object(name=shelf_5, pos=[0.9        0.         1.41725156]),
#  'shelf_6': Object(name=shelf_6, pos=[0.9        0.         1.41725156]),
#  'shelf_7': Object(name=shelf_7, pos=[0.9        0.         1.41725156]),
#  'shelf_8': Object(name=shelf_8, pos=[0.9        0.         1.41725156]),
#  'shelf_9': Object(name=shelf_9, pos=[0.9        0.         1.41725156])}
# doosan Transform(pos=[0.3   0.    0.913], rot=[1. 0. 0. 0.])
# robotiq140_gripper [[ 1.59446764e-09 -9.54287369e-01  2.98890646e-01  9.61460162e-01]
#  [-3.35768678e-01  2.81538392e-01  8.98885715e-01 -2.41946543e-01]
#  [-9.41944476e-01 -1.00358118e-01 -3.20419807e-01  1.39096948e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# ***************************************************************
#
# ******************** Robot Collision Info ********************
# base_0 [0.3   0.    0.913]
# doosan_pedestal [ 0.56     0.345   -0.00188]
# link1 [0.3   0.    1.108]
# link2 [0.32102362 0.03284825 1.108     ]
# link3 [ 0.51895284 -0.09376478  1.61632387]
# link4 [ 0.92438542 -0.35341203  1.43067979]
# link5 [ 0.92438542 -0.35341203  1.43067979]
# link6 [ 0.96146016 -0.24194654  1.39096948]
# right_gripper [ 0.96116874 -0.24282296  1.39128189]
# left_outer_knuckle [ 1.00678148 -0.20207678  1.37678335]
# left_outer_finger [ 1.03580664 -0.21418985  1.38112801]
# left_inner_finger [ 1.12029467 -0.16378266  1.36321462]
# left_inner_finger_pad [ 1.10799448 -0.11499755  1.34580142]
# right_outer_knuckle [ 0.94837719 -0.1848625   1.37059513]
# right_outer_finger [ 0.917197   -0.17923047  1.3685607 ]
# right_inner_finger [ 0.87832135 -0.0924627   1.33757618]
# right_inner_finger_pad [ 0.91797324 -0.05899012  1.32566756]
# right_inner_knuckle [ 0.96740716 -0.18404127  1.37031759]
# left_inner_knuckle [ 0.99164606 -0.19118552  1.37288582]
# ***************************************************************
#
# ******************** Object Collision Info ********************
# shelf_0 [0.9        0.         1.41725156]
# shelf_1 [0.9        0.         1.41725156]
# shelf_2 [0.9        0.         1.41725156]
# shelf_3 [0.9        0.         1.41725156]
# shelf_4 [0.9        0.         1.41725156]
# shelf_5 [0.9        0.         1.41725156]
# shelf_6 [0.9        0.         1.41725156]
# shelf_7 [0.9        0.         1.41725156]
# shelf_8 [0.9        0.         1.41725156]
# shelf_9 [0.9        0.         1.41725156]
# shelf_10 [0.9        0.         1.41725156]
# shelf_11 [0.9        0.         1.41725156]
# shelf_12 [0.9        0.         1.41725156]
# shelf_13 [0.9        0.         1.41725156]
# shelf_14 [0.9        0.         1.41725156]
# shelf_15 [0.9        0.         1.41725156]
# shelf_16 [0.9        0.         1.41725156]
# shelf_17 [0.9        0.         1.41725156]
# shelf_18 [0.9        0.         1.41725156]
# shelf_19 [0.9        0.         1.41725156]
# bin_0 [0.        1.        0.3864222]
# bin_1 [0.        1.        0.3864222]
# bin_2 [0.        1.        0.3864222]
# bin_3 [0.        1.        0.3864222]
# bin_4 [0.        1.        0.3864222]
# bin_5 [0.        1.        0.3864222]
# bin_6 [0.        1.        0.3864222]
# bin_7 [0.        1.        0.3864222]
# bin_8 [0.        1.        0.3864222]
# bin_9 [0.        1.        0.3864222]
# bin_10 [0.        1.        0.3864222]
# bin_11 [0.        1.        0.3864222]
# bin_12 [0.        1.        0.3864222]
# bin_13 [0.        1.        0.3864222]
# bin_14 [0.        1.        0.3864222]
# bin_15 [0.        1.        0.3864222]
# bin_16 [0.        1.        0.3864222]
# bin_17 [0.        1.        0.3864222]
# bin_18 [0.        1.        0.3864222]
# bin_19 [0.        1.        0.3864222]
# goal_bottle [1.04 0.   1.29]
# ***************************************************************
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 30
#      26 for pick_action in pick_actions:
#      27     for pick_scene in pick.get_possible_transitions(
#      28         pick.scene_mngr.init_scene, action=pick_action
#      29     ):
# ---> 30         pick_joint_path = pick.get_possible_joint_path_level_2(
#      31             scene=pick_scene, grasp_poses=pick_scene.grasp_poses
#      32         )
#      33         if pick_joint_path:
#      34             place_actions = list(place.get_possible_actions_level_1(pick_scene))
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/pytamp/action/pick.py:155, in PickAction.get_possible_joint_path_level_2(self, scene, grasp_poses, init_thetas)
#     152 success_joint_path = True
#     154 # default pose -> pre_grasp_pose (rrt)
# --> 155 pre_grasp_joint_path = self.get_rrt_star_path(default_thetas, pre_grasp_pose)
#     156 self.cost = 0
#     157 if pre_grasp_joint_path:
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/pytamp/action/activity.py:117, in ActivityBase.get_rrt_star_path(self, cur_q, goal_pose, goal_q, max_iter, n_step)
#     116 def get_rrt_star_path(self, cur_q, goal_pose=None, goal_q=None, max_iter=500, n_step=10):
# --> 117     self.rrt_planner.run(self.scene_mngr, cur_q, goal_pose, goal_q=goal_q, max_iter=max_iter)
#     118     return self.rrt_planner.get_joint_path(n_step=n_step)
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/pykin/utils/kin_utils.py:76, in logging_time.<locals>.wrapper_fn(*args, **kwargs)
#      74 def wrapper_fn(*args, **kwargs):
#      75     start_time = time.time()
# ---> 76     result = original_fn(*args, **kwargs)
#      77     end_time = time.time()
#      78     print(f"WorkingTime[{original_fn.__name__}]: {end_time-start_time:.4f} sec\n")
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/pytamp/planners/rrt_star_planner.py:130, in RRTStarPlanner.run(self, scene_mngr, cur_q, goal_pose, goal_q, max_iter)
#     128         # ![DEBUG]
#     129         if self._scene_mngr.is_debug_mode:
# --> 130             self._scene_mngr.render_debug(title="Collision Fail")
#     131 else:
#     132     if limit_cnt > 1:
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/pytamp/scene/scene_manager.py:381, in SceneManager.render_debug(self, title)
#     379 def render_debug(self, title="Error Scene"):
#     380     fig, ax = p_utils.init_3d_figure(name=title)
# --> 381     self.render_scene(ax)
#     382     if self.scene.grasp_poses:
#     383         self.render_axis(ax, self.scene.grasp_poses["grasp"])
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/pytamp/scene/scene_manager.py:413, in SceneManager.render_scene(self, ax, scene, alpha, robot_color, only_visible_geom, visible_text, geom)
#     410     geom = self.geom
#     412 if self.is_pyplot:
# --> 413     self.render.render_scene(
#     414         ax,
#     415         scene.objs,
#     416         scene.robot,
#     417         alpha,
#     418         robot_color,
#     419         geom=geom,
#     420         only_visible_geom=only_visible_geom,
#     421         visible_text=visible_text,
#     422     )
#     423 else:
#     424     if not self.render.trimesh_scene:
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/pytamp/scene/render.py:92, in RenderPyPlot.render_scene(ax, objs, robot, alpha, robot_color, geom, only_visible_geom, visible_text)
#      89 @staticmethod
#      90 def render_scene(ax, objs, robot, alpha, robot_color, geom, only_visible_geom, visible_text):
#      91     RenderPyPlot.render_objects(ax, objs, alpha)
# ---> 92     RenderPyPlot.render_robot(
#      93         ax, robot, alpha, robot_color, geom, only_visible_geom, visible_text
#      94     )
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/pytamp/scene/render.py:120, in RenderPyPlot.render_robot(ax, robot, alpha, robot_color, geom, only_visible_geom, visible_text, visible_gripper)
#     109 @staticmethod
#     110 def render_robot(
#     111     ax,
#    (...)
#     118     visible_gripper=False,
#     119 ):
# --> 120     p_utils.plot_robot(
#     121         ax,
#     122         robot,
#     123         alpha=alpha,
#     124         color=robot_color,
#     125         geom=geom,
#     126         only_visible_geom=only_visible_geom,
#     127         visible_text=visible_text,
#     128     )
#     129     if visible_gripper:
#     130         RenderPyPlot.render_gripper(ax, robot, alpha, robot_color)
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/pykin/utils/plot_utils.py:237, in plot_robot(ax, robot, geom, only_visible_geom, visible_text, visible_scatter, alpha, color)
#     234 plot_basis(ax, robot)
#     236 if only_visible_geom:
# --> 237     plot_geom(ax, robot, geom, alpha=alpha, color=color)
#     239     if robot.has_gripper and robot.gripper.is_attached:
#     240         plot_attached_object(ax, robot, alpha)
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/pykin/utils/plot_utils.py:312, in plot_geom(ax, robot, geom, alpha, color)
#     310 plot_basis(ax, robot)
#     311 for link, info in robot.info[geom].items():
# --> 312     plot_geom_from_info(ax, robot, link, geom, info, alpha, color)
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/pykin/utils/plot_utils.py:321, in plot_geom_from_info(ax, robot, link, geom, info, alpha, color)
#     319     for idx, mesh in enumerate(meshes):
#     320         mesh_color = get_mesh_color(robot, link, geom, idx, color)
# --> 321         plot_mesh(ax, mesh=mesh, h_mat=h_mat, alpha=alpha, color=mesh_color)
#     323 if info[1] == "cylinder":
#     324     for idx, param in enumerate(info[2]):
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/pykin/utils/plot_utils.py:623, in plot_mesh(ax, mesh, h_mat, s, alpha, color)
#     621 vertices = np.hstack((vertices, np.ones((len(vertices), 1))))
#     622 vertices = np.dot(vertices, h_mat.T)[:, :3]
# --> 623 vectors = np.array([vertices[[i, j, k]] for i, j, k in mesh.faces])
#     625 surface = Poly3DCollection(vectors)
#     626 surface.set_facecolor(color)
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/pykin/utils/plot_utils.py:623, in <listcomp>(.0)
#     621 vertices = np.hstack((vertices, np.ones((len(vertices), 1))))
#     622 vertices = np.dot(vertices, h_mat.T)[:, :3]
# --> 623 vectors = np.array([vertices[[i, j, k]] for i, j, k in mesh.faces])
#     625 surface = Poly3DCollection(vectors)
#     626 surface.set_facecolor(color)
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/pykin/robots/robot.py:8, in handler(signum, frame)
#       7 def handler(signum, frame):
# ----> 8     exit()
#
# NameError: name 'exit' is not defined
