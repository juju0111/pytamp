# %%
from pykin.utils import plot_utils as p_utils
from pytamp.action.pick import PickAction
from pytamp.action.place import PlaceAction
from pytamp.benchmark import Benchmark3

benchmark3 = Benchmark3(robot_name="doosan", geom="collision", is_pyplot=True)
pick = PickAction(
    benchmark3.scene_mngr, n_contacts=0, n_directions=0, retreat_distance=0.1
)
place = PlaceAction(
    benchmark3.scene_mngr, n_samples_held_obj=0, n_samples_support_obj=10
)

pick_actions = list(pick.get_possible_actions_level_1())

pnp_all_joint_path = []
pick_all_objects = []
place_all_object_poses = []

pnp_path = []
pick_objects = []
place_object_poses = []

success_joint_path = False
cnt = 0
for pick_action in pick_actions:
    for pick_scene in pick.get_possible_transitions(
        pick.scene_mngr.init_scene, action=pick_action
    ):
        pick_joint_path = pick.get_possible_joint_path_level_2(
            scene=pick_scene, grasp_poses=pick_scene.grasp_poses
        )
        if pick_joint_path:
            place_actions = list(place.get_possible_actions_level_1(pick_scene))
            for place_action in place_actions:
                for place_scene in place.get_possible_transitions(
                    scene=pick_scene, action=place_action
                ):
                    place_joint_path = place.get_possible_joint_path_level_2(
                        scene=place_scene,
                        release_poses=place_scene.release_poses,
                        init_thetas=pick_joint_path[-1][
                            place.move_data.MOVE_default_grasp
                        ][-1],
                    )
                    if place_joint_path:
                        success_joint_path = True
                        pnp_path += pick_joint_path + place_joint_path
                        pick_objects.append(pick_scene.robot.gripper.attached_obj_name)
                        place_object_poses.append(
                            place_scene.objs[place_scene.pick_obj_name].h_mat
                        )
                        break
                if success_joint_path:
                    break
        if success_joint_path:
            break
    if success_joint_path:
        break
pnp_all_joint_path.append(pnp_path)
pick_all_objects.append(pick_objects)
place_all_object_poses.append(place_object_poses)
# Out:
# *********************** Logical States ***********************
# OrderedDict([('rect_box0',
#               {'on': Object(name=table, pos=[ 1.   -0.6  -0.03])}),
#              ('rect_box1',
#               {'on': Object(name=rect_box0, pos=[0.72       0.3        0.79119365])}),
#              ('rect_box2',
#               {'on': Object(name=rect_box1, pos=[0.72       0.3        0.86107828])}),
#              ('square_box0',
#               {'on': Object(name=table, pos=[ 1.   -0.6  -0.03])}),
#              ('square_box1',
#               {'on': Object(name=square_box0, pos=[0.85       0.4        0.79125948])}),
#              ('square_box2',
#               {'on': Object(name=square_box1, pos=[0.85       0.4        0.86125948])}),
#              ('goal_can',
#               {'on': Object(name=clearbox, pos=[0.7        0.4        0.73537763])}),
#              ('milk1',
#               {'on': Object(name=clearbox, pos=[0.7        0.4        0.73537763])}),
#              ('milk2',
#               {'on': Object(name=clearbox, pos=[0.7        0.4        0.73537763])}),
#              ('milk3',
#               {'on': Object(name=clearbox, pos=[0.7        0.4        0.73537763])}),
#              ('milk4',
#               {'on': Object(name=clearbox, pos=[0.7        0.4        0.73537763])}),
#              ('table', {'static': True}),
#              ('tray_blue', {'static': True}),
#              ('clearbox',
#               {'on': Object(name=table, pos=[ 1.   -0.6  -0.03]),
#                'static': True}),
#              ('robotiq140_gripper', {'holding': None})])
# ***************************************************************
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# [INFO] [RRT Star Planner]: The joint limit has been successfully checked. Pose error is 0.000000
# solve the problem using LM2!!
# Iterators : 6
# WorkingTime[inverse_kinematics]: 0.0067 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 3 --> 20
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000001
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000001
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# Cost is 1.639
# WorkingTime[run]: 2.7588 sec
#
# WorkingTime[run]: 0.0786 sec
#
# WorkingTime[run]: 0.0791 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 4 --> 30
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# [INFO] [RRT Star Planner]: The joint limit has been successfully checked. Pose error is 0.000000
# Cost is 1.64
# WorkingTime[run]: 2.9752 sec
#
# solve the problem using LM2!!
# Iterators : 6
# WorkingTime[inverse_kinematics]: 0.0058 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 3 --> 20
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000001
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000001
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# Cost is 1.427
# WorkingTime[run]: 2.8635 sec
#
# WorkingTime[run]: 0.0825 sec
#
# WorkingTime[run]: 0.0803 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 2 --> 10
# Cost is 1.042
# WorkingTime[run]: 2.5576 sec
# /home/juju/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/matplotlib/animation.py:887: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you have outputted the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(

# %%
place.simulate_path(
    pnp_all_joint_path,
    pick_all_objects,
    place_all_object_poses,
    is_save=True,
    video_name="benchmark3_pnp_test"
)
# Out:
# PWD :  /home/juju/pytamp/examples/doosan/action/rearrangement1
# Animation Finished..
# Save finished..

# %%
c_list
# Out:
# array([1.00000000e-02, 2.78255940e-02, 7.74263683e-02, 2.15443469e-01,
#        5.99484250e-01, 1.66810054e+00, 4.64158883e+00, 1.29154967e+01,
#        3.59381366e+01, 1.00000000e+02])

# %%
import numpy as np
import argparse
import os

from pykin.utils import plot_utils as p_utils
from pytamp.benchmark import Benchmark3
from pytamp.search.mcts import MCTS

# #? python3 benchmark3_test.py --budgets 1000 --max_depth 20 --seed 3 --algo bai_ucb
parser = argparse.ArgumentParser(description="Test Benchmark 3.")
parser.add_argument("--budgets", metavar="T", type=int, default=100, help="Horizon")
parser.add_argument("--max_depth", metavar="H", type=int, default=20, help="Max depth")
parser.add_argument("--seed", metavar="i", type=int, default=2, help="A random seed")
parser.add_argument(
    "--algo",
    metavar="alg",
    type=str,
    default="bai_perturb",
    choices=["bai_perturb", "bai_ucb", "uct", "random", "greedy"],
    help="Choose one (bai_perturb, bai_ucb, uct)",
)
parser.add_argument(
    "--debug_mode",
    default=False,
    type=lambda x: (str(x).lower() == "true"),
    help="Debug mode",
)
try:
    args = parser.parse_args() #call from command line
except:
    args = parser.parse_args(args=[]) #call from notebook
    
debug_mode = args.debug_mode
budgets = args.budgets
max_depth = args.max_depth
algo = args.algo
seed = args.seed
np.random.seed(seed)

benchmark3 = Benchmark3(
    robot_name="doosan", geom="collision", is_pyplot=True,
)

final_level_1_values = []
final_level_2_values = []
final_optimal_nodes = []
final_pnp_all_joint_paths = []
final_pick_all_objects = []
final_place_all_object_poses = []
# final_optimal_trees = []
c_list = 10 ** np.linspace(-2, 2.0, 10)

c = c_list[5]
# Out:
# usage: ipykernel_launcher.py [-h] [--budgets T] [--max_depth H] [--seed i]
#                              [--algo alg] [--debug_mode DEBUG_MODE]
# ipykernel_launcher.py: error: unrecognized arguments: -f /home/juju/.local/share/jupyter/runtime/kernel-5bb36955-4942-4ddd-b9c8-043b13c16087.json
# *********************** Logical States ***********************
# OrderedDict([('rect_box0',
#               {'on': Object(name=table, pos=[ 1.   -0.6  -0.03])}),
#              ('rect_box1',
#               {'on': Object(name=rect_box0, pos=[0.72       0.3        0.79119365])}),
#              ('rect_box2',
#               {'on': Object(name=rect_box1, pos=[0.72       0.3        0.86107828])}),
#              ('square_box0',
#               {'on': Object(name=table, pos=[ 1.   -0.6  -0.03])}),
#              ('square_box1',
#               {'on': Object(name=square_box0, pos=[0.85       0.4        0.79125948])}),
#              ('square_box2',
#               {'on': Object(name=square_box1, pos=[0.85       0.4        0.86125948])}),
#              ('goal_can',
#               {'on': Object(name=clearbox, pos=[0.7        0.4        0.73537763])}),
#              ('milk1',
#               {'on': Object(name=clearbox, pos=[0.7        0.4        0.73537763])}),
#              ('milk2',
#               {'on': Object(name=clearbox, pos=[0.7        0.4        0.73537763])}),
#              ('milk3',
#               {'on': Object(name=clearbox, pos=[0.7        0.4        0.73537763])}),
#              ('milk4',
#               {'on': Object(name=clearbox, pos=[0.7        0.4        0.73537763])}),
#              ('table', {'static': True}),
#              ('tray_blue', {'static': True}),
#              ('clearbox',
#               {'on': Object(name=table, pos=[ 1.   -0.6  -0.03]),
#                'static': True}),
#              ('robotiq140_gripper', {'holding': None})])
# ***************************************************************

# %%
for i in range(budgets):
#     print(
#         f"\n[{idx+1}/{len(c_list)}] Benchmark: {benchmark3.scene_mngr.scene.bench_num}, Algo: {algo}, C: {c}, Seed: {seed}"
#     )
    mcts.do_planning(i)

final_level_1_values.append(mcts.values_for_level_1)
final_level_2_values.append(mcts.values_for_level_2)

if mcts.level_wise_2_success:
    (
        pnp_all_joint_paths,
        pick_all_objects,
        place_all_object_poses,
    ) = mcts.get_all_joint_path(mcts.optimal_nodes)
    final_pnp_all_joint_paths.append(pnp_all_joint_paths)
    final_pick_all_objects.append(pick_all_objects)
    final_place_all_object_poses.append(place_all_object_poses)
    final_optimal_nodes.append(mcts.optimal_nodes)
    
    
else:
    final_pnp_all_joint_paths.append([])
    final_pick_all_objects.append([])
    final_place_all_object_poses.append([])
    final_optimal_nodes.append([])
    # final_optimal_trees.append(mcts.tree.nodes)
#     del mcts
#     # print(final_optimal_trees)
#     print("delete mcts")
# Out:
# =========== Search iteration : 1 ===========
# [Action] Pick milk3
# [Reward] S(0) -> A(4) -> S'(6) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(6) -> A(8) -> S'(15) Reward : -1
# [Action] Pick rect_box2
# [Reward] S(15) -> A(30) -> S'(34) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(34) -> A(36) -> S'(39) Reward : -1
# [Action] Pick square_box2
# [Reward] S(39) -> A(46) -> S'(49) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(49) -> A(52) -> S'(56) Reward : -1
# [Action] Pick milk1
# [Reward] S(56) -> A(62) -> S'(64) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(64) -> A(67) -> S'(71) Reward : -1
# [Action] Pick milk2
# [Reward] S(71) -> A(78) -> S'(81) Reward : 2
# Current logical action is None.. Reward is -1.1111111111111112
# [Reward] S(81) -> A(None) -> S'(None) Reward : -1.111
# =========== Search iteration : 2 ===========
# [Action] Pick square_box2
# [Reward] S(0) -> A(2) -> S'(83) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(83) -> A(85) -> S'(98) Reward : -1
# [Action] Pick milk3
# [Reward] S(98) -> A(104) -> S'(105) Reward : 2
# [Action] Place milk3 on table
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 5
#       1 for i in range(budgets):
#       2 #     print(
#       3 #         f"\n[{idx+1}/{len(c_list)}] Benchmark: {benchmark3.scene_mngr.scene.bench_num}, Algo: {algo}, C: {c}, Seed: {seed}"
#       4 #     )
# ----> 5     mcts.do_planning(i)
#       7 final_level_1_values.append(mcts.values_for_level_1)
#       8 final_level_2_values.append(mcts.values_for_level_2)
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/pytamp/search/mcts.py:151, in MCTS.do_planning(self, iter)
#     148     self.visualize_tree("Next Logical Node", self.tree)
#     149 self.success_level_1_leaf_node = None
# --> 151 self._level_wise_1_optimize(state_node=0, depth=0)
#     152 max_level_1_value = self.get_max_value_level_1()
#     153 self.values_for_level_1.append(max_level_1_value)
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/pytamp/search/mcts.py:268, in MCTS._level_wise_1_optimize(self, state_node, depth)
#     263     if self.scene_mngr.scene.bench_num >= 3:
#     264         discount_value = -0.5
#     265     value = (
#     266         reward
#     267         + discount_value
# --> 268         + self.gamma * self._level_wise_1_optimize(next_state_node, depth + 1)
#     269     )
#     271 self._update_value(cur_state_node, value)
#     272 # print(f"{sc.MAGENTA}[Backpropagation]{sc.ENDC} Cur state Node : {cur_state_node}, Value : {np.round(value,3)}")
#     273 # if self.debug_mode:
#     274 #     self.visualize_tree("Backpropagation", self.tree)
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/pytamp/search/mcts.py:268, in MCTS._level_wise_1_optimize(self, state_node, depth)
#     263     if self.scene_mngr.scene.bench_num >= 3:
#     264         discount_value = -0.5
#     265     value = (
#     266         reward
#     267         + discount_value
# --> 268         + self.gamma * self._level_wise_1_optimize(next_state_node, depth + 1)
#     269     )
#     271 self._update_value(cur_state_node, value)
#     272 # print(f"{sc.MAGENTA}[Backpropagation]{sc.ENDC} Cur state Node : {cur_state_node}, Value : {np.round(value,3)}")
#     273 # if self.debug_mode:
#     274 #     self.visualize_tree("Backpropagation", self.tree)
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/pytamp/search/mcts.py:268, in MCTS._level_wise_1_optimize(self, state_node, depth)
#     263     if self.scene_mngr.scene.bench_num >= 3:
#     264         discount_value = -0.5
#     265     value = (
#     266         reward
#     267         + discount_value
# --> 268         + self.gamma * self._level_wise_1_optimize(next_state_node, depth + 1)
#     269     )
#     271 self._update_value(cur_state_node, value)
#     272 # print(f"{sc.MAGENTA}[Backpropagation]{sc.ENDC} Cur state Node : {cur_state_node}, Value : {np.round(value,3)}")
#     273 # if self.debug_mode:
#     274 #     self.visualize_tree("Backpropagation", self.tree)
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/pytamp/search/mcts.py:237, in MCTS._level_wise_1_optimize(self, state_node, depth)
#     231     print(
#     232         f"{sc.COLOR_BROWN}[Action]{sc.ENDC} {sc.OKGREEN}Place {cur_logical_action[self.pick_action.info.HELD_OBJ_NAME]} on {cur_logical_action[self.pick_action.info.PLACE_OBJ_NAME]}{sc.ENDC}"
#     233     )
#     235 # ? Select Next State
#     236 # *======================================================================================================================== #
# --> 237 next_state_node = self._select_next_state_node(
#     238     cur_logical_action_node, cur_state, cur_logical_action, depth, self._sampling_method
#     239 )
#     240 # assert next_state_node is not None, f"Next state node is None... Why??"
#     241 if next_state_node is not None:
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/pytamp/search/mcts.py:358, in MCTS._select_next_state_node(self, cur_logical_action_node, cur_state, cur_logical_action, depth, exploration_method)
#     355 visit = self.tree.nodes[cur_logical_action_node][NodeData.VISIT]
#     356 if visit == 0:
#     357     # print(f"Logical action node {cur_logical_action_node} is a leaf node, So expand")
# --> 358     self._expand_next_state_node(
#     359         cur_logical_action_node, cur_state, cur_logical_action, depth
#     360     )
#     361 expanded_children = [child for child in self.tree.neighbors(cur_logical_action_node)]
#     362 if not expanded_children:
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/pytamp/search/mcts.py:381, in MCTS._expand_next_state_node(self, cur_logical_action_node, cur_state, cur_logical_action, depth)
#     376     next_states = list(
#     377         self.pick_action.get_possible_transitions(cur_state, cur_logical_action)
#     378     )
#     380 if logical_action_type == "place":
# --> 381     next_states = list(
#     382         self.place_action.get_possible_transitions(cur_state, cur_logical_action)
#     383     )
#     385 for next_state in next_states:
#     386     next_node = self.tree.number_of_nodes()
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/pytamp/action/place.py:245, in PlaceAction.get_possible_transitions(self, scene, action)
#     242 place_obj_name = action[self.info.PLACE_OBJ_NAME]
#     244 for release_poses, obj_pose_transformed in action[self.info.RELEASE_POSES]:
# --> 245     next_scene = deepcopy(scene)
#     247     ## Change transition
#     248     next_scene.release_poses = release_poses
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/copy.py:270, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268 if state is not None:
#     269     if deep:
# --> 270         state = deepcopy(state, memo)
#     271     if hasattr(y, '__setstate__'):
#     272         y.__setstate__(state)
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/copy.py:230, in _deepcopy_dict(x, memo, deepcopy)
#     228 memo[id(x)] = y
#     229 for key, value in x.items():
# --> 230     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231 return y
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/copy.py:270, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268 if state is not None:
#     269     if deep:
# --> 270         state = deepcopy(state, memo)
#     271     if hasattr(y, '__setstate__'):
#     272         y.__setstate__(state)
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/copy.py:230, in _deepcopy_dict(x, memo, deepcopy)
#     228 memo[id(x)] = y
#     229 for key, value in x.items():
# --> 230     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231 return y
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/copy.py:230, in _deepcopy_dict(x, memo, deepcopy)
#     228 memo[id(x)] = y
#     229 for key, value in x.items():
# --> 230     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231 return y
#
#     [... skipping similar frames: deepcopy at line 146 (1 times)]
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/copy.py:230, in _deepcopy_dict(x, memo, deepcopy)
#     228 memo[id(x)] = y
#     229 for key, value in x.items():
# --> 230     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231 return y
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/copy.py:205, in _deepcopy_list(x, memo, deepcopy)
#     203 append = y.append
#     204 for a in x:
# --> 205     append(deepcopy(a, memo))
#     206 return y
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/copy.py:205, in _deepcopy_list(x, memo, deepcopy)
#     203 append = y.append
#     204 for a in x:
# --> 205     append(deepcopy(a, memo))
#     206 return y
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/copy.py:153, in deepcopy(x, memo, _nil)
#     151 copier = getattr(x, "__deepcopy__", None)
#     152 if copier is not None:
# --> 153     y = copier(memo)
#     154 else:
#     155     reductor = dispatch_table.get(cls)
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/trimesh/base.py:3026, in Trimesh.__deepcopy__(self, *args)
#    3024 def __deepcopy__(self, *args):
#    3025     # interpret deep copy as "get rid of cached data"
# -> 3026     return self.copy(include_cache=False)
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/trimesh/base.py:3012, in Trimesh.copy(self, include_cache)
#    3009 copied._density = self._density
#    3011 # make sure cache ID is set initially
# -> 3012 copied._cache.verify()
#    3014 if include_cache:
#    3015     # shallow copy cached items into the new cache
#    3016     # since the data didn't change here when the
#    3017     # data in the new mesh is changed these items
#    3018     # will be dumped in the new mesh but preserved
#    3019     # in the original mesh
#    3020     copied._cache.cache.update(self._cache.cache)
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/trimesh/caching.py:391, in Cache.verify(self)
#     388     return
#     390 # check the hash of our data
# --> 391 id_new = self._id_function()
#     393 # things changed
#     394 if id_new != self.id_current:
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/trimesh/caching.py:689, in DataStore.__hash__(self)
#     679 def __hash__(self):
#     680     """
#     681     Get a hash reflecting everything in the DataStore.
#     682
#    (...)
#     686       hash of data in hexadecimal
#     687     """
#     688     return hash_fast(np.array(
# --> 689         [hash(v) for v in self.data.values()],
#     690         dtype=np.int64).tobytes())
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/trimesh/caching.py:689, in <listcomp>(.0)
#     679 def __hash__(self):
#     680     """
#     681     Get a hash reflecting everything in the DataStore.
#     682
#    (...)
#     686       hash of data in hexadecimal
#     687     """
#     688     return hash_fast(np.array(
# --> 689         [hash(v) for v in self.data.values()],
#     690         dtype=np.int64).tobytes())
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/trimesh/caching.py:244, in TrackedArray.__hash__(self)
#     241     return self._hashed
#     243 if self.flags['C_CONTIGUOUS']:
# --> 244     hashed = hash_fast(self)
#     245 else:
#     246     # the case where we have sliced our nice
#     247     # contiguous array into a non- contiguous block
#     248     # for example (note slice *after* track operation):
#     249     # t = tracked_array(np.random.random(10))[::-1]
#     250     hashed = hash_fast(np.ascontiguousarray(self))
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/trimesh/caching.py:50, in hash_fallback(item)
#      49 def hash_fallback(item):
# ---> 50     return int(_blake2b(item).hexdigest(), 16)
#
# KeyboardInterrupt:

# %%
mcts.do_planning(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 mcts.do_planning(0)
#
# NameError: name 'mcts' is not defined

# %%
mcts.tree.nodes[4]
# Out:
# {'depth': 1,
#  'state': <pytamp.scene.scene.Scene at 0x7f57cfc38b80>,
#  'action': {'type': 'pick',
#   'pick_obj_name': 'milk3',
#   'grasp_poses': [{'grasp': array([[ 0.        ,  1.        ,  0.        ,  0.6       ],
#            [ 0.99144486,  0.        , -0.13052619,  0.52708418],
#            [-0.13052619,  0.        , -0.99144486,  1.11511846],
#            [ 0.        ,  0.        ,  0.        ,  1.        ]]),
#     'pre_grasp': array([[ 0.        ,  1.        ,  0.        ,  0.6       ],
#            [ 0.99144486,  0.        , -0.13052619,  0.54666311],
#            [-0.13052619,  0.        , -0.99144486,  1.26383519],
#            [ 0.        ,  0.        ,  0.        ,  1.        ]]),
#     'post_grasp': array([[ 0.        ,  1.        ,  0.        ,  0.6       ],
#            [ 0.99144486,  0.        , -0.13052619,  0.52708418],
#            [-0.13052619,  0.        , -0.99144486,  1.26511846],
#            [ 0.        ,  0.        ,  0.        ,  1.        ]])},
#    {'grasp': array([[ 0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#              6.00000000e-01],
#            [ 1.00000000e+00,  0.00000000e+00,  1.22464680e-16,
#              5.00000000e-01],
#            [ 1.22464680e-16,  0.00000000e+00, -1.00000000e+00,
#              1.11689365e+00],
#            [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#              1.00000000e+00]]),
#     'pre_grasp': array([[ 0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#              6.00000000e-01],
#            [ 1.00000000e+00,  0.00000000e+00,  1.22464680e-16,
#              5.00000000e-01],
#            [ 1.22464680e-16,  0.00000000e+00, -1.00000000e+00,
#              1.26689365e+00],
#            [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#              1.00000000e+00]]),
#     'post_grasp': array([[ 0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#              6.00000000e-01],
#            [ 1.00000000e+00,  0.00000000e+00,  1.22464680e-16,
#              5.00000000e-01],
#            [ 1.22464680e-16,  0.00000000e+00, -1.00000000e+00,
#              1.26689365e+00],
#            [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#              1.00000000e+00]])},
#    {'grasp': array([[ 0.        ,  1.        ,  0.        ,  0.6       ],
#            [ 0.99144486,  0.        ,  0.13052619,  0.47291582],
#            [ 0.13052619,  0.        , -0.99144486,  1.11511846],
#            [ 0.        ,  0.        ,  0.        ,  1.        ]]),
#     'pre_grasp': array([[ 0.        ,  1.        ,  0.        ,  0.6       ],
#            [ 0.99144486,  0.        ,  0.13052619,  0.45333689],
#            [ 0.13052619,  0.        , -0.99144486,  1.26383519],
#            [ 0.        ,  0.        ,  0.        ,  1.        ]]),
#     'post_grasp': array([[ 0.        ,  1.        ,  0.        ,  0.6       ],
#            [ 0.99144486,  0.        ,  0.13052619,  0.47291582],
#            [ 0.13052619,  0.        , -0.99144486,  1.26511846],
#            [ 0.        ,  0.        ,  0.        ,  1.        ]])}]},
#  'value': -1.1111111111111112,
#  'value_history': [-1.1111111111111112],
#  'visit': 1,
#  'number': 4,
#  'type': 'action',
#  'joints': [],
#  'level1': False,
#  'level2': False,
#  'success': False,
#  'cost': 0,
#  'test': ()}

# %%
c_list = c_list[6:]

# %%
mcts = MCTS(
    scene_mngr=benchmark3.scene_mngr,
    sampling_method=algo,
    budgets=budgets,
    max_depth=max_depth,
    c=c,
    debug_mode=debug_mode,
)
for i in range(budgets):
    print(
        f"\n[{idx+1}/{len(c_list)}] Benchmark: {benchmark3.scene_mngr.scene.bench_num}, Algo: {algo}, C: {c}, Seed: {seed}"
    )
    mcts.do_planning(i)

final_level_1_values.append(mcts.values_for_level_1)
final_level_2_values.append(mcts.values_for_level_2)

if mcts.level_wise_2_success:
    (
        pnp_all_joint_paths,
        pick_all_objects,
        place_all_object_poses,
    ) = mcts.get_all_joint_path(mcts.optimal_nodes)
    final_pnp_all_joint_paths.append(pnp_all_joint_paths)
    final_pick_all_objects.append(pick_all_objects)
    final_place_all_object_poses.append(place_all_object_poses)
    final_optimal_nodes.append(mcts.optimal_nodes)
    break
else:
    final_pnp_all_joint_paths.append([])
    final_pick_all_objects.append([])
    final_place_all_object_poses.append([])
    final_optimal_nodes.append([])
# Out:
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 1 ===========
# [Action] Pick milk1
# [Reward] S(0) -> A(3) -> S'(6) Reward : 2
# Current logical action is None.. Reward is -10.0
# [Reward] S(6) -> A(None) -> S'(None) Reward : -10.0
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 2 ===========
# [Action] Pick milk3
# [Reward] S(0) -> A(4) -> S'(10) Reward : 2
# Current logical action is None.. Reward is -10.0
# [Reward] S(10) -> A(None) -> S'(None) Reward : -10.0
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 3 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(13) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(13) -> A(14) -> S'(20) Reward : -1
# [Action] Pick milk1
# [Reward] S(20) -> A(22) -> S'(25) Reward : 2
# Current logical action is None.. Reward is -3.3333333333333335
# [Reward] S(25) -> A(None) -> S'(None) Reward : -3.333
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 4 ===========
# [Action] Pick square_box2
# [Reward] S(0) -> A(2) -> S'(27) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(27) -> A(30) -> S'(38) Reward : -1
# [Action] Pick rect_box2
# [Reward] S(38) -> A(39) -> S'(44) Reward : 2
# Current logical action is None.. Reward is -3.3333333333333335
# [Reward] S(44) -> A(None) -> S'(None) Reward : -3.333
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 5 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(11) Reward : 2
# Current logical action is None.. Reward is -10.0
# [Reward] S(11) -> A(None) -> S'(None) Reward : -10.0
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 6 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(87) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(87) -> A(88) -> S'(90) Reward : -1
# [Action] Pick square_box1
# [Reward] S(90) -> A(91) -> S'(95) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(95) -> A(96) -> S'(99) Reward : -1
# [Action] Pick milk3
# [Reward] S(99) -> A(105) -> S'(106) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(106) -> A(109) -> S'(118) Reward : -1
# [Action] Pick milk2
# [Reward] S(118) -> A(122) -> S'(125) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(125) -> A(126) -> S'(127) Reward : -1
# [Action] Pick goal_can
# [Reward] S(127) -> A(132) -> S'(134) Reward : 2
# Current logical action is None.. Reward is -0.7692307692307693
# [Reward] S(134) -> A(None) -> S'(None) Reward : -0.769
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 7 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick milk1
# [Reward] S(59) -> A(73) -> S'(138) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(138) -> A(139) -> S'(141) Reward : -1
# [Action] Pick square_box2
# [Reward] S(141) -> A(148) -> S'(151) Reward : 2
# Current logical action is None.. Reward is -2.0
# [Reward] S(151) -> A(None) -> S'(None) Reward : -2.0
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 8 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick milk3
# [Reward] S(59) -> A(74) -> S'(155) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(155) -> A(156) -> S'(157) Reward : -1
# [Action] Pick milk2
# [Reward] S(157) -> A(160) -> S'(162) Reward : 2
# Current logical action is None.. Reward is -2.0
# [Reward] S(162) -> A(None) -> S'(None) Reward : -2.0
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 9 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(76) Reward : 2
# Current logical action is None.. Reward is -3.3333333333333335
# [Reward] S(76) -> A(None) -> S'(None) Reward : -3.333
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 10 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(77) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(77) -> A(164) -> S'(182) Reward : -1
# [Action] Pick square_box1
# [Reward] S(182) -> A(185) -> S'(190) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(190) -> A(191) -> S'(193) Reward : -1
# [Action] Pick milk3
# [Reward] S(193) -> A(204) -> S'(206) Reward : 2
# Current logical action is None.. Reward is -1.4285714285714286
# [Reward] S(206) -> A(None) -> S'(None) Reward : -1.429
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 11 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick square_box1
# [Reward] S(80) -> A(82) -> S'(210) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(210) -> A(211) -> S'(220) Reward : -1
# [Action] Pick milk3
# [Reward] S(220) -> A(228) -> S'(231) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(231) -> A(232) -> S'(233) Reward : -1
# [Action] Pick milk1
# [Reward] S(233) -> A(234) -> S'(237) Reward : 2
# Current logical action is None.. Reward is -1.1111111111111112
# [Reward] S(237) -> A(None) -> S'(None) Reward : -1.111
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 12 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk3
# [Reward] S(80) -> A(84) -> S'(241) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(241) -> A(242) -> S'(247) Reward : -1
# [Action] Pick milk1
# [Reward] S(247) -> A(252) -> S'(255) Reward : 2
# Current logical action is None.. Reward is -1.4285714285714286
# [Reward] S(255) -> A(None) -> S'(None) Reward : -1.429
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 13 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(280) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(280) -> A(281) -> S'(282) Reward : -1
# [Action] Pick milk2
# [Reward] S(282) -> A(289) -> S'(290) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(290) -> A(293) -> S'(294) Reward : -1
# [Action] Pick square_box1
# [Reward] S(294) -> A(296) -> S'(297) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(297) -> A(300) -> S'(304) Reward : -1
# [Action] Pick goal_can
# [Reward] S(304) -> A(308) -> S'(310) Reward : 2
# Current logical action is None.. Reward is -0.7692307692307693
# [Reward] S(310) -> A(None) -> S'(None) Reward : -0.769
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 14 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(86) Reward : 2
# Current logical action is None.. Reward is -2.0
# [Reward] S(86) -> A(None) -> S'(None) Reward : -2.0
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 15 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick square_box1
# [Reward] S(270) -> A(276) -> S'(312) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(312) -> A(315) -> S'(318) Reward : -1
# [Action] Pick milk3
# [Reward] S(318) -> A(319) -> S'(322) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(322) -> A(323) -> S'(329) Reward : -1
# [Action] Pick milk2
# [Reward] S(329) -> A(331) -> S'(334) Reward : 2
# Current logical action is None.. Reward is -0.9090909090909091
# [Reward] S(334) -> A(None) -> S'(None) Reward : -0.909
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 16 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# [INFO] [RRT Star Planner]: The joint limit has been successfully checked. Pose error is 0.000001
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Action Node: 1 Action: Pick rect_box2
# Action Node: 46  Action: Place rect_box2 on table
# Action Node: 72 Action: Pick square_box2
# Action Node: 78  Action: Place square_box2 on table
# Action Node: 83 Action: Pick milk1
# Action Node: 257  Action: Place milk1 on table
# Action Node: 277 Action: Pick milk3
# Action Node: 335  Action: Place milk3 on table
# Action Node: 349 Action: Pick milk2
# Action Node: 353  Action: Place milk2 on table
# Action Node: 355 Action: Pick square_box1
# Action Node: 359  Action: Place square_box1 on table
# Action Node: 361 Action: Pick goal_can
# Action Node: 365  Action: Place goal_can on tray_blue
# pick rect_box2
# solve the problem using LM2!!
# Iterators : 6
# WorkingTime[inverse_kinematics]: 0.0062 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 3 --> 20
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000001
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000002
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# Cost is 1.594
# WorkingTime[run]: 2.6292 sec
#
# WorkingTime[run]: 0.0772 sec
#
# WorkingTime[run]: 0.0767 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 4 --> 30
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# [INFO] [RRT Star Planner]: The joint limit has been successfully checked. Pose error is 0.000001
# Cost is 1.612
# WorkingTime[run]: 2.7825 sec
#
# place rect_box2 on table
# solve the problem using LM2!!
# Iterators : 7
# WorkingTime[inverse_kinematics]: 0.0060 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 3 --> 20
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000002
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000003
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# Cost is 1.465
# WorkingTime[run]: 2.7683 sec
#
# WorkingTime[run]: 0.0780 sec
#
# WorkingTime[run]: 0.0764 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 3 --> 20
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# [INFO] [RRT Star Planner]: The joint limit has been successfully checked. Pose error is 0.000002
# Cost is 1.462
# WorkingTime[run]: 2.4962 sec
#
# Success pnp
# pick square_box2
# solve the problem using LM2!!
# Iterators : 7
# WorkingTime[inverse_kinematics]: 0.0059 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 3 --> 20
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000001
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000003
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# Cost is 1.447
# WorkingTime[run]: 2.6665 sec
#
# WorkingTime[run]: 0.0752 sec
#
# WorkingTime[run]: 0.0778 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 4 --> 30
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# [INFO] [RRT Star Planner]: The joint limit has been successfully checked. Pose error is 0.000002
# Cost is 1.539
# WorkingTime[run]: 2.8242 sec
#
# place square_box2 on table
# solve the problem using LM2!!
# Iterators : 6
# WorkingTime[inverse_kinematics]: 0.0053 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 5 --> 40
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000003
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000003
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# Cost is 2.407
# WorkingTime[run]: 2.7872 sec
#
# WorkingTime[run]: 0.0764 sec
#
# WorkingTime[run]: 0.0764 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 4 --> 30
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# [INFO] [RRT Star Planner]: The joint limit has been successfully checked. Pose error is 0.000000
# Cost is 2.518
# WorkingTime[run]: 2.5542 sec
#
# Success pnp
# pick milk1
# solve the problem using LM2!!
# Iterators : 8
# WorkingTime[inverse_kinematics]: 0.0071 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 3 --> 20
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000001
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000002
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# Cost is 2.0
# WorkingTime[run]: 2.4919 sec
#
# WorkingTime[run]: 0.0744 sec
#
# WorkingTime[run]: 0.0744 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 3 --> 20
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# [INFO] [RRT Star Planner]: The joint limit has been successfully checked. Pose error is 0.000001
# Cost is 2.041
# WorkingTime[run]: 2.6705 sec
#
# place milk1 on table
# solve the problem using LM2!!
# Iterators : 7
# WorkingTime[inverse_kinematics]: 0.0060 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 3 --> 20
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000002
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000004
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# Cost is 1.4
# WorkingTime[run]: 2.6294 sec
#
# WorkingTime[run]: 0.0756 sec
#
# WorkingTime[run]: 0.0734 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 3 --> 20
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# [INFO] [RRT Star Planner]: The joint limit has been successfully checked. Pose error is 0.000000
# Cost is 1.407
# WorkingTime[run]: 2.5062 sec
#
# Success pnp
# pick milk3
# solve the problem using LM2!!
# Iterators : 8
# WorkingTime[inverse_kinematics]: 0.0067 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 4 --> 30
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000001
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000002
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# Cost is 2.669
# WorkingTime[run]: 2.4631 sec
#
# WorkingTime[run]: 0.0791 sec
#
# WorkingTime[run]: 0.0740 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 4 --> 30
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# [INFO] [RRT Star Planner]: The joint limit has been successfully checked. Pose error is 0.000001
# Cost is 2.671
# WorkingTime[run]: 2.5867 sec
#
# place milk3 on table
# solve the problem using LM2!!
# Iterators : 11
# WorkingTime[inverse_kinematics]: 0.0087 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 5 --> 40
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000002
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000007
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# Cost is 3.045
# WorkingTime[run]: 2.6390 sec
#
# WorkingTime[run]: 0.0759 sec
#
# WorkingTime[run]: 0.0760 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 5 --> 40
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# [INFO] [RRT Star Planner]: The joint limit has been successfully checked. Pose error is 0.000001
# Cost is 3.139
# WorkingTime[run]: 2.4607 sec
#
# Success pnp
# pick milk2
# solve the problem using LM2!!
# Iterators : 6
# WorkingTime[inverse_kinematics]: 0.0053 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 2 --> 10
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000002
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000002
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# Cost is 1.205
# WorkingTime[run]: 2.5135 sec
#
# WorkingTime[run]: 0.0753 sec
#
# WorkingTime[run]: 0.0756 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 2 --> 10
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# [INFO] [RRT Star Planner]: The joint limit has been successfully checked. Pose error is 0.000000
# Cost is 1.159
# WorkingTime[run]: 2.6302 sec
#
# place milk2 on table
# solve the problem using LM2!!
# Iterators : 6
# WorkingTime[inverse_kinematics]: 0.0057 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 2 --> 10
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000003
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000004
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# Cost is 1.186
# WorkingTime[run]: 2.8672 sec
#
# WorkingTime[run]: 0.0764 sec
#
# WorkingTime[run]: 0.0751 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 2 --> 10
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# [INFO] [RRT Star Planner]: The joint limit has been successfully checked. Pose error is 0.000002
# Cost is 1.186
# WorkingTime[run]: 2.6195 sec
#
# Success pnp
# pick square_box1
# solve the problem using LM2!!
# Iterators : 9
# WorkingTime[inverse_kinematics]: 0.0075 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 3 --> 20
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000001
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000003
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# Cost is 1.989
# WorkingTime[run]: 2.5996 sec
#
# WorkingTime[run]: 0.0767 sec
#
# WorkingTime[run]: 0.0763 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 3 --> 20
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# [INFO] [RRT Star Planner]: The joint limit has been successfully checked. Pose error is 0.000000
# Cost is 1.868
# WorkingTime[run]: 2.6849 sec
#
# place square_box1 on table
# solve the problem using LM2!!
# Iterators : 8
# WorkingTime[inverse_kinematics]: 0.0066 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 3 --> 20
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000002
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000003
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# Cost is 1.835
# WorkingTime[run]: 2.6699 sec
#
# WorkingTime[run]: 0.0741 sec
#
# WorkingTime[run]: 0.0738 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 3 --> 20
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# [INFO] [RRT Star Planner]: The joint limit has been successfully checked. Pose error is 0.000002
# Cost is 1.649
# WorkingTime[run]: 2.5466 sec
#
# Success pnp
# pick goal_can
# solve the problem using LM2!!
# Iterators : 6
# WorkingTime[inverse_kinematics]: 0.0052 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 3 --> 20
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000001
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000002
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# Cost is 1.631
# WorkingTime[run]: 2.4760 sec
#
# WorkingTime[run]: 0.0764 sec
#
# WorkingTime[run]: 0.0766 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 3 --> 20
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# [INFO] [RRT Star Planner]: The joint limit has been successfully checked. Pose error is 0.000001
# Cost is 1.646
# WorkingTime[run]: 2.6449 sec
#
# place goal_can on tray_blue
# solve the problem using LM2!!
# Iterators : 5
# WorkingTime[inverse_kinematics]: 0.0046 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 4 --> 30
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000004
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000004
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# Cost is 1.75
# WorkingTime[run]: 2.7255 sec
#
# WorkingTime[run]: 0.0778 sec
#
# WorkingTime[run]: 0.0755 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 3 --> 20
# Cost is 1.723
# WorkingTime[run]: 2.5616 sec
#
# Success pnp
# Update Sub optimal Nodes!! Value is 10.4128.
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 17 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 18 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 19 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 20 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 21 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 22 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 23 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 24 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 25 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 26 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 27 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 28 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 29 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 30 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 31 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 32 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 33 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 34 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 35 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# ...
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 88 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 89 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 90 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 91 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 92 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 93 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 94 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 95 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 96 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 97 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 98 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 99 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!
#
# [1/10] Benchmark: 3, Algo: bai_perturb, C: 0.01, Seed: 2
# =========== Search iteration : 100 ===========
# [Action] Pick rect_box2
# [Reward] S(0) -> A(1) -> S'(12) Reward : 2
# [Action] Place rect_box2 on table
# [Reward] S(12) -> A(46) -> S'(59) Reward : -1
# [Action] Pick square_box2
# [Reward] S(59) -> A(72) -> S'(75) Reward : 2
# [Action] Place square_box2 on table
# [Reward] S(75) -> A(78) -> S'(80) Reward : -1
# [Action] Pick milk1
# [Reward] S(80) -> A(83) -> S'(85) Reward : 2
# [Action] Place milk1 on table
# [Reward] S(85) -> A(257) -> S'(270) Reward : -1
# [Action] Pick milk3
# [Reward] S(270) -> A(277) -> S'(278) Reward : 2
# [Action] Place milk3 on table
# [Reward] S(278) -> A(335) -> S'(337) Reward : -1
# [Action] Pick milk2
# [Reward] S(337) -> A(349) -> S'(352) Reward : 2
# [Action] Place milk2 on table
# [Reward] S(352) -> A(353) -> S'(354) Reward : -1
# [Action] Pick square_box1
# [Reward] S(354) -> A(355) -> S'(358) Reward : 2
# [Action] Place square_box1 on table
# [Reward] S(358) -> A(359) -> S'(360) Reward : -1
# [Action] Pick goal_can
# [Reward] S(360) -> A(361) -> S'(362) Reward : 2
# [Action] Place goal_can on tray_blue
# [Reward] S(362) -> A(365) -> S'(368) Reward : -1
# Success!!!!!
# Terminal State! Reward is 10
# Aleady has optimal nodes!!

# %%
if mcts.level_wise_2_success:
    (
        pnp_all_joint_paths,
        pick_all_objects,
        place_all_object_poses,
    ) = mcts.get_all_joint_path(mcts.optimal_nodes)
    final_pnp_all_joint_paths.append(pnp_all_joint_paths)
    final_pick_all_objects.append(pick_all_objects)
    final_place_all_object_poses.append(place_all_object_poses)
    final_optimal_nodes.append(mcts.optimal_nodes)

# %%
final_pnp_all_joint_paths
# Out:
# [[[OrderedDict([('pre_grasp',
#                  [array([ 0.01375477,  0.01333856,  2.07516883, -0.00569038,  1.05283205,
#                          -0.04177105]),
#                   array([ 0.02750954,  0.02667713,  2.05594256, -0.01138076,  1.05846654,
#                          -0.08354211]),
#                   array([ 0.0412643 ,  0.04001569,  2.03671628, -0.01707114,  1.06410103,
#                          -0.12531316]),
#                   array([ 0.05501907,  0.05335426,  2.01749001, -0.02276152,  1.06973553,
#                          -0.16708422]),
#                   array([ 0.06877384,  0.06669282,  1.99826374, -0.0284519 ,  1.07537002,
#                          -0.20885527]),
#                   array([ 0.08252861,  0.08003139,  1.97903747, -0.03414229,  1.08100452,
#                          -0.25062633]),
#                   array([ 0.09628337,  0.09336995,  1.95981119, -0.03983267,  1.08663901,
#                          -0.29239738]),
#                   array([ 0.11003814,  0.10670852,  1.94058492, -0.04552305,  1.0922735 ,
#                          -0.33416844]),
#                   array([ 0.12379291,  0.12004708,  1.92135865, -0.05121343,  1.097908  ,
#                          -0.37593949]),
#                   array([ 0.13754768,  0.13338565,  1.90213237, -0.05690381,  1.10354249,
#                          -0.41771055]),
#                   array([ 0.15827897,  0.17477413,  1.84756736, -0.05117032,  1.11695182,
#                          -0.49856753]),
#                   array([ 0.17901026,  0.21616262,  1.79300235, -0.04543683,  1.13036115,
#                          -0.57942451]),
#                   array([ 0.19974155,  0.25755111,  1.73843734, -0.03970335,  1.14377048,
#                          -0.66028149]),
#                   array([ 0.22047285,  0.29893959,  1.68387232, -0.03396986,  1.15717981,
#                          -0.74113848]),
#                   array([ 0.24120414,  0.34032808,  1.62930731, -0.02823637,  1.17058913,
#                          -0.82199546]),
#                   array([ 0.26193543,  0.38171657,  1.5747423 , -0.02250288,  1.18399846,
#                          -0.90285244]),
#                   array([ 0.28266672,  0.42310505,  1.52017729, -0.01676939,  1.19740779,
#                          -0.98370943]),
#                   array([ 0.30339801,  0.46449354,  1.46561228, -0.01103591,  1.21081712,
#                          -1.06456641]),
#                   array([ 0.3241293 ,  0.50588203,  1.41104726, -0.00530242,  1.22422645,
#                          -1.14542339]),
#                   array([ 3.44860596e-01,  5.47270513e-01,  1.35648225e+00,  4.31069074e-04,
#                           1.23763578e+00, -1.22628038e+00])]),
#                 ('grasp',
#                  [array([ 3.44860596e-01,  5.47270513e-01,  1.35648225e+00,  4.31069074e-04,
#                           1.23763578e+00, -1.22628038e+00]),
#                   array([ 3.44861025e-01,  5.48167630e-01,  1.35812379e+00,  4.31444025e-04,
#                           1.23509745e+00, -1.22628110e+00]),
#                   array([ 3.44864945e-01,  5.57505294e-01,  1.37405265e+00,  4.35421283e-04,
#                           1.20983092e+00, -1.22628883e+00]),
#                   array([ 3.44868866e-01,  5.67455869e-01,  1.38913954e+00,  4.39714927e-04,
#                           1.18479344e+00, -1.22629668e+00]),
#                   array([ 3.44872787e-01,  5.78007633e-01,  1.40339517e+00,  4.44330859e-04,
#                           1.15998604e+00, -1.22630466e+00]),
#                   array([ 3.44876708e-01,  5.89148982e-01,  1.41682868e+00,  4.49275538e-04,
#                           1.13541118e+00, -1.22631278e+00]),
#                   array([ 3.44880629e-01,  6.00868330e-01,  1.42944784e+00,  4.54555911e-04,
#                           1.11107267e+00, -1.22632106e+00]),
#                   array([ 3.44884550e-01,  6.13154034e-01,  1.44125924e+00,  4.60179329e-04,
#                           1.08697556e+00, -1.22632951e+00]),
#                   array([ 3.44888471e-01,  6.25994331e-01,  1.45226842e+00,  4.66153474e-04,
#                           1.06312607e+00, -1.22633814e+00]),
#                   array([ 3.44892392e-01,  6.39377282e-01,  1.46248002e+00,  4.72486270e-04,
#                           1.03953152e+00, -1.22634698e+00]),
#                   array([ 3.44896313e-01,  6.53290733e-01,  1.47189788e+00,  4.79185793e-04,
#                           1.01620021e+00, -1.22635602e+00]),
#                   array([ 3.44899842e-01,  6.66256178e-01,  1.47969794e+00,  4.85535637e-04,
#                           9.95434699e-01, -1.22636435e+00])]),
#                 ('post_grasp',
#                  [array([ 3.44899842e-01,  6.66256178e-01,  1.47969794e+00,  4.85535637e-04,
#                           9.95434699e-01, -1.22636435e+00]),
#                   array([ 3.44899431e-01,  6.64792682e-01,  1.47886789e+00,  4.84815665e-04,
#                           9.97727983e-01, -1.22636344e+00]),
#                   array([ 3.44895506e-01,  6.50463904e-01,  1.47008256e+00,  4.77817203e-04,
#                           1.02084208e+00, -1.22635422e+00]),
#                   array([ 3.44891581e-01,  6.36655737e-01,  1.46050607e+00,  4.71191967e-04,
#                           1.04422672e+00, -1.22634522e+00]),
#                   array([ 3.44887656e-01,  6.23380517e-01,  1.45013516e+00,  4.64931842e-04,
#                           1.06787285e+00, -1.22633643e+00]),
#                   array([ 3.44883731e-01,  6.10650350e-01,  1.43896582e+00,  4.59028774e-04,
#                           1.09177236e+00, -1.22632784e+00]),
#                   array([ 3.44879805e-01,  5.98477135e-01,  1.42699324e+00,  4.53474882e-04,
#                           1.11591814e+00, -1.22631943e+00]),
#                   array([ 3.44875880e-01,  5.86872609e-01,  1.41421169e+00,  4.48262545e-04,
#                           1.14030421e+00, -1.22631119e+00]),
#                   array([ 3.44871955e-01,  5.75848394e-01,  1.40061436e+00,  4.43384487e-04,
#                           1.16492574e+00, -1.22630310e+00]),
#                   array([ 3.44868029e-01,  5.65416073e-01,  1.38619322e+00,  4.38833855e-04,
#                           1.18977920e+00, -1.22629516e+00]),
#                   array([ 3.44864104e-01,  5.55587264e-01,  1.37093883e+00,  4.34604295e-04,
#                           1.21486239e+00, -1.22628734e+00]),
#                   array([ 3.44860570e-01,  5.47267047e-01,  1.35648837e+00,  4.31067417e-04,
#                           1.23763306e+00, -1.22628040e+00])]),
#                 ('default_grasp',
#                  [array([ 0.33700046,  0.53874382,  1.36577334, -0.00548809,  1.23004338,
#                          -1.20061162]),
#                   array([ 0.32914036,  0.53022059,  1.37505831, -0.01140726,  1.22245369,
#                          -1.17494283]),
#                   array([ 0.32128025,  0.52169736,  1.38434329, -0.01732642,  1.214864  ,
#                          -1.14927405]),
#                   array([ 0.31342014,  0.51317414,  1.39362826, -0.02324558,  1.20727431,
#                          -1.12360527]),
#                   array([ 0.30556004,  0.50465091,  1.40291323, -0.02916474,  1.19968462,
#                          -1.09793648]),
#                   array([ 0.29769993,  0.49612768,  1.4121982 , -0.03508391,  1.19209494,
#                          -1.0722677 ]),
#                   array([ 0.28983982,  0.48760445,  1.42148317, -0.04100307,  1.18450525,
#                          -1.04659891]),
#                   array([ 0.28197971,  0.47908123,  1.43076814, -0.04692223,  1.17691556,
#                          -1.02093013]),
#                   array([ 0.27411961,  0.470558  ,  1.44005311, -0.05284139,  1.16932587,
#                          -0.99526135]),
#                   array([ 0.2662595 ,  0.46203477,  1.44933808, -0.05876056,  1.16173618,
#                          -0.96959256]),
#                   array([ 0.24519518,  0.4206001 ,  1.50496729, -0.05372511,  1.14887445,
#                          -0.87936447]),
#                   array([ 0.22413086,  0.37916543,  1.5605965 , -0.04868967,  1.13601271,
#                          -0.78913637]),
#                   array([ 0.20306654,  0.33773075,  1.61622571, -0.04365422,  1.12315097,
#                          -0.69890827]),
#                   array([ 0.18200222,  0.29629608,  1.67185492, -0.03861878,  1.11028923,
#                          -0.60868018]),
#                   array([ 0.1609379 ,  0.25486141,  1.72748413, -0.03358333,  1.0974275 ,
#                          -0.51845208]),
#                   array([ 0.13987358,  0.21342673,  1.78311334, -0.02854788,  1.08456576,
#                          -0.42822398]),
#                   array([ 0.11880926,  0.17199206,  1.83874255, -0.02351244,  1.07170402,
#                          -0.33799588]),
#                   array([ 0.09774494,  0.13055739,  1.89437176, -0.01847699,  1.05884228,
#                          -0.24776779]),
#                   array([ 0.07668062,  0.08912271,  1.95000096, -0.01344155,  1.04598054,
#                          -0.15753969]),
#                   array([ 0.0556163 ,  0.04768804,  2.00563017, -0.0084061 ,  1.03311881,
#                          -0.06731159]),
#                   array([ 0.05005467,  0.04291924,  2.01450667, -0.00756549,  1.03452668,
#                          -0.06058043]),
#                   array([ 0.04449304,  0.03815043,  2.02338316, -0.00672488,  1.03593456,
#                          -0.05384927]),
#                   array([ 0.03893141,  0.03338163,  2.03225965, -0.00588427,  1.03734243,
#                          -0.04711812]),
#                   array([ 0.03336978,  0.02861282,  2.04113615, -0.00504366,  1.0387503 ,
#                          -0.04038696]),
#                   array([ 0.02780815,  0.02384402,  2.05001264, -0.00420305,  1.04015818,
#                          -0.0336558 ]),
#                   array([ 0.02224652,  0.01907522,  2.05888913, -0.00336244,  1.04156605,
#                          -0.02692464]),
#                   array([ 0.01668489,  0.01430641,  2.06776562, -0.00252183,  1.04297393,
#                          -0.02019348]),
#                   array([ 1.11232602e-02,  9.53760819e-03,  2.07664212e+00, -1.68122088e-03,
#                           1.04438180e+00, -1.34623187e-02]),
#                   array([ 5.56163008e-03,  4.76880410e-03,  2.08551861e+00, -8.40610441e-04,
#                           1.04578968e+00, -6.73115934e-03]),
#                   array([ 0.00000000e+00, -1.08420217e-19,  2.09439510e+00,  0.00000000e+00,
#                           1.04719755e+00,  0.00000000e+00])])]),
#    OrderedDict([('pre_release',
#                  [array([-0.01109361,  0.01344046,  2.0751019 , -0.00419134,  1.04531007,
#                          -0.0069898 ]),
#                   array([-0.02218722,  0.02688092,  2.05580869, -0.00838269,  1.0434226 ,
#                          -0.0139796 ]),
#                   array([-0.03328084,  0.04032138,  2.03651548, -0.01257403,  1.04153512,
#                          -0.0209694 ]),
#                   array([-0.04437445,  0.05376184,  2.01722228, -0.01676538,  1.03964764,
#                          -0.0279592 ]),
#                   array([-0.05546806,  0.0672023 ,  1.99792907, -0.02095672,  1.03776017,
#                          -0.034949  ]),
#                   array([-0.06656167,  0.08064277,  1.97863586, -0.02514806,  1.03587269,
#                          -0.0419388 ]),
#                   array([-0.07765528,  0.09408323,  1.95934266, -0.02933941,  1.03398521,
#                          -0.0489286 ]),
#                   array([-0.08874889,  0.10752369,  1.94004945, -0.03353075,  1.03209774,
#                          -0.0559184 ]),
#                   array([-0.09984251,  0.12096415,  1.92075624, -0.0377221 ,  1.03021026,
#                          -0.0629082 ]),
#                   array([-0.11093612,  0.13440461,  1.90146304, -0.04191344,  1.02832278,
#                          -0.069898  ]),
#                   array([-0.15089921,  0.20169952,  1.82502826, -0.03767834,  1.04518245,
#                          -0.11398088]),
#                   array([-0.19086229,  0.26899442,  1.74859349, -0.03344323,  1.06204211,
#                          -0.15806377]),
#                   array([-0.23082538,  0.33628933,  1.67215871, -0.02920812,  1.07890178,
#                          -0.20214665]),
#                   array([-0.27078847,  0.40358424,  1.59572394, -0.02497302,  1.09576144,
#                          -0.24622953]),
#                   array([-0.31075156,  0.47087914,  1.51928916, -0.02073791,  1.11262111,
#                          -0.29031242]),
#                   array([-0.35071465,  0.53817405,  1.44285438, -0.01650281,  1.12948077,
#                          -0.3343953 ]),
#                   array([-0.39067773,  0.60546896,  1.36641961, -0.0122677 ,  1.14634043,
#                          -0.37847818]),
#                   array([-0.43064082,  0.67276386,  1.28998483, -0.00803259,  1.1632001 ,
#                          -0.42256106]),
#                   array([-0.47060391,  0.74005877,  1.21355006, -0.00379749,  1.18005976,
#                          -0.46664395]),
#                   array([-5.10566998e-01,  8.07353676e-01,  1.13711528e+00,  4.37617031e-04,
#                           1.19691943e+00, -5.10726829e-01])]),
#                 ('release',
#                  [array([-5.10566998e-01,  8.07353676e-01,  1.13711528e+00,  4.37617031e-04,
#                           1.19691943e+00, -5.10726829e-01]),
#                   array([-5.10566502e-01,  8.08791937e-01,  1.13862788e+00,  4.38119439e-04,
#                           1.19396895e+00, -5.10727718e-01]),
#                   array([-5.10561901e-01,  8.23746238e-01,  1.15281336e+00,  4.43420830e-04,
#                           1.16482915e+00, -5.10737012e-01]),
#                   array([-5.10557301e-01,  8.39643427e-01,  1.16540430e+00,  4.49102217e-04,
#                           1.13634101e+00, -5.10746336e-01]),
#                   array([-5.10552700e-01,  8.56450619e-01,  1.17642883e+00,  4.55156312e-04,
#                           1.10850928e+00, -5.10755698e-01]),
#                   array([-5.10548099e-01,  8.74136462e-01,  1.18591007e+00,  4.61574786e-04,
#                           1.08134218e+00, -5.10765106e-01]),
#                   array([-5.10543498e-01,  8.92670901e-01,  1.19386682e+00,  4.68347851e-04,
#                           1.05485098e+00, -5.10774561e-01]),
#                   array([-5.10538897e-01,  9.12025027e-01,  1.20031412e+00,  4.75463832e-04,
#                           1.02904954e+00, -5.10784062e-01]),
#                   array([-5.10534295e-01,  9.32170984e-01,  1.20526367e+00,  4.82908733e-04,
#                           1.00395402e+00, -5.10793604e-01]),
#                   array([-5.10529694e-01,  9.53081942e-01,  1.20872415e+00,  4.90665799e-04,
#                           9.79582563e-01, -5.10803177e-01]),
#                   array([-5.10525093e-01,  9.74732109e-01,  1.21070150e+00,  4.98715067e-04,
#                           9.55955040e-01, -5.10812767e-01]),
#                   array([-5.10520952e-01,  9.94828849e-01,  1.21121583e+00,  5.06189806e-04,
#                           9.35343954e-01, -5.10821397e-01])]),
#                 ('post_release',
#                  [array([-5.10520952e-01,  9.94828849e-01,  1.21121583e+00,  5.06189806e-04,
#                           9.35343954e-01, -5.10821397e-01]),
#                   array([-5.10521414e-01,  9.92564880e-01,  1.21122540e+00,  5.05348697e-04,
#                           9.37598126e-01, -5.10820442e-01]),
#                   array([-5.10526021e-01,  9.70341334e-01,  1.21043172e+00,  4.97083168e-04,
#                           9.60615329e-01, -5.10810857e-01]),
#                   array([-5.10530627e-01,  9.48837167e-01,  1.20815777e+00,  4.89091235e-04,
#                           9.84393427e-01, -5.10801275e-01]),
#                   array([-5.10535234e-01,  9.28077284e-01,  1.20439973e+00,  4.81395772e-04,
#                           1.00891134e+00, -5.10791713e-01]),
#                   array([-5.10539840e-01,  9.08087688e-01,  1.19915113e+00,  4.74016067e-04,
#                           1.03414952e+00, -5.10782184e-01]),
#                   array([-5.10544447e-01,  8.88895410e-01,  1.19240271e+00,  4.66968293e-04,
#                           1.06009020e+00, -5.10772698e-01]),
#                   array([-5.10549054e-01,  8.70528511e-01,  1.18414214e+00,  4.60265953e-04,
#                           1.08671765e+00, -5.10763258e-01]),
#                   array([-5.10553660e-01,  8.53016118e-01,  1.17435367e+00,  4.53920314e-04,
#                           1.11401850e+00, -5.10753866e-01]),
#                   array([-5.10558267e-01,  8.36388529e-01,  1.16301769e+00,  4.47940844e-04,
#                           1.14198206e+00, -5.10744518e-01]),
#                   array([-5.10562874e-01,  8.20677376e-01,  1.15011014e+00,  4.42335638e-04,
#                           1.17060074e+00, -5.10735207e-01]),
#                   array([-5.10567021e-01,  8.07348308e-01,  1.13712564e+00,  4.37616867e-04,
#                           1.19691429e+00, -5.10726852e-01])]),
#                 ('default_release',
#                  [array([-0.47007514,  0.73947819,  1.21160951,  0.00389681,  1.18385536,
#                          -0.46604378]),
#                   array([-0.42958326,  0.67160807,  1.28609339,  0.007356  ,  1.17079642,
#                          -0.42136072]),
#                   array([-0.38909138,  0.60373795,  1.36057726,  0.01081519,  1.15773748,
#                          -0.37667765]),
#                   array([-0.3485995 ,  0.53586784,  1.43506113,  0.01427438,  1.14467855,
#                          -0.33199458]),
#                   array([-0.30810762,  0.46799772,  1.50954501,  0.01773356,  1.13161961,
#                          -0.28731151]),
#                   array([-0.26761574,  0.4001276 ,  1.58402888,  0.02119275,  1.11856067,
#                          -0.24262844]),
#                   array([-0.22712386,  0.33225748,  1.65851276,  0.02465194,  1.10550174,
#                          -0.19794537]),
#                   array([-0.18663198,  0.26438736,  1.73299663,  0.02811113,  1.0924428 ,
#                          -0.1532623 ]),
#                   array([-0.1461401 ,  0.19651724,  1.80748051,  0.03157032,  1.07938386,
#                          -0.10857924]),
#                   array([-0.10564822,  0.12864713,  1.88196438,  0.03502951,  1.06632493,
#                          -0.06389617]),
#                   array([-0.0950834 ,  0.11578241,  1.90320745,  0.03152656,  1.06441219,
#                          -0.05750655]),
#                   array([-0.08451858,  0.1029177 ,  1.92445052,  0.02802361,  1.06249945,
#                          -0.05111693]),
#                   array([-0.07395376,  0.09005299,  1.9456936 ,  0.02452066,  1.06058671,
#                          -0.04472732]),
#                   array([-0.06338893,  0.07718828,  1.96693667,  0.02101771,  1.05867398,
#                          -0.0383377 ]),
#                   array([-0.05282411,  0.06432356,  1.98817974,  0.01751476,  1.05676124,
#                          -0.03194808]),
#                   array([-0.04225929,  0.05145885,  2.00942281,  0.0140118 ,  1.0548485 ,
#                          -0.02555847]),
#                   array([-0.03169447,  0.03859414,  2.03066589,  0.01050885,  1.05293576,
#                          -0.01916885]),
#                   array([-0.02112964,  0.02572943,  2.05190896,  0.0070059 ,  1.05102303,
#                          -0.01277923]),
#                   array([-0.01056482,  0.01286471,  2.07315203,  0.00350295,  1.04911029,
#                          -0.00638962]),
#                   array([0.        , 0.        , 2.0943951 , 0.        , 1.04719755,
#                          0.        ])])]),
#    OrderedDict([('pre_grasp',
#                  [array([ 0.03663012,  0.06731679,  2.0049637 , -0.00333966,  1.06304401,
#                           0.03532771]),
#                   array([ 0.07326024,  0.13463358,  1.91553231, -0.00667931,  1.07889047,
#                           0.07065542]),
#                   array([ 0.10989036,  0.20195037,  1.82610091, -0.01001897,  1.09473693,
#                           0.10598313]),
#                   array([ 0.14652048,  0.26926716,  1.73666951, -0.01335862,  1.11058339,
#                           0.14131084]),
#                   array([ 0.1831506 ,  0.33658395,  1.64723811, -0.01669828,  1.12642985,
#                           0.17663855]),
#                   array([ 0.21978072,  0.40390074,  1.55780672, -0.02003793,  1.14227631,
#                           0.21196626]),
#                   array([ 0.25641084,  0.47121753,  1.46837532, -0.02337759,  1.15812277,
#                           0.24729397]),
#                   array([ 0.29304096,  0.53853432,  1.37894392, -0.02671724,  1.17396923,
#                           0.28262168]),
#                   array([ 0.32967108,  0.60585111,  1.28951252, -0.0300569 ,  1.18981569,
#                           0.31794939]),
#                   array([ 0.3663012 ,  0.6731679 ,  1.20008113, -0.03339655,  1.20566215,
#                           0.3532771 ]),
#                   array([ 0.37227863,  0.67983142,  1.18423319, -0.03571617,  1.20921036,
#                           0.3620504 ]),
#                   array([ 0.37825607,  0.68649495,  1.16838525, -0.03803578,  1.21275857,
#                           0.3708237 ]),
#                   array([ 0.3842335 ,  0.69315848,  1.15253731, -0.0403554 ,  1.21630677,
#                           0.379597  ]),
#                   array([ 0.39021093,  0.699822  ,  1.13668937, -0.04267501,  1.21985498,
#                           0.3883703 ]),
#                   array([ 0.39618836,  0.70648553,  1.12084143, -0.04499463,  1.22340319,
#                           0.39714359]),
#                   array([ 0.40216579,  0.71314905,  1.10499349, -0.04731425,  1.22695139,
#                           0.40591689]),
#                   array([ 0.40814323,  0.71981258,  1.08914555, -0.04963386,  1.2304996 ,
#                           0.41469019]),
#                   array([ 0.41412066,  0.7264761 ,  1.07329761, -0.05195348,  1.23404781,
#                           0.42346349]),
#                   array([ 0.42009809,  0.73313963,  1.05744967, -0.05427309,  1.23759602,
#                           0.43223678]),
#                   array([ 0.42607552,  0.73980315,  1.04160173, -0.05659271,  1.24114422,
#                           0.44101008])]),
#                 ('grasp',
#                  [array([ 0.42607552,  0.73980315,  1.04160173, -0.05659271,  1.24114422,
#                           0.44101008]),
#                   array([ 0.42598422,  0.74080123,  1.04280315, -0.05662388,  1.23894348,
#                           0.44104736]),
#                   array([ 0.42507289,  0.75111475,  1.05425815, -0.05695054,  1.21715942,
#                           0.44141721]),
#                   array([ 0.42416519,  0.76198661,  1.06474922, -0.05730105,  1.19578088,
#                           0.44178179]),
#                   array([ 0.4232611 ,  0.77340075,  1.07429439, -0.05767463,  1.17480589,
#                           0.44214174]),
#                   array([ 0.42236061,  0.78534203,  1.08290927, -0.05807051,  1.15423399,
#                           0.44249755]),
#                   array([ 0.4214637 ,  0.79779611,  1.09060732, -0.05848787,  1.13406608,
#                           0.44284956]),
#                   array([ 0.42057034,  0.81074936,  1.09740006, -0.05892589,  1.11430429,
#                           0.44319791]),
#                   array([ 0.41968051,  0.82418877,  1.10329728, -0.05938365,  1.09495179,
#                           0.44354262]),
#                   array([ 0.41879421,  0.83810194,  1.10830723, -0.05986019,  1.07601277,
#                           0.44388352]),
#                   array([ 0.41791139,  0.852477  ,  1.1124367 , -0.06035448,  1.05749229,
#                           0.44422031]),
#                   array([ 0.41711984,  0.86580008,  1.11540496, -0.06081358,  1.04118654,
#                           0.44451949])]),
#                 ('post_grasp',
#                  [array([ 0.41711984,  0.86580008,  1.11540496, -0.06081358,  1.04118654,
#                           0.44451949]),
#                   array([ 0.41711948,  0.86460914,  1.11449995, -0.06073898,  1.04327831,
#                           0.44437154]),
#                   array([ 0.41711608,  0.85302026,  1.10488369, -0.06001112,  1.06444446,
#                           0.44289618]),
#                   array([ 0.41711268,  0.84196808,  1.09434477, -0.0593147 ,  1.08599679,
#                           0.44142913]),
#                   array([ 0.41710928,  0.83146792,  1.08286705, -0.05864987,  1.10793611,
#                           0.43996962]),
#                   array([ 0.41710587,  0.82153598,  1.0704319 , -0.05801677,  1.13026479,
#                           0.43851671]),
#                   array([ 0.41710247,  0.81218952,  1.05701792, -0.0574155 ,  1.15298696,
#                           0.43706933]),
#                   array([ 0.41709907,  0.80344697,  1.04260053, -0.05684616,  1.17610874,
#                           0.43562622]),
#                   array([ 0.41709567,  0.79532825,  1.02715144, -0.05630889,  1.19963847,
#                           0.43418597]),
#                   array([ 0.41709226,  0.78785494,  1.01063808, -0.05580385,  1.22358707,
#                           0.43274697]),
#                   array([ 0.41708886,  0.78105073,  0.99302288, -0.05533124,  1.2479684 ,
#                           0.43130742]),
#                   array([ 0.4170858 ,  0.77552056,  0.97619132, -0.05493387,  1.27029579,
#                           0.4300097 ])]),
#                 ('default_grasp',
#                  [array([ 0.41569965,  0.7729432 ,  0.97990756, -0.0547513 ,  1.26955435,
#                           0.4285806 ]),
#                   array([ 0.41431351,  0.77036583,  0.9836238 , -0.05456873,  1.2688129 ,
#                           0.42715151]),
#                   array([ 0.41292737,  0.76778847,  0.98734003, -0.05438617,  1.26807146,
#                           0.42572241]),
#                   array([ 0.41154123,  0.7652111 ,  0.99105627, -0.0542036 ,  1.26733001,
#                           0.42429332]),
#                   array([ 0.41015508,  0.76263374,  0.99477251, -0.05402103,  1.26658857,
#                           0.42286423]),
#                   array([ 0.40876894,  0.76005637,  0.99848875, -0.05383847,  1.26584712,
#                           0.42143513]),
#                   array([ 0.4073828 ,  0.75747901,  1.00220498, -0.0536559 ,  1.26510568,
#                           0.42000604]),
#                   array([ 0.40599666,  0.75490165,  1.00592122, -0.05347333,  1.26436423,
#                           0.41857694]),
#                   array([ 0.40461051,  0.75232428,  1.00963746, -0.05329076,  1.26362279,
#                           0.41714785]),
#                   array([ 0.40322437,  0.74974692,  1.0133537 , -0.0531082 ,  1.26288135,
#                           0.41571876]),
#                   array([ 0.36980213,  0.68239492,  1.09078979, -0.04613401,  1.24595501,
#                           0.37747031]),
#                   array([ 0.33637989,  0.61504292,  1.16822589, -0.03915982,  1.22902868,
#                           0.33922187]),
#                   array([ 0.30295765,  0.54769093,  1.24566198, -0.03218564,  1.21210235,
#                           0.30097343]),
#                   array([ 0.26953541,  0.48033893,  1.32309808, -0.02521145,  1.19517602,
#                           0.26272498]),
#                   array([ 0.23611317,  0.41298693,  1.40053417, -0.01823726,  1.17824969,
#                           0.22447654]),
#                   array([ 0.20269093,  0.34563494,  1.47797027, -0.01126307,  1.16132336,
#                           0.18622809]),
#                   array([ 0.16926869,  0.27828294,  1.55540637, -0.00428889,  1.14439703,
#                           0.14797965]),
#                   array([0.13584645, 0.21093094, 1.63284246, 0.0026853 , 1.1274707 ,
#                          0.10973121]),
#                   array([0.10242421, 0.14357895, 1.71027856, 0.00965949, 1.11054437,
#                          0.07148276]),
#                   array([0.06900197, 0.07622695, 1.78771465, 0.01663367, 1.09361804,
#                          0.03323432]),
#                   array([0.06210177, 0.06860425, 1.8183827 , 0.01497031, 1.08897599,
#                          0.02991089]),
#                   array([0.05520157, 0.06098156, 1.84905074, 0.01330694, 1.08433394,
#                          0.02658745]),
#                   array([0.04830138, 0.05335886, 1.87971879, 0.01164357, 1.07969189,
#                          0.02326402]),
#                   array([0.04140118, 0.04573617, 1.91038683, 0.0099802 , 1.07504984,
#                          0.01994059]),
#                   array([0.03450098, 0.03811347, 1.94105488, 0.00831684, 1.07040779,
#                          0.01661716]),
#                   array([0.02760079, 0.03049078, 1.97172292, 0.00665347, 1.06576574,
#                          0.01329373]),
#                   array([0.02070059, 0.02286808, 2.00239097, 0.0049901 , 1.0611237 ,
#                          0.0099703 ]),
#                   array([0.01380039, 0.01524539, 2.03305901, 0.00332673, 1.05648165,
#                          0.00664686]),
#                   array([6.90019663e-03, 7.62269500e-03, 2.06372706e+00, 1.66336738e-03,
#                          1.05183960e+00, 3.32343175e-03]),
#                   array([ 0.00000000e+00,  0.00000000e+00,  2.09439510e+00, -8.67361738e-19,
#                           1.04719755e+00,  0.00000000e+00])])]),
#    OrderedDict([('pre_release',
#                  [array([-1.22280339e-03,  1.02196505e-03,  2.09356883e+00,  2.67767957e-04,
#                           1.04716078e+00, -4.65881471e-03]),
#                   array([-2.44560678e-03,  2.04393010e-03,  2.09274255e+00,  5.35535914e-04,
#                           1.04712400e+00, -9.31762942e-03]),
#                   array([-3.66841017e-03,  3.06589515e-03,  2.09191627e+00,  8.03303871e-04,
#                           1.04708723e+00, -1.39764441e-02]),
#                   array([-4.89121356e-03,  4.08786020e-03,  2.09109000e+00,  1.07107183e-03,
#                           1.04705045e+00, -1.86352588e-02]),
#                   array([-6.11401695e-03,  5.10982525e-03,  2.09026372e+00,  1.33883979e-03,
#                           1.04701368e+00, -2.32940735e-02]),
#                   array([-7.33682033e-03,  6.13179030e-03,  2.08943744e+00,  1.60660774e-03,
#                           1.04697690e+00, -2.79528883e-02]),
#                   array([-8.55962372e-03,  7.15375535e-03,  2.08861117e+00,  1.87437570e-03,
#                           1.04694013e+00, -3.26117030e-02]),
#                   array([-0.00978243,  0.00817572,  2.08778489,  0.00214214,  1.04690335,
#                          -0.03727052]),
#                   array([-0.01100523,  0.00919769,  2.08695861,  0.00240991,  1.04686658,
#                          -0.04192933]),
#                   array([-0.01222803,  0.01021965,  2.08613234,  0.00267768,  1.0468298 ,
#                          -0.04658815]),
#                   array([-0.01345084,  0.01124162,  2.08530606,  0.00294545,  1.04679303,
#                          -0.05124696]),
#                   array([-0.01467364,  0.01226358,  2.08447979,  0.00321322,  1.04675625,
#                          -0.05590578]),
#                   array([-0.01589644,  0.01328555,  2.08365351,  0.00348098,  1.04671948,
#                          -0.06056459]),
#                   array([-0.01711925,  0.01430751,  2.08282723,  0.00374875,  1.0466827 ,
#                          -0.06522341]),
#                   array([-0.01834205,  0.01532948,  2.08200096,  0.00401652,  1.04664593,
#                          -0.06988222]),
#                   array([-0.01956485,  0.01635144,  2.08117468,  0.00428429,  1.04660915,
#                          -0.07454104]),
#                   array([-0.02078766,  0.01737341,  2.0803484 ,  0.00455206,  1.04657238,
#                          -0.07919985]),
#                   array([-0.02201046,  0.01839537,  2.07952213,  0.00481982,  1.0465356 ,
#                          -0.08385866]),
#                   array([-0.02323326,  0.01941734,  2.07869585,  0.00508759,  1.04649882,
#                          -0.08851748]),
#                   array([-0.02445607,  0.0204393 ,  2.07786957,  0.00535536,  1.04646205,
#                          -0.09317629]),
#                   array([-0.04859289,  0.05334309,  2.05005606,  0.01709593,  1.04015532,
#                          -0.20398398]),
#                   array([-0.07272972,  0.08624687,  2.02224254,  0.0288365 ,  1.03384858,
#                          -0.31479167]),
#                   array([-0.09686654,  0.11915066,  1.99442902,  0.04057707,  1.02754185,
#                          -0.42559935]),
#                   array([-0.12100337,  0.15205444,  1.96661551,  0.05231765,  1.02123511,
#                          -0.53640704]),
#                   array([-0.1451402 ,  0.18495823,  1.93880199,  0.06405822,  1.01492838,
#                          -0.64721472]),
#                   array([-0.16927702,  0.21786201,  1.91098847,  0.07579879,  1.00862164,
#                          -0.75802241]),
#                   array([-0.19341385,  0.2507658 ,  1.88317496,  0.08753936,  1.00231491,
#                          -0.8688301 ]),
#                   array([-0.21755067,  0.28366958,  1.85536144,  0.09927993,  0.99600818,
#                          -0.97963778]),
#                   array([-0.2416875 ,  0.31657337,  1.82754792,  0.11102051,  0.98970144,
#                          -1.09044547]),
#                   array([-0.26582432,  0.34947715,  1.79973441,  0.12276108,  0.98339471,
#                          -1.20125315]),
#                   array([-0.2976373 ,  0.36333374,  1.78974135,  0.12327232,  0.98801878,
#                          -1.30361118]),
#                   array([-0.32945027,  0.37719032,  1.7797483 ,  0.12378357,  0.99264286,
#                          -1.4059692 ]),
#                   array([-0.36126325,  0.39104691,  1.76975525,  0.12429481,  0.99726694,
#                          -1.50832722]),
#                   array([-0.39307622,  0.4049035 ,  1.7597622 ,  0.12480606,  1.00189102,
#                          -1.61068525]),
#                   array([-0.4248892 ,  0.41876008,  1.74976914,  0.12531731,  1.0065151 ,
#                          -1.71304327]),
#                   array([-0.45670217,  0.43261667,  1.73977609,  0.12582855,  1.01113918,
#                          -1.81540129]),
#                   array([-0.48851515,  0.44647325,  1.72978304,  0.1263398 ,  1.01576325,
#                          -1.91775932]),
#                   array([-0.52032812,  0.46032984,  1.71978999,  0.12685104,  1.02038733,
#                          -2.02011734]),
#                   array([-0.55214109,  0.47418643,  1.70979694,  0.12736229,  1.02501141,
#                          -2.12247536]),
#                   array([-0.58395407,  0.48804301,  1.69980388,  0.12787353,  1.02963549,
#                          -2.22483339])]),
#                 ('release',
#                  [array([-0.58395407,  0.48804301,  1.69980388,  0.12787353,  1.02963549,
#                          -2.22483339]),
#                   array([-0.58395341,  0.49012717,  1.70117002,  0.12813795,  1.02621362,
#                          -2.22534602]),
#                   array([-0.58394743,  0.51159619,  1.71402305,  0.1309282 ,  0.9921779 ,
#                          -2.23057802]),
#                   array([-0.58394145,  0.53408077,  1.72549877,  0.13396743,  0.95851383,
#                          -2.23598924]),
#                   array([-0.58393547,  0.55754595,  1.7355916 ,  0.13726883,  0.92526276,
#                          -2.24159395]),
#                   array([-0.58392949,  0.58195392,  1.74429584,  0.14084605,  0.89246899,
#                          -2.24740656]),
#                   array([-0.5839235 ,  0.6072642 ,  1.75160596,  0.14471301,  0.86017936,
#                          -2.25344152]),
#                   array([-0.58391751,  0.63343379,  1.75751687,  0.14888378,  0.82844273,
#                          -2.25971312]),
#                   array([-0.58391152,  0.66041751,  1.76202419,  0.15337225,  0.79730946,
#                          -2.26623533]),
#                   array([-0.58390552,  0.68816831,  1.76512438,  0.15819191,  0.76683092,
#                          -2.27302149]),
#                   array([-0.58389952,  0.71663767,  1.76681492,  0.16335542,  0.73705881,
#                          -2.28008402]),
#                   array([-0.58389412,  0.74283356,  1.76712997,  0.16830606,  0.71091056,
#                          -2.28668577])]),
#                 ('post_release',
#                  [array([-0.58389412,  0.74283356,  1.76712997,  0.16830606,  0.71091056,
#                          -2.28668577]),
#                   array([-0.58389482,  0.73989536,  1.76715873,  0.16774028,  0.71377871,
#                          -2.28593979]),
#                   array([-0.58390078,  0.710887  ,  1.76659641,  0.16229326,  0.74294881,
#                          -2.27864798]),
#                   array([-0.58390674,  0.6825577 ,  1.76462322,  0.15719939,  0.77286662,
#                          -2.27164155]),
#                   array([-0.5839127 ,  0.65495677,  1.76124081,  0.15244694,  0.80348049,
#                          -2.26490912]),
#                   array([-0.58391866,  0.62813247,  1.75645192,  0.14802305,  0.83473873,
#                          -2.25843807]),
#                   array([-0.58392462,  0.60213151,  1.75026026,  0.14391413,  0.86659014,
#                          -2.25221488]),
#                   array([-0.58393057,  0.57699866,  1.74267039,  0.14010621,  0.89898462,
#                          -2.2462255 ]),
#                   array([-0.58393652,  0.55277643,  1.73368749,  0.13658525,  0.93187366,
#                          -2.2404556 ]),
#                   array([-0.58394247,  0.52950478,  1.72331715,  0.13333734,  0.9652109 ,
#                          -2.23489073]),
#                   array([-0.58394842,  0.50722096,  1.71156509,  0.13034894,  0.99895258,
#                          -2.22951649]),
#                   array([-0.58395378,  0.48803859,  1.69981144,  0.12787042,  1.02963218,
#                          -2.22483089])]),
#                 ('default_release',
#                  [array([-0.561679  ,  0.47417219,  1.69899949,  0.12412497,  1.00350033,
#                          -2.13259344]),
#                   array([-0.53940423,  0.46030579,  1.69818755,  0.12037952,  0.97736848,
#                          -2.040356  ]),
#                   array([-0.51712946,  0.44643939,  1.6973756 ,  0.11663408,  0.95123663,
#                          -1.94811855]),
#                   array([-0.49485468,  0.43257298,  1.69656366,  0.11288863,  0.92510478,
#                          -1.8558811 ]),
#                   array([-0.47257991,  0.41870658,  1.69575172,  0.10914318,  0.89897293,
#                          -1.76364365]),
#                   array([-0.45030514,  0.40484018,  1.69493977,  0.10539773,  0.87284109,
#                          -1.6714062 ]),
#                   array([-0.42803036,  0.39097377,  1.69412783,  0.10165228,  0.84670924,
#                          -1.57916875]),
#                   array([-0.40575559,  0.37710737,  1.69331588,  0.09790684,  0.82057739,
#                          -1.4869313 ]),
#                   array([-0.38348082,  0.36324097,  1.69250394,  0.09416139,  0.79444554,
#                          -1.39469385]),
#                   array([-0.36120604,  0.34937456,  1.69169199,  0.09041594,  0.76831369,
#                          -1.3024564 ]),
#                   array([-0.32767488,  0.32854533,  1.71008755,  0.08467104,  0.78402406,
#                          -1.20215334]),
#                   array([-0.29414371,  0.30771609,  1.72848311,  0.07892614,  0.79973443,
#                          -1.10185027]),
#                   array([-0.26061255,  0.28688685,  1.74687867,  0.07318124,  0.8154448 ,
#                          -1.0015472 ]),
#                   array([-0.22708139,  0.26605761,  1.76527422,  0.06743634,  0.83115517,
#                          -0.90124414]),
#                   array([-0.19355022,  0.24522837,  1.78366978,  0.06169144,  0.84686554,
#                          -0.80094107]),
#                   array([-0.16001906,  0.22439914,  1.80206534,  0.05594654,  0.86257591,
#                          -0.700638  ]),
#                   array([-0.12648789,  0.2035699 ,  1.8204609 ,  0.05020164,  0.87828628,
#                          -0.60033494]),
#                   array([-0.09295673,  0.18274066,  1.83885645,  0.04445674,  0.89399665,
#                          -0.50003187]),
#                   array([-0.05942557,  0.16191142,  1.85725201,  0.03871184,  0.90970702,
#                          -0.39972881]),
#                   array([-0.0258944 ,  0.14108219,  1.87564757,  0.03296694,  0.92541738,
#                          -0.29942574]),
#                   array([-0.02330496,  0.12697397,  1.89752232,  0.02967025,  0.9375954 ,
#                          -0.26948317]),
#                   array([-0.02071552,  0.11286575,  1.91939707,  0.02637355,  0.94977342,
#                          -0.23954059]),
#                   array([-0.01812608,  0.09875753,  1.94127183,  0.02307686,  0.96195143,
#                          -0.20959802]),
#                   array([-0.01553664,  0.08464931,  1.96314658,  0.01978017,  0.97412945,
#                          -0.17965544]),
#                   array([-0.0129472 ,  0.07054109,  1.98502133,  0.01648347,  0.98630747,
#                          -0.14971287]),
#                   array([-0.01035776,  0.05643287,  2.00689609,  0.01318678,  0.99848548,
#                          -0.1197703 ]),
#                   array([-0.00776832,  0.04232466,  2.02877084,  0.00989008,  1.0106635 ,
#                          -0.08982772]),
#                   array([-0.00517888,  0.02821644,  2.0506456 ,  0.00659339,  1.02284152,
#                          -0.05988515]),
#                   array([-0.00258944,  0.01410822,  2.07252035,  0.00329669,  1.03501953,
#                          -0.02994257]),
#                   array([-2.16840434e-19,  0.00000000e+00,  2.09439510e+00, -8.67361738e-19,
#                           1.04719755e+00,  0.00000000e+00])])]),
#    OrderedDict([('pre_grasp',
#                  [array([ 0.0165156 ,  0.03849001,  2.04123831,  0.00866194,  1.05260573,
#                          -0.0707386 ]),
#                   array([ 0.03303121,  0.07698001,  1.98808153,  0.01732388,  1.0580139 ,
#                          -0.14147719]),
#                   array([ 0.04954681,  0.11547002,  1.93492474,  0.02598582,  1.06342208,
#                          -0.21221579]),
#                   array([ 0.06606241,  0.15396002,  1.88176795,  0.03464776,  1.06883026,
#                          -0.28295439]),
#                   array([ 0.08257802,  0.19245003,  1.82861116,  0.04330971,  1.07423843,
#                          -0.35369298]),
#                   array([ 0.09909362,  0.23094003,  1.77545437,  0.05197165,  1.07964661,
#                          -0.42443158]),
#                   array([ 0.11560922,  0.26943004,  1.72229759,  0.06063359,  1.08505479,
#                          -0.49517018]),
#                   array([ 0.13212483,  0.30792004,  1.6691408 ,  0.06929553,  1.09046296,
#                          -0.56590877]),
#                   array([ 0.14864043,  0.34641005,  1.61598401,  0.07795747,  1.09587114,
#                          -0.63664737]),
#                   array([ 0.16515603,  0.38490006,  1.56282722,  0.08661941,  1.10127932,
#                          -0.70738596]),
#                   array([ 0.195775  ,  0.42344998,  1.51065336,  0.09127161,  1.12163445,
#                          -0.77613579]),
#                   array([ 0.22639397,  0.4619999 ,  1.45847949,  0.0959238 ,  1.14198958,
#                          -0.84488561]),
#                   array([ 0.25701294,  0.50054982,  1.40630562,  0.10057599,  1.16234471,
#                          -0.91363543]),
#                   array([ 0.28763191,  0.53909975,  1.35413176,  0.10522819,  1.18269984,
#                          -0.98238525]),
#                   array([ 0.31825088,  0.57764967,  1.30195789,  0.10988038,  1.20305497,
#                          -1.05113507]),
#                   array([ 0.34886984,  0.61619959,  1.24978402,  0.11453257,  1.2234101 ,
#                          -1.11988489]),
#                   array([ 0.37948881,  0.65474951,  1.19761016,  0.11918477,  1.24376523,
#                          -1.18863472]),
#                   array([ 0.41010778,  0.69329943,  1.14543629,  0.12383696,  1.26412036,
#                          -1.25738454]),
#                   array([ 0.44072675,  0.73184936,  1.09326242,  0.12848916,  1.28447549,
#                          -1.32613436]),
#                   array([ 0.47134572,  0.77039928,  1.04108856,  0.13314135,  1.30483062,
#                          -1.39488418])]),
#                 ('grasp',
#                  [array([ 0.47134572,  0.77039928,  1.04108856,  0.13314135,  1.30483062,
#                          -1.39488418]),
#                   array([ 0.47156097,  0.77123327,  1.04257213,  0.13322005,  1.30250618,
#                          -1.39498829]),
#                   array([ 0.47371228,  0.77993002,  1.0568294 ,  0.13404796,  1.27947981,
#                          -1.39602336]),
#                   array([ 0.47586141,  0.78922831,  1.07008555,  0.13494134,  1.2568523 ,
#                          -1.39704571]),
#                   array([ 0.47800834,  0.79910982,  1.0823648 ,  0.13589875,  1.23461792,
#                          -1.39805805]),
#                   array([ 0.48015305,  0.80955742,  1.09368823,  0.13691878,  1.21277287,
#                          -1.39906264]),
#                   array([ 0.48229552,  0.82055499,  1.10407416,  0.13800006,  1.19131507,
#                          -1.40006135]),
#                   array([ 0.48443574,  0.83208729,  1.11353851,  0.13914119,  1.17024393,
#                          -1.40105569]),
#                   array([ 0.4865737 ,  0.84413984,  1.12209507,  0.14034069,  1.14956023,
#                          -1.40204674]),
#                   array([ 0.48870937,  0.85669877,  1.12975576,  0.14159705,  1.12926596,
#                          -1.40303527]),
#                   array([ 0.49084275,  0.86975083,  1.13653077,  0.14290859,  1.10936419,
#                          -1.40402164]),
#                   array([ 0.49276081,  0.88190876,  1.14187827,  0.1441347 ,  1.0917915 ,
#                          -1.40490754])]),
#                 ('post_grasp',
#                  [array([ 0.49276081,  0.88190876,  1.14187827,  0.1441347 ,  1.0917915 ,
#                          -1.40490754]),
#                   array([ 0.49276044,  0.88061896,  1.14113751,  0.14398328,  1.09380083,
#                          -1.40457932]),
#                   array([ 0.49275703,  0.86802356,  1.13318369,  0.14250485,  1.11414041,
#                          -1.40129781]),
#                   array([ 0.49275363,  0.85593707,  1.12433716,  0.14108931,  1.13486417,
#                          -1.39802176]),
#                   array([ 0.49275022,  0.84437336,  1.11458596,  0.13973784,  1.15597015,
#                          -1.39475031]),
#                   array([ 0.49274681,  0.83334696,  1.10391623,  0.13845153,  1.17745759,
#                          -1.39148221]),
#                   array([ 0.4927434 ,  0.82287312,  1.09231197,  0.13723138,  1.19932714,
#                          -1.38821586]),
#                   array([ 0.49273999,  0.81296794,  1.07975482,  0.13607837,  1.22158093,
#                          -1.38494928]),
#                   array([ 0.49273658,  0.80364853,  1.06622367,  0.13499348,  1.24422284,
#                          -1.38168011]),
#                   array([ 0.49273318,  0.79493316,  1.05169425,  0.13397771,  1.26725864,
#                          -1.37840557]),
#                   array([ 0.49272977,  0.78684151,  1.03613869,  0.13303218,  1.29069635,
#                          -1.37512246]),
#                   array([ 0.4927267 ,  0.78010991,  1.02123491,  0.13224223,  1.31214254,
#                          -1.37215728])]),
#                 ('default_grasp',
#                  [array([ 0.46839082,  0.73475631,  1.05620169,  0.12242944,  1.29707615,
#                          -1.29481279]),
#                   array([ 0.44405494,  0.68940272,  1.09116847,  0.11261664,  1.28200977,
#                          -1.21746829]),
#                   array([ 0.41971906,  0.64404912,  1.12613526,  0.10280385,  1.26694338,
#                          -1.14012379]),
# ...
#                          -1.13747618]),
#                   array([ 0.37842038,  0.61108722,  1.42841429,  0.13495556,  1.04767038,
#                          -1.19280105]),
#                   array([ 0.388982  ,  0.63873519,  1.40115435,  0.13970131,  1.05585582,
#                          -1.24812591])]),
#                 ('grasp',
#                  [array([ 0.388982  ,  0.63873519,  1.40115435,  0.13970131,  1.05585582,
#                          -1.24812591]),
#                   array([ 0.38921051,  0.64008811,  1.40205026,  0.13986761,  1.05360084,
#                          -1.24825378]),
#                   array([ 0.39149326,  0.65392021,  1.41054142,  0.14158637,  1.03121519,
#                          -1.24956109]),
#                   array([ 0.39377147,  0.66824951,  1.41823322,  0.14339651,  1.00913465,
#                          -1.2509144 ]),
#                   array([ 0.39604513,  0.68306335,  1.42512903,  0.14529871,  0.98736862,
#                          -1.25231551]),
#                   array([ 0.39831423,  0.69834894,  1.43123165,  0.14729352,  0.96592715,
#                          -1.25376597]),
#                   array([ 0.40057877,  0.7140934 ,  1.43654338,  0.14938127,  0.9448209 ,
#                          -1.25526701]),
#                   array([ 0.40283873,  0.73028371,  1.44106613,  0.15156209,  0.92406103,
#                          -1.25681952]),
#                   array([ 0.40509411,  0.7469068 ,  1.4448014 ,  0.15383581,  0.90365914,
#                          -1.25842402]),
#                   array([ 0.4073449 ,  0.76394949,  1.44775038,  0.15620197,  0.8836272 ,
#                          -1.26008062]),
#                   array([ 0.40959109,  0.78139861,  1.44991397,  0.15865969,  0.86397748,
#                          -1.26178897]),
#                   array([ 0.41160872,  0.79743942,  1.45119022,  0.16094888,  0.84662983,
#                          -1.26337005])]),
#                 ('post_grasp',
#                  [array([ 0.41160872,  0.79743942,  1.45119022,  0.16094888,  0.84662983,
#                          -1.26337005]),
#                   array([ 0.41160829,  0.7957475 ,  1.45083786,  0.16065926,  0.84864755,
#                          -1.26293326]),
#                   array([ 0.41160448,  0.77908177,  1.44683621,  0.15783128,  0.86905423,
#                          -1.25860846]),
#                   array([ 0.41160067,  0.76285314,  1.44204749,  0.1551206 ,  0.88981564,
#                          -1.25436089]),
#                   array([ 0.41159686,  0.74707472,  1.43647013,  0.15252606,  0.91092007,
#                          -1.25018894]),
#                   array([ 0.41159306,  0.73175955,  1.43010224,  0.15004623,  0.9323563 ,
#                          -1.24609064]),
#                   array([ 0.41158925,  0.71692054,  1.42294144,  0.14767945,  0.95411365,
#                          -1.2420637 ]),
#                   array([ 0.41158544,  0.70257044,  1.41498489,  0.1454239 ,  0.97618202,
#                          -1.23810556]),
#                   array([ 0.41158164,  0.6887219 ,  1.40622917,  0.14327763,  0.99855204,
#                          -1.23421341]),
#                   array([ 0.41157783,  0.67538741,  1.3966702 ,  0.14123861,  1.02121509,
#                          -1.23038421]),
#                   array([ 0.41157403,  0.66257937,  1.38630316,  0.13930476,  1.04416341,
#                          -1.22661476]),
#                   array([ 0.4115706 ,  0.65151242,  1.37627724,  0.13765249,  1.06505515,
#                          -1.22327054])]),
#                 ('default_grasp',
#                  [array([ 0.37506143,  0.59904241,  1.4219751 ,  0.12732138,  1.06184096,
#                          -1.12411154]),
#                   array([ 0.33855226,  0.5465724 ,  1.46767296,  0.11699028,  1.05862677,
#                          -1.02495253]),
#                   array([ 0.3020431 ,  0.49410239,  1.51337082,  0.10665917,  1.05541259,
#                          -0.92579353]),
#                   array([ 0.26553393,  0.44163238,  1.55906868,  0.09632806,  1.0521984 ,
#                          -0.82663453]),
#                   array([ 0.22902476,  0.38916237,  1.60476654,  0.08599696,  1.04898421,
#                          -0.72747553]),
#                   array([ 0.19251559,  0.33669236,  1.65046441,  0.07566585,  1.04577002,
#                          -0.62831653]),
#                   array([ 0.15600642,  0.28422235,  1.69616227,  0.06533474,  1.04255583,
#                          -0.52915753]),
#                   array([ 0.11949725,  0.23175234,  1.74186013,  0.05500364,  1.03934165,
#                          -0.42999853]),
#                   array([ 0.08298808,  0.17928233,  1.78755799,  0.04467253,  1.03612746,
#                          -0.33083953]),
#                   array([ 0.04647892,  0.12681232,  1.83325585,  0.03434142,  1.03291327,
#                          -0.23168053]),
#                   array([ 0.04183102,  0.11413108,  1.85936978,  0.03090728,  1.0343417 ,
#                          -0.20851247]),
#                   array([ 0.03718313,  0.10144985,  1.8854837 ,  0.02747314,  1.03577013,
#                          -0.18534442]),
#                   array([ 0.03253524,  0.08876862,  1.91159763,  0.02403899,  1.03719855,
#                          -0.16217637]),
#                   array([ 0.02788735,  0.07608739,  1.93771155,  0.02060485,  1.03862698,
#                          -0.13900832]),
#                   array([ 0.02323946,  0.06340616,  1.96382548,  0.01717071,  1.04005541,
#                          -0.11584026]),
#                   array([ 0.01859157,  0.05072493,  1.9899394 ,  0.01373657,  1.04148384,
#                          -0.09267221]),
#                   array([ 0.01394367,  0.03804369,  2.01605333,  0.01030243,  1.04291227,
#                          -0.06950416]),
#                   array([ 0.00929578,  0.02536246,  2.04216725,  0.00686828,  1.04434069,
#                          -0.04633611]),
#                   array([ 0.00464789,  0.01268123,  2.06828118,  0.00343414,  1.04576912,
#                          -0.02316805]),
#                   array([0.        , 0.        , 2.0943951 , 0.        , 1.04719755,
#                          0.        ])])]),
#    OrderedDict([('pre_release',
#                  [array([-0.00778373, -0.00317555,  2.07534831,  0.00246047,  1.05412299,
#                           0.05247679]),
#                   array([-0.01556747, -0.0063511 ,  2.05630153,  0.00492095,  1.06104843,
#                           0.10495358]),
#                   array([-0.0233512 , -0.00952665,  2.03725474,  0.00738142,  1.06797387,
#                           0.15743037]),
#                   array([-0.03113494, -0.0127022 ,  2.01820795,  0.0098419 ,  1.07489931,
#                           0.20990717]),
#                   array([-0.03891867, -0.01587775,  1.99916116,  0.01230237,  1.08182475,
#                           0.26238396]),
#                   array([-0.04670241, -0.0190533 ,  1.98011437,  0.01476285,  1.08875018,
#                           0.31486075]),
#                   array([-0.05448614, -0.02222885,  1.96106758,  0.01722332,  1.09567562,
#                           0.36733754]),
#                   array([-0.06226988, -0.0254044 ,  1.9420208 ,  0.0196838 ,  1.10260106,
#                           0.41981433]),
#                   array([-0.07005361, -0.02857995,  1.92297401,  0.02214427,  1.1095265 ,
#                           0.47229112]),
#                   array([-0.07783734, -0.0317555 ,  1.90392722,  0.02460475,  1.11645194,
#                           0.52476792]),
#                   array([-0.06975646, -0.00451814,  1.8913066 ,  0.00925903,  1.11662538,
#                           0.63467204]),
#                   array([-0.06167557,  0.02271921,  1.87868598, -0.0060867 ,  1.11679882,
#                           0.74457616]),
#                   array([-0.05359469,  0.04995656,  1.86606536, -0.02143242,  1.11697226,
#                           0.85448028]),
#                   array([-0.0455138 ,  0.07719392,  1.85344473, -0.03677814,  1.1171457 ,
#                           0.9643844 ]),
#                   array([-0.03743292,  0.10443127,  1.84082411, -0.05212386,  1.11731913,
#                           1.07428852]),
#                   array([-0.02935203,  0.13166863,  1.82820349, -0.06746958,  1.11749257,
#                           1.18419264]),
#                   array([-0.02127115,  0.15890598,  1.81558287, -0.0828153 ,  1.11766601,
#                           1.29409676]),
#                   array([-0.01319026,  0.18614333,  1.80296225, -0.09816102,  1.11783945,
#                           1.40400088]),
#                   array([-0.00510938,  0.21338069,  1.79034163, -0.11350675,  1.11801289,
#                           1.513905  ]),
#                   array([ 0.00297151,  0.24061804,  1.777721  , -0.12885247,  1.11818633,
#                           1.62380912]),
#                   array([ 0.00332371,  0.24162476,  1.77829856, -0.13052931,  1.11759626,
#                           1.62564768]),
#                   array([ 0.00367591,  0.24263147,  1.77887612, -0.13220615,  1.11700618,
#                           1.62748624]),
#                   array([ 0.00402811,  0.24363819,  1.77945368, -0.133883  ,  1.11641611,
#                           1.6293248 ]),
#                   array([ 0.00438032,  0.2446449 ,  1.78003124, -0.13555984,  1.11582603,
#                           1.63116335]),
#                   array([ 0.00473252,  0.24565162,  1.7806088 , -0.13723668,  1.11523596,
#                           1.63300191]),
#                   array([ 0.00508472,  0.24665833,  1.78118636, -0.13891352,  1.11464589,
#                           1.63484047]),
#                   array([ 0.00543693,  0.24766505,  1.78176392, -0.14059037,  1.11405581,
#                           1.63667903]),
#                   array([ 0.00578913,  0.24867176,  1.78234148, -0.14226721,  1.11346574,
#                           1.63851758]),
#                   array([ 0.00614133,  0.24967848,  1.78291904, -0.14394405,  1.11287566,
#                           1.64035614]),
#                   array([ 0.00649354,  0.25068519,  1.7834966 , -0.1456209 ,  1.11228559,
#                           1.6421947 ])]),
#                 ('release',
#                  [array([ 0.00649354,  0.25068519,  1.7834966 , -0.1456209 ,  1.11228559,
#                           1.6421947 ]),
#                   array([ 0.00649421,  0.25231897,  1.78570198, -0.14589577,  1.10848765,
#                           1.64281652]),
#                   array([ 0.006501  ,  0.26945681,  1.80698935, -0.14884266,  1.07048037,
#                           1.64918813]),
#                   array([ 0.0065078 ,  0.28791775,  1.82695513, -0.15213604,  1.03248936,
#                           1.65583019]),
#                   array([ 0.00651459,  0.30768858,  1.84558735, -0.15580638,  0.99454199,
#                           1.66277595]),
#                   array([ 0.00652139,  0.32875175,  1.86287214, -0.15988806,  0.95667211,
#                           1.67006188]),
#                   array([ 0.00652818,  0.35108492,  1.87879422, -0.16441972,  0.91891999,
#                           1.67772814]),
#                   array([ 0.00653499,  0.37466054,  1.89333741, -0.16944473,  0.88133232,
#                           1.68581904]),
#                   array([ 0.00654179,  0.39944562,  1.90648507, -0.17501166,  0.843962  ,
#                           1.69438359]),
#                   array([ 0.0065486 ,  0.42540153,  1.91822058, -0.18117489,  0.80686789,
#                           1.70347616]),
#                   array([ 0.00655541,  0.45248398,  1.92852783, -0.1879952 ,  0.77011444,
#                           1.71315708]),
#                   array([ 0.00656155,  0.47778031,  1.93657057, -0.19475119,  0.73738501,
#                           1.72242819])]),
#                 ('post_release',
#                  [array([ 0.00656155,  0.47778031,  1.93657057, -0.19475119,  0.73738501,
#                           1.72242819]),
#                   array([ 0.00656103,  0.47492406,  1.93574326, -0.1939668 ,  0.74099843,
#                           1.72136785]),
#                   array([ 0.00655411,  0.44697636,  1.92658906, -0.18657228,  0.77742969,
#                           1.71116824]),
#                   array([ 0.00654721,  0.42011582,  1.91599436, -0.17988854,  0.81425682,
#                           1.70161006]),
#                   array([ 0.00654031,  0.39439114,  1.90397458, -0.1738492 ,  0.85141126,
#                           1.69262768]),
#                   array([ 0.00653342,  0.36984548,  1.890546  , -0.16839481,  0.88882963,
#                           1.68416202]),
#                   array([ 0.00652654,  0.34651632,  1.87572526, -0.1634722 ,  0.92645424,
#                           1.67615983]),
#                   array([ 0.00651966,  0.32443556,  1.85952896, -0.15903386,  0.96423341,
#                           1.66857306]),
#                   array([ 0.00651279,  0.30362966,  1.84197314, -0.15503742,  1.00212174,
#                           1.66135829]),
#                   array([ 0.00650592,  0.28411998,  1.82307282, -0.15144512,  1.04008024,
#                           1.65447613]),
#                   array([ 0.00649905,  0.26592315,  1.80284155, -0.14822339,  1.07807635,
#                           1.64789078]),
#                   array([ 0.00649288,  0.25067883,  1.78350504, -0.14561599,  1.11228331,
#                           1.64219068])]),
#                 ('default_release',
#                  [array([ 0.00444934,  0.23594359,  1.78642595, -0.15014516,  1.10774696,
#                           1.58577831]),
#                   array([ 0.00240579,  0.22120835,  1.78934687, -0.15467433,  1.10321061,
#                           1.52936595]),
#                   array([ 3.62248974e-04,  2.06473111e-01,  1.79226778e+00, -1.59203502e-01,
#                           1.09867427e+00,  1.47295358e+00]),
#                   array([-1.68129468e-03,  1.91737871e-01,  1.79518870e+00, -1.63732671e-01,
#                           1.09413792e+00,  1.41654121e+00]),
#                   array([-0.00372484,  0.17700263,  1.79810961, -0.16826184,  1.08960157,
#                           1.36012884]),
#                   array([-0.00576838,  0.16226739,  1.80103053, -0.17279101,  1.08506523,
#                           1.30371647]),
#                   array([-0.00781193,  0.14753215,  1.80395145, -0.17732018,  1.08052888,
#                           1.24730411]),
#                   array([-0.00985547,  0.13279691,  1.80687236, -0.18184935,  1.07599253,
#                           1.19089174]),
#                   array([-0.01189901,  0.11806167,  1.80979328, -0.18637852,  1.07145619,
#                           1.13447937]),
#                   array([-0.01394256,  0.10332643,  1.81271419, -0.19090769,  1.06691984,
#                           1.078067  ]),
#                   array([-0.0125483 ,  0.09299379,  1.84088228, -0.17181692,  1.06494761,
#                           0.9702603 ]),
#                   array([-0.01115405,  0.08266115,  1.86905038, -0.15272615,  1.06297538,
#                           0.8624536 ]),
#                   array([-0.00975979,  0.0723285 ,  1.89721847, -0.13363538,  1.06100315,
#                           0.7546469 ]),
#                   array([-0.00836553,  0.06199586,  1.92538656, -0.11454461,  1.05903092,
#                           0.6468402 ]),
#                   array([-0.00697128,  0.05166322,  1.95355465, -0.09545385,  1.0570587 ,
#                           0.5390335 ]),
#                   array([-0.00557702,  0.04133057,  1.98172274, -0.07636308,  1.05508647,
#                           0.4312268 ]),
#                   array([-0.00418277,  0.03099793,  2.00989083, -0.05727231,  1.05311424,
#                           0.3234201 ]),
#                   array([-0.00278851,  0.02066529,  2.03805892, -0.03818154,  1.05114201,
#                           0.2156134 ]),
#                   array([-1.39425566e-03,  1.03326431e-02,  2.06622701e+00, -1.90907690e-02,
#                           1.04916978e+00,  1.07806700e-01]),
#                   array([ 0.00000000e+00,  0.00000000e+00,  2.09439510e+00, -5.42101086e-20,
#                           1.04719755e+00,  0.00000000e+00])])])]]]

# %%
mcts.place_action.simulate_path(
    final_pnp_all_joint_paths[0],
    pick_all_objects,
    place_all_object_poses,
    is_save=True,
    video_name="MCTS_Benchamrk3_pytamp_jh",
)
# Out:
# PWD :  /home/juju/pytamp/examples/doosan/action/rearrangement1
# KeyboardInterrupt
# Error in callback <function flush_figures at 0x7f2c9021b550> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/IPython/core/formatters.py:177, in DisplayFormatter.format(self, obj, include, exclude)
#     175 md = None
#     176 try:
# --> 177     data = formatter(obj)
#     178 except:
#     179     # FIXME: log the exception
#     180     raise
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/IPython/core/formatters.py:221, in catch_format_error(method, self, *args, **kwargs)
#     219 """show traceback on failed format call"""
#     220 try:
# --> 221     r = method(self, *args, **kwargs)
#     222 except NotImplementedError:
#     223     # don't warn on NotImplementedErrors
#     224     return self._check_return(None, args[0])
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/IPython/core/formatters.py:338, in BaseFormatter.__call__(self, obj)
#     336     pass
#     337 else:
# --> 338     return printer(obj)
#     339 # Finally look for special method names
#     340 method = get_real_method(obj, self.print_method)
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/matplotlib/backend_bases.py:2295, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2289     renderer = _get_renderer(
#    2290         self.figure,
#    2291         functools.partial(
#    2292             print_method, orientation=orientation)
#    2293     )
#    2294     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2295         self.figure.draw(renderer)
#    2297 if bbox_inches:
#    2298     if bbox_inches == "tight":
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/matplotlib/artist.py:73, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      71 @wraps(draw)
#      72 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73     result = draw(artist, renderer, *args, **kwargs)
#      74     if renderer._rasterizing:
#      75         renderer.stop_rasterizing()
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/matplotlib/figure.py:2837, in Figure.draw(self, renderer)
#    2834         # ValueError can occur when resizing a window.
#    2836 self.patch.draw(renderer)
# -> 2837 mimage._draw_list_compositing_images(
#    2838     renderer, self, artists, self.suppressComposite)
#    2840 for sfig in self.subfigs:
#    2841     sfig.draw(renderer)
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/mpl_toolkits/mplot3d/axes3d.py:451, in Axes3D.draw(self, renderer)
#     448 zorder_offset = max(axis.get_zorder()
#     449                     for axis in self._get_axis_list()) + 1
#     450 collection_zorder = patch_zorder = zorder_offset
# --> 451 for artist in sorted(collections_and_patches,
#     452                      key=do_3d_projection,
#     453                      reverse=True):
#     454     if isinstance(artist, mcoll.Collection):
#     455         artist.zorder = collection_zorder
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/mpl_toolkits/mplot3d/axes3d.py:440, in Axes3D.draw.<locals>.do_3d_projection(artist)
#     437     return artist.do_3d_projection(renderer)
#     438 else:
#     439     # Call this directly once the deprecation period expires.
# --> 440     return artist.do_3d_projection()
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/matplotlib/_api/deprecation.py:389, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     384 @functools.wraps(func)
#     385 def wrapper(*inner_args, **inner_kwargs):
#     386     if len(inner_args) <= name_idx and name not in inner_kwargs:
#     387         # Early return in the simple, non-deprecated case (much faster than
#     388         # calling bind()).
# --> 389         return func(*inner_args, **inner_kwargs)
#     390     arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     391     if is_varargs and arguments.get(name):
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/mpl_toolkits/mplot3d/art3d.py:823, in Poly3DCollection.do_3d_projection(self, renderer)
#     819         cedge = cedge.repeat(len(xyzlist), axis=0)
#     821 if xyzlist:
#     822     # sort by depth (furthest drawn first)
# --> 823     z_segments_2d = sorted(
#     824         ((self._zsortfunc(zs), np.column_stack([xs, ys]), fc, ec, idx)
#     825          for idx, ((xs, ys, zs), fc, ec)
#     826          in enumerate(zip(xyzlist, cface, cedge))),
#     827         key=lambda x: x[0], reverse=True)
#     829     _, segments_2d, self._facecolors2d, self._edgecolors2d, idxs = \
#     830         zip(*z_segments_2d)
#     831 else:
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/mpl_toolkits/mplot3d/art3d.py:824, in <genexpr>(.0)
#     819         cedge = cedge.repeat(len(xyzlist), axis=0)
#     821 if xyzlist:
#     822     # sort by depth (furthest drawn first)
#     823     z_segments_2d = sorted(
# --> 824         ((self._zsortfunc(zs), np.column_stack([xs, ys]), fc, ec, idx)
#     825          for idx, ((xs, ys, zs), fc, ec)
#     826          in enumerate(zip(xyzlist, cface, cedge))),
#     827         key=lambda x: x[0], reverse=True)
#     829     _, segments_2d, self._facecolors2d, self._edgecolors2d, idxs = \
#     830         zip(*z_segments_2d)
#     831 else:
#
# File <__array_function__ internals>:180, in average(*args, **kwargs)
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/numpy/lib/function_base.py:518, in average(a, axis, weights, returned, keepdims)
#     515     keepdims_kw = {'keepdims': keepdims}
#     517 if weights is None:
# --> 518     avg = a.mean(axis, **keepdims_kw)
#     519     scl = avg.dtype.type(a.size/avg.size)
#     520 else:
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/numpy/core/_methods.py:168, in _mean(a, axis, dtype, out, keepdims, where)
#     164 arr = asanyarray(a)
#     166 is_float16_result = False
# --> 168 rcount = _count_reduce_items(arr, axis, keepdims=keepdims, where=where)
#     169 if rcount == 0 if where is True else umr_any(rcount == 0, axis=None):
#     170     warnings.warn("Mean of empty slice.", RuntimeWarning, stacklevel=2)
#
# File ~/anaconda3/envs/TAMP_39/lib/python3.9/site-packages/numpy/core/_methods.py:71, in _count_reduce_items(arr, axis, keepdims, where)
#      68 if where is True:
#      69     # no boolean mask given, calculate items according to axis
#      70     if axis is None:
# ---> 71         axis = tuple(range(arr.ndim))
#      72     elif not isinstance(axis, tuple):
#      73         axis = (axis,)
#
# KeyboardInterrupt:

# %%
place_all_object_poses[0]
# Out:
# [array([[ 9.99999973e-01,  2.30372276e-04, -5.55111512e-16,
#           9.04814158e-01],
#         [-2.30372276e-04,  9.99999973e-01, -1.57209315e-18,
#          -4.13413837e-01],
#         [ 5.27355937e-16,  1.68051337e-18,  1.00000000e+00,
#           8.23434152e-01],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00]]),
#  array([[-9.99999984e-01, -1.76974488e-04, -6.66133815e-16,
#           6.25911128e-01],
#         [ 1.76974488e-04, -9.99999984e-01,  2.27682456e-18,
#          -2.56086796e-01],
#         [-6.93889390e-16,  2.11419424e-18,  1.00000000e+00,
#           7.70299977e-01],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00]]),
#  array([[ 2.03673204e-04, -9.99999979e-01,  7.15572621e-14,
#           5.35368534e-01],
#         [ 9.99999979e-01,  2.03673204e-04,  1.43041774e-13,
#          -5.15268482e-01],
#         [-1.43056357e-13,  7.15281241e-14,  1.00000000e+00,
#           7.70234152e-01],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00]]),
#  array([[-9.99999973e-01, -2.30372276e-04,  3.60822483e-16,
#           7.54472013e-01],
#         [ 2.30372276e-04, -9.99999973e-01,  8.67361738e-19,
#          -3.38342278e-01],
#         [ 2.49800181e-16,  1.02999206e-18,  1.00000000e+00,
#           7.70299977e-01],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00]]),
#  array([[ 1.76974488e-04, -9.99999984e-01, -6.10622664e-16,
#           8.05170900e-01],
#         [ 9.99999984e-01,  1.76974488e-04,  2.05998413e-18,
#           1.69339516e-03],
#         [ 1.10588622e-17, -6.93889390e-16,  1.00000000e+00,
#           8.23434152e-01],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00]]),
#  array([[ 2.30372276e-04, -9.99999973e-01,  4.16333634e-16,
#           5.02997228e-01],
#         [ 9.99999973e-01,  2.30372276e-04,  1.02999206e-18,
#          -2.96799766e-01],
#         [-2.33645568e-17,  3.33066907e-16,  1.00000000e+00,
#           8.23434152e-01],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00]]),
#  array([[ 9.99999984e-01,  1.76974488e-04, -6.38378239e-16,
#           5.99359323e-01],
#         [-1.76974488e-04,  9.99999984e-01,  2.16840434e-18,
#          -1.67853871e-03],
#         [ 6.93889390e-16, -2.00577402e-18,  1.00000000e+00,
#           8.81093381e-01],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.00000000e+00]])]

# %%
mcts.visualize_tree("Siccess nodes", mcts.tree)
