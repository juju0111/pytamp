# %%
import numpy as np
import argparse
import os

from pykin.utils import plot_utils as p_utils
from pytamp.benchmark import Benchmark4
from pytamp.search.mcts import MCTS


# #? python3 benchmark4_test.py --budgets 1000 --max_depth 20 --seed 3 --algo bai_ucb
parser = argparse.ArgumentParser(description="Test Benchmark 4.")
parser.add_argument("--budgets", metavar="T", type=int, default=100, help="Horizon")
parser.add_argument("--max_depth", metavar="H", type=int, default=20, help="Max depth")
parser.add_argument("--seed", metavar="i", type=int, default=1, help="A random seed")
parser.add_argument(
    "--algo",
    metavar="alg",
    type=str,
    default="bai_perturb",
    choices=["bai_perturb", "bai_ucb", "uct", "random", "greedy"],
    help="Choose one (bai_perturb, bai_ucb, uct)",
)
parser.add_argument(
    "--debug_mode", default=False, type=lambda x: (str(x).lower() == "true"), help="Debug mode"
)
parser.add_argument(
    "--disk_number", metavar="N", type=int, default=3, help="Disk Number(5 or less.)"
)
try:
    args = parser.parse_args() #call from command line
except:
    args = parser.parse_args(args=[]) #call from notebook
debug_mode = args.debug_mode
budgets = args.budgets
max_depth = args.max_depth
algo = args.algo
seed = args.seed
number = args.disk_number
np.random.seed(seed)

benchmark4 = Benchmark4(robot_name="doosan", geom="collision", is_pyplot=True, disk_num=number)
final_level_1_values = []
final_level_2_values = []
final_optimal_nodes = []
final_pnp_all_joint_paths = []
final_pick_all_objects = []
final_place_all_object_poses = []
# final_optimal_trees = []
c_list = 10 ** np.linspace(-2, 2.0, 10)
# Out:
# usage: ipykernel_launcher.py [-h] [--budgets T] [--max_depth H] [--seed i]
#                              [--algo alg] [--debug_mode DEBUG_MODE]
#                              [--disk_number N]
# ipykernel_launcher.py: error: unrecognized arguments: -f /home/juju/.local/share/jupyter/runtime/kernel-b8409916-58d0-4cb9-8845-d7671847443f.json
# hanoi_disk_0
# hanoi_disk_1
# hanoi_disk_2
# *********************** Logical States ***********************
# OrderedDict([('peg_1',
#               {'hung': [Object(name=hanoi_disk_0, pos=[0.69991433 0.3        0.75529998]),
#                         Object(name=hanoi_disk_1, pos=[0.69991433 0.3        0.79529998]),
#                         Object(name=hanoi_disk_2, pos=[0.69991433 0.3        0.83529997])],
#                'on': Object(name=table, pos=[ 1.   -0.6  -0.03]),
#                'static': True}),
#              ('peg_2',
#               {'on': Object(name=table, pos=[ 1.   -0.6  -0.03]),
#                'static': True}),
#              ('peg_3',
#               {'on': Object(name=table, pos=[ 1.   -0.6  -0.03]),
#                'static': True}),
#              ('hanoi_disk_0',
#               {'hang': Object(name=peg_1, pos=[0.7        0.3        0.83529998]),
#                'on': Object(name=table, pos=[ 1.   -0.6  -0.03]),
#                'support': [Object(name=hanoi_disk_1, pos=[0.69991433 0.3        0.79529998])]}),
#              ('hanoi_disk_1',
#               {'hang': Object(name=peg_1, pos=[0.7        0.3        0.83529998]),
#                'on': Object(name=hanoi_disk_0, pos=[0.69991433 0.3        0.75529998]),
#                'support': [Object(name=hanoi_disk_2, pos=[0.69991433 0.3        0.83529997])]}),
#              ('hanoi_disk_2',
#               {'hang': Object(name=peg_1, pos=[0.7        0.3        0.83529998]),
#                'on': Object(name=hanoi_disk_1, pos=[0.69991433 0.3        0.79529998])}),
#              ('table',
#               {'holding': None,
#                'static': True,
#                'support': [Object(name=peg_1, pos=[0.7        0.3        0.83529998]),
#                            Object(name=peg_2, pos=[0.7        0.         0.83529998]),
#                            Object(name=peg_3, pos=[ 0.7        -0.3         0.83529998]),
#                            Object(name=hanoi_disk_0, pos=[0.69991433 0.3        0.75529998])]}),
#              ('robotiq140_gripper', {'holding': None})])
# ***************************************************************

# %%
# for idx, c in enumerate(c_list):
mcts = MCTS(
    scene_mngr=benchmark4.scene_mngr,
    sampling_method=algo,
    budgets=budgets,
    max_depth=max_depth,
    c=c_list[6],
    debug_mode=debug_mode,
)
for i in range(budgets):
#     print(
#         f"\n[{idx+1}/{len(c_list)}] Benchmark: {benchmark3.scene_mngr.scene.bench_num}, Algo: {algo}, C: {c}, Seed: {seed}"
#     )
    mcts.do_planning(i)

final_level_1_values.append(mcts.values_for_level_1)
final_level_2_values.append(mcts.values_for_level_2)

if mcts.level_wise_2_success:
    (
        pnp_all_joint_paths,
        pick_all_objects,
        place_all_object_poses,
    ) = mcts.get_all_joint_path(mcts.optimal_nodes)
    final_pnp_all_joint_paths.append(pnp_all_joint_paths)
    final_pick_all_objects.append(pick_all_objects)
    final_place_all_object_poses.append(place_all_object_poses)
    final_optimal_nodes.append(mcts.optimal_nodes)
    
    
else:
    final_pnp_all_joint_paths.append([])
    final_pick_all_objects.append([])
    final_place_all_object_poses.append([])
    final_optimal_nodes.append([])
    # final_optimal_trees.append(mcts.tree.nodes)
#     del mcts
#     # print(final_optimal_trees)
#     print("delete mcts")
# Out:
# =========== Search iteration : 1 ===========
# [Action] Pick hanoi_disk_2
# [Reward] S(0) -> A(1) -> S'(2) Reward : -1
# [Action] Place hanoi_disk_2 on table
# [Reward] S(2) -> A(3) -> S'(7) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(7) -> A(10) -> S'(11) Reward : 2
# [Action] Place hanoi_disk_1 on table
# [Reward] S(11) -> A(12) -> S'(15) Reward : -1
# [Action] Pick hanoi_disk_0
# Good Action
# [Reward] S(15) -> A(16) -> S'(18) Reward : 2
# Current logical action is None.. Reward is -2.0
# [Reward] S(18) -> A(None) -> S'(None) Reward : -2.0
# =========== Search iteration : 2 ===========
# [Action] Pick hanoi_disk_2
# [Reward] S(0) -> A(1) -> S'(2) Reward : -1
# [Action] Place hanoi_disk_2 on table
# [Reward] S(2) -> A(3) -> S'(8) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(8) -> A(19) -> S'(20) Reward : 2
# [Action] Place hanoi_disk_1 on table
# [Reward] S(20) -> A(21) -> S'(24) Reward : -1
# [Action] Pick hanoi_disk_2
# Good Action
# [Reward] S(24) -> A(26) -> S'(27) Reward : 2
# [Action] Place hanoi_disk_2 on hanoi_disk_0
# [Reward] S(27) -> A(28) -> S'(30) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(30) -> A(33) -> S'(34) Reward : 2
# [Action] Place hanoi_disk_1 on table
# [Reward] S(34) -> A(35) -> S'(38) Reward : -1
# [Action] Pick hanoi_disk_2
# Good Action
# [Reward] S(38) -> A(39) -> S'(40) Reward : 2
# [Action] Place hanoi_disk_2 on hanoi_disk_1
# [Reward] S(40) -> A(42) -> S'(43) Reward : -1
# [Action] Pick hanoi_disk_0
# Good Action
# [Reward] S(43) -> A(46) -> S'(47) Reward : 2
# [Action] Place hanoi_disk_0 on table
# [Reward] S(47) -> A(48) -> S'(50) Reward : -1
# [Action] Pick hanoi_disk_2
# Good Action
# [Reward] S(50) -> A(52) -> S'(53) Reward : 2
# [Action] Place hanoi_disk_2 on hanoi_disk_0
# [Reward] S(53) -> A(55) -> S'(56) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(56) -> A(59) -> S'(60) Reward : 2
# [Action] Place hanoi_disk_1 on table
# [Reward] S(60) -> A(61) -> S'(62) Reward : -1
# [Action] Pick hanoi_disk_2
# Good Action
# [Reward] S(62) -> A(64) -> S'(65) Reward : 2
# [Action] Place hanoi_disk_2 on hanoi_disk_1
# [Reward] S(65) -> A(67) -> S'(70) Reward : -1
# [Action] Pick hanoi_disk_0
# Good Action
# [Reward] S(70) -> A(71) -> S'(72) Reward : 2
# [Action] Place hanoi_disk_0 on table
# [Reward] S(72) -> A(73) -> S'(74) Reward : -1
# Exceeded the maximum depth!!
# =========== Search iteration : 3 ===========
# [Action] Pick hanoi_disk_2
# [Reward] S(0) -> A(1) -> S'(2) Reward : -1
# [Action] Place hanoi_disk_2 on table
# [Reward] S(2) -> A(3) -> S'(9) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(9) -> A(77) -> S'(78) Reward : 2
# [Action] Place hanoi_disk_1 on table
# [Reward] S(78) -> A(79) -> S'(81) Reward : -1
# [Action] Pick hanoi_disk_2
# Good Action
# [Reward] S(81) -> A(84) -> S'(85) Reward : 2
# [Action] Place hanoi_disk_2 on hanoi_disk_0
# [Reward] S(85) -> A(86) -> S'(90) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(90) -> A(91) -> S'(92) Reward : 2
# [Action] Place hanoi_disk_1 on table
# [Reward] S(92) -> A(93) -> S'(95) Reward : -1
# [Action] Pick hanoi_disk_2
# Good Action
# [Reward] S(95) -> A(97) -> S'(98) Reward : 2
# [Action] Place hanoi_disk_2 on table
# [Reward] S(98) -> A(99) -> S'(101) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(101) -> A(105) -> S'(106) Reward : 2
# [Action] Place hanoi_disk_1 on hanoi_disk_0
# [Reward] S(106) -> A(107) -> S'(108) Reward : -1
# [Action] Pick hanoi_disk_2
# Good Action
# [Reward] S(108) -> A(111) -> S'(112) Reward : 2
# [Action] Place hanoi_disk_2 on hanoi_disk_1
# [Reward] S(112) -> A(114) -> S'(115) Reward : -1
# Current logical action is None.. Reward is -0.7142857142857143
# [Reward] S(115) -> A(None) -> S'(None) Reward : -0.714
# =========== Search iteration : 4 ===========
# [Action] Pick hanoi_disk_2
# [Reward] S(0) -> A(1) -> S'(2) Reward : -1
# [Action] Place hanoi_disk_2 on table
# [Reward] S(2) -> A(3) -> S'(8) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(8) -> A(19) -> S'(20) Reward : 2
# [Action] Place hanoi_disk_1 on table
# [Reward] S(20) -> A(21) -> S'(22) Reward : -1
# [Action] Pick hanoi_disk_2
# Good Action
# [Reward] S(22) -> A(119) -> S'(120) Reward : 2
# [Action] Place hanoi_disk_2 on hanoi_disk_1
# [Reward] S(120) -> A(122) -> S'(125) Reward : -1
# [Action] Pick hanoi_disk_0
# Good Action
# [Reward] S(125) -> A(126) -> S'(127) Reward : 2
# [Action] Place hanoi_disk_0 on table
# [Reward] S(127) -> A(128) -> S'(130) Reward : -1
# [Action] Pick hanoi_disk_2
# Good Action
# [Reward] S(130) -> A(132) -> S'(133) Reward : 2
# [Action] Place hanoi_disk_2 on hanoi_disk_0
# [Reward] S(133) -> A(135) -> S'(138) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(138) -> A(139) -> S'(140) Reward : 2
# [Action] Place hanoi_disk_1 on table
# [Reward] S(140) -> A(141) -> S'(143) Reward : -1
# [Action] Pick hanoi_disk_2
# Good Action
# [Reward] S(143) -> A(145) -> S'(146) Reward : 2
# [Action] Place hanoi_disk_2 on hanoi_disk_1
# [Reward] S(146) -> A(148) -> S'(149) Reward : -1
# [Action] Pick hanoi_disk_0
# Good Action
# [Reward] S(149) -> A(152) -> S'(153) Reward : 2
# [Action] Place hanoi_disk_0 on table
# [Reward] S(153) -> A(154) -> S'(155) Reward : -1
# [Action] Pick hanoi_disk_2
# Good Action
# [Reward] S(155) -> A(158) -> S'(159) Reward : 2
# [Action] Place hanoi_disk_2 on table
# [Reward] S(159) -> A(160) -> S'(164) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(164) -> A(166) -> S'(167) Reward : 2
# [Action] Place hanoi_disk_1 on hanoi_disk_0
# [Reward] S(167) -> A(168) -> S'(169) Reward : -1
# Exceeded the maximum depth!!
# =========== Search iteration : 5 ===========
# [Action] Pick hanoi_disk_2
# [Reward] S(0) -> A(1) -> S'(2) Reward : -1
# [Action] Place hanoi_disk_2 on table
# [Reward] S(2) -> A(3) -> S'(4) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(4) -> A(172) -> S'(173) Reward : 2
# [Action] Place hanoi_disk_1 on table
# [Reward] S(173) -> A(174) -> S'(176) Reward : -1
# [Action] Pick hanoi_disk_0
# Good Action
# [Reward] S(176) -> A(178) -> S'(180) Reward : 2
# Current logical action is None.. Reward is -2.0
# [Reward] S(180) -> A(None) -> S'(None) Reward : -2.0
# =========== Search iteration : 6 ===========
# [Action] Pick hanoi_disk_2
# [Reward] S(0) -> A(1) -> S'(2) Reward : -1
# [Action] Place hanoi_disk_2 on table
# [Reward] S(2) -> A(3) -> S'(5) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(5) -> A(181) -> S'(182) Reward : 2
# [Action] Place hanoi_disk_1 on table
# [Reward] S(182) -> A(183) -> S'(185) Reward : -1
# [Action] Pick hanoi_disk_2
# Good Action
# [Reward] S(185) -> A(188) -> S'(189) Reward : 2
# [Action] Place hanoi_disk_2 on hanoi_disk_0
# [Reward] S(189) -> A(190) -> S'(192) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(192) -> A(195) -> S'(196) Reward : 2
# [Action] Place hanoi_disk_1 on table
# [Reward] S(196) -> A(197) -> S'(198) Reward : -1
# [Action] Pick hanoi_disk_2
# Good Action
# [Reward] S(198) -> A(201) -> S'(202) Reward : 2
# [Action] Place hanoi_disk_2 on hanoi_disk_1
# [Reward] S(202) -> A(204) -> S'(207) Reward : -1
# [Action] Pick hanoi_disk_0
# Good Action
# [Reward] S(207) -> A(208) -> S'(209) Reward : 2
# [Action] Place hanoi_disk_0 on table
# [Reward] S(209) -> A(210) -> S'(212) Reward : -1
# [Action] Pick hanoi_disk_2
# Good Action
# [Reward] S(212) -> A(214) -> S'(215) Reward : 2
# [Action] Place hanoi_disk_2 on hanoi_disk_0
# [Reward] S(215) -> A(217) -> S'(219) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(219) -> A(221) -> S'(222) Reward : 2
# [Action] Place hanoi_disk_1 on table
# [Reward] S(222) -> A(223) -> S'(224) Reward : -1
# [Action] Pick hanoi_disk_2
# Good Action
# [Reward] S(224) -> A(227) -> S'(228) Reward : 2
# [Action] Place hanoi_disk_2 on table
# [Reward] S(228) -> A(229) -> S'(232) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(232) -> A(234) -> S'(235) Reward : 2
# [Action] Place hanoi_disk_1 on hanoi_disk_0
# [Reward] S(235) -> A(236) -> S'(239) Reward : -1
# Exceeded the maximum depth!!
# =========== Search iteration : 7 ===========
# [Action] Pick hanoi_disk_2
# [Reward] S(0) -> A(1) -> S'(2) Reward : -1
# [Action] Place hanoi_disk_2 on table
# [Reward] S(2) -> A(3) -> S'(5) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(5) -> A(181) -> S'(182) Reward : 2
# [Action] Place hanoi_disk_1 on table
# [Reward] S(182) -> A(183) -> S'(186) Reward : -1
# [Action] Pick hanoi_disk_0
# Good Action
# [Reward] S(186) -> A(240) -> S'(242) Reward : 2
# Current logical action is None.. Reward is -2.0
# [Reward] S(242) -> A(None) -> S'(None) Reward : -2.0
# =========== Search iteration : 8 ===========
# [Action] Pick hanoi_disk_2
# [Reward] S(0) -> A(1) -> S'(2) Reward : -1
# [Action] Place hanoi_disk_2 on table
# [Reward] S(2) -> A(3) -> S'(6) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(6) -> A(243) -> S'(244) Reward : 2
# [Action] Place hanoi_disk_1 on table
# [Reward] S(244) -> A(245) -> S'(246) Reward : -1
# [Action] Pick hanoi_disk_0
# Good Action
# [Reward] S(246) -> A(249) -> S'(251) Reward : 2
# Current logical action is None.. Reward is -2.0
# [Reward] S(251) -> A(None) -> S'(None) Reward : -2.0
# =========== Search iteration : 9 ===========
# [Action] Pick hanoi_disk_2
# [Reward] S(0) -> A(1) -> S'(2) Reward : -1
# [Action] Place hanoi_disk_2 on table
# [Reward] S(2) -> A(3) -> S'(6) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(6) -> A(243) -> S'(244) Reward : 2
# [Action] Place hanoi_disk_1 on table
# [Reward] S(244) -> A(245) -> S'(248) Reward : -1
# [Action] Pick hanoi_disk_0
# Good Action
# [Reward] S(248) -> A(252) -> S'(254) Reward : 2
# Current logical action is None.. Reward is -2.0
# [Reward] S(254) -> A(None) -> S'(None) Reward : -2.0
# =========== Search iteration : 10 ===========
# [Action] Pick hanoi_disk_2
# [Reward] S(0) -> A(1) -> S'(2) Reward : -1
# [Action] Place hanoi_disk_2 on table
# [Reward] S(2) -> A(3) -> S'(7) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(7) -> A(10) -> S'(11) Reward : 2
# [Action] Place hanoi_disk_1 on table
# [Reward] S(11) -> A(12) -> S'(13) Reward : -1
# [Action] Pick hanoi_disk_0
# Good Action
# [Reward] S(13) -> A(255) -> S'(257) Reward : 2
# Current logical action is None.. Reward is -2.0
# [Reward] S(257) -> A(None) -> S'(None) Reward : -2.0
# =========== Search iteration : 11 ===========
# [Action] Pick hanoi_disk_2
# [Reward] S(0) -> A(1) -> S'(2) Reward : -1
# [Action] Place hanoi_disk_2 on table
# [Reward] S(2) -> A(3) -> S'(4) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(4) -> A(172) -> S'(173) Reward : 2
# [Action] Place hanoi_disk_1 on table
# [Reward] S(173) -> A(174) -> S'(175) Reward : -1
# [Action] Pick hanoi_disk_2
# Good Action
# [Reward] S(175) -> A(259) -> S'(260) Reward : 2
# [Action] Place hanoi_disk_2 on hanoi_disk_1
# [Reward] S(260) -> A(262) -> S'(264) Reward : -1
# [Action] Pick hanoi_disk_0
# Good Action
# [Reward] S(264) -> A(266) -> S'(267) Reward : 2
# [Action] Place hanoi_disk_0 on table
# [Reward] S(267) -> A(268) -> S'(271) Reward : -1
# [Action] Pick hanoi_disk_2
# Good Action
# [Reward] S(271) -> A(272) -> S'(273) Reward : 2
# [Action] Place hanoi_disk_2 on hanoi_disk_0
# [Reward] S(273) -> A(275) -> S'(276) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(276) -> A(279) -> S'(280) Reward : 2
# [Action] Place hanoi_disk_1 on table
# [Reward] S(280) -> A(281) -> S'(282) Reward : -1
# [Action] Pick hanoi_disk_2
# Good Action
# [Reward] S(282) -> A(285) -> S'(286) Reward : 2
# [Action] Place hanoi_disk_2 on table
# [Reward] S(286) -> A(287) -> S'(289) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(289) -> A(293) -> S'(294) Reward : 2
# [Action] Place hanoi_disk_1 on hanoi_disk_0
# [Reward] S(294) -> A(295) -> S'(297) Reward : -1
# [Action] Pick hanoi_disk_2
# Good Action
# [Reward] S(297) -> A(299) -> S'(300) Reward : 2
# [Action] Place hanoi_disk_2 on table
# [Reward] S(300) -> A(301) -> S'(304) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(304) -> A(306) -> S'(307) Reward : 2
# [Action] Place hanoi_disk_1 on table
# [Reward] S(307) -> A(308) -> S'(309) Reward : -1
# Exceeded the maximum depth!!
# =========== Search iteration : 12 ===========
# [Action] Pick hanoi_disk_2
# [Reward] S(0) -> A(1) -> S'(2) Reward : -1
# [Action] Place hanoi_disk_2 on table
# [Reward] S(2) -> A(3) -> S'(5) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(5) -> A(181) -> S'(182) Reward : 2
# [Action] Place hanoi_disk_1 on table
# [Reward] S(182) -> A(183) -> S'(184) Reward : -1
# [Action] Pick hanoi_disk_2
# Good Action
# [Reward] S(184) -> A(313) -> S'(314) Reward : 2
# [Action] Place hanoi_disk_2 on hanoi_disk_1
# [Reward] S(314) -> A(316) -> S'(318) Reward : -1
# [Action] Pick hanoi_disk_0
# Good Action
# [Reward] S(318) -> A(320) -> S'(321) Reward : 2
# [Action] Place hanoi_disk_0 on table
# [Reward] S(321) -> A(322) -> S'(323) Reward : -1
# [Action] Pick hanoi_disk_2
# Good Action
# [Reward] S(323) -> A(326) -> S'(327) Reward : 2
# [Action] Place hanoi_disk_2 on hanoi_disk_0
# [Reward] S(327) -> A(329) -> S'(332) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(332) -> A(333) -> S'(334) Reward : 2
# [Action] Place hanoi_disk_1 on table
# [Reward] S(334) -> A(335) -> S'(336) Reward : -1
# [Action] Pick hanoi_disk_2
# Good Action
# [Reward] S(336) -> A(339) -> S'(340) Reward : 2
# [Action] Place hanoi_disk_2 on hanoi_disk_1
# [Reward] S(340) -> A(342) -> S'(345) Reward : -1
# [Action] Pick hanoi_disk_0
# Good Action
# [Reward] S(345) -> A(346) -> S'(347) Reward : 2
# [Action] Place hanoi_disk_0 on table
# [Reward] S(347) -> A(348) -> S'(351) Reward : -1
# [Action] Pick hanoi_disk_2
# Good Action
# [Reward] S(351) -> A(352) -> S'(353) Reward : 2
# [Action] Place hanoi_disk_2 on table
# [Reward] S(353) -> A(354) -> S'(356) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(356) -> A(360) -> S'(361) Reward : 2
# [Action] Place hanoi_disk_1 on hanoi_disk_0
# [Reward] S(361) -> A(362) -> S'(363) Reward : -1
# Exceeded the maximum depth!!
# =========== Search iteration : 13 ===========
# [Action] Pick hanoi_disk_2
# [Reward] S(0) -> A(1) -> S'(2) Reward : -1
# [Action] Place hanoi_disk_2 on table
# [Reward] S(2) -> A(3) -> S'(8) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(8) -> A(19) -> S'(20) Reward : 2
# [Action] Place hanoi_disk_1 on table
# [Reward] S(20) -> A(21) -> S'(23) Reward : -1
# [Action] Pick hanoi_disk_0
# Good Action
# [Reward] S(23) -> A(366) -> S'(368) Reward : 2
# Current logical action is None.. Reward is -2.0
# [Reward] S(368) -> A(None) -> S'(None) Reward : -2.0
# =========== Search iteration : 14 ===========
# [Action] Pick hanoi_disk_2
# [Reward] S(0) -> A(1) -> S'(2) Reward : -1
# [Action] Place hanoi_disk_2 on table
# [Reward] S(2) -> A(3) -> S'(9) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(9) -> A(77) -> S'(78) Reward : 2
# [Action] Place hanoi_disk_1 on table
# [Reward] S(78) -> A(79) -> S'(82) Reward : -1
# [Action] Pick hanoi_disk_0
# Good Action
# [Reward] S(82) -> A(369) -> S'(371) Reward : 2
# Current logical action is None.. Reward is -2.0
# [Reward] S(371) -> A(None) -> S'(None) Reward : -2.0
# =========== Search iteration : 15 ===========
# [Action] Pick hanoi_disk_2
# [Reward] S(0) -> A(1) -> S'(2) Reward : -1
# [Action] Place hanoi_disk_2 on table
# [Reward] S(2) -> A(3) -> S'(4) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(4) -> A(172) -> S'(173) Reward : 2
# [Action] Place hanoi_disk_1 on table
# [Reward] S(173) -> A(174) -> S'(177) Reward : -1
# [Action] Pick hanoi_disk_2
# Good Action
# [Reward] S(177) -> A(373) -> S'(374) Reward : 2
# [Action] Place hanoi_disk_2 on hanoi_disk_1
# [Reward] S(374) -> A(376) -> S'(378) Reward : -1
# [Action] Pick hanoi_disk_0
# Good Action
# [Reward] S(378) -> A(380) -> S'(381) Reward : 2
# [Action] Place hanoi_disk_0 on table
# [Reward] S(381) -> A(382) -> S'(383) Reward : -1
# [Action] Pick hanoi_disk_2
# Good Action
# [Reward] S(383) -> A(386) -> S'(387) Reward : 2
# [Action] Place hanoi_disk_2 on table
# [Reward] S(387) -> A(388) -> S'(391) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(391) -> A(394) -> S'(395) Reward : 2
# [Action] Place hanoi_disk_1 on hanoi_disk_0
# [Reward] S(395) -> A(396) -> S'(398) Reward : -1
# [Action] Pick hanoi_disk_2
# Good Action
# [Reward] S(398) -> A(400) -> S'(401) Reward : 2
# [Action] Place hanoi_disk_2 on hanoi_disk_1
# [Reward] S(401) -> A(403) -> S'(406) Reward : -1
# Current logical action is None.. Reward is -0.7142857142857143
# [Reward] S(406) -> A(None) -> S'(None) Reward : -0.714
# =========== Search iteration : 16 ===========
# [Action] Pick hanoi_disk_2
# [Reward] S(0) -> A(1) -> S'(2) Reward : -1
# [Action] Place hanoi_disk_2 on table
# [Reward] S(2) -> A(3) -> S'(6) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(6) -> A(243) -> S'(244) Reward : 2
# [Action] Place hanoi_disk_1 on table
# [Reward] S(244) -> A(245) -> S'(247) Reward : -1
# [Action] Pick hanoi_disk_0
# Good Action
# [Reward] S(247) -> A(407) -> S'(409) Reward : 2
# Current logical action is None.. Reward is -2.0
# [Reward] S(409) -> A(None) -> S'(None) Reward : -2.0
# =========== Search iteration : 17 ===========
# [Action] Pick hanoi_disk_2
# [Reward] S(0) -> A(1) -> S'(2) Reward : -1
# [Action] Place hanoi_disk_2 on table
# [Reward] S(2) -> A(3) -> S'(9) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(9) -> A(77) -> S'(78) Reward : 2
# [Action] Place hanoi_disk_1 on table
# [Reward] S(78) -> A(79) -> S'(82) Reward : -1
# [Action] Pick hanoi_disk_2
# Good Action
# [Reward] S(82) -> A(370) -> S'(410) Reward : 2
# [Action] Place hanoi_disk_2 on hanoi_disk_1
# [Reward] S(410) -> A(412) -> S'(414) Reward : -1
# [Action] Pick hanoi_disk_0
# Good Action
# [Reward] S(414) -> A(416) -> S'(417) Reward : 2
# [Action] Place hanoi_disk_0 on table
# [Reward] S(417) -> A(418) -> S'(419) Reward : -1
# [Action] Pick hanoi_disk_2
# Good Action
# [Reward] S(419) -> A(422) -> S'(423) Reward : 2
# [Action] Place hanoi_disk_2 on table
# [Reward] S(423) -> A(424) -> S'(428) Reward : -1
# [Action] Pick hanoi_disk_1
# Good Action
# [Reward] S(428) -> A(430) -> S'(431) Reward : 2
# [Action] Place hanoi_disk_1 on hanoi_disk_0
# [Reward] S(431) -> A(432) -> S'(434) Reward : -1
# [Action] Pick hanoi_disk_2
# Good Action
# [Reward] S(434) -> A(436) -> S'(437) Reward : 2
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# [INFO] [RRT Star Planner]: The joint limit has been successfully checked. Pose error is 0.000002
# [Action] Place hanoi_disk_2 on hanoi_disk_1
# [Reward] S(437) -> A(439) -> S'(442) Reward : -1
# Success!!!!!
# Terminal State! Reward is 15
# Action Node: 1 Action: Pick hanoi_disk_2
# Action Node: 3  Action: Place hanoi_disk_2 on table
# Action Node: 77 Action: Pick hanoi_disk_1
# Action Node: 79  Action: Place hanoi_disk_1 on table
# Action Node: 370 Action: Pick hanoi_disk_2
# Action Node: 412  Action: Place hanoi_disk_2 on hanoi_disk_1
# Action Node: 416 Action: Pick hanoi_disk_0
# Action Node: 418  Action: Place hanoi_disk_0 on table
# Action Node: 422 Action: Pick hanoi_disk_2
# Action Node: 424  Action: Place hanoi_disk_2 on table
# Action Node: 430 Action: Pick hanoi_disk_1
# Action Node: 432  Action: Place hanoi_disk_1 on hanoi_disk_0
# Action Node: 436 Action: Pick hanoi_disk_2
# Action Node: 439  Action: Place hanoi_disk_2 on hanoi_disk_1
# pick hanoi_disk_2
# solve the problem using LM2!!
# Iterators : 7
# WorkingTime[inverse_kinematics]: 0.0061 sec
# KeyboardInterrupt

# %%
mcts.place_action.simulate_path(
    final_pnp_all_joint_paths[0],
    final_pick_all_objects[0],
    final_place_all_object_poses[0],
    is_save=True,
    video_name="benchmark4_MCTS"
)
# Out:
# PWD :  /home/juju/pytamp/examples/doosan/action/rearrangement1
# Animation Finished..
# Save finished..

# %%
mcts.visualize_tree("Siccess nodes", mcts.tree)
