# %%
import numpy as np
import argparse
import os

from pykin.utils import plot_utils as p_utils
from pytamp.benchmark import Benchmark2
from pytamp.search.mcts import MCTS

# ? python3 benchmark2_test.py --budgets 100 --max_depth 14 --seed 1 --algo bai_perturb
parser = argparse.ArgumentParser(description="Test Benchmark 2.")
parser.add_argument("--budgets", metavar="T", type=int, default=100, help="Horizon")
parser.add_argument("--max_depth", metavar="H", type=int, default=16, help="Max depth")
parser.add_argument("--seed", metavar="i", type=int, default=1, help="A random seed")
parser.add_argument(
    "--algo",
    metavar="alg",
    type=str,
    default="bai_perturb",
    choices=["bai_perturb", "bai_ucb", "uct", "random", "greedy"],
    help="Choose one (bai_perturb, bai_ucb, uct)",
)
parser.add_argument(
    "--debug_mode",
    default=False,
    type=lambda x: (str(x).lower() == "true"),
    help="Debug mode",
)
parser.add_argument(
    "--bottle_number",
    metavar="N",
    type=int,
    default=3,
    help="Bottle Number(6 or less.)",
)
try:
    args = parser.parse_args() #call from command line
except:
    args = parser.parse_args(args=[]) #call from notebook
    

debug_mode = args.debug_mode
budgets = args.budgets
max_depth = args.max_depth
algo = args.algo
seed = args.seed
number = args.bottle_number
np.random.seed(seed)
# Out:
# usage: ipykernel_launcher.py [-h] [--budgets T] [--max_depth H] [--seed i]
#                              [--algo alg] [--debug_mode DEBUG_MODE]
#                              [--bottle_number N]
# ipykernel_launcher.py: error: unrecognized arguments: -f /home/juju/.local/share/jupyter/runtime/kernel-acb02259-e03e-4ab5-8c54-7d41ce07f099.json

# %%
benchmark2 = Benchmark2(
    robot_name="doosan", geom="collision", is_pyplot=True, bottle_num=number
)
final_level_1_values = []
final_level_2_values = []
final_optimal_nodes = []
final_pnp_all_joint_paths = []
final_pick_all_objects = []
final_place_all_object_poses = []
# final_optimal_trees = []
c_list = 10 ** np.linspace(-2, 2.0, 10)
# c_list = c_list[6:]

mcts = MCTS(
    scene_mngr=benchmark2.scene_mngr,
    sampling_method=algo,
    budgets=budgets,
    max_depth=max_depth,
    c=c_list[6],
    debug_mode=debug_mode,
)
# Out:
# *********************** Logical States ***********************
# OrderedDict([('shelf_0', {'static': True}),
#              ('bin_0', {'static': True}),
#              ('shelf_1', {'static': True}),
#              ('bin_1', {'static': True}),
#              ('shelf_2', {'static': True}),
#              ('bin_2', {'static': True}),
#              ('shelf_3', {'static': True}),
#              ('bin_3', {'static': True}),
#              ('shelf_4', {'static': True}),
#              ('bin_4', {'static': True}),
#              ('shelf_5', {'static': True}),
#              ('bin_5', {'static': True}),
#              ('shelf_6', {'static': True}),
#              ('bin_6', {'static': True}),
#              ('shelf_7', {'static': True}),
#              ('bin_7', {'static': True}),
#              ('shelf_8', {'static': True}),
#              ('bin_8', {'static': True}),
#              ('shelf_9',
#               {'static': True,
#                'support': [Object(name=bottle_1, pos=[0.98 0.08 1.29]),
#                            Object(name=bottle_2, pos=[ 0.98 -0.08  1.29]),
#                            Object(name=goal_bottle, pos=[1.04 0.   1.29])]}),
#              ('bin_9', {'static': True}),
#              ('shelf_10', {'static': True}),
#              ('bin_10', {'static': True}),
#              ('shelf_11', {'static': True}),
#              ('bin_11', {'static': True}),
#              ('shelf_12', {'static': True}),
#              ('bin_12', {'static': True}),
#              ('shelf_13', {'static': True}),
#              ('bin_13', {'static': True}),
#              ('shelf_14', {'static': True}),
#              ('bin_14', {'static': True}),
#              ('shelf_15', {'static': True}),
#              ('bin_15', {'static': True}),
#              ('shelf_16', {'static': True}),
#              ('bin_16', {'static': True}),
#              ('shelf_17', {'static': True}),
#              ('bin_17', {'static': True}),
#              ('shelf_18', {'static': True}),
#              ('bin_18', {'static': True}),
#              ('shelf_19', {'static': True}),
#              ('bin_19', {'static': True}),
#              ('bottle_1',
#               {'on': Object(name=shelf_9, pos=[0.9        0.         1.41725156])}),
#              ('bottle_2',
#               {'on': Object(name=shelf_9, pos=[0.9        0.         1.41725156])}),
#              ('goal_bottle',
#               {'on': Object(name=shelf_9, pos=[0.9        0.         1.41725156])}),
#              ('robotiq140_gripper', {'holding': None})])
# ***************************************************************

# %%
for i in range(budgets):
#     print(
#         f"\n[{idx+1}/{len(c_list)}] Benchmark: {benchmark2.scene_mngr.scene.bench_num}, Algo: {algo}, C: {c}, Seed: {seed}"
#     )
    mcts.do_planning(i)
# Out:
# =========== Search iteration : 1 ===========
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# (False, 'No object collided..')
# [Action] Pick goal_bottle
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# [Reward] S(0) -> A(3) -> S'(16) Reward : 1
# Success!!!!!
# Terminal State! Reward is 5
# Action Node: 3 Action: Pick goal_bottle
# pick goal_bottle
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0689 sec
#
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0684 sec
#
# Retry compute IK.. Pose error is 2.588471
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0713 sec
#
# Retry compute IK.. Pose error is 2.588469
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0705 sec
#
# Retry compute IK.. Pose error is 2.588482
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0706 sec
#
# Retry compute IK.. Pose error is 2.588469
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0728 sec
#
# Retry compute IK.. Pose error is 2.588468
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0739 sec
#
# Retry compute IK.. Pose error is 2.588467
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0723 sec
#
# Retry compute IK.. Pose error is 2.588470
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0713 sec
#
# Retry compute IK.. Pose error is 2.588480
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0712 sec
#
# Retry compute IK.. Pose error is 2.588467
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0711 sec
#
# Retry compute IK.. Pose error is 2.588467
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0714 sec
#
# Retry compute IK.. Pose error is 2.588483
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0701 sec
#
# Retry compute IK.. Pose error is 2.588467
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0710 sec
#
# Retry compute IK.. Pose error is 2.588467
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0716 sec
#
# Retry compute IK.. Pose error is 2.588467
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0692 sec
#
# Retry compute IK.. Pose error is 2.588467
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0695 sec
#
# Retry compute IK.. Pose error is 2.588467
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0730 sec
#
# Retry compute IK.. Pose error is 2.588470
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0703 sec
#
# Retry compute IK.. Pose error is 2.588467
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0710 sec
#
# Retry compute IK.. Pose error is 2.588470
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0747 sec
#
# Retry compute IK.. Pose error is 2.588466
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0706 sec
#
# Retry compute IK.. Pose error is 2.588483
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0705 sec
#
# Retry compute IK.. Pose error is 2.588467
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0721 sec
#
# Retry compute IK.. Pose error is 2.588486
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0709 sec
#
# Retry compute IK.. Pose error is 2.588467
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0708 sec
#
# Retry compute IK.. Pose error is 2.588480
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0712 sec
#
# Retry compute IK.. Pose error is 2.588468
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0700 sec
#
# Retry compute IK.. Pose error is 2.588467
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0675 sec
#
# Retry compute IK.. Pose error is 2.588467
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0681 sec
#
# Retry compute IK.. Pose error is 2.588467
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0693 sec
#
# Retry compute IK.. Pose error is 2.588466
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0690 sec
#
# Retry compute IK.. Pose error is 2.588466
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0720 sec
#
# Retry compute IK.. Pose error is 2.588467
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0707 sec
#
# Retry compute IK.. Pose error is 2.588467
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0712 sec
#
# Retry compute IK.. Pose error is 2.588482
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0717 sec
#
# Retry compute IK.. Pose error is 2.588466
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0740 sec
#
# Retry compute IK.. Pose error is 2.588467
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0747 sec
#
# Retry compute IK.. Pose error is 2.588469
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0718 sec
#
# Retry compute IK.. Pose error is 2.588483
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0710 sec
#
# Retry compute IK.. Pose error is 2.588467
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0720 sec
#
# Retry compute IK.. Pose error is 2.588467
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0721 sec
#
# Retry compute IK.. Pose error is 2.588467
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0693 sec
#
# Retry compute IK.. Pose error is 2.588469
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0687 sec
#
# Retry compute IK.. Pose error is 2.588486
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0699 sec
#
# Retry compute IK.. Pose error is 2.588485
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0678 sec
#
# Retry compute IK.. Pose error is 2.588468
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0676 sec
#
# Retry compute IK.. Pose error is 2.588467
# solve the problem using LM2!!
# [ERROR] [RRT Star Planner]: Not found IK solution
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0726 sec
#
# Retry compute IK.. Pose error is 2.588474
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0716 sec
#
# Retry compute IK.. Pose error is 2.588470
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0694 sec
#
# Retry compute IK.. Pose error is 2.588468
# WorkingTime[run]: 3.6802 sec
#
# Pick joint Fail
# [[0, 3, 16]]
# =========== Search iteration : 2 ===========
# [Action] Pick bottle_1
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# [Reward] S(0) -> A(1) -> S'(29) Reward : 1
# 0.06856813256500868
# (True, {('bottle_1', 'shelf_4'), ('bottle_1', 'shelf_9')})
# Current logical action is None.. Reward is -10.0
# [Reward] S(29) -> A(None) -> S'(None) Reward : -10.0
# =========== Search iteration : 3 ===========
# [Action] Pick goal_bottle
# [Reward] S(0) -> A(3) -> S'(9) Reward : 1
# Success!!!!!
# Terminal State! Reward is 5
# Action Node: 3 Action: Pick goal_bottle
# pick goal_bottle
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0717 sec
#
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0707 sec
#
# Retry compute IK.. Pose error is 4.085922
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0711 sec
#
# Retry compute IK.. Pose error is 4.085972
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0721 sec
#
# Retry compute IK.. Pose error is 4.085838
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0772 sec
#
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0692 sec
#
# Retry compute IK.. Pose error is 4.086408
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0698 sec
#
# Retry compute IK.. Pose error is 4.085911
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0776 sec
#
# Retry compute IK.. Pose error is 4.085855
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0716 sec
#
# Retry compute IK.. Pose error is 4.085953
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0716 sec
#
# Retry compute IK.. Pose error is 4.085846
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0711 sec
#
# Retry compute IK.. Pose error is 4.085930
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0711 sec
#
# Retry compute IK.. Pose error is 4.085910
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0723 sec
#
# Retry compute IK.. Pose error is 4.085938
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0720 sec
#
# Retry compute IK.. Pose error is 4.085933
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0715 sec
#
# Retry compute IK.. Pose error is 4.085921
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0715 sec
#
# Retry compute IK.. Pose error is 4.085894
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0683 sec
#
# Retry compute IK.. Pose error is 4.085870
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0711 sec
#
# Retry compute IK.. Pose error is 4.085879
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0745 sec
#
# Retry compute IK.. Pose error is 4.085964
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0733 sec
#
# Retry compute IK.. Pose error is 4.085863
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0741 sec
#
# Retry compute IK.. Pose error is 4.085986
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0714 sec
#
# Retry compute IK.. Pose error is 4.086112
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0687 sec
#
# Retry compute IK.. Pose error is 4.085899
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0687 sec
#
# Retry compute IK.. Pose error is 4.085931
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0704 sec
#
# Retry compute IK.. Pose error is 4.085900
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0725 sec
#
# Retry compute IK.. Pose error is 4.085984
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0699 sec
#
# Retry compute IK.. Pose error is 4.085986
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0710 sec
#
# Retry compute IK.. Pose error is 4.085927
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0743 sec
#
# Retry compute IK.. Pose error is 4.085912
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0705 sec
#
# Retry compute IK.. Pose error is 4.085921
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0709 sec
#
# Retry compute IK.. Pose error is 4.085845
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0690 sec
#
# Retry compute IK.. Pose error is 4.086027
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0706 sec
#
# Retry compute IK.. Pose error is 4.085931
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0803 sec
#
# Retry compute IK.. Pose error is 4.085964
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0705 sec
#
# Retry compute IK.. Pose error is 4.085946
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0697 sec
#
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0688 sec
#
# Retry compute IK.. Pose error is 4.085919
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0705 sec
#
# Retry compute IK.. Pose error is 4.086009
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0705 sec
#
# Retry compute IK.. Pose error is 4.085926
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0710 sec
#
# Retry compute IK.. Pose error is 4.085828
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0674 sec
#
# Retry compute IK.. Pose error is 4.085883
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0715 sec
#
# Retry compute IK.. Pose error is 4.085916
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0721 sec
#
# Retry compute IK.. Pose error is 4.085913
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0732 sec
#
# Retry compute IK.. Pose error is 4.085935
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0765 sec
#
# Retry compute IK.. Pose error is 4.085976
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0726 sec
#
# Retry compute IK.. Pose error is 4.086057
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0739 sec
#
# Retry compute IK.. Pose error is 4.085991
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0726 sec
#
# Retry compute IK.. Pose error is 4.085947
# solve the problem using LM2!!
# [ERROR] [RRT Star Planner]: Not found IK solution
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0722 sec
#
# Retry compute IK.. Pose error is 4.085940
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0681 sec
#
# Retry compute IK.. Pose error is 4.085903
# WorkingTime[run]: 3.7167 sec
#
# Pick joint Fail
# [[0, 3, 16], [0, 3, 9]]
# =========== Search iteration : 4 ===========
# [Action] Pick goal_bottle
# [Reward] S(0) -> A(3) -> S'(9) Reward : 1
# Success!!!!!
# Terminal State! Reward is 5
# Aleady has optimal nodes!!
# =========== Search iteration : 5 ===========
# [Action] Pick goal_bottle
# [Reward] S(0) -> A(3) -> S'(4) Reward : 1
# Success!!!!!
# Terminal State! Reward is 5
# Action Node: 3 Action: Pick goal_bottle
# pick goal_bottle
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0729 sec
#
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0724 sec
#
# Retry compute IK.. Pose error is 5.134063
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0720 sec
#
# Retry compute IK.. Pose error is 5.134033
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0719 sec
#
# Retry compute IK.. Pose error is 5.134002
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0729 sec
#
# Retry compute IK.. Pose error is 5.134100
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0722 sec
#
# Retry compute IK.. Pose error is 5.134059
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0697 sec
#
# Retry compute IK.. Pose error is 5.134317
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0711 sec
#
# Retry compute IK.. Pose error is 5.134152
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0749 sec
#
# Retry compute IK.. Pose error is 5.134099
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0720 sec
#
# Retry compute IK.. Pose error is 5.134016
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0725 sec
#
# Retry compute IK.. Pose error is 5.134104
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0725 sec
#
# Retry compute IK.. Pose error is 5.134078
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0720 sec
#
# Retry compute IK.. Pose error is 5.134193
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0717 sec
#
# Retry compute IK.. Pose error is 5.134138
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0719 sec
#
# Retry compute IK.. Pose error is 5.134350
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0709 sec
#
# Retry compute IK.. Pose error is 5.134144
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0723 sec
#
# Retry compute IK.. Pose error is 5.134087
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0712 sec
#
# Retry compute IK.. Pose error is 5.134138
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0723 sec
#
# Retry compute IK.. Pose error is 5.134132
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0730 sec
#
# Retry compute IK.. Pose error is 5.134122
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0726 sec
#
# Retry compute IK.. Pose error is 5.134199
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0804 sec
#
# Retry compute IK.. Pose error is 5.134198
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0721 sec
#
# Retry compute IK.. Pose error is 5.134091
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0719 sec
#
# Retry compute IK.. Pose error is 5.134117
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0703 sec
#
# Retry compute IK.. Pose error is 5.134113
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0711 sec
#
# Retry compute IK.. Pose error is 5.134348
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0720 sec
#
# Retry compute IK.. Pose error is 5.134096
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0718 sec
#
# Retry compute IK.. Pose error is 5.134129
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0725 sec
#
# Retry compute IK.. Pose error is 5.134285
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0718 sec
#
# Retry compute IK.. Pose error is 5.134128
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0691 sec
#
# Retry compute IK.. Pose error is 5.134118
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0703 sec
#
# Retry compute IK.. Pose error is 5.134628
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0704 sec
#
# Retry compute IK.. Pose error is 5.134120
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0678 sec
#
# Retry compute IK.. Pose error is 5.134130
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0816 sec
#
# Retry compute IK.. Pose error is 5.134062
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0710 sec
#
# Retry compute IK.. Pose error is 5.134149
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0721 sec
#
# Retry compute IK.. Pose error is 5.134084
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0720 sec
#
# Retry compute IK.. Pose error is 5.133852
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0689 sec
#
# Retry compute IK.. Pose error is 5.134141
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0713 sec
#
# Retry compute IK.. Pose error is 5.134345
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0734 sec
#
# Retry compute IK.. Pose error is 5.134160
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0725 sec
#
# Retry compute IK.. Pose error is 5.134116
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0723 sec
#
# Retry compute IK.. Pose error is 5.134129
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0721 sec
#
# Retry compute IK.. Pose error is 5.134115
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0712 sec
#
# Retry compute IK.. Pose error is 5.134066
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0722 sec
#
# Retry compute IK.. Pose error is 5.134090
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0727 sec
#
# Retry compute IK.. Pose error is 5.134218
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0720 sec
#
# Retry compute IK.. Pose error is 5.134146
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0711 sec
#
# Retry compute IK.. Pose error is 5.134132
# solve the problem using LM2!!
# [ERROR] [RRT Star Planner]: Not found IK solution
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0744 sec
#
# Retry compute IK.. Pose error is 5.134159
# WorkingTime[run]: 3.7461 sec
#
# Pick joint Fail
# [[0, 3, 16], [0, 3, 9], [0, 3, 4]]
# =========== Search iteration : 6 ===========
# [Action] Pick bottle_2
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# [Reward] S(0) -> A(2) -> S'(38) Reward : 1
# 0.06856813256500868
# Current logical action is None.. Reward is -10.0
# [Reward] S(38) -> A(None) -> S'(None) Reward : -10.0
# =========== Search iteration : 7 ===========
# [Action] Pick goal_bottle
# [Reward] S(0) -> A(3) -> S'(18) Reward : 1
# Success!!!!!
# Terminal State! Reward is 5
# Action Node: 3 Action: Pick goal_bottle
# pick goal_bottle
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0719 sec
#
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0722 sec
#
# Retry compute IK.. Pose error is 2.714543
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0738 sec
#
# Retry compute IK.. Pose error is 2.714543
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0727 sec
#
# Retry compute IK.. Pose error is 2.714549
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0725 sec
#
# Retry compute IK.. Pose error is 2.714543
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0793 sec
#
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0732 sec
#
# Retry compute IK.. Pose error is 2.714545
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0722 sec
#
# Retry compute IK.. Pose error is 2.714548
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0692 sec
#
# Retry compute IK.. Pose error is 2.714541
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0710 sec
#
# Retry compute IK.. Pose error is 2.714545
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0686 sec
#
# Retry compute IK.. Pose error is 2.714539
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0688 sec
#
# Retry compute IK.. Pose error is 2.714555
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0708 sec
#
# Retry compute IK.. Pose error is 2.714543
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0702 sec
#
# Retry compute IK.. Pose error is 2.714547
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0728 sec
#
# Retry compute IK.. Pose error is 2.714546
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0760 sec
#
# Retry compute IK.. Pose error is 2.714549
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0725 sec
#
# Retry compute IK.. Pose error is 2.714547
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0738 sec
#
# Retry compute IK.. Pose error is 2.714544
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0718 sec
#
# Retry compute IK.. Pose error is 2.714546
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0696 sec
#
# Retry compute IK.. Pose error is 2.714546
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0685 sec
#
# Retry compute IK.. Pose error is 2.714563
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0711 sec
#
# Retry compute IK.. Pose error is 2.714549
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0724 sec
#
# Retry compute IK.. Pose error is 2.714545
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0727 sec
#
# Retry compute IK.. Pose error is 2.714548
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0725 sec
#
# Retry compute IK.. Pose error is 2.714537
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0712 sec
#
# Retry compute IK.. Pose error is 2.714544
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0719 sec
#
# Retry compute IK.. Pose error is 2.714545
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0731 sec
#
# Retry compute IK.. Pose error is 2.714552
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0717 sec
#
# Retry compute IK.. Pose error is 2.714546
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0728 sec
#
# Retry compute IK.. Pose error is 2.714548
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0733 sec
#
# Retry compute IK.. Pose error is 2.714544
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0701 sec
#
# Retry compute IK.. Pose error is 2.714538
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0690 sec
#
# Retry compute IK.. Pose error is 2.714548
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0698 sec
#
# Retry compute IK.. Pose error is 2.714545
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0731 sec
#
# Retry compute IK.. Pose error is 2.714543
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0727 sec
#
# Retry compute IK.. Pose error is 2.714552
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0716 sec
#
# Retry compute IK.. Pose error is 2.714567
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0696 sec
#
# Retry compute IK.. Pose error is 2.714546
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0721 sec
#
# Retry compute IK.. Pose error is 2.714548
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0733 sec
#
# Retry compute IK.. Pose error is 2.714550
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0720 sec
#
# Retry compute IK.. Pose error is 2.714549
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0725 sec
#
# Retry compute IK.. Pose error is 2.714538
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0735 sec
#
# Retry compute IK.. Pose error is 2.714579
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0729 sec
#
# Retry compute IK.. Pose error is 2.714549
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0725 sec
#
# Retry compute IK.. Pose error is 2.714546
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0740 sec
#
# Retry compute IK.. Pose error is 2.714543
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0707 sec
#
# Retry compute IK.. Pose error is 2.714547
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0705 sec
#
# Retry compute IK.. Pose error is 2.714549
# solve the problem using LM2!!
# [ERROR] [RRT Star Planner]: Not found IK solution
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0742 sec
#
# Retry compute IK.. Pose error is 2.714547
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0698 sec
#
# Retry compute IK.. Pose error is 2.714568
# WorkingTime[run]: 3.7312 sec
#
# Pick joint Fail
# [[0, 3, 16], [0, 3, 9], [0, 3, 4], [0, 3, 18]]
# =========== Search iteration : 8 ===========
# [Action] Pick goal_bottle
# [Reward] S(0) -> A(3) -> S'(6) Reward : 1
# Success!!!!!
# Terminal State! Reward is 5
# Action Node: 3 Action: Pick goal_bottle
# pick goal_bottle
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0706 sec
#
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0721 sec
#
# Retry compute IK.. Pose error is 5.104035
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0714 sec
#
# Retry compute IK.. Pose error is 5.104104
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0713 sec
#
# Retry compute IK.. Pose error is 5.104095
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0736 sec
#
# Retry compute IK.. Pose error is 5.103867
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0749 sec
#
# Retry compute IK.. Pose error is 5.103900
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0722 sec
#
# Retry compute IK.. Pose error is 5.103575
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0731 sec
#
# Retry compute IK.. Pose error is 5.104022
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0717 sec
#
# Retry compute IK.. Pose error is 5.104055
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0721 sec
#
# Retry compute IK.. Pose error is 5.104028
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0750 sec
#
# Retry compute IK.. Pose error is 5.103870
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0711 sec
#
# Retry compute IK.. Pose error is 5.104061
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0708 sec
#
# Retry compute IK.. Pose error is 5.104091
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0719 sec
#
# Retry compute IK.. Pose error is 5.104012
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0705 sec
#
# Retry compute IK.. Pose error is 5.104013
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0711 sec
#
# Retry compute IK.. Pose error is 5.104154
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0761 sec
#
# Retry compute IK.. Pose error is 5.103914
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0720 sec
#
# Retry compute IK.. Pose error is 5.104007
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0703 sec
#
# Retry compute IK.. Pose error is 5.103888
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0721 sec
#
# Retry compute IK.. Pose error is 5.103991
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0698 sec
#
# Retry compute IK.. Pose error is 5.103916
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0805 sec
#
# Retry compute IK.. Pose error is 5.103993
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0699 sec
#
# Retry compute IK.. Pose error is 5.103980
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0716 sec
#
# Retry compute IK.. Pose error is 5.103980
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0720 sec
#
# Retry compute IK.. Pose error is 5.104118
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0724 sec
#
# Retry compute IK.. Pose error is 5.104025
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0717 sec
#
# Retry compute IK.. Pose error is 5.103991
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0723 sec
#
# Retry compute IK.. Pose error is 5.104059
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0733 sec
#
# Retry compute IK.. Pose error is 5.103809
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0692 sec
#
# Retry compute IK.. Pose error is 5.104074
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0712 sec
#
# Retry compute IK.. Pose error is 5.103918
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0727 sec
#
# Retry compute IK.. Pose error is 5.104081
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0717 sec
#
# Retry compute IK.. Pose error is 5.103615
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0690 sec
#
# Retry compute IK.. Pose error is 5.104028
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0703 sec
#
# Retry compute IK.. Pose error is 5.104086
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0687 sec
#
# Retry compute IK.. Pose error is 5.104023
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0690 sec
#
# Retry compute IK.. Pose error is 5.103869
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0709 sec
#
# Retry compute IK.. Pose error is 5.156956
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0730 sec
#
# Retry compute IK.. Pose error is 5.103997
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0705 sec
#
# Retry compute IK.. Pose error is 5.103894
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0703 sec
#
# Retry compute IK.. Pose error is 5.104246
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0712 sec
#
# Retry compute IK.. Pose error is 5.103972
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0718 sec
#
# Retry compute IK.. Pose error is 5.103935
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0725 sec
#
# Retry compute IK.. Pose error is 5.104012
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0715 sec
#
# Retry compute IK.. Pose error is 5.103928
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0794 sec
#
# Retry compute IK.. Pose error is 5.104042
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0739 sec
#
# Retry compute IK.. Pose error is 5.104012
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0731 sec
#
# Retry compute IK.. Pose error is 5.104106
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0741 sec
#
# Retry compute IK.. Pose error is 5.103994
# solve the problem using LM2!!
# [ERROR] [RRT Star Planner]: Not found IK solution
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0723 sec
#
# Retry compute IK.. Pose error is 5.104057
# WorkingTime[run]: 3.7452 sec
#
# Pick joint Fail
# [[0, 3, 16], [0, 3, 9], [0, 3, 4], [0, 3, 18], [0, 3, 6]]
# =========== Search iteration : 9 ===========
# [Action] Pick goal_bottle
# [Reward] S(0) -> A(3) -> S'(16) Reward : 1
# Success!!!!!
# Terminal State! Reward is 5
# Aleady has optimal nodes!!
# =========== Search iteration : 10 ===========
# [Action] Pick goal_bottle
# [Reward] S(0) -> A(3) -> S'(6) Reward : 1
# Success!!!!!
# Terminal State! Reward is 5
# Aleady has optimal nodes!!
# =========== Search iteration : 11 ===========
# [Action] Pick goal_bottle
# [Reward] S(0) -> A(3) -> S'(4) Reward : 1
# Success!!!!!
# Terminal State! Reward is 5
# Aleady has optimal nodes!!
# =========== Search iteration : 12 ===========
# [Action] Pick goal_bottle
# [Reward] S(0) -> A(3) -> S'(18) Reward : 1
# Success!!!!!
# Terminal State! Reward is 5
# Aleady has optimal nodes!!
# =========== Search iteration : 13 ===========
# [Action] Pick goal_bottle
# [Reward] S(0) -> A(3) -> S'(6) Reward : 1
# Success!!!!!
# Terminal State! Reward is 5
# Aleady has optimal nodes!!
# =========== Search iteration : 14 ===========
# [Action] Pick goal_bottle
# [Reward] S(0) -> A(3) -> S'(14) Reward : 1
# Success!!!!!
# Terminal State! Reward is 5
# Action Node: 3 Action: Pick goal_bottle
# pick goal_bottle
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0725 sec
#
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0692 sec
#
# Retry compute IK.. Pose error is 2.714555
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0709 sec
#
# Retry compute IK.. Pose error is 2.714549
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0683 sec
#
# Retry compute IK.. Pose error is 2.714544
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0669 sec
#
# Retry compute IK.. Pose error is 2.714550
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0731 sec
#
# Retry compute IK.. Pose error is 2.714544
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0700 sec
#
# Retry compute IK.. Pose error is 2.714554
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0688 sec
#
# Retry compute IK.. Pose error is 2.714555
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0695 sec
#
# Retry compute IK.. Pose error is 2.714544
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0710 sec
#
# Retry compute IK.. Pose error is 2.714546
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0748 sec
#
# Retry compute IK.. Pose error is 2.714548
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0723 sec
#
# Retry compute IK.. Pose error is 2.714582
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0707 sec
#
# Retry compute IK.. Pose error is 2.714602
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0681 sec
#
# Retry compute IK.. Pose error is 2.714553
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0689 sec
#
# Retry compute IK.. Pose error is 2.714556
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0683 sec
#
# Retry compute IK.. Pose error is 2.714551
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0672 sec
#
# Retry compute IK.. Pose error is 2.714555
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0735 sec
#
# Retry compute IK.. Pose error is 2.714551
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0709 sec
#
# Retry compute IK.. Pose error is 2.714552
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0700 sec
#
# Retry compute IK.. Pose error is 2.714560
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0699 sec
#
# Retry compute IK.. Pose error is 2.714557
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0698 sec
#
# Retry compute IK.. Pose error is 2.714530
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0724 sec
#
# Retry compute IK.. Pose error is 2.714552
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0730 sec
#
# Retry compute IK.. Pose error is 2.714555
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0714 sec
#
# Retry compute IK.. Pose error is 2.714532
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0718 sec
#
# Retry compute IK.. Pose error is 2.714549
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0724 sec
#
# Retry compute IK.. Pose error is 2.714505
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0686 sec
#
# Retry compute IK.. Pose error is 2.714545
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0718 sec
#
# Retry compute IK.. Pose error is 2.714556
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0719 sec
#
# Retry compute IK.. Pose error is 2.714645
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0693 sec
#
# Retry compute IK.. Pose error is 2.714547
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0703 sec
#
# Retry compute IK.. Pose error is 2.714545
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0701 sec
#
# Retry compute IK.. Pose error is 2.714548
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0685 sec
#
# Retry compute IK.. Pose error is 2.714548
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0674 sec
#
# Retry compute IK.. Pose error is 2.714526
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0708 sec
#
# Retry compute IK.. Pose error is 2.714555
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0710 sec
#
# Retry compute IK.. Pose error is 2.714536
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0694 sec
#
# Retry compute IK.. Pose error is 2.714556
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0734 sec
#
# Retry compute IK.. Pose error is 2.714553
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0689 sec
#
# Retry compute IK.. Pose error is 2.714553
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0694 sec
#
# Retry compute IK.. Pose error is 2.714556
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0715 sec
#
# Retry compute IK.. Pose error is 2.714550
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0717 sec
#
# Retry compute IK.. Pose error is 2.714556
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0700 sec
#
# Retry compute IK.. Pose error is 2.714545
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0728 sec
#
# Retry compute IK.. Pose error is 2.714555
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0702 sec
#
# Retry compute IK.. Pose error is 2.714553
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0708 sec
#
# Retry compute IK.. Pose error is 2.714551
# solve the problem using LM2!!
# ...
# WorkingTime[inverse_kinematics]: 0.0694 sec
#
# Retry compute IK.. Pose error is 2.620828
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0692 sec
#
# Retry compute IK.. Pose error is 2.620828
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0681 sec
#
# Retry compute IK.. Pose error is 2.620832
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0701 sec
#
# Retry compute IK.. Pose error is 2.620845
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0687 sec
#
# Retry compute IK.. Pose error is 2.620861
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0677 sec
#
# Retry compute IK.. Pose error is 2.620828
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0700 sec
#
# Retry compute IK.. Pose error is 2.620824
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0695 sec
#
# Retry compute IK.. Pose error is 2.620830
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0680 sec
#
# Retry compute IK.. Pose error is 2.620774
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0698 sec
#
# Retry compute IK.. Pose error is 2.620831
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0682 sec
#
# Retry compute IK.. Pose error is 2.620819
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0681 sec
#
# Retry compute IK.. Pose error is 2.620828
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0697 sec
#
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0690 sec
#
# Retry compute IK.. Pose error is 2.620836
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0680 sec
#
# Retry compute IK.. Pose error is 2.620832
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0696 sec
#
# Retry compute IK.. Pose error is 2.620832
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0687 sec
#
# Retry compute IK.. Pose error is 2.620838
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0678 sec
#
# Retry compute IK.. Pose error is 2.620834
# solve the problem using LM2!!
# [ERROR] [RRT Star Planner]: Not found IK solution
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0700 sec
#
# Retry compute IK.. Pose error is 2.620844
# WorkingTime[run]: 3.6232 sec
#
# Pick joint Fail
# [[0, 3, 16], [0, 3, 9], [0, 3, 4], [0, 3, 18], [0, 3, 6], [0, 3, 14], [0, 3, 5], [0, 3, 17]]
# =========== Search iteration : 22 ===========
# [Action] Pick goal_bottle
# [Reward] S(0) -> A(3) -> S'(10) Reward : 1
# Success!!!!!
# Terminal State! Reward is 5
# Action Node: 3 Action: Pick goal_bottle
# pick goal_bottle
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0704 sec
#
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0689 sec
#
# Retry compute IK.. Pose error is 4.023817
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0716 sec
#
# Retry compute IK.. Pose error is 4.023751
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0688 sec
#
# Retry compute IK.. Pose error is 4.023838
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0688 sec
#
# Retry compute IK.. Pose error is 4.023802
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0693 sec
#
# Retry compute IK.. Pose error is 4.023823
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0683 sec
#
# Retry compute IK.. Pose error is 4.023786
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0691 sec
#
# Retry compute IK.. Pose error is 4.023725
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0713 sec
#
# Retry compute IK.. Pose error is 4.023807
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0683 sec
#
# Retry compute IK.. Pose error is 4.023840
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0687 sec
#
# Retry compute IK.. Pose error is 4.023816
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0701 sec
#
# Retry compute IK.. Pose error is 4.023814
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0701 sec
#
# Retry compute IK.. Pose error is 4.023784
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0702 sec
#
# Retry compute IK.. Pose error is 4.023795
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0711 sec
#
# Retry compute IK.. Pose error is 4.023821
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0693 sec
#
# Retry compute IK.. Pose error is 4.023938
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0689 sec
#
# Retry compute IK.. Pose error is 4.023846
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0701 sec
#
# Retry compute IK.. Pose error is 4.023849
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0689 sec
#
# Retry compute IK.. Pose error is 4.023824
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0684 sec
#
# Retry compute IK.. Pose error is 4.023655
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0700 sec
#
# Retry compute IK.. Pose error is 4.023802
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0703 sec
#
# Retry compute IK.. Pose error is 4.023847
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0690 sec
#
# Retry compute IK.. Pose error is 4.023778
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0709 sec
#
# Retry compute IK.. Pose error is 4.023816
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0692 sec
#
# Retry compute IK.. Pose error is 4.023900
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0690 sec
#
# Retry compute IK.. Pose error is 4.023817
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0739 sec
#
# Retry compute IK.. Pose error is 4.024286
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0711 sec
#
# Retry compute IK.. Pose error is 4.024168
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0683 sec
#
# Retry compute IK.. Pose error is 4.023848
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0707 sec
#
# Retry compute IK.. Pose error is 4.023883
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0717 sec
#
# Retry compute IK.. Pose error is 4.023806
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0724 sec
#
# Retry compute IK.. Pose error is 4.023782
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0740 sec
#
# Retry compute IK.. Pose error is 4.023830
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0708 sec
#
# Retry compute IK.. Pose error is 4.023780
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0726 sec
#
# Retry compute IK.. Pose error is 4.023865
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0730 sec
#
# Retry compute IK.. Pose error is 4.023796
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0719 sec
#
# Retry compute IK.. Pose error is 4.023877
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0736 sec
#
# Retry compute IK.. Pose error is 4.023764
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0743 sec
#
# Retry compute IK.. Pose error is 4.023811
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0706 sec
#
# Retry compute IK.. Pose error is 4.023813
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0705 sec
#
# Retry compute IK.. Pose error is 4.023797
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0724 sec
#
# Retry compute IK.. Pose error is 4.023842
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0722 sec
#
# Retry compute IK.. Pose error is 4.023812
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0722 sec
#
# Retry compute IK.. Pose error is 4.023810
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0728 sec
#
# Retry compute IK.. Pose error is 4.023801
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0724 sec
#
# Retry compute IK.. Pose error is 4.023685
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0735 sec
#
# Retry compute IK.. Pose error is 4.023787
# solve the problem using LM2!!
# [ERROR] [RRT Star Planner]: Not found IK solution
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0730 sec
#
# Retry compute IK.. Pose error is 4.023792
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0729 sec
#
# Retry compute IK.. Pose error is 4.023866
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0768 sec
#
# Retry compute IK.. Pose error is 4.023816
# WorkingTime[run]: 3.6802 sec
#
# Pick joint Fail
# [[0, 3, 16], [0, 3, 9], [0, 3, 4], [0, 3, 18], [0, 3, 6], [0, 3, 14], [0, 3, 5], [0, 3, 17], [0, 3, 10]]
# =========== Search iteration : 23 ===========
# [Action] Pick goal_bottle
# [Reward] S(0) -> A(3) -> S'(5) Reward : 1
# Success!!!!!
# Terminal State! Reward is 5
# Aleady has optimal nodes!!
# =========== Search iteration : 24 ===========
# [Action] Pick goal_bottle
# [Reward] S(0) -> A(3) -> S'(10) Reward : 1
# Success!!!!!
# Terminal State! Reward is 5
# Aleady has optimal nodes!!
# =========== Search iteration : 25 ===========
# [Action] Pick goal_bottle
# [Reward] S(0) -> A(3) -> S'(17) Reward : 1
# Success!!!!!
# Terminal State! Reward is 5
# Aleady has optimal nodes!!
# =========== Search iteration : 26 ===========
# [Action] Pick goal_bottle
# [Reward] S(0) -> A(3) -> S'(6) Reward : 1
# Success!!!!!
# Terminal State! Reward is 5
# Aleady has optimal nodes!!
# =========== Search iteration : 27 ===========
# [Action] Pick goal_bottle
# [Reward] S(0) -> A(3) -> S'(4) Reward : 1
# Success!!!!!
# Terminal State! Reward is 5
# Aleady has optimal nodes!!
# =========== Search iteration : 28 ===========
# [Action] Pick goal_bottle
# [Reward] S(0) -> A(3) -> S'(18) Reward : 1
# Success!!!!!
# Terminal State! Reward is 5
# Aleady has optimal nodes!!
# =========== Search iteration : 29 ===========
# [Action] Pick goal_bottle
# [Reward] S(0) -> A(3) -> S'(16) Reward : 1
# Success!!!!!
# Terminal State! Reward is 5
# Aleady has optimal nodes!!
# =========== Search iteration : 30 ===========
# [Action] Pick goal_bottle
# [Reward] S(0) -> A(3) -> S'(8) Reward : 1
# Success!!!!!
# Terminal State! Reward is 5
# Action Node: 3 Action: Pick goal_bottle
# pick goal_bottle
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0724 sec
#
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0716 sec
#
# Retry compute IK.. Pose error is 5.134186
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0716 sec
#
# Retry compute IK.. Pose error is 5.134225
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0716 sec
#
# Retry compute IK.. Pose error is 5.134155
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0706 sec
#
# Retry compute IK.. Pose error is 5.134301
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0712 sec
#
# Retry compute IK.. Pose error is 5.134146
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0715 sec
#
# Retry compute IK.. Pose error is 5.134227
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0707 sec
#
# Retry compute IK.. Pose error is 5.134173
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0703 sec
#
# Retry compute IK.. Pose error is 5.133876
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0719 sec
#
# Retry compute IK.. Pose error is 5.134080
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0715 sec
#
# Retry compute IK.. Pose error is 5.134178
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0699 sec
#
# Retry compute IK.. Pose error is 5.134289
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0726 sec
#
# Retry compute IK.. Pose error is 5.134020
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0689 sec
#
# Retry compute IK.. Pose error is 5.134183
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0702 sec
#
# Retry compute IK.. Pose error is 5.134174
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0720 sec
#
# Retry compute IK.. Pose error is 5.134252
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0718 sec
#
# Retry compute IK.. Pose error is 5.134010
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0685 sec
#
# Retry compute IK.. Pose error is 5.134290
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0694 sec
#
# Retry compute IK.. Pose error is 5.134293
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0698 sec
#
# Retry compute IK.. Pose error is 5.134140
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0692 sec
#
# Retry compute IK.. Pose error is 5.134187
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0734 sec
#
# Retry compute IK.. Pose error is 5.134112
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0722 sec
#
# Retry compute IK.. Pose error is 5.133962
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0721 sec
#
# Retry compute IK.. Pose error is 5.134164
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0738 sec
#
# Retry compute IK.. Pose error is 5.134138
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0720 sec
#
# Retry compute IK.. Pose error is 5.134227
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0716 sec
#
# Retry compute IK.. Pose error is 5.134035
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0727 sec
#
# Retry compute IK.. Pose error is 5.134150
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0692 sec
#
# Retry compute IK.. Pose error is 5.134036
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0671 sec
#
# Retry compute IK.. Pose error is 5.134179
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0709 sec
#
# Retry compute IK.. Pose error is 5.134157
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0700 sec
#
# Retry compute IK.. Pose error is 5.134169
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0689 sec
#
# Retry compute IK.. Pose error is 5.134096
# solve the problem using LM2!!
# Iterators : 100
# WorkingTime[inverse_kinematics]: 0.0698 sec
#
# Retry compute IK.. Pose error is 5.134151
# solve the problem using LM2!!
# KeyboardInterrupt

# %%
final_level_1_values.append(mcts.values_for_level_1)
final_level_2_values.append(mcts.values_for_level_2)

if mcts.level_wise_2_success:
    (
        pnp_all_joint_paths,
        pick_all_objects,
        place_all_object_poses,
    ) = mcts.get_all_joint_path(mcts.optimal_nodes)
    final_pnp_all_joint_paths.append(pnp_all_joint_paths)
    final_pick_all_objects.append(pick_all_objects)
    final_place_all_object_poses.append(place_all_object_poses)
    final_optimal_nodes.append(mcts.optimal_nodes)
    
else:
    final_pnp_all_joint_paths.append([])
    final_pick_all_objects.append([])
    final_place_all_object_poses.append([])
    final_optimal_nodes.append([])
    # final_optimal_trees.append(mcts.tree.nodes)

# %%
mcts.place_action.simulate_path(
    final_pnp_all_joint_paths[0],
    pick_all_objects,
    place_all_object_poses,
    is_save=True,
    video_name="MCTS_Benchamrk2_pytamp_jh",
)
# Out:
# [WARNING] [Collision Manager]: bottle_1 not in collision manager!
# Animation Finished..
# Save finished..

# %%
mcts.visualize_tree("Siccess nodes", mcts.tree)
