# %%
import numpy as np
import argparse
import os, time

from pykin.utils import plot_utils as p_utils

from pytamp.benchmark import Benchmark1_for_rearr as Benchmark1
from pytamp.search.mcts_for_rearragement import MCTS_rearrangement

def get_parser():
    parser = argparse.ArgumentParser(description="Test Rearragement 1.")
    parser.add_argument("--budgets", metavar="T", type=int, default=30, help="Horizon")
    parser.add_argument("--max_depth", metavar="H", type=int, default=12, help="Max depth")
#     parser.add_argument("--seed", metavar="i", type=int, default=7, help="A random seed")
#     parser.add_argument("--seed", metavar="i", type=int, default=17, help="A random seed")
    parser.add_argument("--seed", metavar="i", type=int, default=22, help="A random seed")
    parser.add_argument(
        "--algo",
        metavar="alg",
        type=str,
        default="bai_perturb",
        choices=["bai_perturb", "bai_ucb", "uct", "random", "greedy"],
        help="Choose one (bai_perturb, bai_ucb, uct)",
    )
    parser.add_argument(
        "--debug_mode", default=False, type=lambda x: (str(x).lower() == "true"), help="Debug mode"
    )
#     parser.add_argument("--box_number", metavar="N", type=int, default=6, help="Box Number(6 or less)")
    try:
        args = parser.parse_args() #call from command line
    except:
        args = parser.parse_args(args=[]) #call from notebook
    return args 

args = get_parser() 

debug_mode = args.debug_mode
# debug_mode = True
budgets = args.budgets
max_depth = args.max_depth
algo = args.algo
seed = args.seed
np.random.seed(seed)

benchmark1 = Benchmark1(
    robot_name="panda", geom="visual", is_pyplot=False, box_num=4
)

final_level_1_values = []
final_level_2_values = []
final_optimal_nodes = []
final_pnp_all_joint_paths = []
final_pick_all_objects = []
final_place_all_object_poses = []

# final_optimal_trees = []
c_list = 10 ** np.linspace(-2, 2.0, 10)
# Out:
# 2023-08-05 22:06:04.834354: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# usage: ipykernel_launcher.py [-h] [--budgets T] [--max_depth H] [--seed i]
#                              [--algo alg] [--debug_mode DEBUG_MODE]
# ipykernel_launcher.py: error: unrecognized arguments: -f /home/juju/.local/share/jupyter/runtime/kernel-de166504-3b99-4bfc-8f83-108f50d29a86.json
# *********************** Logical States ***********************
# OrderedDict([('A_box',
#               {'on': Object(name=table, pos=[ 1.    -0.6    0.043])}),
#              ('B_box',
#               {'on': Object(name=table, pos=[ 1.    -0.6    0.043])}),
#              ('C_box',
#               {'on': Object(name=table, pos=[ 1.    -0.6    0.043]),
#                'support': [Object(name=D_box, pos=[0.6        0.2        0.88329998])]}),
#              ('D_box',
#               {'on': Object(name=C_box, pos=[0.6        0.2        0.83329998])}),
#              ('tray_red', {'static': True}),
#              ('table',
#               {'static': True,
#                'support': [Object(name=A_box, pos=[0.6        0.         0.83329998]),
#                            Object(name=B_box, pos=[ 0.6        -0.2         0.83329998]),
#                            Object(name=C_box, pos=[0.6        0.2        0.83329998])]}),
#              ('panda_gripper', {'holding': None})])
# ***************************************************************

# %%
benchmark1.scene_mngr.scene.benchmark_config
# Out:
# {1: {'stack_num': 4, 'goal_object': 'tray_red'}}

# %%
# # #######################
# fig, ax = p_utils.init_3d_figure(name="Benchamrk 1")
# # init_scene
# benchmark1.scene_mngr.render_scene(ax)
# benchmark1.render_axis(benchmark1.scene_mngr)
# benchmark1.scene_mngr.show()

# %%
c = 2.5
idx = 0
mcts = MCTS_rearrangement(
    scene_mngr=benchmark1.scene_mngr,
    init_scene=benchmark1.init_scene,
    sampling_method=algo,
    budgets=budgets,
    max_depth=max_depth,
    c=c,
    debug_mode=True,
    use_pick_action=False,
    consider_next_scene=True, 
)

mcts.only_optimize_1 = False
# Out:
# 2023-08-05 22:06:13.159089: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-08-05 22:06:13.188347: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-05 22:06:13.188413: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 3080 computeCapability: 8.6
# coreClock: 1.74GHz coreCount: 68 deviceMemorySize: 9.77GiB deviceMemoryBandwidth: 707.88GiB/s
# 2023-08-05 22:06:13.188438: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-08-05 22:06:13.189929: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-08-05 22:06:13.189979: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-08-05 22:06:13.190470: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2023-08-05 22:06:13.190632: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2023-08-05 22:06:13.191047: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2023-08-05 22:06:13.191408: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2023-08-05 22:06:13.191472: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-08-05 22:06:13.191545: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-05 22:06:13.191618: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-05 22:06:13.191656: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# /home/juju/contact_graspnet/pointnet2/tf_ops/sampling
# <module 'contact_graspnet.contact_graspnet' from '/home/juju/contact_graspnet/contact_graspnet/contact_graspnet.py'>
# --- Get model
# WARNING:tensorflow:From /home/juju/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/tensorflow/python/keras/layers/normalization.py:534: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# /home/juju/contact_graspnet/contact_graspnet/config_utils.py:42: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   global_config = yaml.load(f)
# /home/juju/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/tensorflow/python/keras/legacy_tf_layers/normalization.py:307: UserWarning: `tf.layers.batch_normalization` is deprecated and will be removed in a future version. Please use `tf.keras.layers.BatchNormalization` instead. In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.BatchNormalization` documentation).
#   warnings.warn(
# /home/juju/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer_v1.py:1692: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# WARNING:tensorflow:From /home/juju/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py:602: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# WARNING:tensorflow:From /home/juju/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:206: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# 2023-08-05 22:06:15.287518: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-05 22:06:15.288694: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-05 22:06:15.288773: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 3080 computeCapability: 8.6
# coreClock: 1.74GHz coreCount: 68 deviceMemorySize: 9.77GiB deviceMemoryBandwidth: 707.88GiB/s
# 2023-08-05 22:06:15.288821: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-05 22:06:15.288866: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-05 22:06:15.288899: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-08-05 22:06:15.288939: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# INFO:tensorflow:Restoring parameters from /home/juju/contact_graspnet/checkpoints/scene_test_2048_bs3_hor_sigma_001/model.ckpt-144144
# 2023-08-05 22:06:15.561105: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-08-05 22:06:15.561125: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-08-05 22:06:15.561129: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-08-05 22:06:15.561265: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-05 22:06:15.561350: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-05 22:06:15.561400: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-05 22:06:15.561450: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6748 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:01:00.0, compute capability: 8.6)
# 2023-08-05 22:06:15.662579: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 3609600000 Hz

# %%
sup_obj_name = None
list(mcts.rearr_action.get_arbitrary_location('A_box', support_obj_name=sup_obj_name,scene_for_sample=mcts.init_scene, sample_num= 1))[0]
# Out:
# {'table': array([[ 0.99285475, -0.11932915,  0.        ,  0.45128776],
#         [ 0.11932915,  0.99285475,  0.        ,  0.45036044],
#         [ 0.        ,  0.        ,  1.        ,  0.83379998],
#         [ 0.        ,  0.        ,  0.        ,  1.        ]])}

# %%
start_time = time.time()
for i in range(budgets):
# for i in range(10):
    print(
        f"\n[{idx+1}/{len(c_list)}] Benchmark: {benchmark1.scene_mngr.scene.bench_num}, Algo: {algo}, C: {c}, Seed: {seed}"
    )
    mcts.do_planning_rearrange(i)

    print("########### Running time : ", time.time()- start_time, "##############")
    final_level_1_values.append(mcts.values_for_level_1)
# Out:
# [1/10] Benchmark: 1, Algo: bai_perturb, C: 2.5, Seed: 22
# =========== Search iteration : 1 ===========
# [Action] Rearr A_box to tray_red
# Good Action
# [Reward] S(0) -> A(2) -> S'(109) Reward : 20.0
# [Action] Rearr D_box to table
# [Reward] S(109) -> A(112) -> S'(115) Reward : -1
# [Action] Rearr C_box to A_box
# [Reward] S(115) -> A(119) -> S'(121) Reward : -1
# [Action] Rearr D_box to table
# [Reward] S(121) -> A(123) -> S'(714) Reward : -1
# [Action] Rearr B_box to table
# [Reward] S(714) -> A(715) -> S'(718) Reward : -1
# [Action] Rearr D_box to C_box
# [Reward] S(718) -> A(723) -> S'(1154) Reward : -1
# [Action] Rearr B_box to table
# [Reward] S(1154) -> A(1155) -> S'(1156) Reward : -1
# [Action] Rearr D_box to B_box
# [Reward] S(1156) -> A(1157) -> S'(1158) Reward : -1
# [Action] Rearr C_box to table
# [Reward] S(1158) -> A(1159) -> S'(1160) Reward : -1
# [Action] Rearr A_box to table
# Bad Action
# [Reward] S(1160) -> A(1161) -> S'(1165) Reward : -2.0
# [Action] Rearr C_box to A_box
# [Reward] S(1165) -> A(1167) -> S'(1173) Reward : -1
# [Action] Rearr D_box to C_box
# [Reward] S(1173) -> A(1174) -> S'(1176) Reward : -1
# Exceeded the maximum depth!!
# ########### Running time :  0.24031639099121094 ##############
#
# [1/10] Benchmark: 1, Algo: bai_perturb, C: 2.5, Seed: 22
# =========== Search iteration : 2 ===========
# [Action] Rearr A_box to tray_red
# Good Action
# [Reward] S(0) -> A(2) -> S'(109) Reward : 20.0
# [Action] Rearr D_box to table
# [Reward] S(109) -> A(112) -> S'(115) Reward : -1
# [Action] Rearr C_box to A_box
# [Reward] S(115) -> A(119) -> S'(121) Reward : -1
# [Action] Rearr B_box to table
# [Reward] S(121) -> A(122) -> S'(126) Reward : -1
# [Action] Rearr C_box to table
# [Reward] S(126) -> A(127) -> S'(131) Reward : -1
# [Action] Rearr D_box to A_box
# [Reward] S(131) -> A(136) -> S'(1177) Reward : -1
# [Action] Rearr C_box to B_box
# [Reward] S(1177) -> A(1178) -> S'(1179) Reward : -1
# [Action] Rearr D_box to table
# [Reward] S(1179) -> A(1180) -> S'(1182) Reward : -1
# [Action] Rearr C_box to table
# [Reward] S(1182) -> A(1184) -> S'(1186) Reward : -1
# [Action] Rearr B_box to table
# [Reward] S(1186) -> A(1187) -> S'(1192) Reward : -1
# [Action] Rearr D_box to B_box
# [Reward] S(1192) -> A(1198) -> S'(1200) Reward : -1
# [Action] Rearr A_box to table
# Bad Action
# [Reward] S(1200) -> A(1201) -> S'(1203) Reward : -1.667
# Exceeded the maximum depth!!
# ########### Running time :  0.791834831237793 ##############
#
# [1/10] Benchmark: 1, Algo: bai_perturb, C: 2.5, Seed: 22
# =========== Search iteration : 3 ===========
# [Action] Rearr A_box to tray_red
# Good Action
# [Reward] S(0) -> A(2) -> S'(109) Reward : 20.0
# [Action] Rearr D_box to table
# [Reward] S(109) -> A(112) -> S'(115) Reward : -1
# [Action] Rearr C_box to A_box
# [Reward] S(115) -> A(119) -> S'(121) Reward : -1
# [Action] Rearr D_box to table
# [Reward] S(121) -> A(123) -> S'(714) Reward : -1
# [Action] Rearr B_box to table
# [Reward] S(714) -> A(715) -> S'(718) Reward : -1
# [Action] Rearr C_box to table
# [Reward] S(718) -> A(719) -> S'(724) Reward : -1
# [Action] Rearr A_box to table
# Bad Action
# [Reward] S(724) -> A(725) -> S'(1204) Reward : -2.857
# [Action] Rearr C_box to A_box
# [Reward] S(1204) -> A(1208) -> S'(1216) Reward : -1
# [Action] Rearr D_box to table
# [Reward] S(1216) -> A(1219) -> S'(1223) Reward : -1
# [Action] Rearr B_box to table
# [Reward] S(1223) -> A(1224) -> S'(1228) Reward : -1
# [Action] Rearr C_box to B_box
# [Reward] S(1228) -> A(1230) -> S'(1236) Reward : -1
# [Action] Rearr D_box to tray_red
# [Reward] S(1236) -> A(1242) -> S'(1243) Reward : -1
# Exceeded the maximum depth!!
# ########### Running time :  1.0670628547668457 ##############
#
# [1/10] Benchmark: 1, Algo: bai_perturb, C: 2.5, Seed: 22
# =========== Search iteration : 4 ===========
# [Action] Rearr A_box to tray_red
# Good Action
# [Reward] S(0) -> A(2) -> S'(109) Reward : 20.0
# [Action] Rearr D_box to table
# [Reward] S(109) -> A(112) -> S'(115) Reward : -1
# [Action] Rearr C_box to A_box
# [Reward] S(115) -> A(119) -> S'(121) Reward : -1
# [Action] Rearr B_box to table
# [Reward] S(121) -> A(122) -> S'(126) Reward : -1
# [Action] Rearr C_box to table
# [Reward] S(126) -> A(127) -> S'(131) Reward : -1
# [Action] Rearr D_box to B_box
# [Reward] S(131) -> A(137) -> S'(1244) Reward : -1
# [Action] Rearr C_box to table
# [Reward] S(1244) -> A(1246) -> S'(1248) Reward : -1
# [Action] Rearr D_box to A_box
# [Reward] S(1248) -> A(1250) -> S'(1252) Reward : -1
# [Action] Rearr C_box to B_box
# [Reward] S(1252) -> A(1255) -> S'(1256) Reward : -1
# [Action] Rearr D_box to table
# [Reward] S(1256) -> A(1257) -> S'(1259) Reward : -1
# [Action] Rearr C_box to table
# [Reward] S(1259) -> A(1260) -> S'(1262) Reward : -1
# [Action] Rearr D_box to B_box
# [Reward] S(1262) -> A(1266) -> S'(1268) Reward : -1
# Exceeded the maximum depth!!
# ########### Running time :  1.3290016651153564 ##############
#
# [1/10] Benchmark: 1, Algo: bai_perturb, C: 2.5, Seed: 22
# =========== Search iteration : 5 ===========
# [Action] Rearr A_box to tray_red
# Good Action
# [Reward] S(0) -> A(2) -> S'(109) Reward : 20.0
# [Action] Rearr D_box to table
# [Reward] S(109) -> A(112) -> S'(115) Reward : -1
# [Action] Rearr C_box to A_box
# [Reward] S(115) -> A(119) -> S'(121) Reward : -1
# [Action] Rearr B_box to table
# [Reward] S(121) -> A(122) -> S'(126) Reward : -1
# [Action] Rearr C_box to table
# [Reward] S(126) -> A(127) -> S'(131) Reward : -1
# [Action] Rearr D_box to C_box
# [Reward] S(131) -> A(138) -> S'(1269) Reward : -1
# [Action] Rearr B_box to table
# [Reward] S(1269) -> A(1271) -> S'(1273) Reward : -1
# [Action] Rearr D_box to B_box
# [Reward] S(1273) -> A(1275) -> S'(1276) Reward : -1
# [Action] Rearr C_box to A_box
# [Reward] S(1276) -> A(1279) -> S'(1280) Reward : -1
# [Action] Rearr D_box to table
# [Reward] S(1280) -> A(1281) -> S'(1283) Reward : -1
# [Action] Rearr B_box to table
# [Reward] S(1283) -> A(1284) -> S'(1286) Reward : -1
# [Action] Rearr D_box to C_box
# [Reward] S(1286) -> A(1290) -> S'(1291) Reward : -1
# Exceeded the maximum depth!!
# ########### Running time :  1.5865309238433838 ##############
#
# [1/10] Benchmark: 1, Algo: bai_perturb, C: 2.5, Seed: 22
# =========== Search iteration : 6 ===========
# [Action] Rearr A_box to tray_red
# Good Action
# [Reward] S(0) -> A(2) -> S'(109) Reward : 20.0
# [Action] Rearr D_box to table
# [Reward] S(109) -> A(112) -> S'(115) Reward : -1
# [Action] Rearr C_box to A_box
# [Reward] S(115) -> A(119) -> S'(121) Reward : -1
# [Action] Rearr D_box to table
# [Reward] S(121) -> A(123) -> S'(714) Reward : -1
# [Action] Rearr B_box to table
# [Reward] S(714) -> A(715) -> S'(718) Reward : -1
# [Action] Rearr C_box to table
# [Reward] S(718) -> A(719) -> S'(724) Reward : -1
# [Action] Rearr B_box to table
# [Reward] S(724) -> A(726) -> S'(1292) Reward : -1
# [Action] Rearr A_box to table
# Bad Action
# [Reward] S(1292) -> A(1293) -> S'(1300) Reward : -2.5
# [Action] Rearr B_box to tray_red
# [Reward] S(1300) -> A(1303) -> S'(1311) Reward : -1
# [Action] Rearr D_box to A_box
# [Reward] S(1311) -> A(1316) -> S'(1319) Reward : -1
# [Action] Rearr B_box to table
# [Reward] S(1319) -> A(1320) -> S'(1322) Reward : -1
# [Action] Rearr D_box to tray_red
# [Reward] S(1322) -> A(1328) -> S'(1329) Reward : -1
# Exceeded the maximum depth!!
# ########### Running time :  1.880500078201294 ##############
#
# [1/10] Benchmark: 1, Algo: bai_perturb, C: 2.5, Seed: 22
# =========== Search iteration : 7 ===========
# [Action] Rearr A_box to tray_red
# Good Action
# [Reward] S(0) -> A(2) -> S'(109) Reward : 20.0
# [Action] Rearr D_box to table
# [Reward] S(109) -> A(112) -> S'(115) Reward : -1
# [Action] Rearr C_box to A_box
# [Reward] S(115) -> A(119) -> S'(121) Reward : -1
# [Action] Rearr D_box to table
# [Reward] S(121) -> A(123) -> S'(714) Reward : -1
# [Action] Rearr B_box to table
# [Reward] S(714) -> A(715) -> S'(718) Reward : -1
# [Action] Rearr C_box to table
# [Reward] S(718) -> A(719) -> S'(724) Reward : -1
# [Action] Rearr B_box to A_box
# Good Action
# [Reward] S(724) -> A(727) -> S'(1330) Reward : 2.857
# [Action] Rearr D_box to B_box
# [Reward] S(1330) -> A(1334) -> S'(1336) Reward : -1
# Current logical action is None.. Reward is -6.25
# [Reward] S(1336) -> A(None) -> S'(None) Reward : -6.25
# ########### Running time :  1.957270860671997 ##############
#
# [1/10] Benchmark: 1, Algo: bai_perturb, C: 2.5, Seed: 22
# =========== Search iteration : 8 ===========
# [Action] Rearr A_box to tray_red
# Good Action
# [Reward] S(0) -> A(2) -> S'(109) Reward : 20.0
# [Action] Rearr D_box to table
# [Reward] S(109) -> A(112) -> S'(115) Reward : -1
# [Action] Rearr C_box to A_box
# [Reward] S(115) -> A(119) -> S'(121) Reward : -1
# [Action] Rearr B_box to table
# [Reward] S(121) -> A(122) -> S'(126) Reward : -1
# [Action] Rearr C_box to table
# [Reward] S(126) -> A(127) -> S'(131) Reward : -1
# [Action] Rearr B_box to A_box
# Good Action
# [Reward] S(131) -> A(134) -> S'(139) Reward : 3.333
# [Action] Rearr C_box to table
# [Reward] S(139) -> A(140) -> S'(1337) Reward : -1
# [Action] Rearr D_box to B_box
# [Reward] S(1337) -> A(1338) -> S'(1340) Reward : -1
# Current logical action is None.. Reward is -6.25
# [Reward] S(1340) -> A(None) -> S'(None) Reward : -6.25
# ########### Running time :  2.0351006984710693 ##############
#
# [1/10] Benchmark: 1, Algo: bai_perturb, C: 2.5, Seed: 22
# =========== Search iteration : 9 ===========
# [Action] Rearr A_box to tray_red
# Good Action
# [Reward] S(0) -> A(2) -> S'(109) Reward : 20.0
# [Action] Rearr D_box to table
# [Reward] S(109) -> A(112) -> S'(115) Reward : -1
# [Action] Rearr C_box to A_box
# [Reward] S(115) -> A(119) -> S'(121) Reward : -1
# [Action] Rearr D_box to table
# [Reward] S(121) -> A(123) -> S'(714) Reward : -1
# [Action] Rearr B_box to table
# [Reward] S(714) -> A(715) -> S'(718) Reward : -1
# [Action] Rearr C_box to table
# [Reward] S(718) -> A(719) -> S'(724) Reward : -1
# [Action] Rearr D_box to A_box
# [Reward] S(724) -> A(728) -> S'(1341) Reward : -1
# [Action] Rearr B_box to table
# [Reward] S(1341) -> A(1342) -> S'(1345) Reward : -1
# [Action] Rearr C_box to table
# [Reward] S(1345) -> A(1346) -> S'(1351) Reward : -1
# [Action] Rearr B_box to table
# [Reward] S(1351) -> A(1352) -> S'(1356) Reward : -1
# [Action] Rearr D_box to B_box
# [Reward] S(1356) -> A(1359) -> S'(1361) Reward : -1
# [Action] Rearr C_box to A_box
# [Reward] S(1361) -> A(1363) -> S'(1364) Reward : -1
# Exceeded the maximum depth!!
# ########### Running time :  2.266289234161377 ##############
#
# [1/10] Benchmark: 1, Algo: bai_perturb, C: 2.5, Seed: 22
# =========== Search iteration : 10 ===========
# [Action] Rearr A_box to tray_red
# Good Action
# [Reward] S(0) -> A(2) -> S'(109) Reward : 20.0
# [Action] Rearr D_box to table
# [Reward] S(109) -> A(112) -> S'(115) Reward : -1
# [Action] Rearr C_box to A_box
# [Reward] S(115) -> A(119) -> S'(121) Reward : -1
# [Action] Rearr B_box to table
# [Reward] S(121) -> A(122) -> S'(126) Reward : -1
# [Action] Rearr C_box to table
# [Reward] S(126) -> A(127) -> S'(131) Reward : -1
# [Action] Rearr B_box to A_box
# Good Action
# [Reward] S(131) -> A(134) -> S'(139) Reward : 3.333
# [Action] Rearr C_box to B_box
# Good Action
# [Reward] S(139) -> A(141) -> S'(1365) Reward : 2.857
# [Action] Rearr D_box to table
# [Reward] S(1365) -> A(1366) -> S'(1368) Reward : -1
# [Action] Rearr C_box to table
# Bad Action
# [Reward] S(1368) -> A(1369) -> S'(1370) Reward : -2.222
# [Action] Rearr D_box to table
# [Reward] S(1370) -> A(1371) -> S'(1374) Reward : -1
# [Action] Rearr B_box to table
# Bad Action
# [Reward] S(1374) -> A(1375) -> S'(1378) Reward : -1.818
# [Action] Rearr D_box to B_box
# [Reward] S(1378) -> A(1383) -> S'(1385) Reward : -1
# Exceeded the maximum depth!!
# ########### Running time :  2.49643611907959 ##############
#
# [1/10] Benchmark: 1, Algo: bai_perturb, C: 2.5, Seed: 22
# =========== Search iteration : 11 ===========
# [Action] Rearr A_box to tray_red
# Good Action
# [Reward] S(0) -> A(2) -> S'(109) Reward : 20.0
# [Action] Rearr D_box to table
# [Reward] S(109) -> A(112) -> S'(115) Reward : -1
# [Action] Rearr C_box to A_box
# [Reward] S(115) -> A(119) -> S'(121) Reward : -1
# [Action] Rearr D_box to table
# [Reward] S(121) -> A(123) -> S'(714) Reward : -1
# [Action] Rearr B_box to table
# [Reward] S(714) -> A(715) -> S'(718) Reward : -1
# [Action] Rearr C_box to table
# [Reward] S(718) -> A(719) -> S'(724) Reward : -1
# [Action] Rearr D_box to B_box
# [Reward] S(724) -> A(729) -> S'(1386) Reward : -1
# [Action] Rearr C_box to table
# [Reward] S(1386) -> A(1388) -> S'(1390) Reward : -1
# [Action] Rearr D_box to A_box
# [Reward] S(1390) -> A(1392) -> S'(1394) Reward : -1
# [Action] Rearr C_box to table
# [Reward] S(1394) -> A(1396) -> S'(1398) Reward : -1
# [Action] Rearr B_box to table
# [Reward] S(1398) -> A(1399) -> S'(1403) Reward : -1
# [Action] Rearr D_box to B_box
# [Reward] S(1403) -> A(1405) -> S'(1407) Reward : -1
# Exceeded the maximum depth!!
# ########### Running time :  2.7211010456085205 ##############
#
# [1/10] Benchmark: 1, Algo: bai_perturb, C: 2.5, Seed: 22
# =========== Search iteration : 12 ===========
# [Action] Rearr A_box to tray_red
# Good Action
# [Reward] S(0) -> A(2) -> S'(109) Reward : 20.0
# [Action] Rearr D_box to table
# [Reward] S(109) -> A(112) -> S'(115) Reward : -1
# [Action] Rearr C_box to A_box
# [Reward] S(115) -> A(119) -> S'(121) Reward : -1
# [Action] Rearr B_box to table
# [Reward] S(121) -> A(122) -> S'(126) Reward : -1
# [Action] Rearr C_box to table
# [Reward] S(126) -> A(127) -> S'(131) Reward : -1
# [Action] Rearr B_box to A_box
# Good Action
# [Reward] S(131) -> A(134) -> S'(139) Reward : 3.333
# [Action] Rearr D_box to table
# [Reward] S(139) -> A(142) -> S'(1408) Reward : -1
# [Action] Rearr C_box to B_box
# Good Action
# [Reward] S(1408) -> A(1410) -> S'(1411) Reward : 2.5
# [Action] Rearr D_box to C_box
# Good Action
# [Reward] S(1411) -> A(1413) -> S'(1414) Reward : 2.222
# Success!!!!!
# Terminal State! Reward is 5
# already has grasp_poses
# already has grasp_poses
# already has grasp_poses
# already has grasp_poses
# already has grasp_poses
# already has grasp_poses
# D_box
# Extracted Region Cube Size:  0.4
# Generated 7 grasps for object D_box
# solve with LM1
# Iterators : 8
# WorkingTime[inverse_kinematics]: 0.0080 sec
#
# solve with LM1
# Iterators : 5
# WorkingTime[inverse_kinematics]: 0.0025 sec
#
# solve with LM1
# Iterators : 5
# WorkingTime[inverse_kinematics]: 0.0024 sec
#
# C_box
# Extracted Region Cube Size:  0.4
# Generated 54 grasps for object C_box
# solve with LM1
# Iterators : 8
# WorkingTime[inverse_kinematics]: 0.0056 sec
#
# solve with LM1
# Iterators : 4
# WorkingTime[inverse_kinematics]: 0.0021 sec
#
# solve with LM1
# Iterators : 3
# WorkingTime[inverse_kinematics]: 0.0016 sec
#
# D_box
# Extracted Region Cube Size:  0.4
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# [INFO] [RRT Star Planner]: The joint limit has been successfully checked. Pose error is 0.000002
# Generated 30 grasps for object D_box
# solve with LM1
# Iterators : 8
# WorkingTime[inverse_kinematics]: 0.0051 sec
#
# solve with LM1
# Iterators : 4
# WorkingTime[inverse_kinematics]: 0.0022 sec
#
# solve with LM1
# Iterators : 4
# WorkingTime[inverse_kinematics]: 0.0021 sec
#
# Already know path
# Already know path
# Already know path
# Already know path
# Already know path
# Already know path
# pick D_box
# Grasp_Pose : {'table': array([[ 0.87805008,  0.47856876,  0.        ,  0.55432981],
#        [-0.47856876,  0.87805008,  0.        ,  0.3803486 ],
#        [ 0.        ,  0.        ,  1.        ,  0.83379998],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 'grasp': array([[-0.68163477,  0.71769919,  0.14241392,  0.40665155],
#        [ 0.67762351,  0.6926223 , -0.24718525, -0.07573675],
#        [-0.27604373, -0.07198703, -0.95844538,  0.94408582],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 'pre_grasp': array([[-0.6816348 ,  0.71769917,  0.14241393,  0.39953086],
#        [ 0.6776235 ,  0.6926223 , -0.24718525, -0.06337749],
#        [-0.27604374, -0.07198703, -0.95844537,  0.9920081 ],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]],
#       dtype=float32), 'post_grasp': array([[-0.6816348 ,  0.71769917,  0.14241393,  0.40665156],
#        [ 0.6776235 ,  0.6926223 , -0.24718525, -0.07573675],
#        [-0.27604374, -0.07198703, -0.95844537,  0.99408585],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]],
#       dtype=float32), 'release': array([[ 0.81667703, -0.5433659 , -0.19440155,  0.56727123],
#        [-0.5067921 , -0.8364038 ,  0.20878293,  0.36793095],
#        [-0.27604374, -0.07198703, -0.95844537,  0.94408584],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]],
#       dtype=float32), 'pre_release': array([[ 0.81667703, -0.5433659 , -0.19440155,  0.56727123],
#        [-0.5067921 , -0.8364038 ,  0.20878293,  0.36793095],
#        [-0.27604374, -0.07198703, -0.95844537,  0.99408585],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]],
#       dtype=float32), 'post_release': array([[ 0.81667703, -0.5433659 , -0.19440155,  0.5769913 ],
#        [-0.5067921 , -0.8364038 ,  0.20878293,  0.3574918 ],
#        [-0.27604374, -0.07198703, -0.95844537,  0.9920081 ],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]],
#       dtype=float32)}
# solve with LM1
# Iterators : 8
# WorkingTime[inverse_kinematics]: 0.0042 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 2 --> 10
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000001
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000002
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# Cost is 1.131
# WorkingTime[run]: 3.3741 sec
#
# WorkingTime[run]: 0.0507 sec
#
# WorkingTime[run]: 0.0508 sec
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 2 --> 10
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# [INFO] [RRT Star Planner]: The joint limit has been successfully checked. Pose error is 0.000001
# Cost is 1.113
# WorkingTime[run]: 4.5254 sec
#
# solve with LM1
# Iterators : 12
# WorkingTime[inverse_kinematics]: 0.0062 sec
#
# rewire
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 4 --> 30
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000001
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000000
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# Cost is 3.043
# WorkingTime[run]: 4.4029 sec
#
# WorkingTime[run]: 0.0519 sec
#
# WorkingTime[run]: 0.0517 sec
#
# rewire
# rewire
# rewire
# rewire
# rewire
# rewire
# rewire
# rewire
# rewire
# rewire
# rewire
# rewire
# rewire
# rewire
# rewire
# rewire
# rewire
# rewire
# rewire
# rewire
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 4 --> 30
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# [INFO] [RRT Star Planner]: The joint limit has been successfully checked. Pose error is 0.000001
# Cost is 2.956
# WorkingTime[run]: 3.3979 sec
#
# Success pnp
# pick C_box
# Grasp_Pose : {'B_box': array([[-0.85731345,  0.51479476,  0.        ,  0.50296182],
#        [-0.51479476, -0.85731345,  0.        , -0.41603374],
#        [ 0.        ,  0.        ,  1.        ,  0.93725   ],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 'grasp': array([[-0.93745117,  0.20700679, -0.27988124,  0.52135608],
#        [ 0.21436726,  0.97674322,  0.00440771,  0.28287002],
#        [ 0.27428456, -0.05586535, -0.96002447,  0.93809977],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 'pre_grasp': array([[-0.9374512 ,  0.2070068 , -0.27988124,  0.53535014],
#        [ 0.21436726,  0.9767432 ,  0.00440771,  0.28264964],
#        [ 0.27428454, -0.05586535, -0.9600245 ,  0.986101  ],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]],
#       dtype=float32), 'post_grasp': array([[-0.9374512 ,  0.2070068 , -0.27988124,  0.5213561 ],
#        [ 0.21436726,  0.9767432 ,  0.00440771,  0.28287002],
#        [ 0.27428454, -0.05586535, -0.9600245 ,  0.98809975],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]],
#       dtype=float32), 'release': array([[-0.7626261 , -0.6207767 , -0.18176268,  0.5260197 ],
#        [-0.5858066 ,  0.78199446, -0.21287383, -0.39670318],
#        [ 0.27428454, -0.05586535, -0.9600245 ,  1.0415498 ],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]],
#       dtype=float32), 'pre_release': array([[-0.7626261 , -0.6207767 , -0.18176268,  0.5260197 ],
#        [-0.5858066 ,  0.78199446, -0.21287383, -0.39670318],
#        [ 0.27428454, -0.05586535, -0.9600245 ,  1.0915498 ],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]],
#       dtype=float32), 'post_release': array([[-0.7626261 , -0.6207767 , -0.18176268,  0.53510785],
#        [-0.5858066 ,  0.78199446, -0.21287383, -0.3860595 ],
#        [ 0.27428454, -0.05586535, -0.9600245 ,  1.089551  ],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]],
#       dtype=float32)}
# solve with LM1
# Iterators : 8
# WorkingTime[inverse_kinematics]: 0.0044 sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File src/fcl/fcl.pyx:708, in fcl.fcl.defaultCollisionCallback()
#
# File src/fcl/fcl.pyx:633, in fcl.fcl.collide()
#
# File src/fcl/fcl.pyx:808, in fcl.fcl.c_to_python_contact()
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/fcl/collision_data.py:54, in Contact.__init__(self)
#      53 class Contact:
# ---> 54     def __init__(self):
#      55         self.o1 = None
#      56         self.o2 = None
#
# KeyboardInterrupt:
# Exception ignored in: 'fcl.fcl.CollisionFunction.eval_func'
# Traceback (most recent call last):
#   File "src/fcl/fcl.pyx", line 708, in fcl.fcl.defaultCollisionCallback
#   File "src/fcl/fcl.pyx", line 633, in fcl.fcl.collide
#   File "src/fcl/fcl.pyx", line 808, in fcl.fcl.c_to_python_contact
#   File "/home/juju/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/fcl/collision_data.py", line 54, in __init__
#     def __init__(self):
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File src/fcl/fcl.pyx:708, in fcl.fcl.defaultCollisionCallback()
#
# File src/fcl/fcl.pyx:633, in fcl.fcl.collide()
#
# File src/fcl/fcl.pyx:808, in fcl.fcl.c_to_python_contact()
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/fcl/collision_data.py:54, in Contact.__init__(self)
#      53 class Contact:
# ---> 54     def __init__(self):
#      55         self.o1 = None
#      56         self.o2 = None
#
# KeyboardInterrupt:
# Exception ignored in: 'fcl.fcl.CollisionFunction.eval_func'
# Traceback (most recent call last):
#   File "src/fcl/fcl.pyx", line 708, in fcl.fcl.defaultCollisionCallback
#   File "src/fcl/fcl.pyx", line 633, in fcl.fcl.collide
#   File "src/fcl/fcl.pyx", line 808, in fcl.fcl.c_to_python_contact
#   File "/home/juju/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/fcl/collision_data.py", line 54, in __init__
#     def __init__(self):
# KeyboardInterrupt:
# [INFO] [RRT Star Planner]: Generate Path Successfully!!
# [INFO] [RRT Star Planner]: Path length 5 --> 40
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000001
# [INFO] [Cartesian Planner]: Start to compute Cartesian Planning
# [INFO] [Cartesian Planner]: Generate Path Successfully!! Error is 0.000001
# [INFO] [RRT Star Planner]: Start to compute RRT-star Planning
# Cost is 1.506
# WorkingTime[run]: 3.4140 sec
#
# WorkingTime[run]: 0.0467 sec
#
# WorkingTime[run]: 0.0502 sec

# %%
max_level_1_value = mcts.get_max_value_level_1()
print(max_level_1_value, mcts.history_level_1_dict)

########## level 1 ##########
if mcts.history_level_1_dict:
    j, max_value_nodes = mcts.get_max_value_nodes_level_1()
    
    print()
    print(f"Result {j} : ", max_value_nodes)
    print("state num :", len(max_value_nodes))
    mcts.render_rearr("_", max_value_nodes)
# Out:
# 24.051515151515154 {0: {'nodes': [0, 2, 109, 112, 115, 119, 121, 122, 126, 127, 131, 134, 139, 143, 145, 146, 147, 148, 150, 151, 152, 154, 155], 'value': 24.051515151515154}, 1: {'nodes': [0, 2, 109, 112, 115, 119, 121, 123, 714, 715, 718, 719, 724, 730, 731, 732, 733, 734, 736, 738, 739, 740, 741], 'value': 23.21818181818182}}
#
# Result 0 :  [0, 2, 109, 112, 115, 119, 121, 122, 126, 127, 131, 134, 139, 143, 145, 146, 147, 148, 150, 151, 152, 154, 155]
# state num : 23

# %%
mcts.history_level_2_dict
# Out:
# {}

# %%
mcts.tree.nodes[3]
# Out:
# {'depth': 1,
#  'state': <pytamp.scene.scene.Scene at 0x7f4aaa86b0a0>,
#  'action': {'type': 'rearr',
#   'rearr_obj_name': 'B_box',
#   'place_obj_name': 'table',
#   'rearr_poses': [{'table': array([[-0.86851513, -0.49566266,  0.        ,  0.40902885],
#            [ 0.49566266, -0.86851513,  0.        , -0.20685354],
#            [ 0.        ,  0.        ,  1.        ,  0.83379998],
#            [ 0.        ,  0.        ,  0.        ,  1.        ]])}]},
#  'value': -8.322222222222221,
#  'value_history': [-8.322222222222221],
#  'visit': 1,
#  'number': 3,
#  'type': 'action',
#  'joints': [],
#  'level1': False,
#  'level2': False,
#  'level1_5': False,
#  'success': False,
#  'cost': 0,
#  'test': ()}

# %%
mcts.tree.nodes[9]['state'].rearr_obj_name
# Out:
# 'B_box'

# %%
mcts.tree.nodes[9]['state'].rearr_obj_default_pose
# Out:
# array([[ 1.        ,  0.        ,  0.        ,  0.6       ],
#        [ 0.        ,  1.        ,  0.        , -0.2       ],
#        [ 0.        ,  0.        ,  1.        ,  0.83329998],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])

# %%
mcts.tree.nodes[9]
# Out:
# {'number': 9,
#  'visit': 1,
#  'depth': 1,
#  'state': <pytamp.scene.scene.Scene at 0x7f4a1a78ee50>,
#  'action': {'table': array([[-0.86851513, -0.49566266,  0.        ,  0.40902885],
#          [ 0.49566266, -0.86851513,  0.        , -0.20685354],
#          [ 0.        ,  0.        ,  1.        ,  0.83379998],
#          [ 0.        ,  0.        ,  0.        ,  1.        ]])},
#  'value': -8.322222222222221,
#  'value_history': [-8.322222222222221],
#  'type': 'state',
#  'joints': [],
#  'level1': False,
#  'level2': False,
#  'level1_5': False,
#  'success': False,
#  'cost': 0,
#  'test': ()}

# %%
mcts.rearr_action.scene_mngr.scene.

# %%
mcts.rearr_action.scene_mngr.scene.pick_obj_default_pose

# %%
mcts.infeasible_sub_nodes
# Out:
# [[0,
#   3,
#   110,
#   114,
#   116,
#   119,
#   709,
#   713,
#   1209,
#   1210,
#   1325,
#   1328,
#   1331,
#   1333,
#   1337,
#   1339,
#   1343,
#   1345,
#   1346]]

# %%
 mcts.tree.nodes[1331]['test']= \
    mcts.tree.nodes[1331]['state'].rearr_obj_name, mcts.tree.nodes[1331]['state'].objs[mcts.tree.nodes[1331]['state'].rearr_obj_name].h_mat

# %%
mcts.tree.nodes[1328]
# Out:
# {'depth': 6,
#  'state': <pytamp.scene.scene.Scene at 0x7f5589bd9250>,
#  'action': {'type': 'rearr',
#   'rearr_obj_name': 'D_box',
#   'place_obj_name': 'table',
#   'rearr_poses': [{'table': array([[ 0.68078175,  0.73248632,  0.        ,  0.58170964],
#            [-0.73248632,  0.68078175,  0.        ,  0.26853609],
#            [ 0.        ,  0.        ,  1.        ,  0.83379998],
#            [ 0.        ,  0.        ,  0.        ,  1.        ]])}]},
#  'value': 12.279365079365078,
#  'value_history': [12.279365079365078,
#   -8.1,
#   -6.6,
#   -7.418181818181818,
#   -8.45,
#   -4.998412698412698,
#   -0.33881673881674024,
#   -3.5610389610389617,
#   -3.9650793650793665,
#   -1.498412698412698,
#   12.279365079365078,
#   12.279365079365078,
#   -3.9650793650793665,
#   -2.7428571428571433,
#   12.279365079365078,
#   12.279365079365078,
#   12.279365079365078,
#   12.279365079365078,
#   12.279365079365078,
#   -4.965079365079367,
#   -1.1468975468975477,
#   12.279365079365078,
#   12.279365079365078,
#   -7.4105339105339105,
#   -4.631746031746033,
#   -3.9650793650793665,
#   12.279365079365078,
#   12.279365079365078,
#   12.279365079365078,
#   12.279365079365078,
#   12.279365079365078,
#   -1.498412698412698,
#   12.279365079365078,
#   -1.498412698412698,
#   12.279365079365078,
#   -3.9650793650793665,
#   -4.40952380952381,
#   -4.631746031746033,
#   10.679365079365079,
#   10.679365079365079,
#   10.679365079365079,
#   10.679365079365079,
#   10.679365079365079,
#   10.679365079365079],
#  'visit': 44,
#  'number': 1328,
#  'type': 'action',
#  'joints': [],
#  'level1': True,
#  'level2': False,
#  'level1_5': True,
#  'success': True,
#  'cost': 0,
#  'test': (),
#  'grasp_set': array([[[-0.36815826,  0.40344385,  0.83767087,  0.5304205 ],
#          [ 0.40369913,  0.88095671, -0.24686477, -0.08287205],
#          [-0.83754786,  0.24728173, -0.48720146,  0.93682238],
#          [ 0.        ,  0.        ,  0.        ,  1.        ]],
#
#         [[-0.53006397,  0.23704182,  0.81415192,  0.52708828],
#          [ 0.21466303,  0.96636891, -0.14160107, -0.08548618],
#          [-0.82033649,  0.09971073, -0.5631215 ,  0.94794085],
#          [ 0.        ,  0.        ,  0.        ,  1.        ]],
#
#         [[-0.81318097,  0.1548324 ,  0.56103806,  0.55242414],
#          [ 0.15277104,  0.98694772, -0.05094306, -0.09214169],
#          [-0.5616029 ,  0.04428445, -0.82622102,  0.96187418],
#          [ 0.        ,  0.        ,  0.        ,  1.        ]],
#
#         [[ 0.76631611,  0.63695958,  0.08391637,  0.62439143],
#          [ 0.59613001, -0.65625519, -0.462556  , -0.02928217],
#          [-0.2395589 ,  0.40448912, -0.88260978,  0.98992365],
#          [ 0.        ,  0.        ,  0.        ,  1.        ]],
#
#         [[ 0.86227862,  0.49800511, -0.09201436,  0.63059009],
#          [ 0.37276426, -0.7471118 , -0.55033696, -0.02888454],
#          [-0.34281563,  0.44024415, -0.82985702,  0.98908845],
#          [ 0.        ,  0.        ,  0.        ,  1.        ]],
#
#         [[-0.0787573 ,  0.39284577,  0.91622544,  0.5184348 ],
#          [ 0.22500604,  0.90236878, -0.36756369, -0.06503288],
#          [-0.9711691 ,  0.17720804, -0.15946088,  0.92543626],
#          [ 0.        ,  0.        ,  0.        ,  1.        ]],
#
#         [[ 0.82417277,  0.0949099 ,  0.55832903,  0.56041584],
#          [ 0.13118786, -0.99103749, -0.02518628, -0.08539374],
#          [ 0.55093454,  0.09400377, -0.82923723,  0.97356026],
#          [ 0.        ,  0.        ,  0.        ,  1.        ]],
#
#         [[ 0.70949131,  0.00815336,  0.70466705,  0.54952983],
#          [ 0.02540944, -0.99957889, -0.01401768, -0.08359038],
#          [ 0.70425602,  0.02785067, -0.70939964,  0.96500046],
#          [ 0.        ,  0.        ,  0.        ,  1.        ]]]),
#  'grasp_poses': [{'grasp': array([[-0.36815826,  0.40344385,  0.83767087,  0.5304205 ],
#           [ 0.40369913,  0.88095671, -0.24686477, -0.08287205],
#           [-0.83754786,  0.24728173, -0.48720146,  0.93682238],
#           [ 0.        ,  0.        ,  0.        ,  1.        ]]),
#    'pre_grasp': array([[-0.36815825,  0.40344384,  0.83767086,  0.48853695],
#           [ 0.40369913,  0.8809567 , -0.24686477, -0.07052881],
#           [-0.83754784,  0.24728173, -0.48720145,  0.9611825 ],
#           [ 0.        ,  0.        ,  0.        ,  1.        ]],
#          dtype=float32),
#    'post_grasp': array([[-0.36815825,  0.40344384,  0.83767086,  0.5304205 ],
#           [ 0.40369913,  0.8809567 , -0.24686477, -0.08287205],
#           [-0.83754784,  0.24728173, -0.48720145,  0.98682237],
#           [ 0.        ,  0.        ,  0.        ,  1.        ]],
#          dtype=float32)}]}

# %%
max_value_nodes = mcts.history_level_1_dict[1]['nodes']

# %%
for i,n in enumerate(max_value_nodes):
    print(n)
    if i%2==0:
        print(mcts.tree.nodes[n].get("test"))
# Out:
# 0
# ()
# 3
# 110
# ('B_box', array([[ 0.88352883, -0.46837678,  0.        ,  0.42680358],
#        [ 0.46837678,  0.88352883,  0.        , -0.08573273],
#        [ 0.        ,  0.        ,  1.        ,  0.83379998],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]))
# 114
# 116
# ('D_box', array([[-0.04774756,  0.99885943,  0.        ,  0.41575984],
#        [-0.99885943, -0.04774756,  0.        , -0.08075851],
#        [ 0.        ,  0.        ,  1.        ,  0.88429998],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]))
# 119
# 709
# ('C_box', array([[ 0.49807009, -0.86713677,  0.        ,  0.6555496 ],
#        [ 0.86713677,  0.49807009,  0.        , -0.09832989],
#        [ 0.        ,  0.        ,  1.        ,  0.83379998],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]))
# 713
# 1209
# ('D_box', array([[ 0.81071744, -0.58543764,  0.        ,  0.64499405],
#        [ 0.58543764,  0.81071744,  0.        , -0.10155243],
#        [ 0.        ,  0.        ,  1.        ,  0.88429998],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]))
# 1210
# 1325
# ('A_box', array([[ 0.09882089, -0.99510524,  0.        ,  0.56571056],
#        [ 0.99510524,  0.09882089,  0.        , -0.31633223],
#        [ 0.        ,  0.        ,  1.        ,  0.83625   ],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]))
# 1328
# 1331
# ()
# 1333
# 1337
# ('B_box', array([[ 0.80472055, -0.5936538 ,  0.        ,  0.57061566],
#        [ 0.5936538 ,  0.80472055,  0.        , -0.31947263],
#        [ 0.        ,  0.        ,  1.        ,  0.88675   ],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]))
# 1340
# 1581
# ('D_box', array([[-0.04375392,  0.99904234,  0.        ,  0.41257643],
#        [-0.99904234, -0.04375392,  0.        , -0.21907044],
#        [ 0.        ,  0.        ,  1.        ,  0.83379998],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]))
# 1584
# 1585
# ('C_box', array([[ 0.77201814, -0.6356005 ,  0.        ,  0.56087687],
#        [ 0.6356005 ,  0.77201814,  0.        , -0.32219377],
#        [ 0.        ,  0.        ,  1.        ,  0.93725   ],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]))
# 1587
# 1863
# ('D_box', array([[-0.84077055,  0.54139161,  0.        ,  0.56024383],
#        [-0.54139161, -0.84077055,  0.        , -0.31078613],
#        [ 0.        ,  0.        ,  1.        ,  0.98775   ],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]))

# %%
mcts.tree.nodes[1331].get("test")
# Out:
# ('D_box',
#  array([[ 0.68078175,  0.73248632,  0.        ,  0.58170964],
#         [-0.73248632,  0.68078175,  0.        ,  0.26853609],
#         [ 0.        ,  0.        ,  1.        ,  0.83379998],
#         [ 0.        ,  0.        ,  0.        ,  1.        ]]))

# %%
final_level_1_values = []
final_level_2_values = []
final_optimal_nodes = []
final_pnp_all_joint_paths = []
final_pick_all_objects = []
final_place_all_object_poses = []
if mcts.level_wise_2_success:
    (
        pnp_all_joint_paths,
        pick_all_objects,
        place_all_object_poses,
    ) = mcts.get_all_joint_path(max_value_nodes)
    final_pnp_all_joint_paths.append(pnp_all_joint_paths)
    final_pick_all_objects.append(pick_all_objects)
    final_place_all_object_poses.append(place_all_object_poses)
    final_optimal_nodes.append(mcts.optimal_nodes)
else:
    final_pnp_all_joint_paths.append([])
    final_pick_all_objects.append([])
    final_place_all_object_poses.append([])
    final_optimal_nodes.append([])

# %%
final_pnp_all_joint_paths
# Out:
# [[[OrderedDict([('pre_grasp',
#                  [array([-1.00379255e-03,  1.98070483e-01,  4.07715568e-04, -2.61554611e+00,
#                          -7.82984782e-04,  2.93994722e+00, -7.88797054e-01]),
#                   array([-2.00758510e-03,  1.99791425e-01,  8.15431136e-04, -2.61309835e+00,
#                          -1.56596956e-03,  2.93830179e+00, -7.92195945e-01]),
#                   array([-3.01137765e-03,  2.01512367e-01,  1.22314670e-03, -2.61065058e+00,
#                          -2.34895435e-03,  2.93665635e+00, -7.95594835e-01]),
#                   array([-4.01517020e-03,  2.03233309e-01,  1.63086227e-03, -2.60820282e+00,
#                          -3.13193913e-03,  2.93501092e+00, -7.98993726e-01]),
#                   array([-5.01896275e-03,  2.04954251e-01,  2.03857784e-03, -2.60575505e+00,
#                          -3.91492391e-03,  2.93336549e+00, -8.02392617e-01]),
#                   array([-6.02275530e-03,  2.06675194e-01,  2.44629341e-03, -2.60330729e+00,
#                          -4.69790869e-03,  2.93172005e+00, -8.05791507e-01]),
#                   array([-7.02654786e-03,  2.08396136e-01,  2.85400898e-03, -2.60085952e+00,
#                          -5.48089348e-03,  2.93007462e+00, -8.09190398e-01]),
#                   array([-0.00803034,  0.21011708,  0.00326172, -2.59841176, -0.00626388,
#                           2.92842919, -0.81258929]),
#                   array([-0.00903413,  0.21183802,  0.00366944, -2.59596399, -0.00704686,
#                           2.92678375, -0.81598818]),
#                   array([-0.01003793,  0.21355896,  0.00407716, -2.59351623, -0.00782985,
#                           2.92513832, -0.81938707]),
#                   array([-0.03949251,  0.25040726,  0.01378995, -2.5273063 , -0.02707067,
#                           2.87418512, -0.90310138]),
#                   array([-0.0689471 ,  0.28725557,  0.02350274, -2.46109638, -0.0463115 ,
#                           2.82323192, -0.98681569]),
#                   array([-0.09840168,  0.32410387,  0.03321553, -2.39488646, -0.06555232,
#                           2.77227872, -1.07053   ]),
#                   array([-0.12785627,  0.36095217,  0.04292832, -2.32867653, -0.08479315,
#                           2.72132552, -1.15424431]),
#                   array([-0.15731085,  0.39780048,  0.05264111, -2.26246661, -0.10403397,
#                           2.67037232, -1.23795862]),
#                   array([-0.18676544,  0.43464878,  0.06235391, -2.19625668, -0.1232748 ,
#                           2.61941912, -1.32167293]),
#                   array([-0.21622002,  0.47149708,  0.0720667 , -2.13004676, -0.14251562,
#                           2.56846592, -1.40538724]),
#                   array([-0.24567461,  0.50834538,  0.08177949, -2.06383683, -0.16175645,
#                           2.51751272, -1.48910155]),
#                   array([-0.27512919,  0.54519369,  0.09149228, -1.99762691, -0.18099728,
#                           2.46655952, -1.57281586]),
#                   array([-0.30458378,  0.58204199,  0.10120507, -1.93141698, -0.2002381 ,
#                           2.41560632, -1.65653018]),
#                   array([-0.31891794,  0.62026686,  0.10927818, -1.89084732, -0.21515366,
#                           2.39478029, -1.72108669]),
#                   array([-0.3332521 ,  0.65849173,  0.11735129, -1.85027767, -0.23006921,
#                           2.37395426, -1.78564321]),
#                   array([-0.34758625,  0.69671661,  0.12542439, -1.80970801, -0.24498477,
#                           2.35312823, -1.85019973]),
#                   array([-0.36192041,  0.73494148,  0.1334975 , -1.76913835, -0.25990032,
#                           2.33230219, -1.91475625]),
#                   array([-0.37625457,  0.77316635,  0.14157061, -1.72856869, -0.27481588,
#                           2.31147616, -1.97931277]),
#                   array([-0.39058873,  0.81139123,  0.14964372, -1.68799903, -0.28973143,
#                           2.29065013, -2.04386929]),
#                   array([-0.40492289,  0.8496161 ,  0.15771682, -1.64742937, -0.30464699,
#                           2.2698241 , -2.1084258 ]),
#                   array([-0.41925705,  0.88784097,  0.16578993, -1.60685971, -0.31956254,
#                           2.24899807, -2.17298232]),
#                   array([-0.43359121,  0.92606584,  0.17386304, -1.56629006, -0.3344781 ,
#                           2.22817203, -2.23753884]),
#                   array([-0.44792537,  0.96429072,  0.18193614, -1.5257204 , -0.34939365,
#                           2.207346  , -2.30209536])]),
#                 ('grasp',
#                  [array([-0.44792537,  0.96429072,  0.18193614, -1.5257204 , -0.34939365,
#                           2.207346  , -2.30209536]),
#                   array([-0.44792725,  0.96504731,  0.18174546, -1.52576443, -0.34958523,
#                           2.20815387, -2.30199112]),
#                   array([-0.44793271,  0.97269182,  0.17982813, -1.52607149, -0.35149462,
#                           2.21618418, -2.30095822]),
#                   array([-0.44791695,  0.98045948,  0.17789581, -1.52615641, -0.35338974,
#                           2.22412438, -2.29994397]),
#                   array([-0.44788086,  0.98834934,  0.1759497 , -1.52601936, -0.35526898,
#                           2.23197373, -2.29894937]),
#                   array([-0.44782533,  0.9963605 ,  0.17399103, -1.52566043, -0.35713079,
#                           2.23973145, -2.29797543]),
#                   array([-0.44775127,  1.0044921 ,  0.17202106, -1.52507963, -0.3589736 ,
#                           2.24739671, -2.29702316]),
#                   array([-0.44765961,  1.01274333,  0.17004107, -1.5242769 , -0.36079588,
#                           2.25496864, -2.29609359]),
#                   array([-0.44755126,  1.02111344,  0.16805236, -1.52325207, -0.36259613,
#                           2.2624463 , -2.29518776]),
#                   array([-0.44742718,  1.02960172,  0.16605625, -1.52200491, -0.36437287,
#                           2.26982872, -2.29430671]),
#                   array([-0.44728829,  1.03820752,  0.16405409, -1.5205351 , -0.36612464,
#                           2.27711489, -2.29345151]),
#                   array([-0.44715143,  1.0460527 ,  0.16224808, -1.51902158, -0.36767872,
#                           2.28358927, -2.29270481])]),
#                 ('post_grasp',
#                  [array([-0.44715143,  1.0460527 ,  0.16224808, -1.51902158, -0.36767872,
#                           2.28358927, -2.29270481]),
#                   array([-0.44729704,  1.0448346 ,  0.16241778, -1.51985379, -0.36757114,
#                           2.28318901, -2.29276641]),
#                   array([-0.44875774,  1.03269017,  0.16412958, -1.52806317, -0.3664636 ,
#                           2.27911554, -2.29341322]),
#                   array([-0.45021826,  1.02065108,  0.16586345, -1.53601931, -0.36529974,
#                           2.274904  , -2.29411823]),
#                   array([-0.45167807,  1.00871589,  0.16761801, -1.54372584, -0.36408026,
#                           2.27055672, -2.29488027]),
#                   array([-0.45313658,  0.99688336,  0.16939184, -1.55118619, -0.36280591,
#                           2.26607609, -2.29569812]),
#                   array([-0.45459321,  0.98515228,  0.17118351, -1.55840364, -0.36147747,
#                           2.26146433, -2.29657063]),
#                   array([-0.45604729,  0.9735217 ,  0.17299159, -1.56538107, -0.36009578,
#                           2.25672353, -2.29749668]),
#                   array([-0.45749812,  0.96199073,  0.1748146 , -1.57212126, -0.3586617 ,
#                           2.25185574, -2.29847506]),
#                   array([-0.458945  ,  0.9505587 ,  0.17665107, -1.57862658, -0.35717614,
#                           2.24686283, -2.29950472]),
#                   array([-0.46038716,  0.9392249 ,  0.1784995 , -1.58489963, -0.35564009,
#                           2.24174679, -2.30058443]),
#                   array([-0.4616805 ,  0.9291079 ,  0.18017204, -1.59034887, -0.35421536,
#                           2.23703873, -2.30159802])]),
#                 ('default_grasp',
#                  [array([-0.45345426,  0.89378967,  0.15412836, -1.61586814, -0.3463212 ,
#                           2.24194762, -2.22829187]),
#                   array([-0.44522801,  0.85847145,  0.12808468, -1.64138742, -0.33842705,
#                           2.24685651, -2.15498571]),
#                   array([-0.43700177,  0.82315323,  0.102041  , -1.66690669, -0.33053289,
#                           2.25176541, -2.08167956]),
#                   array([-0.42877552,  0.78783501,  0.07599732, -1.69242597, -0.32263874,
#                           2.2566743 , -2.0083734 ]),
#                   array([-0.42054927,  0.75251679,  0.04995363, -1.71794525, -0.31474458,
#                           2.26158319, -1.93506725]),
#                   array([-0.41232303,  0.71719857,  0.02390995, -1.74346452, -0.30685043,
#                           2.26649208, -1.86176109]),
#                   array([-4.04096779e-01,  6.81880348e-01, -2.13372899e-03, -1.76898380e+00,
#                          -2.98956276e-01,  2.27140098e+00, -1.78845494e+00]),
#                   array([-0.39587053,  0.64656213, -0.02817741, -1.79450307, -0.29106212,
#                           2.27630987, -1.71514878]),
#                   array([-0.38764429,  0.61124391, -0.05422109, -1.82002235, -0.28316797,
#                           2.28121876, -1.64184263]),
#                   array([-0.37941804,  0.57592568, -0.08026477, -1.84554162, -0.27527381,
#                           2.28612765, -1.56853647]),
#                   array([-0.34276732,  0.54193255, -0.07055008, -1.90219014, -0.2522277 ,
#                           2.33744528, -1.49742385]),
#                   array([-0.3061166 ,  0.50793942, -0.06083539, -1.95883866, -0.22918159,
#                           2.38876291, -1.42631123]),
#                   array([-0.26946587,  0.47394628, -0.0511207 , -2.01548718, -0.20613548,
#                           2.44008055, -1.35519861]),
#                   array([-0.23281515,  0.43995315, -0.041406  , -2.0721357 , -0.18308937,
#                           2.49139818, -1.28408599]),
#                   array([-0.19616443,  0.40596002, -0.03169131, -2.12878422, -0.16004326,
#                           2.54271581, -1.21297337]),
#                   array([-0.15951371,  0.37196688, -0.02197662, -2.18543274, -0.13699715,
#                           2.59403344, -1.14186075]),
#                   array([-0.12286299,  0.33797375, -0.01226193, -2.24208126, -0.11395104,
#                           2.64535107, -1.07074813]),
#                   array([-8.62122681e-02,  3.03980618e-01, -2.54723607e-03, -2.29872978e+00,
#                          -9.09049306e-02,  2.69666870e+00, -9.99635513e-01]),
#                   array([-0.04956155,  0.26998748,  0.00716746, -2.3553783 , -0.06785882,
#                           2.74798633, -0.92852289]),
#                   array([-0.01291083,  0.23599435,  0.01688215, -2.41202682, -0.04481271,
#                           2.79930396, -0.85741027]),
#                   array([-0.01161974,  0.23202987,  0.01519393, -2.43262353, -0.04033144,
#                           2.81353283, -0.85020906]),
#                   array([-0.01032866,  0.22806539,  0.01350572, -2.45322023, -0.03585017,
#                           2.8277617 , -0.84300785]),
#                   array([-0.00903758,  0.22410091,  0.0118175 , -2.47381694, -0.0313689 ,
#                           2.84199057, -0.83580664]),
#                   array([-0.0077465 ,  0.22013643,  0.01012929, -2.49441364, -0.02688763,
#                           2.85621944, -0.82860543]),
#                   array([-0.00645541,  0.21617195,  0.00844107, -2.51501035, -0.02240635,
#                           2.87044831, -0.82140422]),
#                   array([-0.00516433,  0.21220747,  0.00675286, -2.53560706, -0.01792508,
#                           2.88467718, -0.81420301]),
#                   array([-0.00387325,  0.20824298,  0.00506464, -2.55620376, -0.01344381,
#                           2.89890605, -0.8070018 ]),
#                   array([-2.58216507e-03,  2.04278503e-01,  3.37642964e-03, -2.57680047e+00,
#                          -8.96254200e-03,  2.91313492e+00, -7.99800585e-01]),
#                   array([-1.29108254e-03,  2.00314022e-01,  1.68821482e-03, -2.59739717e+00,
#                          -4.48127100e-03,  2.92736378e+00, -7.92599374e-01]),
#                   array([-2.71050543e-20,  1.96349541e-01, -1.08420217e-19, -2.61799388e+00,
#                           0.00000000e+00,  2.94159265e+00, -7.85398163e-01])]),
#                 ('pre_release',
#                  [array([-1.11828902e-02,  2.05665904e-01,  2.23966539e-03, -2.60935758e+00,
#                          -2.31319369e-02,  2.92963980e+00, -8.26412040e-01]),
#                   array([-0.02236578,  0.21498227,  0.00447933, -2.60072128, -0.04626387,
#                           2.91768695, -0.86742592]),
#                   array([-0.03354867,  0.22429863,  0.006719  , -2.59208499, -0.06939581,
#                           2.9057341 , -0.90843979]),
#                   array([-0.04473156,  0.233615  ,  0.00895866, -2.58344869, -0.09252775,
#                           2.89378125, -0.94945367]),
#                   array([-0.05591445,  0.24293136,  0.01119833, -2.57481239, -0.11565968,
#                           2.8818284 , -0.99046755]),
#                   array([-0.06709734,  0.25224772,  0.01343799, -2.5661761 , -0.13879162,
#                           2.86987555, -1.03148142]),
#                   array([-0.07828023,  0.26156409,  0.01567766, -2.5575398 , -0.16192356,
#                           2.8579227 , -1.0724953 ]),
#                   array([-0.08946312,  0.27088045,  0.01791732, -2.5489035 , -0.1850555 ,
#                           2.84596985, -1.11350918]),
#                   array([-0.10064601,  0.28019681,  0.02015699, -2.54026721, -0.20818743,
#                           2.834017  , -1.15452306]),
#                   array([-0.1118289 ,  0.28951318,  0.02239665, -2.53163091, -0.23131937,
#                           2.82206415, -1.19553693]),
#                   array([-0.13149899,  0.31618697,  0.02778748, -2.51474045, -0.2695308 ,
#                           2.80839275, -1.3057596 ]),
#                   array([-0.15116908,  0.34286076,  0.0331783 , -2.49785   , -0.30774223,
#                           2.79472134, -1.41598226]),
#                   array([-0.17083918,  0.36953455,  0.03856912, -2.48095954, -0.34595367,
#                           2.78104994, -1.52620493]),
#                   array([-0.19050927,  0.39620834,  0.04395994, -2.46406908, -0.3841651 ,
#                           2.76737853, -1.63642759]),
#                   array([-0.21017936,  0.42288213,  0.04935076, -2.44717863, -0.42237653,
#                           2.75370713, -1.74665026]),
#                   array([-0.22984945,  0.44955592,  0.05474159, -2.43028817, -0.46058796,
#                           2.74003572, -1.85687292]),
#                   array([-0.24951954,  0.47622971,  0.06013241, -2.41339771, -0.49879939,
#                           2.72636432, -1.96709559]),
#                   array([-0.26918963,  0.5029035 ,  0.06552323, -2.39650725, -0.53701083,
#                           2.71269291, -2.07731825]),
#                   array([-0.28885972,  0.52957729,  0.07091405, -2.3796168 , -0.57522226,
#                           2.69902151, -2.18754092]),
#                   array([-0.30852981,  0.55625108,  0.07630487, -2.36272634, -0.61343369,
#                           2.68535011, -2.29776358]),
#                   array([-0.30886035,  0.55669551,  0.07742921, -2.36378131, -0.61398235,
#                           2.68532163, -2.30245552]),
#                   array([-0.30919089,  0.55713994,  0.07855356, -2.36483628, -0.61453101,
#                           2.68529316, -2.30714746]),
#                   array([-0.30952143,  0.55758437,  0.0796779 , -2.36589124, -0.61507967,
#                           2.68526469, -2.3118394 ]),
#                   array([-0.30985197,  0.5580288 ,  0.08080224, -2.36694621, -0.61562833,
#                           2.68523622, -2.31653134]),
#                   array([-0.3101825 ,  0.55847323,  0.08192658, -2.36800118, -0.61617699,
#                           2.68520775, -2.32122328]),
#                   array([-0.31051304,  0.55891766,  0.08305092, -2.36905615, -0.61672566,
#                           2.68517928, -2.32591521]),
#                   array([-0.31084358,  0.55936209,  0.08417526, -2.37011112, -0.61727432,
#                           2.68515081, -2.33060715]),
#                   array([-0.31117412,  0.55980652,  0.0852996 , -2.37116608, -0.61782298,
#                           2.68512234, -2.33529909]),
#                   array([-0.31150466,  0.56025095,  0.08642394, -2.37222105, -0.61837164,
#                           2.68509386, -2.33999103]),
#                   array([-0.31183519,  0.56069538,  0.08754828, -2.37327602, -0.6189203 ,
#                           2.68506539, -2.34468297]),
#                   array([-0.31188743,  0.56076561,  0.08772596, -2.37344274, -0.619007  ,
#                           2.68506089, -2.34542445]),
#                   array([-0.31193967,  0.56083585,  0.08790365, -2.37360946, -0.61909371,
#                           2.68505639, -2.34616593]),
#                   array([-0.3119919 ,  0.56090608,  0.08808133, -2.37377618, -0.61918042,
#                           2.68505189, -2.34690741]),
#                   array([-0.31204414,  0.56097632,  0.08825901, -2.3739429 , -0.61926712,
#                           2.6850474 , -2.34764889]),
#                   array([-0.31209637,  0.56104655,  0.08843669, -2.37410962, -0.61935383,
#                           2.6850429 , -2.34839037]),
#                   array([-0.31214861,  0.56111679,  0.08861438, -2.37427634, -0.61944054,
#                           2.6850384 , -2.34913185]),
#                   array([-0.31220084,  0.56118702,  0.08879206, -2.37444306, -0.61952724,
#                           2.6850339 , -2.34987333]),
#                   array([-0.31225308,  0.56125725,  0.08896974, -2.37460978, -0.61961395,
#                           2.6850294 , -2.35061481]),
#                   array([-0.31230532,  0.56132749,  0.08914742, -2.37477649, -0.61970066,
#                           2.6850249 , -2.35135629]),
#                   array([-0.31235755,  0.56139772,  0.08932511, -2.37494321, -0.61978736,
#                           2.6850204 , -2.35209777])]),
#                 ('release',
#                  [array([-0.31235755,  0.56139772,  0.08932511, -2.37494321, -0.61978736,
#                           2.6850204 , -2.35209777]),
#                   array([-0.31188328,  0.56288263,  0.08871697, -2.37428338, -0.62046869,
#                           2.68583846, -2.35141245]),
#                   array([-0.30712441,  0.57777293,  0.0826555 , -2.36756542, -0.62714802,
#                           2.69398102, -2.34463251]),
#                   array([-0.30236013,  0.59268278,  0.07665223, -2.36067112, -0.63356813,
#                           2.70203082, -2.33801155]),
#                   array([-0.29759985,  0.60761119,  0.07071693, -2.35360246, -0.63972793,
#                           2.70998589, -2.33155116]),
#                   array([-0.29285266,  0.62255716,  0.06485876, -2.34636131, -0.64562707,
#                           2.71784394, -2.32525255]),
#                   array([-0.28812723,  0.63751987,  0.0590862 , -2.33894934, -0.65126596,
#                           2.72560256, -2.31911652]),
#                   array([-0.28343196,  0.65249822,  0.05340727, -2.33136823, -0.65664555,
#                           2.73325893, -2.31314373]),
#                   array([-0.2787747 ,  0.66749144,  0.04782917, -2.32361952, -0.66176762,
#                           2.74081034, -2.3073343 ]),
#                   array([-0.2741632 ,  0.6824981 ,  0.04235891, -2.31570471, -0.6666341 ,
#                           2.74825333, -2.30168856]),
#                   array([-0.26960444,  0.69751767,  0.03700238, -2.30762502, -0.67124796,
#                           2.75558503, -2.29620603]),
#                   array([-0.26555228,  0.71104553,  0.03228346, -2.30021322, -0.67518698,
#                           2.76208553, -2.29141103])]),
#                 ('post_release',
#                  [array([-0.26555228,  0.71104553,  0.03228346, -2.30021322, -0.67518698,
#                           2.76208553, -2.29141103]),
#                   array([-0.26591276,  0.70969335,  0.03296478, -2.30073965, -0.67459898,
#                           2.76116576, -2.29190496]),
#                   array([-0.26953454,  0.69619094,  0.03983171, -2.30590028, -0.66858558,
#                           2.75190824, -2.29691521]),
#                   array([-0.27315495,  0.68276059,  0.0467557 , -2.31087326, -0.66236737,
#                           2.74258547, -2.30202013]),
#                   array([-0.27676707,  0.6694038 ,  0.05372881, -2.31565698, -0.65594762,
#                           2.73319981, -2.30721709]),
#                   array([-0.28036386,  0.65612201,  0.06074273, -2.32024994, -0.64933023,
#                           2.7237535 , -2.31250314]),
#                   array([-0.2839383 ,  0.64291678,  0.06778898, -2.32465036, -0.64251957,
#                           2.71424845, -2.31787522]),
#                   array([-0.28748345,  0.62978917,  0.0748589 , -2.32885682, -0.63552047,
#                           2.70468619, -2.32333013]),
#                   array([-0.29099211,  0.61674114,  0.08194333, -2.33286733, -0.62833866,
#                           2.6950685 , -2.3288641 ]),
#                   array([-0.29445753,  0.60377339,  0.08903337, -2.33668057, -0.62097991,
#                           2.68539621, -2.33447367]),
#                   array([-0.29787263,  0.59088779,  0.09611955, -2.34029459, -0.61345104,
#                           2.67567057, -2.34015461]),
#                   array([-0.30089759,  0.57936204,  0.10248603, -2.34337557, -0.60653549,
#                           2.66687246, -2.34532501])]),
#                 ('default_release',
#                  [array([-0.28497424,  0.56590232,  0.09902939, -2.34154007, -0.58558156,
#                           2.66879163, -2.29661849]),
#                   array([-0.26905089,  0.55244261,  0.09557275, -2.33970457, -0.56462762,
#                           2.67071081, -2.24791196]),
#                   array([-0.25312754,  0.53898289,  0.09211612, -2.33786907, -0.54367368,
#                           2.67262998, -2.19920543]),
#                   array([-0.23720419,  0.52552318,  0.08865948, -2.33603356, -0.52271975,
#                           2.67454915, -2.15049891]),
#                   array([-0.22128084,  0.51206346,  0.08520284, -2.33419806, -0.50176581,
#                           2.67646832, -2.10179238]),
#                   array([-0.20535748,  0.49860374,  0.0817462 , -2.33236256, -0.48081187,
#                           2.67838749, -2.05308585]),
#                   array([-0.18943413,  0.48514403,  0.07828956, -2.33052706, -0.45985793,
#                           2.68030666, -2.00437933]),
#                   array([-0.17351078,  0.47168431,  0.07483292, -2.32869155, -0.438904  ,
#                           2.68222583, -1.9556728 ]),
#                   array([-0.15758743,  0.45822459,  0.07137629, -2.32685605, -0.41795006,
#                           2.68414501, -1.90696627]),
#                   array([-0.14166408,  0.44476488,  0.06791965, -2.32502055, -0.39699612,
#                           2.68606418, -1.85825975]),
#                   array([-0.12749767,  0.41992334,  0.06112768, -2.35431788, -0.35729651,
#                           2.71161702, -1.75097359]),
#                   array([-0.11333126,  0.39508181,  0.05433572, -2.38361522, -0.3175969 ,
#                           2.73716987, -1.64368743]),
#                   array([-0.09916486,  0.37024028,  0.04754375, -2.41291255, -0.27789729,
#                           2.76272272, -1.53640127]),
#                   array([-0.08499845,  0.34539874,  0.04075179, -2.44220988, -0.23819767,
#                           2.78827557, -1.42911511]),
#                   array([-0.07083204,  0.32055721,  0.03395982, -2.47150721, -0.19849806,
#                           2.81382842, -1.32182895]),
#                   array([-0.05666563,  0.29571568,  0.02716786, -2.50080455, -0.15879845,
#                           2.83938126, -1.2145428 ]),
#                   array([-0.04249922,  0.27087414,  0.02037589, -2.53010188, -0.11909884,
#                           2.86493411, -1.10725664]),
#                   array([-0.02833282,  0.24603261,  0.01358393, -2.55939921, -0.07939922,
#                           2.89048696, -0.99997048]),
#                   array([-0.01416641,  0.22119107,  0.00679196, -2.58869655, -0.03969961,
#                           2.91603981, -0.89268432]),
#                   array([ 0.        ,  0.19634954,  0.        , -2.61799388,  0.        ,
#                           2.94159265, -0.78539816])])]),
#    OrderedDict([('pre_grasp',
#                  [array([ 0.07543144,  0.22990516, -0.05266334, -2.57792689, -0.06085012,
#                           2.94654718, -0.75982767]),
#                   array([ 0.15086288,  0.26346077, -0.10532667, -2.5378599 , -0.12170023,
#                           2.95150171, -0.73425718]),
#                   array([ 0.22629433,  0.29701638, -0.15799001, -2.49779291, -0.18255035,
#                           2.95645624, -0.70868669]),
#                   array([ 0.30172577,  0.330572  , -0.21065334, -2.45772592, -0.24340046,
#                           2.96141076, -0.6831162 ]),
#                   array([ 0.37715721,  0.36412761, -0.26331668, -2.41765893, -0.30425058,
#                           2.96636529, -0.65754571]),
#                   array([ 0.45258865,  0.39768323, -0.31598001, -2.37759195, -0.36510069,
#                           2.97131982, -0.63197522]),
#                   array([ 0.52802009,  0.43123884, -0.36864335, -2.33752496, -0.42595081,
#                           2.97627435, -0.60640473]),
#                   array([ 0.60345154,  0.46479446, -0.42130669, -2.29745797, -0.48680092,
#                           2.98122887, -0.58083424]),
#                   array([ 0.67888298,  0.49835007, -0.47397002, -2.25739098, -0.54765104,
#                           2.9861834 , -0.55526375]),
#                   array([ 0.75431442,  0.53190569, -0.52663336, -2.21732399, -0.60850115,
#                           2.99113793, -0.52969326]),
#                   array([ 0.78730757,  0.55498305, -0.54673278, -2.20985727, -0.64828335,
#                           2.99793552, -0.51582126]),
#                   array([ 0.82030072,  0.57806041, -0.5668322 , -2.20239055, -0.68806554,
#                           3.0047331 , -0.50194926]),
#                   array([ 0.85329387,  0.60113778, -0.58693163, -2.19492383, -0.72784773,
#                           3.01153069, -0.48807725]),
#                   array([ 0.88628703,  0.62421514, -0.60703105, -2.18745711, -0.76762992,
#                           3.01832828, -0.47420525]),
#                   array([ 0.91928018,  0.64729251, -0.62713048, -2.17999038, -0.80741211,
#                           3.02512586, -0.46033325]),
#                   array([ 0.95227333,  0.67036987, -0.6472299 , -2.17252366, -0.8471943 ,
#                           3.03192345, -0.44646125]),
#                   array([ 0.98526648,  0.69344723, -0.66732932, -2.16505694, -0.88697649,
#                           3.03872104, -0.43258924]),
#                   array([ 1.01825963,  0.7165246 , -0.68742875, -2.15759022, -0.92675868,
#                           3.04551863, -0.41871724]),
#                   array([ 1.05125278,  0.73960196, -0.70752817, -2.1501235 , -0.96654088,
#                           3.05231621, -0.40484524]),
#                   array([ 1.08424593,  0.76267932, -0.72762759, -2.14265678, -1.00632307,
#                           3.0591138 , -0.39097323])]),
#                 ('grasp',
#                  [array([ 1.08424593,  0.76267932, -0.72762759, -2.14265678, -1.00632307,
#                           3.0591138 , -0.39097323]),
#                   array([ 1.08348069,  0.76420661, -0.72741729, -2.14157931, -1.0061817 ,
#                           3.0598631 , -0.39077736]),
#                   array([ 1.07579877,  0.77944534, -0.72527987, -2.13068543, -1.00470566,
#                           3.06720393, -0.3888881 ]),
#                   array([ 1.06808934,  0.79457427, -0.72309459, -2.11963499, -1.00313512,
#                           3.07426892, -0.38712418]),
#                   array([ 1.06034618,  0.80959102, -0.72085703, -2.10842844, -1.00147177,
#                           3.08105598, -0.38549069]),
#                   array([ 1.05256317,  0.82449344, -0.71856286, -2.09706597, -0.99971786,
#                           3.08756307, -0.38399229]),
#                   array([ 1.04473435,  0.8392796 , -0.71620787, -2.08554758, -0.99787614,
#                           3.09378824, -0.38263328]),
#                   array([ 1.03685394,  0.85394784, -0.71378802, -2.07387306, -0.9959498 ,
#                           3.09972967, -0.38141756]),
#                   array([ 1.02891637,  0.86849682, -0.71129941, -2.06204199, -0.99394242,
#                           3.10538569, -0.38034874]),
#                   array([ 1.02091629,  0.8829255 , -0.70873834, -2.05005374, -0.99185785,
#                           3.1107548 , -0.3794301 ]),
#                   array([ 1.01284861,  0.89723321, -0.70610132, -2.03790749, -0.98970021,
#                           3.11583569, -0.3786647 ]),
#                   array([ 1.00552585,  0.91000642, -0.7036603 , -2.02683992, -0.9876994 ,
#                           3.12016114, -0.3781092 ])]),
#                 ('post_grasp',
#                  [array([ 1.00552585,  0.91000642, -0.7036603 , -2.02683992, -0.9876994 ,
#                           3.12016114, -0.3781092 ]),
#                   array([ 1.00537401,  0.90838283, -0.70348375, -2.0275967 , -0.98783316,
#                           3.11945679, -0.37896405]),
#                   array([ 1.00378963,  0.89209749, -0.70162669, -2.03508392, -0.98903279,
#                           3.11226969, -0.38765487]),
#                   array([ 1.00214098,  0.87580238, -0.69967167, -2.04243267, -0.99000036,
#                           3.10491004, -0.39652775]),
#                   array([ 1.0004354 ,  0.85950614, -0.69762481, -2.04964221, -0.99073162,
#                           3.09738616, -0.4055777 ]),
#                   array([ 0.99868036,  0.84321751, -0.69549253, -2.05671155, -0.99122323,
#                           3.08970633, -0.4147991 ]),
#                   array([ 0.99688362,  0.82694542, -0.69328165, -2.06363948, -0.99147289,
#                           3.08187895, -0.42418556]),
#                   array([ 0.99505272,  0.81069798, -0.69099895, -2.07042474, -0.99147922,
#                           3.07391186, -0.4337307 ]),
#                   array([ 0.99319564,  0.79448407, -0.68865175, -2.07706575, -0.99124191,
#                           3.06581329, -0.44342687]),
#                   array([ 0.9913198 ,  0.77831178, -0.68624698, -2.08356064, -0.99076142,
#                           3.05759072, -0.45326681]),
#                   array([ 0.98943321,  0.76218884, -0.68379217, -2.08990792, -0.99003942,
#                           3.04925157, -0.46324232]),
#                   array([ 0.98773244,  0.74772722, -0.68154617, -2.09549251, -0.98918513,
#                           3.04165276, -0.47232902])]),
#                 ('default_grasp',
#                  [array([ 0.94383975,  0.72201572, -0.6486917 , -2.10399106, -0.94679585,
#                           3.02441381, -0.48012152]),
#                   array([ 0.89994706,  0.69630422, -0.61583724, -2.1124896 , -0.90440656,
#                           3.00717486, -0.48791403]),
#                   array([ 0.85605437,  0.67059272, -0.58298277, -2.12098815, -0.86201728,
#                           2.98993591, -0.49570653]),
#                   array([ 0.81216169,  0.64488122, -0.5501283 , -2.12948669, -0.81962799,
#                           2.97269696, -0.50349904]),
#                   array([ 0.768269  ,  0.61916973, -0.51727384, -2.13798524, -0.7772387 ,
#                           2.95545801, -0.51129155]),
#                   array([ 0.72437631,  0.59345823, -0.48441937, -2.14648379, -0.73484942,
#                           2.93821906, -0.51908405]),
#                   array([ 0.68048362,  0.56774673, -0.4515649 , -2.15498233, -0.69246013,
#                           2.92098011, -0.52687656]),
#                   array([ 0.63659093,  0.54203523, -0.41871044, -2.16348088, -0.65007084,
#                           2.90374116, -0.53466906]),
#                   array([ 0.59269825,  0.51632374, -0.38585597, -2.17197943, -0.60768156,
#                           2.88650221, -0.54246157]),
#                   array([ 0.54880556,  0.49061224, -0.3530015 , -2.18047797, -0.56529227,
#                           2.86926327, -0.55025407]),
#                   array([ 0.493925  ,  0.46118597, -0.31770135, -2.22422956, -0.50876304,
#                           2.8764962 , -0.57376848]),
#                   array([ 0.43904445,  0.4317597 , -0.2824012 , -2.26798115, -0.45223382,
#                           2.88372914, -0.59728289]),
#                   array([ 0.38416389,  0.40233343, -0.24710105, -2.31173274, -0.39570459,
#                           2.89096208, -0.6207973 ]),
#                   array([ 0.32928333,  0.37290716, -0.2118009 , -2.35548433, -0.33917536,
#                           2.89819502, -0.64431171]),
#                   array([ 0.27440278,  0.34348089, -0.17650075, -2.39923592, -0.28264614,
#                           2.90542796, -0.66782612]),
#                   array([ 0.21952222,  0.31405462, -0.1412006 , -2.44298752, -0.22611691,
#                           2.9126609 , -0.69134053]),
#                   array([ 0.16464167,  0.28462835, -0.10590045, -2.48673911, -0.16958768,
#                           2.91989384, -0.71485494]),
#                   array([ 0.10976111,  0.25520208, -0.0706003 , -2.5304907 , -0.11305845,
#                           2.92712678, -0.73836935]),
#                   array([ 0.05488056,  0.22577581, -0.03530015, -2.57424229, -0.05652923,
#                           2.93435971, -0.76188375]),
#                   array([ 0.        ,  0.19634954,  0.        , -2.61799388,  0.        ,
#                           2.94159265, -0.78539816])]),
#                 ('pre_release',
#                  [array([ 0.0222767 ,  0.20062913, -0.0178418 , -2.60600231, -0.01678844,
#                           2.91775203, -0.74503458]),
#                   array([ 0.0445534 ,  0.20490871, -0.0356836 , -2.59401074, -0.03357688,
#                           2.8939114 , -0.70467101]),
#                   array([ 0.06683011,  0.20918829, -0.05352539, -2.58201917, -0.05036532,
#                           2.87007077, -0.66430743]),
#                   array([ 0.08910681,  0.21346788, -0.07136719, -2.5700276 , -0.06715376,
#                           2.84623014, -0.62394385]),
#                   array([ 0.11138351,  0.21774746, -0.08920899, -2.55803603, -0.0839422 ,
#                           2.82238951, -0.58358027]),
#                   array([ 0.13366021,  0.22202705, -0.10705079, -2.54604446, -0.10073064,
#                           2.79854888, -0.54321669]),
#                   array([ 0.15593692,  0.22630663, -0.12489258, -2.53405289, -0.11751907,
#                           2.77470826, -0.50285311]),
#                   array([ 0.17821362,  0.23058622, -0.14273438, -2.52206133, -0.13430751,
#                           2.75086763, -0.46248953]),
#                   array([ 0.20049032,  0.2348658 , -0.16057618, -2.51006976, -0.15109595,
#                           2.727027  , -0.42212595]),
#                   array([ 0.22276702,  0.23914539, -0.17841798, -2.49807819, -0.16788439,
#                           2.70318637, -0.38176238]),
#                   array([ 0.25470091,  0.25997321, -0.20972095, -2.48847529, -0.19772324,
#                           2.67070647, -0.33337226]),
#                   array([ 0.28663479,  0.28080103, -0.24102392, -2.4788724 , -0.22756209,
#                           2.63822657, -0.28498214]),
#                   array([ 0.31856867,  0.30162886, -0.27232689, -2.4692695 , -0.25740094,
#                           2.60574667, -0.23659203]),
#                   array([ 0.35050255,  0.32245668, -0.30362986, -2.45966661, -0.28723979,
#                           2.57326677, -0.18820191]),
#                   array([ 0.38243643,  0.3432845 , -0.33493283, -2.45006371, -0.31707864,
#                           2.54078687, -0.13981179]),
#                   array([ 0.41437032,  0.36411233, -0.3662358 , -2.44046082, -0.34691749,
#                           2.50830697, -0.09142168]),
#                   array([ 0.4463042 ,  0.38494015, -0.39753877, -2.43085792, -0.37675634,
#                           2.47582707, -0.04303156]),
#                   array([ 0.47823808,  0.40576797, -0.42884174, -2.42125503, -0.40659519,
#                           2.44334717,  0.00535855]),
#                   array([ 0.51017196,  0.4265958 , -0.46014471, -2.41165213, -0.43643404,
#                           2.41086727,  0.05374867]),
#                   array([ 0.54210584,  0.44742362, -0.49144768, -2.40204924, -0.46627289,
#                           2.37838737,  0.10213879])]),
#                 ('release',
#                  [array([ 0.54210584,  0.44742362, -0.49144768, -2.40204924, -0.46627289,
#                           2.37838737,  0.10213879]),
#                   array([ 0.5417998 ,  0.44890584, -0.49108368, -2.40171825, -0.46595652,
#                           2.37948158,  0.10233446]),
#                   array([ 0.5387153 ,  0.463766  , -0.48740134, -2.39827128, -0.46281164,
#                           2.39033241,  0.10430863]),
#                   array([ 0.5356026 ,  0.47863866, -0.48366059, -2.39461994, -0.45971848,
#                           2.40100206,  0.10631918]),
#                   array([ 0.53246682,  0.49352095, -0.47986961, -2.39076497, -0.45668021,
#                           2.41148827,  0.10836678]),
#                   array([ 0.52931307,  0.50841021, -0.47603647, -2.38670728, -0.45369947,
#                           2.42178902,  0.1104518 ]),
#                   array([ 0.52614631,  0.52330419, -0.47216895, -2.38244766, -0.45077833,
#                           2.4319026 ,  0.11257421]),
#                   array([ 0.52297138,  0.53820081, -0.4682746 , -2.37798698, -0.44791837,
#                           2.44182749,  0.11473365]),
#                   array([ 0.51979296,  0.5530983 , -0.46436065, -2.37332626, -0.44512068,
#                           2.45156259,  0.11692952]),
#                   array([ 0.51661557,  0.56799463, -0.46043409, -2.36846657, -0.44238597,
#                           2.46110656,  0.11916079]),
#                   array([ 0.51344342,  0.5828885 , -0.45650143, -2.36340878, -0.43971437,
#                           2.47045862,  0.12142622]),
#                   array([ 0.51059634,  0.5962897 , -0.45296197, -2.35868848, -0.43736379,
#                           2.4787109 ,  0.12349319])]),
#                 ('post_release',
#                  [array([ 0.51059634,  0.5962897 , -0.45296197, -2.35868848, -0.43736379,
#                           2.4787109 ,  0.12349319]),
#                   array([ 0.51099843,  0.59522554, -0.45289158, -2.35857408, -0.43717456,
#                           2.47745185,  0.12338055]),
#                   array([ 0.51500964,  0.58466211, -0.45217452, -2.35730725, -0.43527483,
#                           2.46481914,  0.12226457]),
#                   array([ 0.51899422,  0.5742571 , -0.45143291, -2.35583304, -0.43336573,
#                           2.45214565,  0.12116933]),
#                   array([ 0.52295076,  0.56401348, -0.45066576, -2.35415181, -0.43144765,
#                           2.43943466,  0.12009438]),
#                   array([ 0.52687789,  0.55393425, -0.44987217, -2.35226396, -0.4295209 ,
#                           2.42668953,  0.11903921]),
#                   array([ 0.53077436,  0.54402224, -0.44905134, -2.35017002, -0.42758573,
#                           2.41391356,  0.11800325]),
#                   array([ 0.53463889,  0.53428036, -0.44820254, -2.34787037, -0.42564224,
#                           2.40110999,  0.11698579]),
#                   array([ 0.53847041,  0.52471115, -0.44732521, -2.34536573, -0.42369061,
#                           2.388282  ,  0.11598613]),
#                   array([ 0.54226786,  0.51531712, -0.44641889, -2.34265654, -0.42173085,
#                           2.3754325 ,  0.11500334]),
#                   array([ 0.54603025,  0.50610092, -0.44548318, -2.33974345, -0.41976296,
#                           2.36256468,  0.11403661]),
#                   array([ 0.54938569,  0.49796052, -0.44461569, -2.33694787, -0.41798489,
#                           2.35097057,  0.11317958])]),
#                 ('default_release',
#                  [array([ 0.53168866,  0.4862424 , -0.42764144, -2.34502038, -0.40241976,
#                           2.36645303,  0.08298976]),
#                   array([ 0.51399163,  0.47452427, -0.41066718, -2.3530929 , -0.38685463,
#                           2.3819355 ,  0.05279994]),
#                   array([ 0.4962946 ,  0.46280614, -0.39369293, -2.36116541, -0.3712895 ,
#                           2.39741796,  0.02261012]),
#                   array([ 0.47859756,  0.45108802, -0.37671867, -2.36923793, -0.35572437,
#                           2.41290043, -0.00757971]),
#                   array([ 0.46090053,  0.43936989, -0.35974442, -2.37731044, -0.34015924,
#                           2.42838289, -0.03776953]),
#                   array([ 0.4432035 ,  0.42765176, -0.34277016, -2.38538295, -0.32459411,
#                           2.44386535, -0.06795935]),
#                   array([ 0.42550647,  0.41593364, -0.32579591, -2.39345547, -0.30902898,
#                           2.45934782, -0.09814917]),
#                   array([ 0.40780944,  0.40421551, -0.30882165, -2.40152798, -0.29346385,
#                           2.47483028, -0.12833899]),
#                   array([ 0.39011241,  0.39249738, -0.2918474 , -2.40960049, -0.27789872,
#                           2.49031275, -0.15852881]),
#                   array([ 0.37241538,  0.38077926, -0.27487314, -2.41767301, -0.26233359,
#                           2.50579521, -0.18871863]),
#                   array([ 0.33517384,  0.36233629, -0.24738583, -2.4377051 , -0.23610023,
#                           2.54937496, -0.24838658]),
#                   array([ 0.29793231,  0.34389331, -0.21989851, -2.45773718, -0.20986687,
#                           2.5929547 , -0.30805454]),
#                   array([ 0.26069077,  0.32545034, -0.1924112 , -2.47776927, -0.18363351,
#                           2.63653444, -0.36772249]),
#                   array([ 0.22344923,  0.30700737, -0.16492388, -2.49780136, -0.15740015,
#                           2.68011419, -0.42739044]),
#                   array([ 0.18620769,  0.2885644 , -0.13743657, -2.51783344, -0.13116679,
#                           2.72369393, -0.4870584 ]),
#                   array([ 0.14896615,  0.27012143, -0.10994926, -2.53786553, -0.10493343,
#                           2.76727368, -0.54672635]),
#                   array([ 0.11172461,  0.25167846, -0.08246194, -2.55789762, -0.07870008,
#                           2.81085342, -0.6063943 ]),
#                   array([ 0.07448308,  0.23323548, -0.05497463, -2.5779297 , -0.05246672,
#                           2.85443317, -0.66606226]),
#                   array([ 0.03724154,  0.21479251, -0.02748731, -2.59796179, -0.02623336,
#                           2.89801291, -0.72573021]),
#                   array([ 0.00000000e+00,  1.96349541e-01,  1.08420217e-19, -2.61799388e+00,
#                          -4.33680869e-19,  2.94159265e+00, -7.85398163e-01])])]),
#    OrderedDict([('pre_grasp',
#                  [array([-0.00518513,  0.2234996 ,  0.01535917, -2.57025742, -0.01739366,
#                           2.90378727, -0.82532244]),
#                   array([-0.01037027,  0.25064966,  0.03071834, -2.52252097, -0.03478732,
#                           2.86598189, -0.86524671]),
#                   array([-0.0155554 ,  0.27779973,  0.04607752, -2.47478452, -0.05218098,
#                           2.82817651, -0.90517099]),
#                   array([-0.02074053,  0.30494979,  0.06143669, -2.42704806, -0.06957465,
#                           2.79037113, -0.94509526]),
#                   array([-0.02592566,  0.33209985,  0.07679586, -2.37931161, -0.08696831,
#                           2.75256575, -0.98501954]),
#                   array([-0.0311108 ,  0.35924991,  0.09215503, -2.33157515, -0.10436197,
#                           2.71476037, -1.02494381]),
#                   array([-0.03629593,  0.38639997,  0.10751421, -2.2838387 , -0.12175563,
#                           2.67695499, -1.06486809]),
#                   array([-0.04148106,  0.41355003,  0.12287338, -2.23610224, -0.13914929,
#                           2.63914961, -1.10479236]),
#                   array([-0.04666619,  0.44070009,  0.13823255, -2.18836579, -0.15654295,
#                           2.60134423, -1.14471664]),
#                   array([-0.05185133,  0.46785015,  0.15359172, -2.14062934, -0.17393662,
#                           2.56353885, -1.18464092]),
#                   array([-0.04259549,  0.51937026,  0.17169109, -2.07316342, -0.18260503,
#                           2.51556349, -1.24687719]),
#                   array([-0.03333965,  0.57089037,  0.18979046, -2.0056975 , -0.19127344,
#                           2.46758813, -1.30911346]),
#                   array([-0.02408382,  0.62241048,  0.20788983, -1.93823157, -0.19994186,
#                           2.41961277, -1.37134974]),
#                   array([-0.01482798,  0.67393058,  0.2259892 , -1.87076565, -0.20861027,
#                           2.37163741, -1.43358601]),
#                   array([-0.00557214,  0.72545069,  0.24408857, -1.80329973, -0.21727868,
#                           2.32366206, -1.49582229]),
#                   array([ 0.00368369,  0.7769708 ,  0.26218793, -1.73583381, -0.2259471 ,
#                           2.2756867 , -1.55805856]),
#                   array([ 0.01293953,  0.8284909 ,  0.2802873 , -1.66836789, -0.23461551,
#                           2.22771134, -1.62029483]),
#                   array([ 0.02219537,  0.88001101,  0.29838667, -1.60090197, -0.24328392,
#                           2.17973598, -1.68253111]),
#                   array([ 0.0314512 ,  0.93153112,  0.31648604, -1.53343605, -0.25195234,
#                           2.13176062, -1.74476738]),
#                   array([ 0.04070704,  0.98305122,  0.33458541, -1.46597013, -0.26062075,
#                           2.08378526, -1.80700366]),
#                   array([ 0.04017696,  0.98556382,  0.33533916, -1.46381521, -0.26109233,
#                           2.08157452, -1.80984694]),
#                   array([ 0.03964688,  0.98807642,  0.33609292, -1.46166029, -0.26156392,
#                           2.07936378, -1.81269023]),
#                   array([ 0.0391168 ,  0.99058902,  0.33684668, -1.45950538, -0.2620355 ,
#                           2.07715305, -1.81553352]),
#                   array([ 0.03858673,  0.99310162,  0.33760044, -1.45735046, -0.26250709,
#                           2.07494231, -1.81837681]),
#                   array([ 0.03805665,  0.99561421,  0.33835419, -1.45519554, -0.26297867,
#                           2.07273157, -1.82122009]),
#                   array([ 0.03752657,  0.99812681,  0.33910795, -1.45304062, -0.26345026,
#                           2.07052083, -1.82406338]),
#                   array([ 0.03699649,  1.00063941,  0.33986171, -1.4508857 , -0.26392184,
#                           2.06831009, -1.82690667]),
#                   array([ 0.03646641,  1.00315201,  0.34061547, -1.44873078, -0.26439343,
#                           2.06609935, -1.82974996]),
#                   array([ 0.03593633,  1.00566461,  0.34136923, -1.44657586, -0.26486501,
#                           2.06388862, -1.83259325]),
#                   array([ 0.03540626,  1.00817721,  0.34212298, -1.44442094, -0.2653366 ,
#                           2.06167788, -1.83543653]),
#                   array([ 0.03487618,  1.0106898 ,  0.34287674, -1.44226603, -0.26580818,
#                           2.05946714, -1.83827982]),
#                   array([ 0.0343461 ,  1.0132024 ,  0.3436305 , -1.44011111, -0.26627977,
#                           2.0572564 , -1.84112311]),
#                   array([ 0.03381602,  1.015715  ,  0.34438426, -1.43795619, -0.26675135,
# ...
#                   array([-0.07482792,  0.24041414, -0.00482379, -2.46732974, -0.02097308,
#                           2.75218778, -0.99225494]),
#                   array([-0.04196072,  0.2151218 , -0.00392586, -2.51383368, -0.0139577 ,
#                           2.80668365, -0.89908292]),
#                   array([-0.00909352,  0.18982945, -0.00302792, -2.56033762, -0.00694232,
#                           2.86117952, -0.8059109 ]),
#                   array([-0.00864754,  0.19014922, -0.00287942, -2.56316528, -0.00660185,
#                           2.86512326, -0.80490488]),
#                   array([-8.20156165e-03,  1.90468986e-01, -2.73092058e-03, -2.56599295e+00,
#                          -6.26137075e-03,  2.86906701e+00, -8.03898862e-01]),
#                   array([-7.75558350e-03,  1.90788754e-01, -2.58242070e-03, -2.56882061e+00,
#                          -5.92089479e-03,  2.87301075e+00, -8.02892846e-01]),
#                   array([-7.30960536e-03,  1.91108523e-01, -2.43392082e-03, -2.57164828e+00,
#                          -5.58041884e-03,  2.87695449e+00, -8.01886829e-01]),
#                   array([-6.86362721e-03,  1.91428291e-01, -2.28542095e-03, -2.57447595e+00,
#                          -5.23994289e-03,  2.88089824e+00, -8.00880812e-01]),
#                   array([-6.41764907e-03,  1.91748059e-01, -2.13692107e-03, -2.57730361e+00,
#                          -4.89946694e-03,  2.88484198e+00, -7.99874796e-01]),
#                   array([-5.97167092e-03,  1.92067827e-01, -1.98842119e-03, -2.58013128e+00,
#                          -4.55899098e-03,  2.88878572e+00, -7.98868779e-01]),
#                   array([-5.52569278e-03,  1.92387596e-01, -1.83992132e-03, -2.58295895e+00,
#                          -4.21851503e-03,  2.89272947e+00, -7.97862763e-01]),
#                   array([-5.07971463e-03,  1.92707364e-01, -1.69142144e-03, -2.58578661e+00,
#                          -3.87803908e-03,  2.89667321e+00, -7.96856746e-01]),
#                   array([-4.63373649e-03,  1.93027132e-01, -1.54292156e-03, -2.58861428e+00,
#                          -3.53756313e-03,  2.90061695e+00, -7.95850729e-01]),
#                   array([-4.17036284e-03,  1.93359373e-01, -1.38862941e-03, -2.59155224e+00,
#                          -3.18380682e-03,  2.90471452e+00, -7.94805473e-01]),
#                   array([-3.70698919e-03,  1.93691614e-01, -1.23433725e-03, -2.59449020e+00,
#                          -2.83005050e-03,  2.90881209e+00, -7.93760216e-01]),
#                   array([-3.24361554e-03,  1.94023855e-01, -1.08004509e-03, -2.59742816e+00,
#                          -2.47629419e-03,  2.91290966e+00, -7.92714960e-01]),
#                   array([-2.78024189e-03,  1.94356096e-01, -9.25752938e-04, -2.60036612e+00,
#                          -2.12253788e-03,  2.91700723e+00, -7.91669703e-01]),
#                   array([-2.31686824e-03,  1.94688336e-01, -7.71460781e-04, -2.60330408e+00,
#                          -1.76878156e-03,  2.92110480e+00, -7.90624446e-01]),
#                   array([-1.85349459e-03,  1.95020577e-01, -6.17168625e-04, -2.60624204e+00,
#                          -1.41502525e-03,  2.92520237e+00, -7.89579190e-01]),
#                   array([-1.39012095e-03,  1.95352818e-01, -4.62876469e-04, -2.60918000e+00,
#                          -1.06126894e-03,  2.92929994e+00, -7.88533933e-01]),
#                   array([-9.26747297e-04,  1.95685059e-01, -3.08584313e-04, -2.61211796e+00,
#                          -7.07512626e-04,  2.93339751e+00, -7.87488677e-01]),
#                   array([-4.63373649e-04,  1.96017300e-01, -1.54292156e-04, -2.61505592e+00,
#                          -3.53756313e-04,  2.93749508e+00, -7.86443420e-01]),
#                   array([ 0.        ,  0.19634954,  0.        , -2.61799388,  0.        ,
#                           2.94159265, -0.78539816])]),
#                 ('pre_release',
#                  [array([-0.03813685,  0.21973441, -0.00388186, -2.55624792,  0.01449123,
#                           2.87207986, -0.84790853]),
#                   array([-0.07627369,  0.24311929, -0.00776371, -2.49450197,  0.02898245,
#                           2.80256706, -0.9104189 ]),
#                   array([-0.11441054,  0.26650416, -0.01164557, -2.43275601,  0.04347368,
#                           2.73305426, -0.97292927]),
#                   array([-0.15254738,  0.28988903, -0.01552742, -2.37101005,  0.05796491,
#                           2.66354147, -1.03543964]),
#                   array([-0.19068423,  0.3132739 , -0.01940928, -2.3092641 ,  0.07245613,
#                           2.59402867, -1.09795001]),
#                   array([-0.22882108,  0.33665878, -0.02329113, -2.24751814,  0.08694736,
#                           2.52451587, -1.16046038]),
#                   array([-0.26695792,  0.36004365, -0.02717299, -2.18577219,  0.10143859,
#                           2.45500307, -1.22297074]),
#                   array([-0.30509477,  0.38342852, -0.03105484, -2.12402623,  0.11592981,
#                           2.38549028, -1.28548111]),
#                   array([-0.34323161,  0.40681339, -0.0349367 , -2.06228027,  0.13042104,
#                           2.31597748, -1.34799148]),
#                   array([-0.38136846,  0.43019827, -0.03881855, -2.00053432,  0.14491226,
#                           2.24646468, -1.41050185]),
#                   array([-0.41048284,  0.46150328, -0.0210821 , -1.94708963,  0.14618027,
#                           2.19635929, -1.47875568]),
#                   array([-0.43959721,  0.49280829, -0.00334564, -1.89364495,  0.14744827,
#                           2.14625391, -1.5470095 ]),
#                   array([-0.46871159,  0.5241133 ,  0.01439082, -1.84020027,  0.14871627,
#                           2.09614852, -1.61526333]),
#                   array([-0.49782597,  0.55541831,  0.03212728, -1.78675559,  0.14998427,
#                           2.04604313, -1.68351715]),
#                   array([-0.52694034,  0.58672332,  0.04986374, -1.7333109 ,  0.15125227,
#                           1.99593774, -1.75177098]),
#                   array([-0.55605472,  0.61802833,  0.0676002 , -1.67986622,  0.15252027,
#                           1.94583235, -1.8200248 ]),
#                   array([-0.58516909,  0.64933334,  0.08533666, -1.62642154,  0.15378827,
#                           1.89572696, -1.88827863]),
#                   array([-0.61428347,  0.68063835,  0.10307312, -1.57297686,  0.15505627,
#                           1.84562157, -1.95653245]),
#                   array([-0.64339785,  0.71194337,  0.12080957, -1.51953217,  0.15632427,
#                           1.79551618, -2.02478628]),
#                   array([-0.67251222,  0.74324838,  0.13854603, -1.46608749,  0.15759227,
#                           1.74541079, -2.09304011])]),
#                 ('release',
#                  [array([-0.67251222,  0.74324838,  0.13854603, -1.46608749,  0.15759227,
#                           1.74541079, -2.09304011]),
#                   array([-0.67246179,  0.74399458,  0.13850071, -1.4661597 ,  0.15754952,
#                           1.74621416, -2.09318556]),
#                   array([-0.67195347,  0.75153884,  0.13804584, -1.46674501,  0.15712236,
#                           1.75419507, -2.0946312 ]),
#                   array([-0.67143912,  0.75921369,  0.13758829, -1.46710077,  0.156696  ,
#                           1.76207865, -2.09606117]),
#                   array([-0.67091886,  0.767018  ,  0.13712814, -1.46722706,  0.15627043,
#                           1.76986386, -2.09747567]),
#                   array([-0.67039279,  0.77495079,  0.13666549, -1.46712395,  0.15584567,
#                           1.77754973, -2.09887489]),
#                   array([-0.669861  ,  0.78301115,  0.13620044, -1.4667913 ,  0.15542168,
#                           1.78513524, -2.10025902]),
#                   array([-0.6693236 ,  0.791198  ,  0.1357331 , -1.466229  ,  0.15499847,
#                           1.79261915, -2.10162821]),
#                   array([-0.66878071,  0.79951058,  0.13526357, -1.46543692,  0.15457602,
#                           1.80000055, -2.10298266]),
#                   array([-0.66823237,  0.80794807,  0.13479198, -1.46441436,  0.1541543 ,
#                           1.80727793, -2.10432243]),
#                   array([-0.66767866,  0.81650972,  0.13431846, -1.46316102,  0.1537333 ,
#                           1.81445021, -2.10564767]),
#                   array([-0.6671758 ,  0.82432081,  0.13389075, -1.46183545,  0.153355  ,
#                           1.82081459, -2.10682806])]),
#                 ('post_release',
#                  [array([-0.6671758 ,  0.82432081,  0.13389075, -1.46183545,  0.153355  ,
#                           1.82081459, -2.10682806]),
#                   array([-0.66728067,  0.8242524 ,  0.13385068, -1.46069492,  0.15328258,
#                           1.81959253, -2.10675624]),
#                   array([-0.66831594,  0.82372918,  0.13345206, -1.44903957,  0.15255562,
#                           1.80728189, -2.10602485]),
#                   array([-0.66933209,  0.82342945,  0.13305921, -1.43705698,  0.15183002,
#                           1.79486986, -2.10527868]),
#                   array([-0.67032855,  0.8233587 ,  0.13267231, -1.4247373 ,  0.15110573,
#                           1.78235214, -2.10451692]),
#                   array([-0.67130471,  0.82352284,  0.13229159, -1.41206999,  0.1503827 ,
#                           1.76972417, -2.10373872]),
#                   array([-0.6722599 ,  0.82392838,  0.13191726, -1.39904334,  0.14966084,
#                           1.7569808 , -2.10294312]),
#                   array([-0.67319341,  0.82458221,  0.13154956, -1.38564487,  0.14894007,
#                           1.7441165 , -2.10212916]),
#                   array([-0.67410447,  0.82549188,  0.13118875, -1.37186084,  0.14822028,
#                           1.73112519, -2.10129575]),
#                   array([-0.67499214,  0.82666607,  0.1308351 , -1.35767549,  0.14750131,
#                           1.71799983, -2.10044165]),
#                   array([-0.67585556,  0.82811367,  0.13048887, -1.34307251,  0.14678303,
#                           1.70473311, -2.09956569]),
#                   array([-0.67661097,  0.82965847,  0.1301839 , -1.32955771,  0.14613704,
#                           1.69266545, -2.09875741])]),
#                 ('default_release',
#                  [array([-0.67199845,  0.82213908,  0.12974557, -1.33813955,  0.14626357,
#                           1.69899036, -2.08528563]),
#                   array([-0.66738592,  0.81461968,  0.12930724, -1.34672139,  0.14639009,
#                           1.70531527, -2.07181385]),
#                   array([-0.6627734 ,  0.80710028,  0.12886891, -1.35530322,  0.14651661,
#                           1.71164018, -2.05834207]),
#                   array([-0.65816087,  0.79958088,  0.12843058, -1.36388506,  0.14664314,
#                           1.71796509, -2.04487029]),
#                   array([-0.65354835,  0.79206149,  0.12799224, -1.3724669 ,  0.14676966,
#                           1.72428999, -2.03139851]),
#                   array([-0.64893582,  0.78454209,  0.12755391, -1.38104874,  0.14689618,
#                           1.7306149 , -2.01792673]),
#                   array([-0.6443233 ,  0.77702269,  0.12711558, -1.38963057,  0.1470227 ,
#                           1.73693981, -2.00445495]),
#                   array([-0.63971077,  0.76950329,  0.12667725, -1.39821241,  0.14714923,
#                           1.74326472, -1.99098317]),
#                   array([-0.63509825,  0.76198389,  0.12623892, -1.40679425,  0.14727575,
#                           1.74958963, -1.97751138]),
#                   array([-0.63048572,  0.7544645 ,  0.12580058, -1.41537608,  0.14740227,
#                           1.75591454, -1.9640396 ]),
#                   array([-0.58511471,  0.70906336,  0.10540557, -1.47002012,  0.15044524,
#                           1.81277387, -1.88826071]),
#                   array([-0.53974369,  0.66366222,  0.08501055, -1.52466416,  0.15348821,
#                           1.86963319, -1.81248181]),
#                   array([-0.49437267,  0.61826108,  0.06461553, -1.57930819,  0.15653118,
#                           1.92649252, -1.73670291]),
#                   array([-0.44900166,  0.57285995,  0.04422052, -1.63395223,  0.15957416,
#                           1.98335185, -1.66092402]),
#                   array([-0.40363064,  0.52745881,  0.0238255 , -1.68859627,  0.16261713,
#                           2.04021118, -1.58514512]),
#                   array([-0.35825963,  0.48205767,  0.00343048, -1.7432403 ,  0.1656601 ,
#                           2.09707051, -1.50936622]),
#                   array([-0.31288861,  0.43665653, -0.01696453, -1.79788434,  0.16870307,
#                           2.15392983, -1.43358732]),
#                   array([-0.26751759,  0.3912554 , -0.03735955, -1.85252838,  0.17174604,
#                           2.21078916, -1.35780843]),
#                   array([-0.22214658,  0.34585426, -0.05775457, -1.90717242,  0.17478901,
#                           2.26764849, -1.28202953]),
#                   array([-0.17677556,  0.30045312, -0.07814958, -1.96181645,  0.17783198,
#                           2.32450782, -1.20625063]),
#                   array([-0.1759204 ,  0.29994952, -0.07777153, -1.96499073,  0.17697171,
#                           2.32749299, -1.20421475]),
#                   array([-0.17506525,  0.29944591, -0.07739348, -1.96816501,  0.17611145,
#                           2.33047815, -1.20217886]),
#                   array([-0.17421009,  0.29894231, -0.07701543, -1.97133929,  0.17525118,
#                           2.33346332, -1.20014297]),
#                   array([-0.17335493,  0.2984387 , -0.07663738, -1.97451357,  0.17439091,
#                           2.33644849, -1.19810709]),
#                   array([-0.17249977,  0.2979351 , -0.07625933, -1.97768785,  0.17353064,
#                           2.33943366, -1.1960712 ]),
#                   array([-0.17164462,  0.29743149, -0.07588128, -1.98086213,  0.17267038,
#                           2.34241882, -1.19403531]),
#                   array([-0.17078946,  0.29692789, -0.07550323, -1.98403641,  0.17181011,
#                           2.34540399, -1.19199942]),
#                   array([-0.1699343 ,  0.29642429, -0.07512518, -1.98721068,  0.17094984,
#                           2.34838916, -1.18996354]),
#                   array([-0.16907915,  0.29592068, -0.07474712, -1.99038496,  0.17008957,
#                           2.35137432, -1.18792765]),
#                   array([-0.16822399,  0.29541708, -0.07436907, -1.99355924,  0.1692293 ,
#                           2.35435949, -1.18589176]),
#                   array([-0.15140159,  0.28551032, -0.06693217, -2.05600271,  0.15230637,
#                           2.41308281, -1.1458424 ]),
#                   array([-0.13457919,  0.27560357, -0.05949526, -2.11844617,  0.13538344,
#                           2.47180612, -1.10579304]),
#                   array([-0.11775679,  0.26569682, -0.05205835, -2.18088963,  0.11846051,
#                           2.53052944, -1.06574368]),
#                   array([-0.10093439,  0.25579006, -0.04462144, -2.2433331 ,  0.10153758,
#                           2.58925276, -1.02569432]),
#                   array([-0.08411199,  0.24588331, -0.03718454, -2.30577656,  0.08461465,
#                           2.64797607, -0.98564496]),
#                   array([-0.0672896 ,  0.23597656, -0.02974763, -2.36822002,  0.06769172,
#                           2.70669939, -0.9455956 ]),
#                   array([-0.0504672 ,  0.2260698 , -0.02231072, -2.43066349,  0.05076879,
#                           2.76542271, -0.90554624]),
#                   array([-0.0336448 ,  0.21616305, -0.01487381, -2.49310695,  0.03384586,
#                           2.82414602, -0.86549688]),
#                   array([-0.0168224 ,  0.20625629, -0.00743691, -2.55555041,  0.01692293,
#                           2.88286934, -0.82544752]),
#                   array([ 0.        ,  0.19634954,  0.        , -2.61799388,  0.        ,
#                           2.94159265, -0.78539816])])])]]]

# %%
from pykin.utils.kin_utils import apply_robot_to_scene

mcts.rearr_action.scene_mngr.render.render_objects(mcts.tree.nodes[0]['state'].objs)
# pick.scene_mngr.render.trimesh_scene = apply_robot_to_scene(
#         trimesh_scene=pick.scene_mngr.render.trimesh_scene, 
#         robot=pick.scene_mngr.scene.robot,
#         geom="visual"
#             )
# pick.scene_mngr.render.set_camera_view()

mcts.rearr_action.simulate_path(
    final_pnp_all_joint_paths[0],
    final_pick_all_objects[0],
    final_place_all_object_poses[0],
    is_save=True,
#     video_name="pick_rearrangement1_only_current_scene",
    video_name="benchmark1_grasp_using_contact_graspnet_consider_next_scene",
)
# Out:
# 0 scene
# 100 scene
# 200 scene
# 300 scene
# 400 scene
# 500 scene
# 600 scene
# 700 scene
# 800 scene
# 900 scene
# 1000 scene
# 1100 scene
# 1200 scene
# 1300 scene
# 1400 scene
# Animation Finished..
# PWD :  /home/juju/pytamp/examples/doosan/action/rearrangement1/movie_dir
# Save finished..
