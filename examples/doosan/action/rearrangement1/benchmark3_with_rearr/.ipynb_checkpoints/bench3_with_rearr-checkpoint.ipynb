# %%
import numpy as np
import argparse
import os

from pykin.utils import plot_utils as p_utils
from pytamp.benchmark import Benchmark3_for_rearr as Benchmark3
# from pytamp.benchmark import Benchmark3

from pytamp.search.mcts_for_rearragement import MCTS_rearrangement 


# ? python3 benchmark2_test.py --budgets 100 --max_depth 14 --seed 1 --algo bai_perturb
parser = argparse.ArgumentParser(description="Test Benchmark 3.")
parser.add_argument("--budgets", metavar="T", type=int, default=100, help="Horizon")
parser.add_argument("--max_depth", metavar="H", type=int, default=12, help="Max depth")
parser.add_argument("--seed", metavar="i", type=int, default=12, help="A random seed")
parser.add_argument(
    "--algo",
    metavar="alg",
    type=str,
    default="uct",
    choices=["bai_perturb", "bai_ucb", "uct", "random", "greedy"],
    help="Choose one (bai_perturb, bai_ucb, uct)",
)
parser.add_argument(
    "--debug_mode",
    default=False,
    type=lambda x: (str(x).lower() == "true"),
    help="Debug mode",
)
parser.add_argument(
    "--bottle_number",
    metavar="N",
    type=int,
    default=3,
    help="Bottle Number(6 or less.)",
)
try:
    args = parser.parse_args() #call from command line
except:
    args = parser.parse_args(args=[]) #call from notebook
    

debug_mode = args.debug_mode
budgets = args.budgets
max_depth = args.max_depth
algo = args.algo
seed = args.seed
number = args.bottle_number
np.random.seed(seed)

benchmark3 = Benchmark3(robot_name="panda", geom="collision", is_pyplot=False)

# %%
for n, m in benchmark3.init_scene._support_objects.items():
    print(n)
# Out:
# table
# tray_blue

# %%
# fig, ax = p_utils.init_3d_figure(name="Benchamrk 1")
# # init_scene
# benchmark3.scene_mngr.render_scene(ax)
# benchmark3.render_axis(benchmark3.scene_mngr)
# benchmark3.scene_mngr.show()

# %%
final_level_1_values = []
final_level_2_values = []
final_optimal_nodes = []
final_pnp_all_joint_paths = []
final_pick_all_objects = []
final_place_all_object_poses = []
# final_optimal_trees = []
c_list = 10 ** np.linspace(-2, 2.0, 10)
# c_list = c_list[6:]
c = 2.5

mcts = MCTS_rearrangement(
    scene_mngr=benchmark3.scene_mngr,
    init_scene = benchmark3.init_scene,
    sampling_method=algo,
    budgets=budgets,
    max_depth=max_depth,
    c=c_list[6],
    debug_mode=debug_mode,
    use_pick_action=False,
    consider_next_scene=False,
    do_level_2=True,
    
)

mcts.only_optimize_1 = False
# Out:
# 2023-08-07 04:24:08.817805: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-08-07 04:24:08.837284: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-07 04:24:08.837347: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 3080 computeCapability: 8.6
# coreClock: 1.74GHz coreCount: 68 deviceMemorySize: 9.77GiB deviceMemoryBandwidth: 707.88GiB/s
# 2023-08-07 04:24:08.837362: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-08-07 04:24:08.838932: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-08-07 04:24:08.838973: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-08-07 04:24:08.839476: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2023-08-07 04:24:08.839606: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2023-08-07 04:24:08.840049: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2023-08-07 04:24:08.840417: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2023-08-07 04:24:08.840484: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-08-07 04:24:08.840530: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-07 04:24:08.840601: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-07 04:24:08.840636: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# /home/juju/contact_graspnet/pointnet2/tf_ops/sampling
# <module 'contact_graspnet.contact_graspnet' from '/home/juju/contact_graspnet/contact_graspnet/contact_graspnet.py'>
# --- Get model
# WARNING:tensorflow:From /home/juju/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/tensorflow/python/keras/layers/normalization.py:534: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# /home/juju/contact_graspnet/contact_graspnet/config_utils.py:42: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   global_config = yaml.load(f)
# /home/juju/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/tensorflow/python/keras/legacy_tf_layers/normalization.py:307: UserWarning: `tf.layers.batch_normalization` is deprecated and will be removed in a future version. Please use `tf.keras.layers.BatchNormalization` instead. In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.BatchNormalization` documentation).
#   warnings.warn(
# /home/juju/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer_v1.py:1692: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# WARNING:tensorflow:From /home/juju/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py:602: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# WARNING:tensorflow:From /home/juju/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:206: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# 2023-08-07 04:24:10.965149: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-07 04:24:10.966422: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-07 04:24:10.966556: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 3080 computeCapability: 8.6
# coreClock: 1.74GHz coreCount: 68 deviceMemorySize: 9.77GiB deviceMemoryBandwidth: 707.88GiB/s
# 2023-08-07 04:24:10.966620: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-07 04:24:10.966673: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-07 04:24:10.966708: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-08-07 04:24:10.966745: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# INFO:tensorflow:Restoring parameters from /home/juju/contact_graspnet/checkpoints/scene_test_2048_bs3_hor_sigma_001/model.ckpt-144144
# 2023-08-07 04:24:11.231593: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-08-07 04:24:11.231617: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-08-07 04:24:11.231620: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-08-07 04:24:11.231764: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-07 04:24:11.231886: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-07 04:24:11.231941: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-07 04:24:11.231992: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 219 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:01:00.0, compute capability: 8.6)
# 2023-08-07 04:24:11.326705: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 3609600000 Hz

# %%
import time
start_time = time.time()
idx = 0 


for i in range(budgets):
# for i in range(10):
    print(
        f"\n[{idx+1}/{len(c_list)}] Benchmark: {benchmark3.scene_mngr.scene.bench_num}, Algo: {algo}, C: {c}, Seed: {seed}"
    )
    mcts.do_planning_rearrange(i)

    print("########### Running time : ", time.time()- start_time, "##############")
    final_level_1_values.append(mcts.values_for_level_1)
# Out:
# [1/10] Benchmark: 3, Algo: uct, C: 2.5, Seed: 12
# =========== Search iteration : 1 ===========
# [Action] Rearr rect_box2 to table
# [Reward] S(0) -> A(1) -> S'(17) Reward : -0.5
# table
# table
# table
# table
# table
# table
# [Action] Rearr square_box2 to table
# [Reward] S(17) -> A(19) -> S'(24) Reward : -0.5
# table
# table
# table
# table
# table
# table
# [Action] Rearr milk2 to table
# [Reward] S(24) -> A(26) -> S'(30) Reward : -0.5
# table
# table
# table
# table
# table
# [Action] Rearr milk4 to table
# [Reward] S(30) -> A(34) -> S'(36) Reward : -0.5
# table
# table
# table
# table
# [Action] Rearr rect_box1 to table
# [Reward] S(36) -> A(37) -> S'(42) Reward : -0.5
# table
# table
# table
# [Action] Rearr milk3 to table
# [Reward] S(42) -> A(43) -> S'(45) Reward : -0.5
# table
# table
# [Action] Rearr goal_can to tray_blue
# [Reward] S(45) -> A(47) -> S'(48) Reward : -0.5
# Success!!!!!
# Terminal State! Reward is 10
# rect_box2
# Extracted Region Cube Size:  0.4
# Random sample points
# 2023-08-07 04:24:38.807525: E tensorflow/stream_executor/cuda/cuda_dnn.cc:364] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2023-08-07 04:24:38.810568: E tensorflow/stream_executor/cuda/cuda_dnn.cc:364] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2023-08-07 04:24:38.812119: E tensorflow/stream_executor/cuda/cuda_dnn.cc:364] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2023-08-07 04:24:38.813399: E tensorflow/stream_executor/cuda/cuda_dnn.cc:364] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2023-08-07 04:24:38.813673: I tensorflow/stream_executor/cuda/cuda_driver.cc:789] failed to allocate 64.00M (67108864 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-08-07 04:24:38.813680: W tensorflow/core/common_runtime/bfc_allocator.cc:337] Garbage collection: deallocate free memory regions (i.e., allocations) so that we can re-allocate a larger region to avoid OOM due to memory fragmentation. If you see this message frequently, you are running near the threshold of the available device memory and re-allocation may incur great performance overhead. You may try smaller batch sizes to observe the performance impact. Set TF_ENABLE_GPU_GARBAGE_COLLECTION=false if you'd like to disable this feature.
# 2023-08-07 04:24:38.818814: I tensorflow/stream_executor/cuda/cuda_driver.cc:789] failed to allocate 64.00M (67108864 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-08-07 04:24:38.820657: I tensorflow/stream_executor/cuda/cuda_driver.cc:789] failed to allocate 64.00M (67108864 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-08-07 04:24:48.822444: I tensorflow/stream_executor/cuda/cuda_driver.cc:789] failed to allocate 64.00M (67108864 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-08-07 04:24:48.823891: I tensorflow/stream_executor/cuda/cuda_driver.cc:789] failed to allocate 64.00M (67108864 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-08-07 04:24:48.823927: W tensorflow/core/common_runtime/bfc_allocator.cc:456] Allocator (GPU_0_bfc) ran out of memory trying to allocate 64.00MiB (rounded to 67108864)requested by op layer1/conv2_0/Conv2D
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-08-07 04:24:48.823960: I tensorflow/core/common_runtime/bfc_allocator.cc:991] BFCAllocator dump for GPU_0_bfc
# 2023-08-07 04:24:48.823983: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (256): 	Total Chunks: 64, Chunks in use: 64. 16.0KiB allocated for chunks. 16.0KiB in use in bin. 11.4KiB client-requested in use in bin.
# 2023-08-07 04:24:48.823998: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (512): 	Total Chunks: 118, Chunks in use: 115. 59.8KiB allocated for chunks. 58.0KiB in use in bin. 57.1KiB client-requested in use in bin.
# 2023-08-07 04:24:48.824012: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (1024): 	Total Chunks: 43, Chunks in use: 43. 44.2KiB allocated for chunks. 44.2KiB in use in bin. 44.0KiB client-requested in use in bin.
# 2023-08-07 04:24:48.824026: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (2048): 	Total Chunks: 5, Chunks in use: 5. 10.0KiB allocated for chunks. 10.0KiB in use in bin. 10.0KiB client-requested in use in bin.
# 2023-08-07 04:24:48.824039: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (4096): 	Total Chunks: 9, Chunks in use: 7. 40.0KiB allocated for chunks. 30.0KiB in use in bin. 29.0KiB client-requested in use in bin.
# 2023-08-07 04:24:48.824051: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (8192): 	Total Chunks: 1, Chunks in use: 1. 8.0KiB allocated for chunks. 8.0KiB in use in bin. 8.0KiB client-requested in use in bin.
# 2023-08-07 04:24:48.824065: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (16384): 	Total Chunks: 5, Chunks in use: 4. 98.0KiB allocated for chunks. 72.0KiB in use in bin. 72.0KiB client-requested in use in bin.
# 2023-08-07 04:24:48.824080: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (32768): 	Total Chunks: 5, Chunks in use: 5. 176.0KiB allocated for chunks. 176.0KiB in use in bin. 176.0KiB client-requested in use in bin.
# 2023-08-07 04:24:48.824095: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (65536): 	Total Chunks: 13, Chunks in use: 13. 942.8KiB allocated for chunks. 942.8KiB in use in bin. 912.8KiB client-requested in use in bin.
# 2023-08-07 04:24:48.824109: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (131072): 	Total Chunks: 13, Chunks in use: 10. 2.01MiB allocated for chunks. 1.50MiB in use in bin. 1.50MiB client-requested in use in bin.
# 2023-08-07 04:24:48.824122: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (262144): 	Total Chunks: 5, Chunks in use: 5. 1.63MiB allocated for chunks. 1.63MiB in use in bin. 1.63MiB client-requested in use in bin.
# 2023-08-07 04:24:48.824135: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (524288): 	Total Chunks: 4, Chunks in use: 3. 3.04MiB allocated for chunks. 2.29MiB in use in bin. 2.12MiB client-requested in use in bin.
# 2023-08-07 04:24:48.824148: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (1048576): 	Total Chunks: 3, Chunks in use: 2. 3.96MiB allocated for chunks. 2.74MiB in use in bin. 2.25MiB client-requested in use in bin.
# 2023-08-07 04:24:48.824160: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (2097152): 	Total Chunks: 3, Chunks in use: 2. 7.25MiB allocated for chunks. 5.00MiB in use in bin. 5.00MiB client-requested in use in bin.
# 2023-08-07 04:24:48.824174: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-08-07 04:24:48.824187: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (8388608): 	Total Chunks: 1, Chunks in use: 0. 10.75MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-08-07 04:24:48.824199: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-08-07 04:24:48.824210: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-08-07 04:24:48.824221: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-08-07 04:24:48.824232: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-08-07 04:24:48.824243: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-08-07 04:24:48.824257: I tensorflow/core/common_runtime/bfc_allocator.cc:1014] Bin for 64.00MiB was 64.00MiB, Chunk State:
# 2023-08-07 04:24:48.824267: I tensorflow/core/common_runtime/bfc_allocator.cc:1027] Next region of size 4194304
# 2023-08-07 04:24:48.824286: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de000000 of size 1703936 by op SameWorkerRecvDone action_count 4470614405286937 step 0 next 226
# 2023-08-07 04:24:48.824298: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de1a0000 of size 917504 by op SameWorkerRecvDone action_count 4470614405286938 step 0 next 227
# 2023-08-07 04:24:48.824309: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de280000 of size 512 by op SameWorkerRecvDone action_count 4470614405286939 step 0 next 231
# 2023-08-07 04:24:48.824318: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de280200 of size 512 by op SameWorkerRecvDone action_count 4470614405286940 step 0 next 234
# 2023-08-07 04:24:48.824328: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de280400 of size 256 by op SameWorkerRecvDone action_count 4470614405286941 step 0 next 235
# 2023-08-07 04:24:48.824338: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de280500 of size 256 by op SameWorkerRecvDone action_count 4470614405286942 step 0 next 241
# 2023-08-07 04:24:48.824347: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de280600 of size 512 by op SameWorkerRecvDone action_count 4470614405286943 step 0 next 242
# 2023-08-07 04:24:48.824357: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de280800 of size 16384 by op SameWorkerRecvDone action_count 4470614405286944 step 0 next 254
# 2023-08-07 04:24:48.824367: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de284800 of size 131072 by op SameWorkerRecvDone action_count 4470614405286945 step 0 next 267
# 2023-08-07 04:24:48.824377: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de2a4800 of size 329216 by op SameWorkerRecvDone action_count 4470614405286946 step 0 next 268
# 2023-08-07 04:24:48.824387: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de2f4e00 of size 512 by op SameWorkerRecvDone action_count 4470614405286947 step 0 next 183
# 2023-08-07 04:24:48.824398: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de2f5000 of size 1024 by op SameWorkerRecvDone action_count 4470614405286948 step 0 next 184
# 2023-08-07 04:24:48.824408: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de2f5400 of size 1024 by op SameWorkerRecvDone action_count 4470614405286949 step 0 next 196
# 2023-08-07 04:24:48.824417: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de2f5800 of size 1024 by op SameWorkerRecvDone action_count 4470614405286950 step 0 next 285
# 2023-08-07 04:24:48.824428: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de2f5c00 of size 65536 by op SameWorkerRecvDone action_count 4470614405286951 step 0 next 287
# 2023-08-07 04:24:48.824437: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de305c00 of size 512 by op SameWorkerRecvDone action_count 4470614405286952 step 0 next 296
# 2023-08-07 04:24:48.824447: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de305e00 of size 65536 by op SameWorkerRecvDone action_count 4470614405286953 step 0 next 298
# 2023-08-07 04:24:48.824456: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de315e00 of size 131072 by op SameWorkerRecvDone action_count 4470614405286954 step 0 next 232
# 2023-08-07 04:24:48.824465: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de335e00 of size 512 by op SameWorkerRecvDone action_count 4470614405286955 step 0 next 236
# 2023-08-07 04:24:48.824474: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de336000 of size 131072 by op SameWorkerRecvDone action_count 4470614405286956 step 0 next 243
# 2023-08-07 04:24:48.824485: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de356000 of size 696320 by op SameWorkerRecvDone action_count 4470614405286957 step 0 next 18446744073709551615
# 2023-08-07 04:24:48.824495: I tensorflow/core/common_runtime/bfc_allocator.cc:1027] Next region of size 8388608
# 2023-08-07 04:24:48.824505: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de400000 of size 262144 by op SameWorkerRecvDone action_count 4470614405286958 step 0 next 255
# 2023-08-07 04:24:48.824514: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de440000 of size 131072 by op SameWorkerRecvDone action_count 4470614405286959 step 0 next 269
# 2023-08-07 04:24:48.824524: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de460000 of size 512 by op SameWorkerRecvDone action_count 4470614405286960 step 0 next 270
# 2023-08-07 04:24:48.824533: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de460200 of size 512 by op SameWorkerRecvDone action_count 4470614405286961 step 0 next 177
# 2023-08-07 04:24:48.824542: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de460400 of size 512 by op SameWorkerRecvDone action_count 4470614405286962 step 0 next 197
# 2023-08-07 04:24:48.824552: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de460600 of size 256 by op SameWorkerRecvDone action_count 4470614405286963 step 0 next 205
# 2023-08-07 04:24:48.824561: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de460700 of size 32768 by op SameWorkerRecvDone action_count 4470614405286964 step 0 next 206
# 2023-08-07 04:24:48.824572: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de468700 of size 2048 by op SameWorkerRecvDone action_count 4470614405286965 step 0 next 237
# 2023-08-07 04:24:48.824581: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de468f00 of size 512 by op SameWorkerRecvDone action_count 4470614405286966 step 0 next 244
# 2023-08-07 04:24:48.824590: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de469100 of size 512 by op SameWorkerRecvDone action_count 4470614405286967 step 0 next 256
# 2023-08-07 04:24:48.824600: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de469300 of size 256 by op SameWorkerRecvDone action_count 4470614405286968 step 0 next 273
# 2023-08-07 04:24:48.824609: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de469400 of size 256 by op SameWorkerRecvDone action_count 4470614405286969 step 0 next 275
# 2023-08-07 04:24:48.824618: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de469500 of size 512 by op SameWorkerRecvDone action_count 4470614405286970 step 0 next 188
# 2023-08-07 04:24:48.824628: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de469700 of size 1536 by op SameWorkerRecvDone action_count 4470614405286971 step 0 next 189
# 2023-08-07 04:24:48.824637: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de469d00 of size 65536 by op SameWorkerRecvDone action_count 4470614405286972 step 0 next 198
# 2023-08-07 04:24:48.824648: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de479d00 of size 5120 by op SameWorkerRecvDone action_count 4470614405286973 step 0 next 207
# 2023-08-07 04:24:48.824657: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de47b100 of size 256 by op SameWorkerRecvDone action_count 4470614405286974 step 0 next 214
# 2023-08-07 04:24:48.824666: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de47b200 of size 65536 by op SameWorkerRecvDone action_count 4470614405286975 step 0 next 215
# 2023-08-07 04:24:48.824676: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f62de48b200 of size 512 by op UNUSED action_count 4470614405287132 step 0 next 245
# 2023-08-07 04:24:48.824686: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de48b400 of size 256 by op SameWorkerRecvDone action_count 4470614405286977 step 0 next 257
# 2023-08-07 04:24:48.824696: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de48b500 of size 512 by op SameWorkerRecvDone action_count 4470614405286978 step 0 next 302
# 2023-08-07 04:24:48.824706: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de48b700 of size 82688 by op SameWorkerRecvDone action_count 4470614405286979 step 0 next 286
# 2023-08-07 04:24:48.824715: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de49fa00 of size 1536 by op SameWorkerRecvDone action_count 4470614405286980 step 0 next 301
# 2023-08-07 04:24:48.824724: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f62de4a0000 of size 768 by op UNUSED action_count 4470614405287138 step 0 next 182
# 2023-08-07 04:24:48.824734: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de4a0300 of size 8192 by op SameWorkerRecvDone action_count 4470614405286982 step 0 next 193
# 2023-08-07 04:24:48.824744: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de4a2300 of size 165376 by op SameWorkerRecvDone action_count 4470614405286983 step 0 next 199
# 2023-08-07 04:24:48.824753: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de4ca900 of size 65536 by op SameWorkerRecvDone action_count 4470614405286984 step 0 next 208
# 2023-08-07 04:24:48.824762: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de4da900 of size 65536 by op SameWorkerRecvDone action_count 4470614405286985 step 0 next 216
# 2023-08-07 04:24:48.824772: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de4ea900 of size 131072 by op SameWorkerRecvDone action_count 4470614405286986 step 0 next 219
# 2023-08-07 04:24:48.824781: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de50a900 of size 65536 by op SameWorkerRecvDone action_count 4470614405286987 step 0 next 220
# 2023-08-07 04:24:48.824791: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de51a900 of size 768 by op SameWorkerRecvDone action_count 4470614405286988 step 0 next 238
# 2023-08-07 04:24:48.824800: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de51ac00 of size 32768 by op SameWorkerRecvDone action_count 4470614405286989 step 0 next 246
# 2023-08-07 04:24:48.824810: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de522c00 of size 165376 by op SameWorkerRecvDone action_count 4470614405286990 step 0 next 258
# 2023-08-07 04:24:48.824819: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de54b200 of size 256 by op SameWorkerRecvDone action_count 4470614405286991 step 0 next 185
# 2023-08-07 04:24:48.824829: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de54b300 of size 1024 by op SameWorkerRecvDone action_count 4470614405286992 step 0 next 187
# 2023-08-07 04:24:48.824838: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de54b700 of size 16384 by op SameWorkerRecvDone action_count 4470614405286993 step 0 next 200
# 2023-08-07 04:24:48.824848: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de54f700 of size 1024 by op SameWorkerRecvDone action_count 4470614405286994 step 0 next 209
# 2023-08-07 04:24:48.824858: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de54fb00 of size 2097152 by op SameWorkerRecvDone action_count 4470614405286995 step 0 next 217
# 2023-08-07 04:24:48.824868: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de74fb00 of size 512 by op SameWorkerRecvDone action_count 4470614405286996 step 0 next 239
# 2023-08-07 04:24:48.824877: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de74fd00 of size 512 by op fc1/bn/batchnorm/mul_2 action_count 4470614405287123 step 3 next 272
# 2023-08-07 04:24:48.824887: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de74ff00 of size 512 by op fc1_app/bn/batchnorm/mul_2 action_count 4470614405287125 step 3 next 289
# 2023-08-07 04:24:48.824897: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de750100 of size 512 by op fc1_seg/bn/batchnorm/mul_2 action_count 4470614405287127 step 3 next 291
# 2023-08-07 04:24:48.824906: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de750300 of size 512 by op fc1_off/bn/batchnorm/mul_2 action_count 4470614405287128 step 3 next 222
# 2023-08-07 04:24:48.824916: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f62de750500 of size 4096 by op UNUSED action_count 4470614405287135 step 3 next 248
# 2023-08-07 04:24:48.824927: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de751500 of size 49152 by op SameWorkerRecvDone action_count 4470614405287043 step 0 next 247
# 2023-08-07 04:24:48.824936: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de75d500 of size 16384 by op SameWorkerRecvDone action_count 4470614405287075 step 0 next 280
# 2023-08-07 04:24:48.824946: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f62de761500 of size 168704 by op UNUSED action_count 4470614405287119 step 3 next 259
# 2023-08-07 04:24:48.824955: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de78a800 of size 256 by op SameWorkerRecvDone action_count 4470614405286999 step 0 next 191
# 2023-08-07 04:24:48.824965: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f62de78a900 of size 512 by op UNUSED action_count 4470614405287129 step 3 next 218
# 2023-08-07 04:24:48.824974: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de78ab00 of size 512 by op fc1_seg/bn/batchnorm/add action_count 4470614405287036 step 3 next 211
# 2023-08-07 04:24:48.824985: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de78ad00 of size 256 by op SameWorkerRecvDone action_count 4470614405287074 step 0 next 288
# 2023-08-07 04:24:48.824995: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de78ae00 of size 256 by op SameWorkerRecvDone action_count 4470614405287083 step 0 next 203
# 2023-08-07 04:24:48.825006: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de78af00 of size 256 by op SameWorkerRecvDone action_count 4470614405287046 step 0 next 249
# 2023-08-07 04:24:48.825016: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de78b000 of size 512 by op fc1_off/bn/batchnorm/add action_count 4470614405287048 step 3 next 212
# 2023-08-07 04:24:48.825025: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de78b200 of size 768 by op fc1/bn/batchnorm/add action_count 4470614405287051 step 3 next 260
# 2023-08-07 04:24:48.825035: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de78b500 of size 5120 by op SameWorkerRecvDone action_count 4470614405287041 step 0 next 192
# 2023-08-07 04:24:48.825044: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f62de78c900 of size 26624 by op UNUSED action_count 4470614405287126 step 0 next 178
# 2023-08-07 04:24:48.825053: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de793100 of size 512 by op fc1_app/bn/batchnorm/add action_count 4470614405287052 step 3 next 204
# 2023-08-07 04:24:48.825063: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de793300 of size 512 by op SameWorkerRecvDone action_count 4470614405287053 step 0 next 213
# 2023-08-07 04:24:48.825072: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f62de793500 of size 165888 by op UNUSED action_count 4470614405287114 step 3 next 294
# 2023-08-07 04:24:48.825084: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de7bbd00 of size 98304 by op layer3/GroupPoint action_count 4470614405287111 step 3 next 223
# 2023-08-07 04:24:48.825094: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de7d3d00 of size 129024 by op layer3/GroupPoint_2 action_count 4470614405287113 step 3 next 179
# 2023-08-07 04:24:48.825104: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de7f3500 of size 1024 by op SameWorkerRecvDone action_count 4470614405287060 step 0 next 265
# 2023-08-07 04:24:48.825113: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de7f3900 of size 65536 by op SameWorkerRecvDone action_count 4470614405287061 step 0 next 224
# 2023-08-07 04:24:48.825123: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de803900 of size 512 by op SameWorkerRecvDone action_count 4470614405287062 step 0 next 225
# 2023-08-07 04:24:48.825133: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de803b00 of size 4096 by op SameWorkerRecvDone action_count 4470614405287065 step 0 next 228
# 2023-08-07 04:24:48.825143: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de804b00 of size 196608 by op layer3/GroupPoint_4 action_count 4470614405287112 step 3 next 201
# 2023-08-07 04:24:48.825152: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f62de834b00 of size 196608 by op UNUSED action_count 4470614405287105 step 3 next 240
# 2023-08-07 04:24:48.825162: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de864b00 of size 1024 by op SameWorkerRecvDone action_count 4470614405287068 step 0 next 271
# 2023-08-07 04:24:48.825171: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f62de864f00 of size 786432 by op UNUSED action_count 4470614405287107 step 3 next 278
# 2023-08-07 04:24:48.825181: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de924f00 of size 65536 by op SameWorkerRecvDone action_count 4470614405287070 step 0 next 281
# 2023-08-07 04:24:48.825190: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de934f00 of size 65536 by op SameWorkerRecvDone action_count 4470614405287071 step 0 next 277
# 2023-08-07 04:24:48.825200: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de944f00 of size 393216 by op layer2/GroupPoint action_count 4470614405287072 step 3 next 292
# 2023-08-07 04:24:48.825211: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62de9a4f00 of size 786432 by op layer2/GroupPoint_4 action_count 4470614405287078 step 3 next 221
# 2023-08-07 04:24:48.825220: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62dea64f00 of size 393216 by op layer2/GroupPoint_2 action_count 4470614405287079 step 3 next 233
# 2023-08-07 04:24:48.825230: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f62deac4f00 of size 6144 by op UNUSED action_count 4470614405287108 step 0 next 276
# 2023-08-07 04:24:48.825239: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62deac6700 of size 512 by op SameWorkerRecvDone action_count 4470614405287084 step 0 next 282
# 2023-08-07 04:24:48.825248: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62deac6900 of size 512 by op SameWorkerRecvDone action_count 4470614405287085 step 0 next 284
# 2023-08-07 04:24:48.825258: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f62deac6b00 of size 1283328 by op UNUSED action_count 4470614405287116 step 3 next 18446744073709551615
# 2023-08-07 04:24:48.825268: I tensorflow/core/common_runtime/bfc_allocator.cc:1027] Next region of size 16777216
# 2023-08-07 04:24:48.825278: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f62dec00000 of size 2359296 by op UNUSED action_count 4470614405287131 step 3 next 202
# 2023-08-07 04:24:48.825289: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f62dee40000 of size 3145728 by op layer1/conv2_0/Conv2D-0-TransposeNHWCToNCHW-LayoutOptimizer action_count 4470614405287032 step 3 next 261
# 2023-08-07 04:24:48.825300: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f62df140000 of size 11272192 by op UNUSED action_count 4470614405287130 step 3 next 18446744073709551615
# 2023-08-07 04:24:48.825309: I tensorflow/core/common_runtime/bfc_allocator.cc:1027] Next region of size 2097152
# 2023-08-07 04:24:48.825320: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa00000 of size 1280 by op ScratchBuffer action_count 4470614405286434 step 0 next 1
# 2023-08-07 04:24:48.825330: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa00500 of size 1024 by op SameWorkerRecvDone action_count 4470614405286435 step 0 next 2
# 2023-08-07 04:24:48.825339: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa00900 of size 1024 by op SameWorkerRecvDone action_count 4470614405286436 step 0 next 3
# 2023-08-07 04:24:48.825348: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa00d00 of size 4096 by op SameWorkerRecvDone action_count 4470614405286437 step 0 next 4
# 2023-08-07 04:24:48.825358: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa01d00 of size 2048 by op SameWorkerRecvDone action_count 4470614405286438 step 0 next 5
# 2023-08-07 04:24:48.825368: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa02500 of size 1024 by op SameWorkerRecvDone action_count 4470614405286439 step 0 next 6
# 2023-08-07 04:24:48.825377: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa02900 of size 4096 by op SameWorkerRecvDone action_count 4470614405286440 step 0 next 7
# 2023-08-07 04:24:48.825387: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa03900 of size 1024 by op SameWorkerRecvDone action_count 4470614405286441 step 0 next 8
# 2023-08-07 04:24:48.825396: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa03d00 of size 4096 by op SameWorkerRecvDone action_count 4470614405286442 step 0 next 9
# 2023-08-07 04:24:48.825408: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa04d00 of size 2048 by op SameWorkerRecvDone action_count 4470614405286443 step 0 next 10
# 2023-08-07 04:24:48.825417: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa05500 of size 1024 by op SameWorkerRecvDone action_count 4470614405286444 step 0 next 11
# 2023-08-07 04:24:48.825426: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa05900 of size 2048 by op SameWorkerRecvDone action_count 4470614405286445 step 0 next 12
# 2023-08-07 04:24:48.825435: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa06100 of size 1024 by op SameWorkerRecvDone action_count 4470614405286446 step 0 next 13
# 2023-08-07 04:24:48.825446: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa06500 of size 4096 by op SameWorkerRecvDone action_count 4470614405286447 step 0 next 14
# 2023-08-07 04:24:48.825455: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa07500 of size 2048 by op SameWorkerRecvDone action_count 4470614405286448 step 0 next 15
# 2023-08-07 04:24:48.825465: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa07d00 of size 1024 by op SameWorkerRecvDone action_count 4470614405286449 step 0 next 16
# 2023-08-07 04:24:48.825474: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa08100 of size 1024 by op SameWorkerRecvDone action_count 4470614405286450 step 0 next 17
# 2023-08-07 04:24:48.825484: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa08500 of size 1024 by op SameWorkerRecvDone action_count 4470614405286451 step 0 next 18
# 2023-08-07 04:24:48.825493: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa08900 of size 1024 by op SameWorkerRecvDone action_count 4470614405286452 step 0 next 19
# 2023-08-07 04:24:48.825504: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa08d00 of size 1024 by op SameWorkerRecvDone action_count 4470614405286453 step 0 next 20
# 2023-08-07 04:24:48.825512: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa09100 of size 1024 by op SameWorkerRecvDone action_count 4470614405286454 step 0 next 21
# 2023-08-07 04:24:48.825522: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa09500 of size 1024 by op SameWorkerRecvDone action_count 4470614405286455 step 0 next 22
# 2023-08-07 04:24:48.825531: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa09900 of size 1024 by op SameWorkerRecvDone action_count 4470614405286456 step 0 next 23
# 2023-08-07 04:24:48.825540: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa09d00 of size 512 by op SameWorkerRecvDone action_count 4470614405286457 step 0 next 24
# 2023-08-07 04:24:48.825550: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa09f00 of size 1024 by op SameWorkerRecvDone action_count 4470614405286458 step 0 next 25
# 2023-08-07 04:24:48.825559: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0a300 of size 512 by op SameWorkerRecvDone action_count 4470614405286459 step 0 next 26
# 2023-08-07 04:24:48.825570: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0a500 of size 1024 by op SameWorkerRecvDone action_count 4470614405286460 step 0 next 27
# 2023-08-07 04:24:48.825579: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0a900 of size 512 by op SameWorkerRecvDone action_count 4470614405286461 step 0 next 28
# 2023-08-07 04:24:48.825590: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0ab00 of size 512 by op SameWorkerRecvDone action_count 4470614405286462 step 0 next 29
# 2023-08-07 04:24:48.825599: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0ad00 of size 512 by op SameWorkerRecvDone action_count 4470614405286463 step 0 next 30
# 2023-08-07 04:24:48.825608: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0af00 of size 512 by op SameWorkerRecvDone action_count 4470614405286464 step 0 next 31
# 2023-08-07 04:24:48.825617: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0b100 of size 512 by op SameWorkerRecvDone action_count 4470614405286465 step 0 next 32
# 2023-08-07 04:24:48.825626: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0b300 of size 512 by op SameWorkerRecvDone action_count 4470614405286466 step 0 next 33
# 2023-08-07 04:24:48.825635: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0b500 of size 512 by op SameWorkerRecvDone action_count 4470614405286467 step 0 next 34
# 2023-08-07 04:24:48.825644: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0b700 of size 512 by op SameWorkerRecvDone action_count 4470614405286468 step 0 next 35
# 2023-08-07 04:24:48.825654: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0b900 of size 512 by op SameWorkerRecvDone action_count 4470614405286469 step 0 next 36
# 2023-08-07 04:24:48.825662: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0bb00 of size 512 by op SameWorkerRecvDone action_count 4470614405286470 step 0 next 37
# 2023-08-07 04:24:48.825671: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0bd00 of size 512 by op SameWorkerRecvDone action_count 4470614405286471 step 0 next 38
# 2023-08-07 04:24:48.825680: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0bf00 of size 512 by op SameWorkerRecvDone action_count 4470614405286472 step 0 next 39
# 2023-08-07 04:24:48.825690: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0c100 of size 512 by op SameWorkerRecvDone action_count 4470614405286473 step 0 next 40
# 2023-08-07 04:24:48.825699: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0c300 of size 512 by op SameWorkerRecvDone action_count 4470614405286474 step 0 next 41
# 2023-08-07 04:24:48.825708: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0c500 of size 512 by op SameWorkerRecvDone action_count 4470614405286475 step 0 next 42
# 2023-08-07 04:24:48.825716: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0c700 of size 512 by op SameWorkerRecvDone action_count 4470614405286476 step 0 next 43
# 2023-08-07 04:24:48.825726: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0c900 of size 512 by op SameWorkerRecvDone action_count 4470614405286477 step 0 next 44
# 2023-08-07 04:24:48.825735: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0cb00 of size 512 by op SameWorkerRecvDone action_count 4470614405286478 step 0 next 45
# 2023-08-07 04:24:48.825744: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0cd00 of size 512 by op SameWorkerRecvDone action_count 4470614405286479 step 0 next 46
# 2023-08-07 04:24:48.825753: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0cf00 of size 512 by op SameWorkerRecvDone action_count 4470614405286480 step 0 next 47
# 2023-08-07 04:24:48.825762: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0d100 of size 512 by op SameWorkerRecvDone action_count 4470614405286481 step 0 next 48
# 2023-08-07 04:24:48.825772: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0d300 of size 512 by op SameWorkerRecvDone action_count 4470614405286482 step 0 next 49
# 2023-08-07 04:24:48.825781: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0d500 of size 512 by op SameWorkerRecvDone action_count 4470614405286483 step 0 next 50
# 2023-08-07 04:24:48.825790: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0d700 of size 256 by op SameWorkerRecvDone action_count 4470614405286484 step 0 next 51
# 2023-08-07 04:24:48.825800: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0d800 of size 512 by op SameWorkerRecvDone action_count 4470614405286485 step 0 next 52
# 2023-08-07 04:24:48.825810: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0da00 of size 512 by op SameWorkerRecvDone action_count 4470614405286486 step 0 next 53
# 2023-08-07 04:24:48.825819: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0dc00 of size 512 by op SameWorkerRecvDone action_count 4470614405286487 step 0 next 54
# 2023-08-07 04:24:48.825829: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0de00 of size 256 by op SameWorkerRecvDone action_count 4470614405286488 step 0 next 55
# 2023-08-07 04:24:48.825838: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0df00 of size 256 by op SameWorkerRecvDone action_count 4470614405286489 step 0 next 56
# 2023-08-07 04:24:48.825848: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0e000 of size 512 by op SameWorkerRecvDone action_count 4470614405286490 step 0 next 57
# 2023-08-07 04:24:48.825856: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0e200 of size 256 by op SameWorkerRecvDone action_count 4470614405286491 step 0 next 58
# 2023-08-07 04:24:48.825867: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0e300 of size 512 by op SameWorkerRecvDone action_count 4470614405286492 step 0 next 59
# 2023-08-07 04:24:48.825876: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0e500 of size 512 by op SameWorkerRecvDone action_count 4470614405286493 step 0 next 60
# 2023-08-07 04:24:48.825886: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0e700 of size 256 by op SameWorkerRecvDone action_count 4470614405286494 step 0 next 61
# 2023-08-07 04:24:48.825895: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0e800 of size 256 by op SameWorkerRecvDone action_count 4470614405286495 step 0 next 62
# 2023-08-07 04:24:48.825904: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0e900 of size 1024 by op SameWorkerRecvDone action_count 4470614405286496 step 0 next 63
# 2023-08-07 04:24:48.825918: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0ed00 of size 256 by op SameWorkerRecvDone action_count 4470614405286497 step 0 next 64
# 2023-08-07 04:24:48.825934: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0ee00 of size 256 by op SameWorkerRecvDone action_count 4470614405286498 step 0 next 65
# 2023-08-07 04:24:48.825950: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0ef00 of size 256 by op SameWorkerRecvDone action_count 4470614405286499 step 0 next 66
# 2023-08-07 04:24:48.825965: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0f000 of size 512 by op SameWorkerRecvDone action_count 4470614405286500 step 0 next 67
# 2023-08-07 04:24:48.825979: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0f200 of size 512 by op SameWorkerRecvDone action_count 4470614405286501 step 0 next 68
# 2023-08-07 04:24:48.825993: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0f400 of size 512 by op SameWorkerRecvDone action_count 4470614405286502 step 0 next 69
# 2023-08-07 04:24:48.826008: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0f600 of size 256 by op SameWorkerRecvDone action_count 4470614405286503 step 0 next 70
# 2023-08-07 04:24:48.826024: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0f700 of size 512 by op SameWorkerRecvDone action_count 4470614405286504 step 0 next 71
# 2023-08-07 04:24:48.826039: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0f900 of size 256 by op SameWorkerRecvDone action_count 4470614405286505 step 0 next 72
# 2023-08-07 04:24:48.826054: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0fa00 of size 256 by op SameWorkerRecvDone action_count 4470614405286506 step 0 next 73
# 2023-08-07 04:24:48.826070: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0fb00 of size 256 by op SameWorkerRecvDone action_count 4470614405286507 step 0 next 74
# 2023-08-07 04:24:48.826085: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0fc00 of size 256 by op SameWorkerRecvDone action_count 4470614405286508 step 0 next 75
# 2023-08-07 04:24:48.826101: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0fd00 of size 512 by op SameWorkerRecvDone action_count 4470614405286509 step 0 next 76
# 2023-08-07 04:24:48.826125: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa0ff00 of size 256 by op SameWorkerRecvDone action_count 4470614405286510 step 0 next 77
# 2023-08-07 04:24:48.826144: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa10000 of size 512 by op SameWorkerRecvDone action_count 4470614405286511 step 0 next 78
# 2023-08-07 04:24:48.826161: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa10200 of size 512 by op SameWorkerRecvDone action_count 4470614405286512 step 0 next 79
# 2023-08-07 04:24:48.826187: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa10400 of size 256 by op SameWorkerRecvDone action_count 4470614405286513 step 0 next 80
# 2023-08-07 04:24:48.826203: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa10500 of size 256 by op SameWorkerRecvDone action_count 4470614405286514 step 0 next 81
# 2023-08-07 04:24:48.826219: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa10600 of size 256 by op SameWorkerRecvDone action_count 4470614405286515 step 0 next 82
# 2023-08-07 04:24:48.826236: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa10700 of size 256 by op SameWorkerRecvDone action_count 4470614405286516 step 0 next 83
# 2023-08-07 04:24:48.826259: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa10800 of size 512 by op SameWorkerRecvDone action_count 4470614405286517 step 0 next 84
# 2023-08-07 04:24:48.826274: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa10a00 of size 256 by op SameWorkerRecvDone action_count 4470614405286518 step 0 next 85
# 2023-08-07 04:24:48.826292: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa10b00 of size 256 by op SameWorkerRecvDone action_count 4470614405286519 step 0 next 86
# 2023-08-07 04:24:48.826302: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa10c00 of size 512 by op SameWorkerRecvDone action_count 4470614405286520 step 0 next 87
# 2023-08-07 04:24:48.826311: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa10e00 of size 512 by op SameWorkerRecvDone action_count 4470614405286521 step 0 next 88
# 2023-08-07 04:24:48.826319: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa11000 of size 256 by op SameWorkerRecvDone action_count 4470614405286522 step 0 next 89
# 2023-08-07 04:24:48.826329: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa11100 of size 256 by op SameWorkerRecvDone action_count 4470614405286523 step 0 next 90
# 2023-08-07 04:24:48.826337: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa11200 of size 512 by op SameWorkerRecvDone action_count 4470614405286524 step 0 next 91
# 2023-08-07 04:24:48.826346: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa11400 of size 512 by op SameWorkerRecvDone action_count 4470614405286525 step 0 next 92
# 2023-08-07 04:24:48.826355: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa11600 of size 256 by op SameWorkerRecvDone action_count 4470614405286526 step 0 next 93
# 2023-08-07 04:24:48.826364: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa11700 of size 512 by op SameWorkerRecvDone action_count 4470614405286527 step 0 next 94
# 2023-08-07 04:24:48.826373: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa11900 of size 256 by op SameWorkerRecvDone action_count 4470614405286528 step 0 next 95
# 2023-08-07 04:24:48.826382: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa11a00 of size 256 by op SameWorkerRecvDone action_count 4470614405286529 step 0 next 96
# 2023-08-07 04:24:48.826391: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa11b00 of size 512 by op SameWorkerRecvDone action_count 4470614405286530 step 0 next 97
# 2023-08-07 04:24:48.826400: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa11d00 of size 512 by op SameWorkerRecvDone action_count 4470614405286531 step 0 next 98
# 2023-08-07 04:24:48.826409: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa11f00 of size 512 by op SameWorkerRecvDone action_count 4470614405286532 step 0 next 99
# 2023-08-07 04:24:48.826418: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa12100 of size 256 by op SameWorkerRecvDone action_count 4470614405286533 step 0 next 100
# 2023-08-07 04:24:48.826427: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa12200 of size 512 by op SameWorkerRecvDone action_count 4470614405286534 step 0 next 101
# 2023-08-07 04:24:48.826436: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa12400 of size 256 by op SameWorkerRecvDone action_count 4470614405286535 step 0 next 102
# 2023-08-07 04:24:48.826445: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa12500 of size 1024 by op SameWorkerRecvDone action_count 4470614405286536 step 0 next 103
# 2023-08-07 04:24:48.826454: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f634fa12900 of size 1024 by op SameWorkerRecvDone action_count 4470614405286537 step 0 next 104
# ...
# 2023-08-07 04:24:48.827606: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 917504 totalling 896.0KiB
# 2023-08-07 04:24:48.827618: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 1165824 totalling 1.11MiB
# 2023-08-07 04:24:48.827627: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 1703936 totalling 1.62MiB
# 2023-08-07 04:24:48.827637: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 2097152 totalling 2.00MiB
# 2023-08-07 04:24:48.827648: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 3145728 totalling 3.00MiB
# 2023-08-07 04:24:48.827660: I tensorflow/core/common_runtime/bfc_allocator.cc:1058] Sum Total of in-use chunks: 14.48MiB
# 2023-08-07 04:24:48.827670: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] total_region_allocated_bytes_: 31457280 memory_limit_: 229965824 available bytes: 198508544 curr_region_allocation_bytes_: 67108864
# 2023-08-07 04:24:48.827690: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Stats:
# Limit:                       229965824
# InUse:                        15186176
# MaxInUse:                     50315008
# NumAllocs:                         492
# MaxAllocSize:                 33554432
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-08-07 04:24:48.827722: W tensorflow/core/common_runtime/bfc_allocator.cc:467] ****************************__******___________***********___________________________________******x
# 2023-08-07 04:24:48.827789: W tensorflow/core/framework/op_kernel.cc:1767] OP_REQUIRES failed at conv_ops.cc:662 : Resource exhausted: OOM when allocating tensor with shape[1,64,2048,128] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/tensorflow/python/client/session.py:1375, in BaseSession._do_call(self, fn, *args)
#    1374 try:
# -> 1375   return fn(*args)
#    1376 except errors.OpError as e:
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/tensorflow/python/client/session.py:1359, in BaseSession._do_run.<locals>._run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1358 self._extend_graph()
# -> 1359 return self._call_tf_sessionrun(options, feed_dict, fetch_list,
#    1360                                 target_list, run_metadata)
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/tensorflow/python/client/session.py:1451, in BaseSession._call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1449 def _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list,
#    1450                         run_metadata):
# -> 1451   return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1452                                           fetch_list, target_list,
#    1453                                           run_metadata)
#
# UnknownError: 2 root error(s) found.
#   (0) Unknown: Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, so try looking to see if a warning log message was printed above.
# 	 [[{{node layer1/conv0_0/Conv2D}}]]
# 	 [[layer4/Squeeze/_489]]
#   (1) Unknown: Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, so try looking to see if a warning log message was printed above.
# 	 [[{{node layer1/conv0_0/Conv2D}}]]
# 0 successful operations.
# 0 derived errors ignored.
#
# During handling of the above exception, another exception occurred:
#
# UnknownError                              Traceback (most recent call last)
# Cell In[6], line 11
#       6 for i in range(budgets):
#       7 # for i in range(10):
#       8     print(
#       9         f"\n[{idx+1}/{len(c_list)}] Benchmark: {benchmark3.scene_mngr.scene.bench_num}, Algo: {algo}, C: {c}, Seed: {seed}"
#      10     )
# ---> 11     mcts.do_planning_rearrange(i)
#      13     print("########### Running time : ", time.time()- start_time, "##############")
#      14     final_level_1_values.append(mcts.values_for_level_1)
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/pytamp/search/mcts_for_rearragement.py:269, in MCTS_rearrangement.do_planning_rearrange(self, iter)
#     266 # TODO
#     267 else:
#     268     level_1_5_start_time = time.time()
# --> 269     self._level_wise_between_1_and_2_optimize(
#     270         success_level_1_sub_nodes, self.consider_next_scene
#     271     )
#     272     self.time_used_in_level_1_5 += time.time() - level_1_5_start_time
#     274     if self._do_level_2:
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/pytamp/search/mcts_for_rearragement.py:454, in MCTS_rearrangement._level_wise_between_1_and_2_optimize(self, sub_optimal_nodes, use_next_scene)
#     448     grasps = self.grasp_generator.get_grasp(
#     449         init_scene=self.init_scene,
#     450         next_node=next_node,
#     451         current_node=current_node,
#     452     )
#     453 else:
# --> 454     grasps = self.grasp_generator.get_grasp(
#     455         init_scene=self.init_scene,
#     456         current_node=current_node,
#     457     )
#     459 if len(grasps) > self.grasp_use_num:
#     460     random_list = np.random.choice(len(grasps), self.grasp_use_num, replace=False)
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/pytamp/utils/contact_graspnet_utils.py:362, in Grasp_Using_Contact_GraspNet.get_grasp(self, init_scene, next_node, current_node)
#     356 pc_region_ = self.get_region_to_manipulate(
#     357     cam_pc[:, :3], pc_segments, min_size=min_size, obj_name=obj_to_manipulate
#     358 )
#     360 pred_grasps_cam, s_, c_, g_o_ = {}, {}, {}, {}
# --> 362 pred_grasps_cam, s_, c_, g_o_ = self.generate_grasp(
#     363     pc_region_, pc_segments[obj_to_manipulate], obj_to_manipulate
#     364 )
#     365 collision_free_grasps = self.change_grasp_to_world_coord(pred_grasps_cam, obj_to_manipulate)
#     367 # self.action.remove_mixed_scene()
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/pytamp/utils/contact_graspnet_utils.py:170, in Grasp_Using_Contact_GraspNet.generate_grasp(self, pc_region, pc_segment, obj_name)
#     162 forward_passes = 1
#     163 local_regions = True
#     165 (
#     166     pred_grasps_cam[obj_name],
#     167     scores[obj_name],
#     168     contact_pts[obj_name],
#     169     gripper_openings[obj_name],
# --> 170 ) = self.grasp_estimator.predict_grasps(
#     171     self.sess, pc_region, convert_cam_coords=True, forward_passes=forward_passes
#     172 )
#     174 # Filter grasps
#     175 segment_keys = contact_pts.keys()
#
# File ~/contact_graspnet/contact_graspnet/contact_grasp_estimator.py:273, in GraspEstimator.predict_grasps(self, sess, pc, constant_offset, convert_cam_coords, forward_passes)
#     267 feed_dict = {
#     268     self.placeholders["pointclouds_pl"]: pc_batch,
#     269     self.placeholders["is_training_pl"]: False,
#     270 }
#     272 # Run model inference
# --> 273 pred_grasps_cam, pred_scores, pred_points, offset_pred = sess.run(
#     274     self.inference_ops, feed_dict=feed_dict
#     275 )
#     277 pred_grasps_cam = pred_grasps_cam.reshape(-1, *pred_grasps_cam.shape[-2:])
#     278 pred_points = pred_points.reshape(-1, pred_points.shape[-1])
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/tensorflow/python/client/session.py:967, in BaseSession.run(self, fetches, feed_dict, options, run_metadata)
#     964 run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
#     966 try:
# --> 967   result = self._run(None, fetches, feed_dict, options_ptr,
#     968                      run_metadata_ptr)
#     969   if run_metadata:
#     970     proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/tensorflow/python/client/session.py:1190, in BaseSession._run(self, handle, fetches, feed_dict, options, run_metadata)
#    1187 # We only want to really perform the run if fetches or targets are provided,
#    1188 # or if the call is a partial run that specifies feeds.
#    1189 if final_fetches or final_targets or (handle and feed_dict_tensor):
# -> 1190   results = self._do_run(handle, final_targets, final_fetches,
#    1191                          feed_dict_tensor, options, run_metadata)
#    1192 else:
#    1193   results = []
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/tensorflow/python/client/session.py:1368, in BaseSession._do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1365   return self._call_tf_sessionprun(handle, feed_dict, fetch_list)
#    1367 if handle is None:
# -> 1368   return self._do_call(_run_fn, feeds, fetches, targets, options,
#    1369                        run_metadata)
#    1370 else:
#    1371   return self._do_call(_prun_fn, handle, feeds, fetches)
#
# File ~/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/tensorflow/python/client/session.py:1394, in BaseSession._do_call(self, fn, *args)
#    1389 if 'only supports NHWC tensor format' in message:
#    1390   message += ('\nA possible workaround: Try disabling Grappler optimizer'
#    1391               '\nby modifying the config for creating the session eg.'
#    1392               '\nsession_config.graph_options.rewrite_options.'
#    1393               'disable_meta_optimizer = True')
# -> 1394 raise type(e)(node_def, op, message)
#
# UnknownError: 2 root error(s) found.
#   (0) Unknown: Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, so try looking to see if a warning log message was printed above.
# 	 [[node layer1/conv0_0/Conv2D (defined at home/juju/contact_graspnet/pointnet2/utils/tf_util.py:184) ]]
# 	 [[layer4/Squeeze/_489]]
#   (1) Unknown: Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, so try looking to see if a warning log message was printed above.
# 	 [[node layer1/conv0_0/Conv2D (defined at home/juju/contact_graspnet/pointnet2/utils/tf_util.py:184) ]]
# 0 successful operations.
# 0 derived errors ignored.
#
# Errors may have originated from an input operation.
# Input Source operations connected to node layer1/conv0_0/Conv2D:
#  layer1/sub (defined at home/juju/contact_graspnet/pointnet2/utils/pointnet_util.py:194)
#
# Input Source operations connected to node layer1/conv0_0/Conv2D:
#  layer1/sub (defined at home/juju/contact_graspnet/pointnet2/utils/pointnet_util.py:194)
#
# Original stack trace for 'layer1/conv0_0/Conv2D':
#   File "home/juju/anaconda3/envs/contact_graspnet/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "home/juju/anaconda3/envs/contact_graspnet/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "home/juju/anaconda3/envs/mmpose/lib/python3.8/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "home/juju/anaconda3/envs/mmpose/lib/python3.8/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "home/juju/anaconda3/envs/mmpose/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 711, in start
#     self.io_loop.start()
#   File "home/juju/anaconda3/envs/mmpose/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "home/juju/anaconda3/envs/contact_graspnet/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "home/juju/anaconda3/envs/contact_graspnet/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "home/juju/anaconda3/envs/contact_graspnet/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "home/juju/anaconda3/envs/mmpose/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "home/juju/anaconda3/envs/mmpose/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "home/juju/anaconda3/envs/mmpose/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "home/juju/anaconda3/envs/mmpose/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "home/juju/anaconda3/envs/mmpose/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 411, in do_execute
#     res = shell.run_cell(
#   File "home/juju/anaconda3/envs/mmpose/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 531, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "home/juju/anaconda3/envs/mmpose/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2961, in run_cell
#     result = self._run_cell(
#   File "home/juju/anaconda3/envs/mmpose/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3016, in _run_cell
#     result = runner(coro)
#   File "home/juju/anaconda3/envs/mmpose/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "home/juju/anaconda3/envs/mmpose/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3221, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "home/juju/anaconda3/envs/mmpose/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3400, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "home/juju/anaconda3/envs/mmpose/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3460, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "tmp/ipykernel_83316/3759466814.py", line 12, in <module>
#     mcts = MCTS_rearrangement(
#   File "home/juju/anaconda3/envs/contact_graspnet/lib/python3.8/pytamp/search/mcts_for_rearragement.py", line 176, in __init__
#     self.grasp_generator = Grasp_Using_Contact_GraspNet(
#   File "home/juju/anaconda3/envs/contact_graspnet/lib/python3.8/pytamp/utils/contact_graspnet_utils.py", line 47, in __init__
#     self.grasp_estimator.build_network(robot_name)
#   File "home/juju/contact_graspnet/contact_graspnet/contact_grasp_estimator.py", line 88, in build_network
#     end_points = self._model_func.get_model(
#   File "home/juju/contact_graspnet/contact_graspnet/contact_graspnet.py", line 137, in get_model
#     l1_xyz, l1_points = pointnet_sa_module_msg(
#   File "home/juju/contact_graspnet/pointnet2/utils/pointnet_util.py", line 203, in pointnet_sa_module_msg
#     grouped_points = tf_util.conv2d(grouped_points, num_out_channel, [1,1],
#   File "home/juju/contact_graspnet/pointnet2/utils/tf_util.py", line 184, in conv2d
#     outputs = tf.nn.conv2d(inputs, kernel,
#   File "home/juju/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py", line 206, in wrapper
#     return target(*args, **kwargs)
#   File "home/juju/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/tensorflow/python/ops/nn_ops.py", line 2269, in conv2d
#     return gen_nn_ops.conv2d(
#   File "home/juju/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/tensorflow/python/ops/gen_nn_ops.py", line 969, in conv2d
#     _, _, _op, _outputs = _op_def_library._apply_op_helper(
#   File "home/juju/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/tensorflow/python/framework/op_def_library.py", line 748, in _apply_op_helper
#     op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#   File "home/juju/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/tensorflow/python/framework/ops.py", line 3557, in _create_op_internal
#     ret = Operation(
#   File "home/juju/anaconda3/envs/contact_graspnet/lib/python3.8/site-packages/tensorflow/python/framework/ops.py", line 2045, in __init__
#     self._traceback = tf_stack.extract_stack_for_node(self._c_op)

# %%
mcts.history_level_2_dict

# %%
max_level_1_value = mcts.get_max_value_level_1()
max_level_1_value = mcts.history_level_1_dict[1]

print(max_level_1_value, mcts.history_level_1_dict)

########## level 1 ##########
if mcts.history_level_1_dict:
    j, max_value_nodes = mcts.get_max_value_nodes_level_1()
    
    print()
    print(f"Result {j} : ", max_value_nodes)
    print("state num :", len(max_value_nodes))
#     mcts.render_rearr("_", max_value_nodes)

# %%
minimum_cost_nodes = mcts.get_minimum_cost_node()

# %%
final_level_1_values = []
final_level_2_values = []
final_optimal_nodes = []
final_pnp_all_joint_paths = []
final_pick_all_objects = []
final_place_all_object_poses = []
if mcts.level_wise_2_success:
    (
        pnp_all_joint_paths,
        pick_all_objects,
        place_all_object_poses,
    ) = mcts.get_all_joint_path(minimum_cost_nodes)
    final_pnp_all_joint_paths.append(pnp_all_joint_paths)
    final_pick_all_objects.append(pick_all_objects)
    final_place_all_object_poses.append(place_all_object_poses)
    final_optimal_nodes.append(mcts.optimal_nodes)
else:
    final_pnp_all_joint_paths.append([])
    final_pick_all_objects.append([])
    final_place_all_object_poses.append([])
    final_optimal_nodes.append([])

# %%
minimum_cost_nodes

# %%
from pykin.utils.kin_utils import apply_robot_to_scene

mcts.rearr_action.scene_mngr.render.render_objects(mcts.tree.nodes[0]['state'].objs)
# pick.scene_mngr.render.trimesh_scene = apply_robot_to_scene(
#         trimesh_scene=pick.scene_mngr.render.trimesh_scene, 
#         robot=pick.scene_mngr.scene.robot,
#         geom="visual"
#             )
# pick.scene_mngr.render.set_camera_view()

mcts.rearr_action.simulate_path(
    final_pnp_all_joint_paths[0],
    final_pick_all_objects[0],
    final_place_all_object_poses[0],
    is_save=True,
#     video_name="pick_rearrangement1_only_current_scene",
    video_name="benchmark3_grasp_using_contact_graspnet_consider_next_scene_block_5",
)

# %%
mcts.history_level_2_dict
# Out:
# {0: {'nodes': [0, 1, 32, 33, 38, 42, 45, 47, 48], 'value': 6.18},
#  1: {'nodes': [0, 4, 77, 78, 319, 321, 324, 325, 329, 331, 332],
#   'value': 6.18}}

# %%
nodes
# Out:
# [0, 1, 32, 33, 39, 44, 47, 50, 52, 54, 55]

# %%
max_level_1_value = mcts.get_max_value_level_1()


fig, ax = p_utils.init_3d_figure(name="Level wise 1")

# nodes = mcts.infeasible_sub_nodes[0]
# nodes = mcts.history_level_1_dict[4]['nodes']
# j, nodes = mcts.get_max_value_nodes_level_1()

nodes = mcts.history_level_1_dict[4]['nodes']

print("nodes", nodes)
i = 0
for i in range(len(nodes)//2):
    mcts.rearr_action.deepcopy_scene(mcts.tree.nodes[nodes[2*(i)+1]]['state'])
    
    grasp = mcts.tree.nodes[nodes[2*(i)+1]].get('grasp_poses')
    if grasp:
        grasp = grasp[0]['grasp']
    else:
        print("Here doesn't have grasp")
        
        mcts.rearr_action.scene_mngr.render_objects(ax)
        p_utils.plot_basis(ax)
        mcts.rearr_action.show()
        break
    mcts.rearr_action.scene_mngr.set_gripper_pose(grasp)
    
    gripper_kinematics_info = mcts.rearr_action.scene_mngr.scene.robot.gripper.get_gripper_fk()

    gripper_tip_poses = mcts.scene_mngr.scene.robot.gripper.compute_gripper_tip_pose_from_gripper_pose()


    mcts.rearr_action.scene_mngr.render_axis(ax, gripper_kinematics_info['leftfinger'])
    mcts.rearr_action.scene_mngr.render_axis(ax, gripper_kinematics_info['rightfinger'])
    mcts.rearr_action.scene_mngr.render_axis(ax, mcts.scene_mngr.scene.robot.gripper.compute_gripper_tip_pose_from_gripper_pose(gripper_kinematics_info['rightfinger']))
    mcts.rearr_action.scene_mngr.render_axis(ax, mcts.scene_mngr.scene.robot.gripper.compute_gripper_tip_pose_from_gripper_pose(gripper_kinematics_info['leftfinger']))

    mcts.rearr_action.scene_mngr.render_axis(ax, mcts.rearr_action.scene_mngr.scene.robot.gripper.get_gripper_tcp_pose())
    mcts.rearr_action.scene_mngr.render_gripper(ax)

    mcts.rearr_action.scene_mngr.render_objects(ax)
    p_utils.plot_basis(ax)
    mcts.rearr_action.show()
# Out:
# nodes [0, 1, 32, 33, 39, 44, 47, 50, 52, 54, 55]
# Here doesn't have grasp

# %%
nodes = mcts.history_level_1_dict[4]['nodes']

# %%
# from pytamp.utils.point_cloud_utils import get_combined_pc_from_mixed_scene
i = 0

current_node = mcts.tree.nodes[nodes[2*i + 1]]
next_node = mcts.tree.nodes[nodes[2*i + 2]]
obj_to_manipulate =current_node['action']['rearr_obj_name']

print(obj_to_manipulate)

grasps = mcts.grasp_generator.get_grasp(
    init_scene = benchmark3.init_scene,
    next_node = next_node,
    current_node = current_node,
    )

#next scene의 유무를 통해 combine하냐 마냐 나눠주는 함수 
# mcts.rearr_action.get_mixed_scene_on_next(
#                  next_scene=mcts.tree.nodes[max_value_nodes[2*(i+1)]]['state'],\
#                  current_scene=mcts.tree.nodes[max_value_nodes[2*i+1]]['state'],\
#                  obj_to_manipulate=obj_to_manipulate
#                  )

# mcts.rearr_action.get_mixed_scene_on_current(
#                  next_scene=mcts.tree.nodes[max_value_nodes[2*(i+1)]]['state'],\
#                  current_scene=mcts.tree.nodes[max_value_nodes[2*i+1]]['state'],\
#                  obj_to_manipulate=obj_to_manipulate
#                  )


# mcts.rearr_action.get_combined_pc_from_mixed_scene(
#                                                      next_scene=mcts.tree.nodes[max_value_nodes[2*(i+1)]]['state'],\
#                                                      current_scene=mcts.tree.nodes[max_value_nodes[2*i]]['state'],\
#                                                      obj_to_manipulate=obj_to_manipulate
#                                                      )
# Out:
# milk3
# Extracted Region Cube Size:  0.4140609034817153
# Random sample points
# Generated 9 grasps for object milk3

# %%
fig, ax = p_utils.init_3d_figure(name="Level wise 1")
mcts.rearr_action.deepcopy_scene(mcts.tree.nodes[nodes[2*(i) +1]]['state'])

for grasp in grasps :
    mcts.rearr_action.scene_mngr.set_gripper_pose(grasp)
    mcts.rearr_action.scene_mngr.render_axis(ax, grasp)
# #     mcts.rearr_action.scene_mngr.render_axis(ax, mcts.rearr_action.scene_mngr.scene.robot.gripper.get_gripper_tcp_pose())
    
mcts.rearr_action.scene_mngr.render_objects(ax)
p_utils.plot_basis(ax)
mcts.rearr_action.show()

# %%
obj_file_path = '/home/juju/contact_graspnet/acronym/meshes/5Shelves/4382a7a2860ff8dda67210eeab485ee6.obj'
